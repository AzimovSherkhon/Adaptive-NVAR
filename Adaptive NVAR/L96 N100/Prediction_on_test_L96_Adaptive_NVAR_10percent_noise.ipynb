# %% [markdown]
# # Adaptive Nonlinear Vector Autoregression: Robust Forecasting for Noisy Chaotic Time Series
# ## Author
# - **Name**: Azimov Sherkhon Azizkhon Ugli
# - **Email**: sherxonazimov94@pusan.ac.kr
# - **GitHub**: @AzimovSherkhon
#
# Method: **Adaptive Nonlinear Vector Autoregression**
#
# Code: Prediction on unseen test data
#
# Best Config Found: \
# k=10, hidden_dim=1000, Adam LR=1e-05

# %%
# ============================================================
# Imports & Setup
# ============================================================
import torch
import warnings
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset

# Torch defaults
torch.set_default_dtype(torch.float32)

# ----------------------------
# Device setup (choose GPU 0)
# ----------------------------
if torch.cuda.is_available():
    torch.cuda.set_device(0)   # pick GPU 0
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")

print(f"Device in use: {device}")
if device.type == "cuda":
    print(f"CUDA device: {torch.cuda.current_device()} - {torch.cuda.get_device_name(device)}")

# Suppress unnecessary warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Device in use: cuda:0
# CUDA device: 0 - A100-PCIE-40GB

# %%
# ============================================================
# Load Lorenz 96 Clean Data
# ============================================================
data = np.load("lorenz96_100_noise_0.npy", allow_pickle=True).item()
l96_data = data["data"]   # (100, 1000001)
meta = data["meta"]   # dict with warmup/train/val/test/mean/std
l96 = l96_data.T
print(l96.shape)

# ============================================================
# Visualization: First 10 Variables of Lorenz '96
# ============================================================
plt.figure(figsize=(16, 12))
num_vars_to_plot = 10
time = np.arange(l96.shape[0])

for i in range(num_vars_to_plot):
    plt.subplot(num_vars_to_plot, 1, i + 1)
    plt.plot(time, l96[:, i], label=f'Variable {i+1}', color=f'C{i % 10}')
    plt.ylabel(f'x{i+1}')
    plt.grid(True)
    if i == 0:
        plt.title("Lorenz '96: First 10 variables (Clean data)")
    if i == num_vars_to_plot - 1:
        plt.xlabel('Time')
    plt.legend()
    plt.xlim(0, 2000)  

plt.tight_layout()
plt.show()
# Out:
# (500000, 100)

# %%
# ============================================================
# Reproducibility
# ============================================================
seed = 2025
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


# ============================================================
# # Load Lorenz 63 Noisy Data
# ============================================================
# Measurement noise (applied globally to dataset)
dataset_noise_scale = 0.10
data_noisy = np.load("lorenz96_100_noise_10.npy", allow_pickle=True).item()
X_noisy_dataset = data_noisy["data"]   # (3, 5001)
meta_noise = data_noisy["meta"]   # dict with warmup/train/val/test/mean/std
X_noisy_dataset = X_noisy_dataset.T

# ============================================================
# Visualization: First 10 Variables of Lorenz '96
# ============================================================
plt.figure(figsize=(16, 12))
num_vars_to_plot = 10
time = np.arange(l96.shape[0])

for i in range(num_vars_to_plot):
    plt.subplot(num_vars_to_plot, 1, i + 1)
    plt.plot(time, X_noisy_dataset[:, i], label=f'Variable {i+1}', color=f'C{i % 10}')
    plt.ylabel(f'x{i+1}')
    plt.grid(True)
    if i == 0:
        plt.title("Lorenz '96: First 10 variables (Noisy data)")
    if i == num_vars_to_plot - 1:
        plt.xlabel('Time')
    plt.legend()
    plt.xlim(0, 2000)  

plt.tight_layout()
plt.show()

X = torch.tensor(X_noisy_dataset, dtype=torch.float32)  # noisy input
X_true = torch.tensor(l96, dtype=torch.float32)          # clean reference

# Dataset splits
warmup_len, train_len, val_len, test_len = 1000, 399000, 50000, 50000

X_warmup = X[:warmup_len].to(device)
X_train_clean = X[warmup_len:warmup_len + train_len]
X_val  = X[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test = X[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)

# Ground truth references
X_val_true  = X_true[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test_true = X_true[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)

# Training-time noise (works as a regularization only during training)
train_noise_scale = 0.0  # We only add it for noise free-case
signal_std = X_train_clean.std(dim=0, keepdim=True).cpu().numpy()
train_noise = np.random.normal(0.0, train_noise_scale * signal_std, X_train_clean.shape)
X_train = torch.tensor((X_train_clean.cpu().numpy() + train_noise).astype(np.float32), device=device)

# %%
# ============================================================
# Adaptive NVAR Model
# ============================================================
class FeatureMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)


class AdaptiveNVARModel(nn.Module):
    def __init__(self, dk, m, d, hidden_dim):
        super().__init__()
        self.mlp = FeatureMLP(dk, hidden_dim, m)
        self.readout = nn.Linear(dk + m, d, bias=False)

    def forward(self, H_lin):
        H_nn = self.mlp(H_lin)
        H_total = torch.cat([H_lin, H_nn], dim=1)
        return self.readout(H_total)


# ============================================================
# Helper Functions
# ============================================================
def construct_H_lin(X, k):
    """Constructs delay-embedded features from time series."""
    T = X.shape[0]
    return torch.cat([X[i:T - k + i] for i in range(k)], dim=1)


def init_weights_stable(m):
    """Stable Xavier initialization for linear layers."""
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)
        with torch.no_grad():
            m.weight.mul_(1.0)


# ============================================================
# Training Function (Adam only)
# ============================================================
def train_model_adam_only(
    X, k, m, hidden_dim=200, num_epochs_adam=1000, batch_size=1024,
    save_path="best_joint_model_0percent_noise.pth",
    patience=100, tolerance=1e-8, lr=1e-5, use_amp=False
):
    X = X.to(device)
    H_lin = construct_H_lin(X, k)                 # [n, dk]
    Y = X[k:] - X[k - 1:-1]                       # [n, d]
    n, dk = H_lin.shape
    d = Y.shape[1]

    # Dataset + Dataloader
    dataset = TensorDataset(H_lin, Y)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    # Model: pass hidden_dim
    model = AdaptiveNVARModel(dk=dk, m=m, d=d, hidden_dim=hidden_dim).to(device)
#    # Freeze MLP parameters if needed
#    for param in model.mlp.parameters():
#        param.requires_grad = False

    # Optimizer
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        betas=(0.9, 0.999),
        eps=1e-8,
        weight_decay=0
    )

    # Scheduler (reduces lr when loss plateaus)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, factor=0.5, patience=100
    )

    # AMP scaler
    scaler = torch.cuda.amp.GradScaler(enabled=use_amp)

    adam_losses = []
    best_loss = float('inf')
    epochs_no_improve = 0
    best_model_state = None

    for epoch in range(num_epochs_adam):
        model.train()
        epoch_loss = 0.0

        for H_batch, Y_batch in dataloader:
            H_batch = H_batch.to(device)
            Y_batch = Y_batch.to(device)

            optimizer.zero_grad()

            # Mixed precision forward & backward
            with torch.cuda.amp.autocast(enabled=use_amp):
                Y_hat = model(H_batch)
                loss = F.mse_loss(Y_hat, Y_batch)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            epoch_loss += loss.item() * H_batch.size(0)

        current_loss = epoch_loss / n
        adam_losses.append(current_loss)

        # Step scheduler
        scheduler.step(current_loss)

        if epoch % 10 == 0 or epoch == num_epochs_adam - 1:
            current_lr = optimizer.param_groups[0]['lr']
            print(f"[Adam] Epoch {epoch:5d} | Loss: {current_loss:.4e} | LR: {current_lr:.2e}")

        # Early stopping
        if best_loss - current_loss > tolerance:
            best_loss = current_loss
            best_model_state = model.state_dict()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f"Early stopping triggered at epoch {epoch}")
            break

    # Save best model
    if best_model_state is not None:
        torch.save(best_model_state, save_path)
        print(f"Best model saved with loss {best_loss:.4e} at epoch {epoch - epochs_no_improve}")
    else:
        torch.save(model.state_dict(), save_path)
        print("Model saved (no improvement detected).")

    return model

# %%
# ============================================================ 
# Prediction on Test Data (Adam only)
# ============================================================
k_grid = [10]
hidden_dim_grid = [1000]
adam_lr_grid = [1e-5]
batch_size_grid = [1024]

horizons = [25, 50, 75, 100]

base_seed, num_runs, num_windows = 2025, 5, int(test_len / 100)
d = 100
best_config, best_rmse, all_results = None, float("inf"), []

print("Starting Test Evaluation (Adam only)...\n")

for k in k_grid:
    dk = d * k  
    m = int(10 * dk)   

    for hidden_dim in hidden_dim_grid:
        for lr_adam in adam_lr_grid:
            for batch_size in batch_size_grid:

                all_run_rmses = {h: [] for h in horizons}

                for run in range(num_runs):
                    seed = base_seed + run
                    torch.manual_seed(seed)
                    torch.cuda.manual_seed_all(seed)
                    torch.backends.cudnn.deterministic = True
                    torch.backends.cudnn.benchmark = False

                    model_path = f"model_k{k}_m{m}_hd{hidden_dim}_adam{lr_adam}_bs{batch_size}.pth"

                    # Load or train model
                    model = train_model_adam_only(
                        X_train, k=k, m=m, hidden_dim=hidden_dim,
                        num_epochs_adam=20000,
                        batch_size=batch_size,
                        lr=lr_adam,
                        save_path=model_path
                    )
                    model.eval()

                    window_size = len(X_test_true) // num_windows
                    horizon_rmses = {h: [] for h in horizons}

                    for w in range(num_windows):
                        start, end = w * window_size, (w + 1) * window_size
                        X_test_true_window = X_test_true[start:end]

                        # Initialization: last k points before this test window
                        init_start = warmup_len + train_len + val_len + start - k
                        init_end   = warmup_len + train_len + val_len + start
                        X_init = X[init_start:init_end].to(device)

                        x_t = [x.clone() for x in X_init.unbind(0)]
                        H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

                        predictions = []
                        for _ in range(window_size):
                            with torch.no_grad():
                                delta_x = model(H_lin)
                            x_next = x_t[-1] + delta_x.squeeze(0)
                            predictions.append(x_next)
                            x_t = x_t[1:] + [x_next]
                            H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

                        predictions_np = torch.stack(predictions).cpu().numpy()
                        y_true_np = X_test_true_window.cpu().numpy()

                        for h in horizons:
                            if h <= window_size:
                                rmse = np.sqrt(np.mean((y_true_np[:h] - predictions_np[:h]) ** 2))
                                horizon_rmses[h].append(rmse)

                    # Average RMSEs for this run
                    for h in horizons:
                        avg_rmse = np.mean(horizon_rmses[h])
                        all_run_rmses[h].append(avg_rmse)

                # Average over runs
                avg_rmse_horizons = {h: np.mean(all_run_rmses[h]) for h in horizons}
                std_rmse_horizons = {h: np.std(all_run_rmses[h]) for h in horizons}

                print(f"[Test Evaluation] k={k}, hd={hidden_dim}, Adam LR={lr_adam}, BS={batch_size} → " +
                      ", ".join([f"h={h}: {avg_rmse_horizons[h]:.6f} ± {std_rmse_horizons[h]:.6f}"
                                 for h in horizons]))

                all_results.append((k, m, hidden_dim, lr_adam, batch_size, avg_rmse_horizons))

                # Track best result (e.g., horizon=100)
                if avg_rmse_horizons[100] < best_rmse:
                    best_rmse = avg_rmse_horizons[100]
                    best_config = (k, m, hidden_dim, lr_adam, batch_size)

# ============================================================
# Final Best Results
# ============================================================
print("\n=== Final Results Summary ===")
print(f"Optimal config used: k={best_config[0]}, m={best_config[1]}, hd={best_config[2]}, "
      f"lr={best_config[3]}, bs={best_config[4]}")
# Out:
# Starting Test Evaluation (Adam only)...
#
# [Adam] Epoch     0 | Loss: 2.7087e-02 | LR: 1.00e-05
# [Adam] Epoch    10 | Loss: 1.8655e-02 | LR: 1.00e-05
# [Adam] Epoch    20 | Loss: 1.6480e-02 | LR: 1.00e-05
# [Adam] Epoch    30 | Loss: 1.5786e-02 | LR: 1.00e-05
# [Adam] Epoch    40 | Loss: 1.5567e-02 | LR: 1.00e-05
# [Adam] Epoch    50 | Loss: 1.5482e-02 | LR: 1.00e-05
# [Adam] Epoch    60 | Loss: 1.5442e-02 | LR: 1.00e-05
# [Adam] Epoch    70 | Loss: 1.5420e-02 | LR: 1.00e-05
# [Adam] Epoch    80 | Loss: 1.5407e-02 | LR: 1.00e-05
# [Adam] Epoch    90 | Loss: 1.5398e-02 | LR: 1.00e-05
# [Adam] Epoch   100 | Loss: 1.5392e-02 | LR: 1.00e-05
# [Adam] Epoch   110 | Loss: 1.5386e-02 | LR: 1.00e-05
# [Adam] Epoch   120 | Loss: 1.5382e-02 | LR: 1.00e-05
# [Adam] Epoch   130 | Loss: 1.5378e-02 | LR: 1.00e-05
# [Adam] Epoch   140 | Loss: 1.5374e-02 | LR: 1.00e-05
# [Adam] Epoch   150 | Loss: 1.5371e-02 | LR: 1.00e-05
# [Adam] Epoch   160 | Loss: 1.5368e-02 | LR: 1.00e-05
# [Adam] Epoch   170 | Loss: 1.5365e-02 | LR: 1.00e-05
# [Adam] Epoch   180 | Loss: 1.5361e-02 | LR: 1.00e-05
# [Adam] Epoch   190 | Loss: 1.5357e-02 | LR: 1.00e-05
# [Adam] Epoch   200 | Loss: 1.5354e-02 | LR: 1.00e-05
# [Adam] Epoch   210 | Loss: 1.5350e-02 | LR: 1.00e-05
# [Adam] Epoch   220 | Loss: 1.5346e-02 | LR: 1.00e-05
# [Adam] Epoch   230 | Loss: 1.5341e-02 | LR: 1.00e-05
# [Adam] Epoch   240 | Loss: 1.5337e-02 | LR: 1.00e-05
# [Adam] Epoch   250 | Loss: 1.5332e-02 | LR: 1.00e-05
# [Adam] Epoch   260 | Loss: 1.5327e-02 | LR: 1.00e-05
# [Adam] Epoch   270 | Loss: 1.5320e-02 | LR: 1.00e-05
# [Adam] Epoch   280 | Loss: 1.5313e-02 | LR: 1.00e-05
# [Adam] Epoch   290 | Loss: 1.5304e-02 | LR: 1.00e-05
# [Adam] Epoch   300 | Loss: 1.5293e-02 | LR: 1.00e-05
# [Adam] Epoch   310 | Loss: 1.5280e-02 | LR: 1.00e-05
# [Adam] Epoch   320 | Loss: 1.5266e-02 | LR: 1.00e-05
# [Adam] Epoch   330 | Loss: 1.5250e-02 | LR: 1.00e-05
# [Adam] Epoch   340 | Loss: 1.5233e-02 | LR: 1.00e-05
# [Adam] Epoch   350 | Loss: 1.5212e-02 | LR: 1.00e-05
# [Adam] Epoch   360 | Loss: 1.5189e-02 | LR: 1.00e-05
# [Adam] Epoch   370 | Loss: 1.5164e-02 | LR: 1.00e-05
# [Adam] Epoch   380 | Loss: 1.5138e-02 | LR: 1.00e-05
# [Adam] Epoch   390 | Loss: 1.5114e-02 | LR: 1.00e-05
# [Adam] Epoch   400 | Loss: 1.5092e-02 | LR: 1.00e-05
# [Adam] Epoch   410 | Loss: 1.5070e-02 | LR: 1.00e-05
# [Adam] Epoch   420 | Loss: 1.5047e-02 | LR: 1.00e-05
# [Adam] Epoch   430 | Loss: 1.5022e-02 | LR: 1.00e-05
# [Adam] Epoch   440 | Loss: 1.4994e-02 | LR: 1.00e-05
# [Adam] Epoch   450 | Loss: 1.4963e-02 | LR: 1.00e-05
# [Adam] Epoch   460 | Loss: 1.4931e-02 | LR: 1.00e-05
# [Adam] Epoch   470 | Loss: 1.4899e-02 | LR: 1.00e-05
# [Adam] Epoch   480 | Loss: 1.4867e-02 | LR: 1.00e-05
# [Adam] Epoch   490 | Loss: 1.4835e-02 | LR: 1.00e-05
# [Adam] Epoch   500 | Loss: 1.4802e-02 | LR: 1.00e-05
# [Adam] Epoch   510 | Loss: 1.4767e-02 | LR: 1.00e-05
# [Adam] Epoch   520 | Loss: 1.4730e-02 | LR: 1.00e-05
# [Adam] Epoch   530 | Loss: 1.4693e-02 | LR: 1.00e-05
# [Adam] Epoch   540 | Loss: 1.4654e-02 | LR: 1.00e-05
# [Adam] Epoch   550 | Loss: 1.4614e-02 | LR: 1.00e-05
# [Adam] Epoch   560 | Loss: 1.4575e-02 | LR: 1.00e-05
# [Adam] Epoch   570 | Loss: 1.4536e-02 | LR: 1.00e-05
# [Adam] Epoch   580 | Loss: 1.4498e-02 | LR: 1.00e-05
# [Adam] Epoch   590 | Loss: 1.4459e-02 | LR: 1.00e-05
# [Adam] Epoch   600 | Loss: 1.4422e-02 | LR: 1.00e-05
# [Adam] Epoch   610 | Loss: 1.4387e-02 | LR: 1.00e-05
# [Adam] Epoch   620 | Loss: 1.4352e-02 | LR: 1.00e-05
# [Adam] Epoch   630 | Loss: 1.4316e-02 | LR: 1.00e-05
# [Adam] Epoch   640 | Loss: 1.4278e-02 | LR: 1.00e-05
# [Adam] Epoch   650 | Loss: 1.4240e-02 | LR: 1.00e-05
# [Adam] Epoch   660 | Loss: 1.4201e-02 | LR: 1.00e-05
# [Adam] Epoch   670 | Loss: 1.4162e-02 | LR: 1.00e-05
# [Adam] Epoch   680 | Loss: 1.4123e-02 | LR: 1.00e-05
# [Adam] Epoch   690 | Loss: 1.4085e-02 | LR: 1.00e-05
# [Adam] Epoch   700 | Loss: 1.4046e-02 | LR: 1.00e-05
# [Adam] Epoch   710 | Loss: 1.4006e-02 | LR: 1.00e-05
# [Adam] Epoch   720 | Loss: 1.3967e-02 | LR: 1.00e-05
# [Adam] Epoch   730 | Loss: 1.3929e-02 | LR: 1.00e-05
# [Adam] Epoch   740 | Loss: 1.3892e-02 | LR: 1.00e-05
# [Adam] Epoch   750 | Loss: 1.3857e-02 | LR: 1.00e-05
# [Adam] Epoch   760 | Loss: 1.3824e-02 | LR: 1.00e-05
# [Adam] Epoch   770 | Loss: 1.3793e-02 | LR: 1.00e-05
# [Adam] Epoch   780 | Loss: 1.3764e-02 | LR: 1.00e-05
# [Adam] Epoch   790 | Loss: 1.3736e-02 | LR: 1.00e-05
# [Adam] Epoch   800 | Loss: 1.3709e-02 | LR: 1.00e-05
# [Adam] Epoch   810 | Loss: 1.3683e-02 | LR: 1.00e-05
# [Adam] Epoch   820 | Loss: 1.3658e-02 | LR: 1.00e-05
# [Adam] Epoch   830 | Loss: 1.3634e-02 | LR: 1.00e-05
# [Adam] Epoch   840 | Loss: 1.3610e-02 | LR: 1.00e-05
# [Adam] Epoch   850 | Loss: 1.3586e-02 | LR: 1.00e-05
# [Adam] Epoch   860 | Loss: 1.3563e-02 | LR: 1.00e-05
# [Adam] Epoch   870 | Loss: 1.3540e-02 | LR: 1.00e-05
# [Adam] Epoch   880 | Loss: 1.3518e-02 | LR: 1.00e-05
# [Adam] Epoch   890 | Loss: 1.3496e-02 | LR: 1.00e-05
# [Adam] Epoch   900 | Loss: 1.3474e-02 | LR: 1.00e-05
# [Adam] Epoch   910 | Loss: 1.3451e-02 | LR: 1.00e-05
# [Adam] Epoch   920 | Loss: 1.3429e-02 | LR: 1.00e-05
# [Adam] Epoch   930 | Loss: 1.3407e-02 | LR: 1.00e-05
# [Adam] Epoch   940 | Loss: 1.3384e-02 | LR: 1.00e-05
# [Adam] Epoch   950 | Loss: 1.3362e-02 | LR: 1.00e-05
# [Adam] Epoch   960 | Loss: 1.3340e-02 | LR: 1.00e-05
# [Adam] Epoch   970 | Loss: 1.3318e-02 | LR: 1.00e-05
# [Adam] Epoch   980 | Loss: 1.3296e-02 | LR: 1.00e-05
# [Adam] Epoch   990 | Loss: 1.3274e-02 | LR: 1.00e-05
# [Adam] Epoch  1000 | Loss: 1.3253e-02 | LR: 1.00e-05
# [Adam] Epoch  1010 | Loss: 1.3231e-02 | LR: 1.00e-05
# [Adam] Epoch  1020 | Loss: 1.3210e-02 | LR: 1.00e-05
# [Adam] Epoch  1030 | Loss: 1.3188e-02 | LR: 1.00e-05
# [Adam] Epoch  1040 | Loss: 1.3166e-02 | LR: 1.00e-05
# [Adam] Epoch  1050 | Loss: 1.3145e-02 | LR: 1.00e-05
# [Adam] Epoch  1060 | Loss: 1.3123e-02 | LR: 1.00e-05
# [Adam] Epoch  1070 | Loss: 1.3102e-02 | LR: 1.00e-05
# [Adam] Epoch  1080 | Loss: 1.3080e-02 | LR: 1.00e-05
# [Adam] Epoch  1090 | Loss: 1.3059e-02 | LR: 1.00e-05
# [Adam] Epoch  1100 | Loss: 1.3038e-02 | LR: 1.00e-05
# [Adam] Epoch  1110 | Loss: 1.3017e-02 | LR: 1.00e-05
# [Adam] Epoch  1120 | Loss: 1.2996e-02 | LR: 1.00e-05
# [Adam] Epoch  1130 | Loss: 1.2976e-02 | LR: 1.00e-05
# [Adam] Epoch  1140 | Loss: 1.2955e-02 | LR: 1.00e-05
# [Adam] Epoch  1150 | Loss: 1.2935e-02 | LR: 1.00e-05
# [Adam] Epoch  1160 | Loss: 1.2914e-02 | LR: 1.00e-05
# [Adam] Epoch  1170 | Loss: 1.2894e-02 | LR: 1.00e-05
# [Adam] Epoch  1180 | Loss: 1.2873e-02 | LR: 1.00e-05
# [Adam] Epoch  1190 | Loss: 1.2853e-02 | LR: 1.00e-05
# [Adam] Epoch  1200 | Loss: 1.2833e-02 | LR: 1.00e-05
# [Adam] Epoch  1210 | Loss: 1.2813e-02 | LR: 1.00e-05
# [Adam] Epoch  1220 | Loss: 1.2793e-02 | LR: 1.00e-05
# [Adam] Epoch  1230 | Loss: 1.2773e-02 | LR: 1.00e-05
# [Adam] Epoch  1240 | Loss: 1.2753e-02 | LR: 1.00e-05
# [Adam] Epoch  1250 | Loss: 1.2734e-02 | LR: 1.00e-05
# [Adam] Epoch  1260 | Loss: 1.2714e-02 | LR: 1.00e-05
# [Adam] Epoch  1270 | Loss: 1.2694e-02 | LR: 1.00e-05
# [Adam] Epoch  1280 | Loss: 1.2674e-02 | LR: 1.00e-05
# [Adam] Epoch  1290 | Loss: 1.2654e-02 | LR: 1.00e-05
# [Adam] Epoch  1300 | Loss: 1.2634e-02 | LR: 1.00e-05
# [Adam] Epoch  1310 | Loss: 1.2615e-02 | LR: 1.00e-05
# [Adam] Epoch  1320 | Loss: 1.2595e-02 | LR: 1.00e-05
# [Adam] Epoch  1330 | Loss: 1.2575e-02 | LR: 1.00e-05
# [Adam] Epoch  1340 | Loss: 1.2556e-02 | LR: 1.00e-05
# [Adam] Epoch  1350 | Loss: 1.2536e-02 | LR: 1.00e-05
# [Adam] Epoch  1360 | Loss: 1.2516e-02 | LR: 1.00e-05
# [Adam] Epoch  1370 | Loss: 1.2496e-02 | LR: 1.00e-05
# [Adam] Epoch  1380 | Loss: 1.2476e-02 | LR: 1.00e-05
# [Adam] Epoch  1390 | Loss: 1.2456e-02 | LR: 1.00e-05
# [Adam] Epoch  1400 | Loss: 1.2436e-02 | LR: 1.00e-05
# [Adam] Epoch  1410 | Loss: 1.2415e-02 | LR: 1.00e-05
# [Adam] Epoch  1420 | Loss: 1.2395e-02 | LR: 1.00e-05
# [Adam] Epoch  1430 | Loss: 1.2375e-02 | LR: 1.00e-05
# [Adam] Epoch  1440 | Loss: 1.2354e-02 | LR: 1.00e-05
# [Adam] Epoch  1450 | Loss: 1.2333e-02 | LR: 1.00e-05
# [Adam] Epoch  1460 | Loss: 1.2312e-02 | LR: 1.00e-05
# [Adam] Epoch  1470 | Loss: 1.2291e-02 | LR: 1.00e-05
# [Adam] Epoch  1480 | Loss: 1.2269e-02 | LR: 1.00e-05
# [Adam] Epoch  1490 | Loss: 1.2248e-02 | LR: 1.00e-05
# [Adam] Epoch  1500 | Loss: 1.2227e-02 | LR: 1.00e-05
# [Adam] Epoch  1510 | Loss: 1.2205e-02 | LR: 1.00e-05
# [Adam] Epoch  1520 | Loss: 1.2183e-02 | LR: 1.00e-05
# [Adam] Epoch  1530 | Loss: 1.2162e-02 | LR: 1.00e-05
# [Adam] Epoch  1540 | Loss: 1.2140e-02 | LR: 1.00e-05
# [Adam] Epoch  1550 | Loss: 1.2119e-02 | LR: 1.00e-05
# [Adam] Epoch  1560 | Loss: 1.2097e-02 | LR: 1.00e-05
# [Adam] Epoch  1570 | Loss: 1.2076e-02 | LR: 1.00e-05
# [Adam] Epoch  1580 | Loss: 1.2056e-02 | LR: 1.00e-05
# [Adam] Epoch  1590 | Loss: 1.2035e-02 | LR: 1.00e-05
# [Adam] Epoch  1600 | Loss: 1.2015e-02 | LR: 1.00e-05
# [Adam] Epoch  1610 | Loss: 1.1995e-02 | LR: 1.00e-05
# [Adam] Epoch  1620 | Loss: 1.1975e-02 | LR: 1.00e-05
# [Adam] Epoch  1630 | Loss: 1.1955e-02 | LR: 1.00e-05
# [Adam] Epoch  1640 | Loss: 1.1936e-02 | LR: 1.00e-05
# [Adam] Epoch  1650 | Loss: 1.1917e-02 | LR: 1.00e-05
# [Adam] Epoch  1660 | Loss: 1.1898e-02 | LR: 1.00e-05
# [Adam] Epoch  1670 | Loss: 1.1880e-02 | LR: 1.00e-05
# [Adam] Epoch  1680 | Loss: 1.1862e-02 | LR: 1.00e-05
# [Adam] Epoch  1690 | Loss: 1.1845e-02 | LR: 1.00e-05
# [Adam] Epoch  1700 | Loss: 1.1829e-02 | LR: 1.00e-05
# [Adam] Epoch  1710 | Loss: 1.1813e-02 | LR: 1.00e-05
# [Adam] Epoch  1720 | Loss: 1.1797e-02 | LR: 1.00e-05
# [Adam] Epoch  1730 | Loss: 1.1782e-02 | LR: 1.00e-05
# [Adam] Epoch  1740 | Loss: 1.1767e-02 | LR: 1.00e-05
# [Adam] Epoch  1750 | Loss: 1.1752e-02 | LR: 1.00e-05
# [Adam] Epoch  1760 | Loss: 1.1738e-02 | LR: 1.00e-05
# [Adam] Epoch  1770 | Loss: 1.1724e-02 | LR: 1.00e-05
# [Adam] Epoch  1780 | Loss: 1.1711e-02 | LR: 1.00e-05
# [Adam] Epoch  1790 | Loss: 1.1698e-02 | LR: 1.00e-05
# [Adam] Epoch  1800 | Loss: 1.1686e-02 | LR: 1.00e-05
# [Adam] Epoch  1810 | Loss: 1.1673e-02 | LR: 1.00e-05
# [Adam] Epoch  1820 | Loss: 1.1661e-02 | LR: 1.00e-05
# [Adam] Epoch  1830 | Loss: 1.1650e-02 | LR: 1.00e-05
# [Adam] Epoch  1840 | Loss: 1.1638e-02 | LR: 1.00e-05
# [Adam] Epoch  1850 | Loss: 1.1627e-02 | LR: 1.00e-05
# [Adam] Epoch  1860 | Loss: 1.1616e-02 | LR: 1.00e-05
# [Adam] Epoch  1870 | Loss: 1.1605e-02 | LR: 1.00e-05
# [Adam] Epoch  1880 | Loss: 1.1594e-02 | LR: 1.00e-05
# [Adam] Epoch  1890 | Loss: 1.1584e-02 | LR: 1.00e-05
# [Adam] Epoch  1900 | Loss: 1.1574e-02 | LR: 1.00e-05
# [Adam] Epoch  1910 | Loss: 1.1565e-02 | LR: 1.00e-05
# [Adam] Epoch  1920 | Loss: 1.1555e-02 | LR: 1.00e-05
# [Adam] Epoch  1930 | Loss: 1.1546e-02 | LR: 1.00e-05
# [Adam] Epoch  1940 | Loss: 1.1537e-02 | LR: 1.00e-05
# [Adam] Epoch  1950 | Loss: 1.1528e-02 | LR: 1.00e-05
# [Adam] Epoch  1960 | Loss: 1.1520e-02 | LR: 1.00e-05
# [Adam] Epoch  1970 | Loss: 1.1511e-02 | LR: 1.00e-05
# [Adam] Epoch  1980 | Loss: 1.1503e-02 | LR: 1.00e-05
# [Adam] Epoch  1990 | Loss: 1.1495e-02 | LR: 1.00e-05
# [Adam] Epoch  2000 | Loss: 1.1487e-02 | LR: 1.00e-05
# [Adam] Epoch  2010 | Loss: 1.1480e-02 | LR: 1.00e-05
# [Adam] Epoch  2020 | Loss: 1.1472e-02 | LR: 1.00e-05
# [Adam] Epoch  2030 | Loss: 1.1465e-02 | LR: 1.00e-05
# [Adam] Epoch  2040 | Loss: 1.1458e-02 | LR: 1.00e-05
# [Adam] Epoch  2050 | Loss: 1.1451e-02 | LR: 1.00e-05
# [Adam] Epoch  2060 | Loss: 1.1445e-02 | LR: 1.00e-05
# [Adam] Epoch  2070 | Loss: 1.1438e-02 | LR: 1.00e-05
# [Adam] Epoch  2080 | Loss: 1.1431e-02 | LR: 1.00e-05
# [Adam] Epoch  2090 | Loss: 1.1425e-02 | LR: 1.00e-05
# [Adam] Epoch  2100 | Loss: 1.1418e-02 | LR: 1.00e-05
# [Adam] Epoch  2110 | Loss: 1.1412e-02 | LR: 1.00e-05
# [Adam] Epoch  2120 | Loss: 1.1406e-02 | LR: 1.00e-05
# [Adam] Epoch  2130 | Loss: 1.1400e-02 | LR: 1.00e-05
# [Adam] Epoch  2140 | Loss: 1.1394e-02 | LR: 1.00e-05
# [Adam] Epoch  2150 | Loss: 1.1389e-02 | LR: 1.00e-05
# [Adam] Epoch  2160 | Loss: 1.1383e-02 | LR: 1.00e-05
# [Adam] Epoch  2170 | Loss: 1.1377e-02 | LR: 1.00e-05
# [Adam] Epoch  2180 | Loss: 1.1372e-02 | LR: 1.00e-05
# [Adam] Epoch  2190 | Loss: 1.1367e-02 | LR: 1.00e-05
# [Adam] Epoch  2200 | Loss: 1.1362e-02 | LR: 1.00e-05
# [Adam] Epoch  2210 | Loss: 1.1357e-02 | LR: 1.00e-05
# [Adam] Epoch  2220 | Loss: 1.1352e-02 | LR: 1.00e-05
# [Adam] Epoch  2230 | Loss: 1.1347e-02 | LR: 1.00e-05
# [Adam] Epoch  2240 | Loss: 1.1343e-02 | LR: 1.00e-05
# [Adam] Epoch  2250 | Loss: 1.1338e-02 | LR: 1.00e-05
# [Adam] Epoch  2260 | Loss: 1.1334e-02 | LR: 1.00e-05
# [Adam] Epoch  2270 | Loss: 1.1329e-02 | LR: 1.00e-05
# [Adam] Epoch  2280 | Loss: 1.1325e-02 | LR: 1.00e-05
# [Adam] Epoch  2290 | Loss: 1.1321e-02 | LR: 1.00e-05
# [Adam] Epoch  2300 | Loss: 1.1317e-02 | LR: 1.00e-05
# [Adam] Epoch  2310 | Loss: 1.1312e-02 | LR: 1.00e-05
# [Adam] Epoch  2320 | Loss: 1.1308e-02 | LR: 1.00e-05
# [Adam] Epoch  2330 | Loss: 1.1304e-02 | LR: 1.00e-05
# [Adam] Epoch  2340 | Loss: 1.1300e-02 | LR: 1.00e-05
# [Adam] Epoch  2350 | Loss: 1.1296e-02 | LR: 1.00e-05
# [Adam] Epoch  2360 | Loss: 1.1292e-02 | LR: 1.00e-05
# [Adam] Epoch  2370 | Loss: 1.1288e-02 | LR: 1.00e-05
# [Adam] Epoch  2380 | Loss: 1.1284e-02 | LR: 1.00e-05
# [Adam] Epoch  2390 | Loss: 1.1281e-02 | LR: 1.00e-05
# [Adam] Epoch  2400 | Loss: 1.1277e-02 | LR: 1.00e-05
# [Adam] Epoch  2410 | Loss: 1.1274e-02 | LR: 1.00e-05
# [Adam] Epoch  2420 | Loss: 1.1270e-02 | LR: 1.00e-05
# [Adam] Epoch  2430 | Loss: 1.1267e-02 | LR: 1.00e-05
# [Adam] Epoch  2440 | Loss: 1.1264e-02 | LR: 1.00e-05
# [Adam] Epoch  2450 | Loss: 1.1261e-02 | LR: 1.00e-05
# [Adam] Epoch  2460 | Loss: 1.1258e-02 | LR: 1.00e-05
# [Adam] Epoch  2470 | Loss: 1.1255e-02 | LR: 1.00e-05
# [Adam] Epoch  2480 | Loss: 1.1252e-02 | LR: 1.00e-05
# [Adam] Epoch  2490 | Loss: 1.1249e-02 | LR: 1.00e-05
# [Adam] Epoch  2500 | Loss: 1.1247e-02 | LR: 1.00e-05
# [Adam] Epoch  2510 | Loss: 1.1244e-02 | LR: 1.00e-05
# [Adam] Epoch  2520 | Loss: 1.1241e-02 | LR: 1.00e-05
# [Adam] Epoch  2530 | Loss: 1.1239e-02 | LR: 1.00e-05
# [Adam] Epoch  2540 | Loss: 1.1236e-02 | LR: 1.00e-05
# [Adam] Epoch  2550 | Loss: 1.1234e-02 | LR: 1.00e-05
# [Adam] Epoch  2560 | Loss: 1.1232e-02 | LR: 1.00e-05
# [Adam] Epoch  2570 | Loss: 1.1229e-02 | LR: 1.00e-05
# [Adam] Epoch  2580 | Loss: 1.1227e-02 | LR: 1.00e-05
# [Adam] Epoch  2590 | Loss: 1.1225e-02 | LR: 1.00e-05
# [Adam] Epoch  2600 | Loss: 1.1222e-02 | LR: 1.00e-05
# [Adam] Epoch  2610 | Loss: 1.1220e-02 | LR: 1.00e-05
# [Adam] Epoch  2620 | Loss: 1.1218e-02 | LR: 1.00e-05
# [Adam] Epoch  2630 | Loss: 1.1216e-02 | LR: 1.00e-05
# [Adam] Epoch  2640 | Loss: 1.1214e-02 | LR: 1.00e-05
# [Adam] Epoch  2650 | Loss: 1.1212e-02 | LR: 1.00e-05
# [Adam] Epoch  2660 | Loss: 1.1210e-02 | LR: 1.00e-05
# [Adam] Epoch  2670 | Loss: 1.1208e-02 | LR: 1.00e-05
# [Adam] Epoch  2680 | Loss: 1.1206e-02 | LR: 1.00e-05
# [Adam] Epoch  2690 | Loss: 1.1205e-02 | LR: 1.00e-05
# [Adam] Epoch  2700 | Loss: 1.1203e-02 | LR: 1.00e-05
# [Adam] Epoch  2710 | Loss: 1.1201e-02 | LR: 1.00e-05
# [Adam] Epoch  2720 | Loss: 1.1199e-02 | LR: 1.00e-05
# [Adam] Epoch  2730 | Loss: 1.1198e-02 | LR: 1.00e-05
# [Adam] Epoch  2740 | Loss: 1.1196e-02 | LR: 1.00e-05
# [Adam] Epoch  2750 | Loss: 1.1194e-02 | LR: 1.00e-05
# [Adam] Epoch  2760 | Loss: 1.1193e-02 | LR: 1.00e-05
# [Adam] Epoch  2770 | Loss: 1.1191e-02 | LR: 1.00e-05
# [Adam] Epoch  2780 | Loss: 1.1190e-02 | LR: 1.00e-05
# [Adam] Epoch  2790 | Loss: 1.1188e-02 | LR: 1.00e-05
# [Adam] Epoch  2800 | Loss: 1.1187e-02 | LR: 1.00e-05
# [Adam] Epoch  2810 | Loss: 1.1185e-02 | LR: 1.00e-05
# [Adam] Epoch  2820 | Loss: 1.1184e-02 | LR: 1.00e-05
# [Adam] Epoch  2830 | Loss: 1.1182e-02 | LR: 1.00e-05
# [Adam] Epoch  2840 | Loss: 1.1181e-02 | LR: 1.00e-05
# [Adam] Epoch  2850 | Loss: 1.1180e-02 | LR: 1.00e-05
# [Adam] Epoch  2860 | Loss: 1.1178e-02 | LR: 1.00e-05
# [Adam] Epoch  2870 | Loss: 1.1177e-02 | LR: 1.00e-05
# [Adam] Epoch  2880 | Loss: 1.1176e-02 | LR: 1.00e-05
# [Adam] Epoch  2890 | Loss: 1.1175e-02 | LR: 1.00e-05
# [Adam] Epoch  2900 | Loss: 1.1173e-02 | LR: 1.00e-05
# [Adam] Epoch  2910 | Loss: 1.1172e-02 | LR: 1.00e-05
# [Adam] Epoch  2920 | Loss: 1.1171e-02 | LR: 1.00e-05
# [Adam] Epoch  2930 | Loss: 1.1170e-02 | LR: 1.00e-05
# [Adam] Epoch  2940 | Loss: 1.1169e-02 | LR: 1.00e-05
# [Adam] Epoch  2950 | Loss: 1.1168e-02 | LR: 1.00e-05
# [Adam] Epoch  2960 | Loss: 1.1166e-02 | LR: 1.00e-05
# [Adam] Epoch  2970 | Loss: 1.1165e-02 | LR: 1.00e-05
# [Adam] Epoch  2980 | Loss: 1.1164e-02 | LR: 1.00e-05
# [Adam] Epoch  2990 | Loss: 1.1163e-02 | LR: 1.00e-05
# [Adam] Epoch  3000 | Loss: 1.1162e-02 | LR: 1.00e-05
# [Adam] Epoch  3010 | Loss: 1.1161e-02 | LR: 1.00e-05
# [Adam] Epoch  3020 | Loss: 1.1160e-02 | LR: 1.00e-05
# [Adam] Epoch  3030 | Loss: 1.1159e-02 | LR: 1.00e-05
# [Adam] Epoch  3040 | Loss: 1.1158e-02 | LR: 1.00e-05
# [Adam] Epoch  3050 | Loss: 1.1157e-02 | LR: 1.00e-05
# [Adam] Epoch  3060 | Loss: 1.1156e-02 | LR: 1.00e-05
# [Adam] Epoch  3070 | Loss: 1.1155e-02 | LR: 1.00e-05
# [Adam] Epoch  3080 | Loss: 1.1154e-02 | LR: 1.00e-05
# [Adam] Epoch  3090 | Loss: 1.1153e-02 | LR: 1.00e-05
# [Adam] Epoch  3100 | Loss: 1.1152e-02 | LR: 1.00e-05
# [Adam] Epoch  3110 | Loss: 1.1152e-02 | LR: 1.00e-05
# [Adam] Epoch  3120 | Loss: 1.1151e-02 | LR: 1.00e-05
# [Adam] Epoch  3130 | Loss: 1.1150e-02 | LR: 1.00e-05
# [Adam] Epoch  3140 | Loss: 1.1149e-02 | LR: 1.00e-05
# [Adam] Epoch  3150 | Loss: 1.1148e-02 | LR: 1.00e-05
# [Adam] Epoch  3160 | Loss: 1.1147e-02 | LR: 1.00e-05
# [Adam] Epoch  3170 | Loss: 1.1146e-02 | LR: 1.00e-05
# [Adam] Epoch  3180 | Loss: 1.1146e-02 | LR: 1.00e-05
# [Adam] Epoch  3190 | Loss: 1.1145e-02 | LR: 1.00e-05
# [Adam] Epoch  3200 | Loss: 1.1144e-02 | LR: 1.00e-05
# [Adam] Epoch  3210 | Loss: 1.1143e-02 | LR: 1.00e-05
# [Adam] Epoch  3220 | Loss: 1.1143e-02 | LR: 1.00e-05
# [Adam] Epoch  3230 | Loss: 1.1142e-02 | LR: 1.00e-05
# [Adam] Epoch  3240 | Loss: 1.1141e-02 | LR: 1.00e-05
# [Adam] Epoch  3250 | Loss: 1.1140e-02 | LR: 1.00e-05
# [Adam] Epoch  3260 | Loss: 1.1140e-02 | LR: 1.00e-05
# [Adam] Epoch  3270 | Loss: 1.1139e-02 | LR: 1.00e-05
# [Adam] Epoch  3280 | Loss: 1.1138e-02 | LR: 1.00e-05
# [Adam] Epoch  3290 | Loss: 1.1137e-02 | LR: 1.00e-05
# [Adam] Epoch  3300 | Loss: 1.1137e-02 | LR: 1.00e-05
# [Adam] Epoch  3310 | Loss: 1.1136e-02 | LR: 1.00e-05
# [Adam] Epoch  3320 | Loss: 1.1135e-02 | LR: 1.00e-05
# [Adam] Epoch  3330 | Loss: 1.1135e-02 | LR: 1.00e-05
# [Adam] Epoch  3340 | Loss: 1.1134e-02 | LR: 1.00e-05
# [Adam] Epoch  3350 | Loss: 1.1133e-02 | LR: 1.00e-05
# [Adam] Epoch  3360 | Loss: 1.1133e-02 | LR: 1.00e-05
# [Adam] Epoch  3370 | Loss: 1.1132e-02 | LR: 1.00e-05
# [Adam] Epoch  3380 | Loss: 1.1132e-02 | LR: 1.00e-05
# [Adam] Epoch  3390 | Loss: 1.1131e-02 | LR: 1.00e-05
# [Adam] Epoch  3400 | Loss: 1.1130e-02 | LR: 1.00e-05
# [Adam] Epoch  3410 | Loss: 1.1130e-02 | LR: 1.00e-05
# [Adam] Epoch  3420 | Loss: 1.1129e-02 | LR: 1.00e-05
# [Adam] Epoch  3430 | Loss: 1.1129e-02 | LR: 1.00e-05
# [Adam] Epoch  3440 | Loss: 1.1128e-02 | LR: 1.00e-05
# [Adam] Epoch  3450 | Loss: 1.1127e-02 | LR: 1.00e-05
# [Adam] Epoch  3460 | Loss: 1.1127e-02 | LR: 1.00e-05
# [Adam] Epoch  3470 | Loss: 1.1126e-02 | LR: 1.00e-05
# [Adam] Epoch  3480 | Loss: 1.1126e-02 | LR: 1.00e-05
# [Adam] Epoch  3490 | Loss: 1.1125e-02 | LR: 1.00e-05
# [Adam] Epoch  3500 | Loss: 1.1125e-02 | LR: 1.00e-05
# [Adam] Epoch  3510 | Loss: 1.1124e-02 | LR: 1.00e-05
# [Adam] Epoch  3520 | Loss: 1.1123e-02 | LR: 1.00e-05
# [Adam] Epoch  3530 | Loss: 1.1123e-02 | LR: 1.00e-05
# [Adam] Epoch  3540 | Loss: 1.1122e-02 | LR: 1.00e-05
# [Adam] Epoch  3550 | Loss: 1.1122e-02 | LR: 1.00e-05
# [Adam] Epoch  3560 | Loss: 1.1121e-02 | LR: 1.00e-05
# [Adam] Epoch  3570 | Loss: 1.1121e-02 | LR: 1.00e-05
# [Adam] Epoch  3580 | Loss: 1.1120e-02 | LR: 1.00e-05
# [Adam] Epoch  3590 | Loss: 1.1120e-02 | LR: 1.00e-05
# [Adam] Epoch  3600 | Loss: 1.1119e-02 | LR: 1.00e-05
# [Adam] Epoch  3610 | Loss: 1.1119e-02 | LR: 1.00e-05
# [Adam] Epoch  3620 | Loss: 1.1118e-02 | LR: 1.00e-05
# [Adam] Epoch  3630 | Loss: 1.1118e-02 | LR: 1.00e-05
# [Adam] Epoch  3640 | Loss: 1.1117e-02 | LR: 1.00e-05
# [Adam] Epoch  3650 | Loss: 1.1117e-02 | LR: 1.00e-05
# [Adam] Epoch  3660 | Loss: 1.1116e-02 | LR: 1.00e-05
# [Adam] Epoch  3670 | Loss: 1.1116e-02 | LR: 1.00e-05
# [Adam] Epoch  3680 | Loss: 1.1115e-02 | LR: 1.00e-05
# [Adam] Epoch  3690 | Loss: 1.1115e-02 | LR: 1.00e-05
# [Adam] Epoch  3700 | Loss: 1.1114e-02 | LR: 1.00e-05
# [Adam] Epoch  3710 | Loss: 1.1114e-02 | LR: 1.00e-05
# [Adam] Epoch  3720 | Loss: 1.1114e-02 | LR: 1.00e-05
# [Adam] Epoch  3730 | Loss: 1.1113e-02 | LR: 1.00e-05
# [Adam] Epoch  3740 | Loss: 1.1113e-02 | LR: 1.00e-05
# [Adam] Epoch  3750 | Loss: 1.1112e-02 | LR: 1.00e-05
# [Adam] Epoch  3760 | Loss: 1.1112e-02 | LR: 1.00e-05
# [Adam] Epoch  3770 | Loss: 1.1111e-02 | LR: 1.00e-05
# [Adam] Epoch  3780 | Loss: 1.1111e-02 | LR: 1.00e-05
# [Adam] Epoch  3790 | Loss: 1.1111e-02 | LR: 1.00e-05
# [Adam] Epoch  3800 | Loss: 1.1110e-02 | LR: 1.00e-05
# [Adam] Epoch  3810 | Loss: 1.1110e-02 | LR: 1.00e-05
# [Adam] Epoch  3820 | Loss: 1.1109e-02 | LR: 1.00e-05
# [Adam] Epoch  3830 | Loss: 1.1109e-02 | LR: 1.00e-05
# [Adam] Epoch  3840 | Loss: 1.1108e-02 | LR: 1.00e-05
# [Adam] Epoch  3850 | Loss: 1.1108e-02 | LR: 1.00e-05
# [Adam] Epoch  3860 | Loss: 1.1108e-02 | LR: 1.00e-05
# [Adam] Epoch  3870 | Loss: 1.1107e-02 | LR: 1.00e-05
# [Adam] Epoch  3880 | Loss: 1.1107e-02 | LR: 1.00e-05
# [Adam] Epoch  3890 | Loss: 1.1106e-02 | LR: 1.00e-05
# [Adam] Epoch  3900 | Loss: 1.1106e-02 | LR: 1.00e-05
# [Adam] Epoch  3910 | Loss: 1.1106e-02 | LR: 1.00e-05
# [Adam] Epoch  3920 | Loss: 1.1105e-02 | LR: 1.00e-05
# [Adam] Epoch  3930 | Loss: 1.1105e-02 | LR: 1.00e-05
# [Adam] Epoch  3940 | Loss: 1.1105e-02 | LR: 1.00e-05
# [Adam] Epoch  3950 | Loss: 1.1104e-02 | LR: 1.00e-05
# [Adam] Epoch  3960 | Loss: 1.1104e-02 | LR: 1.00e-05
# [Adam] Epoch  3970 | Loss: 1.1103e-02 | LR: 1.00e-05
# [Adam] Epoch  3980 | Loss: 1.1103e-02 | LR: 1.00e-05
# [Adam] Epoch  3990 | Loss: 1.1103e-02 | LR: 1.00e-05
# [Adam] Epoch  4000 | Loss: 1.1102e-02 | LR: 1.00e-05
# [Adam] Epoch  4010 | Loss: 1.1102e-02 | LR: 1.00e-05
# [Adam] Epoch  4020 | Loss: 1.1102e-02 | LR: 1.00e-05
# [Adam] Epoch  4030 | Loss: 1.1101e-02 | LR: 1.00e-05
# [Adam] Epoch  4040 | Loss: 1.1101e-02 | LR: 1.00e-05
# [Adam] Epoch  4050 | Loss: 1.1101e-02 | LR: 1.00e-05
# [Adam] Epoch  4060 | Loss: 1.1100e-02 | LR: 1.00e-05
# [Adam] Epoch  4070 | Loss: 1.1100e-02 | LR: 1.00e-05
# [Adam] Epoch  4080 | Loss: 1.1099e-02 | LR: 1.00e-05
# [Adam] Epoch  4090 | Loss: 1.1099e-02 | LR: 1.00e-05
# [Adam] Epoch  4100 | Loss: 1.1099e-02 | LR: 1.00e-05
# [Adam] Epoch  4110 | Loss: 1.1098e-02 | LR: 1.00e-05
# [Adam] Epoch  4120 | Loss: 1.1098e-02 | LR: 1.00e-05
# [Adam] Epoch  4130 | Loss: 1.1098e-02 | LR: 1.00e-05
# [Adam] Epoch  4140 | Loss: 1.1097e-02 | LR: 1.00e-05
# [Adam] Epoch  4150 | Loss: 1.1097e-02 | LR: 1.00e-05
# [Adam] Epoch  4160 | Loss: 1.1097e-02 | LR: 1.00e-05
# [Adam] Epoch  4170 | Loss: 1.1096e-02 | LR: 1.00e-05
# [Adam] Epoch  4180 | Loss: 1.1096e-02 | LR: 1.00e-05
# [Adam] Epoch  4190 | Loss: 1.1096e-02 | LR: 1.00e-05
# [Adam] Epoch  4200 | Loss: 1.1095e-02 | LR: 1.00e-05
# [Adam] Epoch  4210 | Loss: 1.1095e-02 | LR: 1.00e-05
# [Adam] Epoch  4220 | Loss: 1.1095e-02 | LR: 1.00e-05
# [Adam] Epoch  4230 | Loss: 1.1094e-02 | LR: 1.00e-05
# [Adam] Epoch  4240 | Loss: 1.1094e-02 | LR: 1.00e-05
# [Adam] Epoch  4250 | Loss: 1.1094e-02 | LR: 1.00e-05
# [Adam] Epoch  4260 | Loss: 1.1093e-02 | LR: 1.00e-05
# [Adam] Epoch  4270 | Loss: 1.1093e-02 | LR: 1.00e-05
# [Adam] Epoch  4280 | Loss: 1.1093e-02 | LR: 1.00e-05
# [Adam] Epoch  4290 | Loss: 1.1092e-02 | LR: 1.00e-05
# [Adam] Epoch  4300 | Loss: 1.1092e-02 | LR: 1.00e-05
# [Adam] Epoch  4310 | Loss: 1.1092e-02 | LR: 1.00e-05
# [Adam] Epoch  4320 | Loss: 1.1092e-02 | LR: 1.00e-05
# [Adam] Epoch  4330 | Loss: 1.1091e-02 | LR: 1.00e-05
# [Adam] Epoch  4340 | Loss: 1.1091e-02 | LR: 1.00e-05
# [Adam] Epoch  4350 | Loss: 1.1091e-02 | LR: 1.00e-05
# [Adam] Epoch  4360 | Loss: 1.1090e-02 | LR: 1.00e-05
# [Adam] Epoch  4370 | Loss: 1.1090e-02 | LR: 1.00e-05
# [Adam] Epoch  4380 | Loss: 1.1090e-02 | LR: 1.00e-05
# [Adam] Epoch  4390 | Loss: 1.1089e-02 | LR: 1.00e-05
# [Adam] Epoch  4400 | Loss: 1.1089e-02 | LR: 1.00e-05
# [Adam] Epoch  4410 | Loss: 1.1089e-02 | LR: 1.00e-05
# [Adam] Epoch  4420 | Loss: 1.1088e-02 | LR: 1.00e-05
# [Adam] Epoch  4430 | Loss: 1.1088e-02 | LR: 1.00e-05
# [Adam] Epoch  4440 | Loss: 1.1088e-02 | LR: 1.00e-05
# [Adam] Epoch  4450 | Loss: 1.1088e-02 | LR: 1.00e-05
# [Adam] Epoch  4460 | Loss: 1.1087e-02 | LR: 1.00e-05
# [Adam] Epoch  4470 | Loss: 1.1087e-02 | LR: 1.00e-05
# [Adam] Epoch  4480 | Loss: 1.1087e-02 | LR: 1.00e-05
# [Adam] Epoch  4490 | Loss: 1.1087e-02 | LR: 1.00e-05
# [Adam] Epoch  4500 | Loss: 1.1086e-02 | LR: 1.00e-05
# [Adam] Epoch  4510 | Loss: 1.1086e-02 | LR: 1.00e-05
# [Adam] Epoch  4520 | Loss: 1.1086e-02 | LR: 1.00e-05
# [Adam] Epoch  4530 | Loss: 1.1085e-02 | LR: 1.00e-05
# [Adam] Epoch  4540 | Loss: 1.1085e-02 | LR: 1.00e-05
# [Adam] Epoch  4550 | Loss: 1.1085e-02 | LR: 1.00e-05
# [Adam] Epoch  4560 | Loss: 1.1084e-02 | LR: 1.00e-05
# [Adam] Epoch  4570 | Loss: 1.1084e-02 | LR: 1.00e-05
# [Adam] Epoch  4580 | Loss: 1.1084e-02 | LR: 1.00e-05
# [Adam] Epoch  4590 | Loss: 1.1084e-02 | LR: 1.00e-05
# [Adam] Epoch  4600 | Loss: 1.1083e-02 | LR: 1.00e-05
# [Adam] Epoch  4610 | Loss: 1.1083e-02 | LR: 1.00e-05
# [Adam] Epoch  4620 | Loss: 1.1083e-02 | LR: 1.00e-05
# [Adam] Epoch  4630 | Loss: 1.1082e-02 | LR: 1.00e-05
# [Adam] Epoch  4640 | Loss: 1.1082e-02 | LR: 1.00e-05
# [Adam] Epoch  4650 | Loss: 1.1082e-02 | LR: 1.00e-05
# [Adam] Epoch  4660 | Loss: 1.1082e-02 | LR: 1.00e-05
# [Adam] Epoch  4670 | Loss: 1.1081e-02 | LR: 1.00e-05
# [Adam] Epoch  4680 | Loss: 1.1081e-02 | LR: 1.00e-05
# [Adam] Epoch  4690 | Loss: 1.1081e-02 | LR: 1.00e-05
# [Adam] Epoch  4700 | Loss: 1.1081e-02 | LR: 1.00e-05
# [Adam] Epoch  4710 | Loss: 1.1080e-02 | LR: 1.00e-05
# [Adam] Epoch  4720 | Loss: 1.1080e-02 | LR: 1.00e-05
# [Adam] Epoch  4730 | Loss: 1.1080e-02 | LR: 1.00e-05
# [Adam] Epoch  4740 | Loss: 1.1080e-02 | LR: 1.00e-05
# [Adam] Epoch  4750 | Loss: 1.1079e-02 | LR: 1.00e-05
# [Adam] Epoch  4760 | Loss: 1.1079e-02 | LR: 1.00e-05
# [Adam] Epoch  4770 | Loss: 1.1079e-02 | LR: 1.00e-05
# [Adam] Epoch  4780 | Loss: 1.1078e-02 | LR: 1.00e-05
# [Adam] Epoch  4790 | Loss: 1.1078e-02 | LR: 1.00e-05
# [Adam] Epoch  4800 | Loss: 1.1078e-02 | LR: 1.00e-05
# [Adam] Epoch  4810 | Loss: 1.1078e-02 | LR: 1.00e-05
# [Adam] Epoch  4820 | Loss: 1.1077e-02 | LR: 1.00e-05
# [Adam] Epoch  4830 | Loss: 1.1077e-02 | LR: 1.00e-05
# [Adam] Epoch  4840 | Loss: 1.1077e-02 | LR: 1.00e-05
# [Adam] Epoch  4850 | Loss: 1.1077e-02 | LR: 1.00e-05
# [Adam] Epoch  4860 | Loss: 1.1076e-02 | LR: 1.00e-05
# [Adam] Epoch  4870 | Loss: 1.1076e-02 | LR: 1.00e-05
# [Adam] Epoch  4880 | Loss: 1.1076e-02 | LR: 1.00e-05
# [Adam] Epoch  4890 | Loss: 1.1076e-02 | LR: 1.00e-05
# [Adam] Epoch  4900 | Loss: 1.1075e-02 | LR: 1.00e-05
# [Adam] Epoch  4910 | Loss: 1.1075e-02 | LR: 1.00e-05
# [Adam] Epoch  4920 | Loss: 1.1075e-02 | LR: 1.00e-05
# [Adam] Epoch  4930 | Loss: 1.1075e-02 | LR: 1.00e-05
# [Adam] Epoch  4940 | Loss: 1.1074e-02 | LR: 1.00e-05
# [Adam] Epoch  4950 | Loss: 1.1074e-02 | LR: 1.00e-05
# [Adam] Epoch  4960 | Loss: 1.1074e-02 | LR: 1.00e-05
# [Adam] Epoch  4970 | Loss: 1.1074e-02 | LR: 1.00e-05
# [Adam] Epoch  4980 | Loss: 1.1073e-02 | LR: 1.00e-05
# [Adam] Epoch  4990 | Loss: 1.1073e-02 | LR: 1.00e-05
# [Adam] Epoch  5000 | Loss: 1.1073e-02 | LR: 1.00e-05
# [Adam] Epoch  5010 | Loss: 1.1073e-02 | LR: 1.00e-05
# [Adam] Epoch  5020 | Loss: 1.1072e-02 | LR: 1.00e-05
# [Adam] Epoch  5030 | Loss: 1.1072e-02 | LR: 1.00e-05
# [Adam] Epoch  5040 | Loss: 1.1072e-02 | LR: 1.00e-05
# [Adam] Epoch  5050 | Loss: 1.1072e-02 | LR: 1.00e-05
# [Adam] Epoch  5060 | Loss: 1.1071e-02 | LR: 1.00e-05
# [Adam] Epoch  5070 | Loss: 1.1071e-02 | LR: 1.00e-05
# [Adam] Epoch  5080 | Loss: 1.1071e-02 | LR: 1.00e-05
# [Adam] Epoch  5090 | Loss: 1.1071e-02 | LR: 1.00e-05
# [Adam] Epoch  5100 | Loss: 1.1071e-02 | LR: 1.00e-05
# [Adam] Epoch  5110 | Loss: 1.1070e-02 | LR: 1.00e-05
# [Adam] Epoch  5120 | Loss: 1.1070e-02 | LR: 1.00e-05
# [Adam] Epoch  5130 | Loss: 1.1070e-02 | LR: 1.00e-05
# [Adam] Epoch  5140 | Loss: 1.1070e-02 | LR: 1.00e-05
# [Adam] Epoch  5150 | Loss: 1.1069e-02 | LR: 1.00e-05
# [Adam] Epoch  5160 | Loss: 1.1069e-02 | LR: 1.00e-05
# [Adam] Epoch  5170 | Loss: 1.1069e-02 | LR: 1.00e-05
# [Adam] Epoch  5180 | Loss: 1.1069e-02 | LR: 1.00e-05
# [Adam] Epoch  5190 | Loss: 1.1068e-02 | LR: 1.00e-05
# [Adam] Epoch  5200 | Loss: 1.1068e-02 | LR: 1.00e-05
# [Adam] Epoch  5210 | Loss: 1.1068e-02 | LR: 1.00e-05
# [Adam] Epoch  5220 | Loss: 1.1068e-02 | LR: 1.00e-05
# [Adam] Epoch  5230 | Loss: 1.1067e-02 | LR: 1.00e-05
# [Adam] Epoch  5240 | Loss: 1.1067e-02 | LR: 1.00e-05
# [Adam] Epoch  5250 | Loss: 1.1067e-02 | LR: 1.00e-05
# [Adam] Epoch  5260 | Loss: 1.1067e-02 | LR: 1.00e-05
# [Adam] Epoch  5270 | Loss: 1.1067e-02 | LR: 1.00e-05
# [Adam] Epoch  5280 | Loss: 1.1066e-02 | LR: 1.00e-05
# [Adam] Epoch  5290 | Loss: 1.1066e-02 | LR: 1.00e-05
# [Adam] Epoch  5300 | Loss: 1.1066e-02 | LR: 1.00e-05
# [Adam] Epoch  5310 | Loss: 1.1066e-02 | LR: 1.00e-05
# [Adam] Epoch  5320 | Loss: 1.1065e-02 | LR: 1.00e-05
# [Adam] Epoch  5330 | Loss: 1.1065e-02 | LR: 1.00e-05
# [Adam] Epoch  5340 | Loss: 1.1065e-02 | LR: 1.00e-05
# [Adam] Epoch  5350 | Loss: 1.1065e-02 | LR: 1.00e-05
# [Adam] Epoch  5360 | Loss: 1.1065e-02 | LR: 1.00e-05
# [Adam] Epoch  5370 | Loss: 1.1064e-02 | LR: 1.00e-05
# [Adam] Epoch  5380 | Loss: 1.1064e-02 | LR: 1.00e-05
# [Adam] Epoch  5390 | Loss: 1.1064e-02 | LR: 1.00e-05
# [Adam] Epoch  5400 | Loss: 1.1064e-02 | LR: 1.00e-05
# [Adam] Epoch  5410 | Loss: 1.1063e-02 | LR: 1.00e-05
# [Adam] Epoch  5420 | Loss: 1.1063e-02 | LR: 1.00e-05
# [Adam] Epoch  5430 | Loss: 1.1063e-02 | LR: 1.00e-05
# [Adam] Epoch  5440 | Loss: 1.1063e-02 | LR: 1.00e-05
# [Adam] Epoch  5450 | Loss: 1.1063e-02 | LR: 1.00e-05
# [Adam] Epoch  5460 | Loss: 1.1062e-02 | LR: 1.00e-05
# [Adam] Epoch  5470 | Loss: 1.1062e-02 | LR: 1.00e-05
# [Adam] Epoch  5480 | Loss: 1.1062e-02 | LR: 1.00e-05
# [Adam] Epoch  5490 | Loss: 1.1062e-02 | LR: 1.00e-05
# [Adam] Epoch  5500 | Loss: 1.1062e-02 | LR: 1.00e-05
# [Adam] Epoch  5510 | Loss: 1.1061e-02 | LR: 1.00e-05
# [Adam] Epoch  5520 | Loss: 1.1061e-02 | LR: 1.00e-05
# [Adam] Epoch  5530 | Loss: 1.1061e-02 | LR: 1.00e-05
# [Adam] Epoch  5540 | Loss: 1.1061e-02 | LR: 1.00e-05
# [Adam] Epoch  5550 | Loss: 1.1060e-02 | LR: 1.00e-05
# [Adam] Epoch  5560 | Loss: 1.1060e-02 | LR: 1.00e-05
# [Adam] Epoch  5570 | Loss: 1.1060e-02 | LR: 1.00e-05
# [Adam] Epoch  5580 | Loss: 1.1060e-02 | LR: 1.00e-05
# [Adam] Epoch  5590 | Loss: 1.1060e-02 | LR: 1.00e-05
# [Adam] Epoch  5600 | Loss: 1.1059e-02 | LR: 1.00e-05
# [Adam] Epoch  5610 | Loss: 1.1059e-02 | LR: 1.00e-05
# [Adam] Epoch  5620 | Loss: 1.1059e-02 | LR: 1.00e-05
# [Adam] Epoch  5630 | Loss: 1.1059e-02 | LR: 1.00e-05
# [Adam] Epoch  5640 | Loss: 1.1059e-02 | LR: 1.00e-05
# [Adam] Epoch  5650 | Loss: 1.1058e-02 | LR: 1.00e-05
# [Adam] Epoch  5660 | Loss: 1.1058e-02 | LR: 1.00e-05
# [Adam] Epoch  5670 | Loss: 1.1058e-02 | LR: 1.00e-05
# [Adam] Epoch  5680 | Loss: 1.1058e-02 | LR: 1.00e-05
# [Adam] Epoch  5690 | Loss: 1.1058e-02 | LR: 1.00e-05
# [Adam] Epoch  5700 | Loss: 1.1057e-02 | LR: 1.00e-05
# [Adam] Epoch  5710 | Loss: 1.1057e-02 | LR: 1.00e-05
# [Adam] Epoch  5720 | Loss: 1.1057e-02 | LR: 1.00e-05
# [Adam] Epoch  5730 | Loss: 1.1057e-02 | LR: 1.00e-05
# [Adam] Epoch  5740 | Loss: 1.1057e-02 | LR: 1.00e-05
# [Adam] Epoch  5750 | Loss: 1.1056e-02 | LR: 1.00e-05
# [Adam] Epoch  5760 | Loss: 1.1056e-02 | LR: 1.00e-05
# [Adam] Epoch  5770 | Loss: 1.1056e-02 | LR: 1.00e-05
# [Adam] Epoch  5780 | Loss: 1.1056e-02 | LR: 1.00e-05
# [Adam] Epoch  5790 | Loss: 1.1056e-02 | LR: 1.00e-05
# [Adam] Epoch  5800 | Loss: 1.1055e-02 | LR: 1.00e-05
# [Adam] Epoch  5810 | Loss: 1.1055e-02 | LR: 1.00e-05
# [Adam] Epoch  5820 | Loss: 1.1055e-02 | LR: 1.00e-05
# [Adam] Epoch  5830 | Loss: 1.1055e-02 | LR: 1.00e-05
# [Adam] Epoch  5840 | Loss: 1.1055e-02 | LR: 1.00e-05
# [Adam] Epoch  5850 | Loss: 1.1054e-02 | LR: 1.00e-05
# [Adam] Epoch  5860 | Loss: 1.1054e-02 | LR: 1.00e-05
# [Adam] Epoch  5870 | Loss: 1.1054e-02 | LR: 1.00e-05
# [Adam] Epoch  5880 | Loss: 1.1054e-02 | LR: 1.00e-05
# [Adam] Epoch  5890 | Loss: 1.1054e-02 | LR: 1.00e-05
# [Adam] Epoch  5900 | Loss: 1.1053e-02 | LR: 1.00e-05
# [Adam] Epoch  5910 | Loss: 1.1053e-02 | LR: 1.00e-05
# [Adam] Epoch  5920 | Loss: 1.1053e-02 | LR: 1.00e-05
# [Adam] Epoch  5930 | Loss: 1.1053e-02 | LR: 1.00e-05
# [Adam] Epoch  5940 | Loss: 1.1053e-02 | LR: 1.00e-05
# [Adam] Epoch  5950 | Loss: 1.1052e-02 | LR: 1.00e-05
# [Adam] Epoch  5960 | Loss: 1.1052e-02 | LR: 1.00e-05
# [Adam] Epoch  5970 | Loss: 1.1052e-02 | LR: 1.00e-05
# [Adam] Epoch  5980 | Loss: 1.1052e-02 | LR: 1.00e-05
# [Adam] Epoch  5990 | Loss: 1.1052e-02 | LR: 1.00e-05
# [Adam] Epoch  6000 | Loss: 1.1051e-02 | LR: 1.00e-05
# [Adam] Epoch  6010 | Loss: 1.1051e-02 | LR: 1.00e-05
# [Adam] Epoch  6020 | Loss: 1.1051e-02 | LR: 1.00e-05
# [Adam] Epoch  6030 | Loss: 1.1051e-02 | LR: 1.00e-05
# [Adam] Epoch  6040 | Loss: 1.1051e-02 | LR: 1.00e-05
# [Adam] Epoch  6050 | Loss: 1.1050e-02 | LR: 1.00e-05
# [Adam] Epoch  6060 | Loss: 1.1050e-02 | LR: 1.00e-05
# [Adam] Epoch  6070 | Loss: 1.1050e-02 | LR: 1.00e-05
# [Adam] Epoch  6080 | Loss: 1.1050e-02 | LR: 1.00e-05
# [Adam] Epoch  6090 | Loss: 1.1050e-02 | LR: 1.00e-05
# [Adam] Epoch  6100 | Loss: 1.1049e-02 | LR: 1.00e-05
# [Adam] Epoch  6110 | Loss: 1.1049e-02 | LR: 1.00e-05
# [Adam] Epoch  6120 | Loss: 1.1049e-02 | LR: 1.00e-05
# [Adam] Epoch  6130 | Loss: 1.1049e-02 | LR: 1.00e-05
# [Adam] Epoch  6140 | Loss: 1.1049e-02 | LR: 1.00e-05
# [Adam] Epoch  6150 | Loss: 1.1049e-02 | LR: 1.00e-05
# [Adam] Epoch  6160 | Loss: 1.1048e-02 | LR: 1.00e-05
# [Adam] Epoch  6170 | Loss: 1.1048e-02 | LR: 1.00e-05
# [Adam] Epoch  6180 | Loss: 1.1048e-02 | LR: 1.00e-05
# [Adam] Epoch  6190 | Loss: 1.1048e-02 | LR: 1.00e-05
# [Adam] Epoch  6200 | Loss: 1.1048e-02 | LR: 1.00e-05
# [Adam] Epoch  6210 | Loss: 1.1047e-02 | LR: 1.00e-05
# [Adam] Epoch  6220 | Loss: 1.1047e-02 | LR: 1.00e-05
# [Adam] Epoch  6230 | Loss: 1.1047e-02 | LR: 1.00e-05
# [Adam] Epoch  6240 | Loss: 1.1047e-02 | LR: 1.00e-05
# [Adam] Epoch  6250 | Loss: 1.1047e-02 | LR: 1.00e-05
# [Adam] Epoch  6260 | Loss: 1.1046e-02 | LR: 1.00e-05
# [Adam] Epoch  6270 | Loss: 1.1046e-02 | LR: 1.00e-05
# [Adam] Epoch  6280 | Loss: 1.1046e-02 | LR: 1.00e-05
# [Adam] Epoch  6290 | Loss: 1.1046e-02 | LR: 1.00e-05
# [Adam] Epoch  6300 | Loss: 1.1046e-02 | LR: 1.00e-05
# [Adam] Epoch  6310 | Loss: 1.1045e-02 | LR: 1.00e-05
# [Adam] Epoch  6320 | Loss: 1.1045e-02 | LR: 1.00e-05
# [Adam] Epoch  6330 | Loss: 1.1045e-02 | LR: 1.00e-05
# [Adam] Epoch  6340 | Loss: 1.1045e-02 | LR: 1.00e-05
# [Adam] Epoch  6350 | Loss: 1.1045e-02 | LR: 1.00e-05
# [Adam] Epoch  6360 | Loss: 1.1045e-02 | LR: 1.00e-05
# [Adam] Epoch  6370 | Loss: 1.1044e-02 | LR: 1.00e-05
# [Adam] Epoch  6380 | Loss: 1.1044e-02 | LR: 1.00e-05
# [Adam] Epoch  6390 | Loss: 1.1044e-02 | LR: 1.00e-05
# [Adam] Epoch  6400 | Loss: 1.1044e-02 | LR: 1.00e-05
# [Adam] Epoch  6410 | Loss: 1.1044e-02 | LR: 1.00e-05
# [Adam] Epoch  6420 | Loss: 1.1044e-02 | LR: 1.00e-05
# [Adam] Epoch  6430 | Loss: 1.1043e-02 | LR: 1.00e-05
# [Adam] Epoch  6440 | Loss: 1.1043e-02 | LR: 1.00e-05
# [Adam] Epoch  6450 | Loss: 1.1043e-02 | LR: 1.00e-05
# [Adam] Epoch  6460 | Loss: 1.1043e-02 | LR: 1.00e-05
# [Adam] Epoch  6470 | Loss: 1.1043e-02 | LR: 1.00e-05
# [Adam] Epoch  6480 | Loss: 1.1042e-02 | LR: 1.00e-05
# [Adam] Epoch  6490 | Loss: 1.1042e-02 | LR: 1.00e-05
# [Adam] Epoch  6500 | Loss: 1.1042e-02 | LR: 1.00e-05
# [Adam] Epoch  6510 | Loss: 1.1042e-02 | LR: 1.00e-05
# [Adam] Epoch  6520 | Loss: 1.1042e-02 | LR: 1.00e-05
# [Adam] Epoch  6530 | Loss: 1.1042e-02 | LR: 1.00e-05
# [Adam] Epoch  6540 | Loss: 1.1041e-02 | LR: 1.00e-05
# [Adam] Epoch  6550 | Loss: 1.1041e-02 | LR: 1.00e-05
# [Adam] Epoch  6560 | Loss: 1.1041e-02 | LR: 1.00e-05
# [Adam] Epoch  6570 | Loss: 1.1041e-02 | LR: 1.00e-05
# [Adam] Epoch  6580 | Loss: 1.1041e-02 | LR: 1.00e-05
# [Adam] Epoch  6590 | Loss: 1.1040e-02 | LR: 1.00e-05
# [Adam] Epoch  6600 | Loss: 1.1040e-02 | LR: 1.00e-05
# [Adam] Epoch  6610 | Loss: 1.1040e-02 | LR: 1.00e-05
# [Adam] Epoch  6620 | Loss: 1.1040e-02 | LR: 1.00e-05
# [Adam] Epoch  6630 | Loss: 1.1040e-02 | LR: 1.00e-05
# [Adam] Epoch  6640 | Loss: 1.1040e-02 | LR: 1.00e-05
# [Adam] Epoch  6650 | Loss: 1.1039e-02 | LR: 1.00e-05
# [Adam] Epoch  6660 | Loss: 1.1039e-02 | LR: 1.00e-05
# [Adam] Epoch  6670 | Loss: 1.1039e-02 | LR: 1.00e-05
# [Adam] Epoch  6680 | Loss: 1.1039e-02 | LR: 1.00e-05
# [Adam] Epoch  6690 | Loss: 1.1039e-02 | LR: 1.00e-05
# [Adam] Epoch  6700 | Loss: 1.1039e-02 | LR: 1.00e-05
# [Adam] Epoch  6710 | Loss: 1.1038e-02 | LR: 1.00e-05
# [Adam] Epoch  6720 | Loss: 1.1038e-02 | LR: 1.00e-05
# [Adam] Epoch  6730 | Loss: 1.1038e-02 | LR: 1.00e-05
# [Adam] Epoch  6740 | Loss: 1.1038e-02 | LR: 1.00e-05
# [Adam] Epoch  6750 | Loss: 1.1038e-02 | LR: 1.00e-05
# [Adam] Epoch  6760 | Loss: 1.1038e-02 | LR: 1.00e-05
# [Adam] Epoch  6770 | Loss: 1.1037e-02 | LR: 1.00e-05
# [Adam] Epoch  6780 | Loss: 1.1037e-02 | LR: 1.00e-05
# [Adam] Epoch  6790 | Loss: 1.1037e-02 | LR: 1.00e-05
# [Adam] Epoch  6800 | Loss: 1.1037e-02 | LR: 1.00e-05
# [Adam] Epoch  6810 | Loss: 1.1037e-02 | LR: 1.00e-05
# [Adam] Epoch  6820 | Loss: 1.1037e-02 | LR: 1.00e-05
# [Adam] Epoch  6830 | Loss: 1.1036e-02 | LR: 1.00e-05
# [Adam] Epoch  6840 | Loss: 1.1036e-02 | LR: 1.00e-05
# [Adam] Epoch  6850 | Loss: 1.1036e-02 | LR: 1.00e-05
# [Adam] Epoch  6860 | Loss: 1.1036e-02 | LR: 1.00e-05
# [Adam] Epoch  6870 | Loss: 1.1036e-02 | LR: 1.00e-05
# [Adam] Epoch  6880 | Loss: 1.1036e-02 | LR: 1.00e-05
# [Adam] Epoch  6890 | Loss: 1.1035e-02 | LR: 1.00e-05
# [Adam] Epoch  6900 | Loss: 1.1035e-02 | LR: 1.00e-05
# [Adam] Epoch  6910 | Loss: 1.1035e-02 | LR: 1.00e-05
# [Adam] Epoch  6920 | Loss: 1.1035e-02 | LR: 1.00e-05
# [Adam] Epoch  6930 | Loss: 1.1035e-02 | LR: 1.00e-05
# [Adam] Epoch  6940 | Loss: 1.1035e-02 | LR: 1.00e-05
# [Adam] Epoch  6950 | Loss: 1.1034e-02 | LR: 1.00e-05
# [Adam] Epoch  6960 | Loss: 1.1034e-02 | LR: 1.00e-05
# [Adam] Epoch  6970 | Loss: 1.1034e-02 | LR: 1.00e-05
# [Adam] Epoch  6980 | Loss: 1.1034e-02 | LR: 1.00e-05
# [Adam] Epoch  6990 | Loss: 1.1034e-02 | LR: 1.00e-05
# [Adam] Epoch  7000 | Loss: 1.1034e-02 | LR: 1.00e-05
# [Adam] Epoch  7010 | Loss: 1.1033e-02 | LR: 1.00e-05
# [Adam] Epoch  7020 | Loss: 1.1033e-02 | LR: 1.00e-05
# [Adam] Epoch  7030 | Loss: 1.1033e-02 | LR: 1.00e-05
# [Adam] Epoch  7040 | Loss: 1.1033e-02 | LR: 1.00e-05
# [Adam] Epoch  7050 | Loss: 1.1033e-02 | LR: 1.00e-05
# [Adam] Epoch  7060 | Loss: 1.1033e-02 | LR: 1.00e-05
# [Adam] Epoch  7070 | Loss: 1.1032e-02 | LR: 1.00e-05
# [Adam] Epoch  7080 | Loss: 1.1032e-02 | LR: 1.00e-05
# [Adam] Epoch  7090 | Loss: 1.1032e-02 | LR: 1.00e-05
# [Adam] Epoch  7100 | Loss: 1.1032e-02 | LR: 1.00e-05
# [Adam] Epoch  7110 | Loss: 1.1032e-02 | LR: 1.00e-05
# [Adam] Epoch  7120 | Loss: 1.1032e-02 | LR: 1.00e-05
# [Adam] Epoch  7130 | Loss: 1.1031e-02 | LR: 1.00e-05
# [Adam] Epoch  7140 | Loss: 1.1031e-02 | LR: 1.00e-05
# [Adam] Epoch  7150 | Loss: 1.1031e-02 | LR: 1.00e-05
# [Adam] Epoch  7160 | Loss: 1.1031e-02 | LR: 1.00e-05
# [Adam] Epoch  7170 | Loss: 1.1031e-02 | LR: 1.00e-05
# [Adam] Epoch  7180 | Loss: 1.1031e-02 | LR: 1.00e-05
# [Adam] Epoch  7190 | Loss: 1.1030e-02 | LR: 1.00e-05
# [Adam] Epoch  7200 | Loss: 1.1030e-02 | LR: 1.00e-05
# [Adam] Epoch  7210 | Loss: 1.1030e-02 | LR: 1.00e-05
# [Adam] Epoch  7220 | Loss: 1.1030e-02 | LR: 1.00e-05
# [Adam] Epoch  7230 | Loss: 1.1030e-02 | LR: 1.00e-05
# [Adam] Epoch  7240 | Loss: 1.1030e-02 | LR: 1.00e-05
# [Adam] Epoch  7250 | Loss: 1.1029e-02 | LR: 1.00e-05
# [Adam] Epoch  7260 | Loss: 1.1029e-02 | LR: 1.00e-05
# [Adam] Epoch  7270 | Loss: 1.1029e-02 | LR: 1.00e-05
# [Adam] Epoch  7280 | Loss: 1.1029e-02 | LR: 1.00e-05
# [Adam] Epoch  7290 | Loss: 1.1029e-02 | LR: 1.00e-05
# [Adam] Epoch  7300 | Loss: 1.1029e-02 | LR: 1.00e-05
# [Adam] Epoch  7310 | Loss: 1.1029e-02 | LR: 1.00e-05
# [Adam] Epoch  7320 | Loss: 1.1028e-02 | LR: 1.00e-05
# [Adam] Epoch  7330 | Loss: 1.1028e-02 | LR: 1.00e-05
# [Adam] Epoch  7340 | Loss: 1.1028e-02 | LR: 1.00e-05
# [Adam] Epoch  7350 | Loss: 1.1028e-02 | LR: 1.00e-05
# [Adam] Epoch  7360 | Loss: 1.1028e-02 | LR: 1.00e-05
# [Adam] Epoch  7370 | Loss: 1.1028e-02 | LR: 1.00e-05
# [Adam] Epoch  7380 | Loss: 1.1027e-02 | LR: 1.00e-05
# [Adam] Epoch  7390 | Loss: 1.1027e-02 | LR: 1.00e-05
# [Adam] Epoch  7400 | Loss: 1.1027e-02 | LR: 1.00e-05
# [Adam] Epoch  7410 | Loss: 1.1027e-02 | LR: 1.00e-05
# [Adam] Epoch  7420 | Loss: 1.1027e-02 | LR: 1.00e-05
# [Adam] Epoch  7430 | Loss: 1.1027e-02 | LR: 1.00e-05
# [Adam] Epoch  7440 | Loss: 1.1026e-02 | LR: 1.00e-05
# [Adam] Epoch  7450 | Loss: 1.1026e-02 | LR: 1.00e-05
# [Adam] Epoch  7460 | Loss: 1.1026e-02 | LR: 1.00e-05
# [Adam] Epoch  7470 | Loss: 1.1026e-02 | LR: 1.00e-05
# [Adam] Epoch  7480 | Loss: 1.1026e-02 | LR: 1.00e-05
# [Adam] Epoch  7490 | Loss: 1.1026e-02 | LR: 1.00e-05
# [Adam] Epoch  7500 | Loss: 1.1026e-02 | LR: 1.00e-05
# [Adam] Epoch  7510 | Loss: 1.1025e-02 | LR: 1.00e-05
# [Adam] Epoch  7520 | Loss: 1.1025e-02 | LR: 1.00e-05
# [Adam] Epoch  7530 | Loss: 1.1025e-02 | LR: 1.00e-05
# [Adam] Epoch  7540 | Loss: 1.1025e-02 | LR: 1.00e-05
# [Adam] Epoch  7550 | Loss: 1.1025e-02 | LR: 1.00e-05
# [Adam] Epoch  7560 | Loss: 1.1025e-02 | LR: 1.00e-05
# [Adam] Epoch  7570 | Loss: 1.1024e-02 | LR: 1.00e-05
# [Adam] Epoch  7580 | Loss: 1.1024e-02 | LR: 1.00e-05
# [Adam] Epoch  7590 | Loss: 1.1024e-02 | LR: 1.00e-05
# [Adam] Epoch  7600 | Loss: 1.1024e-02 | LR: 1.00e-05
# [Adam] Epoch  7610 | Loss: 1.1024e-02 | LR: 1.00e-05
# [Adam] Epoch  7620 | Loss: 1.1024e-02 | LR: 1.00e-05
# [Adam] Epoch  7630 | Loss: 1.1024e-02 | LR: 1.00e-05
# [Adam] Epoch  7640 | Loss: 1.1023e-02 | LR: 1.00e-05
# [Adam] Epoch  7650 | Loss: 1.1023e-02 | LR: 1.00e-05
# [Adam] Epoch  7660 | Loss: 1.1023e-02 | LR: 1.00e-05
# [Adam] Epoch  7670 | Loss: 1.1023e-02 | LR: 1.00e-05
# [Adam] Epoch  7680 | Loss: 1.1023e-02 | LR: 1.00e-05
# [Adam] Epoch  7690 | Loss: 1.1023e-02 | LR: 1.00e-05
# [Adam] Epoch  7700 | Loss: 1.1023e-02 | LR: 1.00e-05
# [Adam] Epoch  7710 | Loss: 1.1022e-02 | LR: 1.00e-05
# [Adam] Epoch  7720 | Loss: 1.1022e-02 | LR: 1.00e-05
# [Adam] Epoch  7730 | Loss: 1.1022e-02 | LR: 1.00e-05
# [Adam] Epoch  7740 | Loss: 1.1022e-02 | LR: 1.00e-05
# [Adam] Epoch  7750 | Loss: 1.1022e-02 | LR: 1.00e-05
# [Adam] Epoch  7760 | Loss: 1.1022e-02 | LR: 1.00e-05
# [Adam] Epoch  7770 | Loss: 1.1021e-02 | LR: 1.00e-05
# [Adam] Epoch  7780 | Loss: 1.1021e-02 | LR: 1.00e-05
# [Adam] Epoch  7790 | Loss: 1.1021e-02 | LR: 1.00e-05
# [Adam] Epoch  7800 | Loss: 1.1021e-02 | LR: 1.00e-05
# [Adam] Epoch  7810 | Loss: 1.1021e-02 | LR: 1.00e-05
# [Adam] Epoch  7820 | Loss: 1.1021e-02 | LR: 1.00e-05
# [Adam] Epoch  7830 | Loss: 1.1021e-02 | LR: 1.00e-05
# [Adam] Epoch  7840 | Loss: 1.1020e-02 | LR: 1.00e-05
# [Adam] Epoch  7850 | Loss: 1.1020e-02 | LR: 1.00e-05
# [Adam] Epoch  7860 | Loss: 1.1020e-02 | LR: 1.00e-05
# [Adam] Epoch  7870 | Loss: 1.1020e-02 | LR: 1.00e-05
# [Adam] Epoch  7880 | Loss: 1.1020e-02 | LR: 1.00e-05
# [Adam] Epoch  7890 | Loss: 1.1020e-02 | LR: 1.00e-05
# [Adam] Epoch  7900 | Loss: 1.1020e-02 | LR: 1.00e-05
# [Adam] Epoch  7910 | Loss: 1.1019e-02 | LR: 1.00e-05
# [Adam] Epoch  7920 | Loss: 1.1019e-02 | LR: 1.00e-05
# [Adam] Epoch  7930 | Loss: 1.1019e-02 | LR: 1.00e-05
# [Adam] Epoch  7940 | Loss: 1.1019e-02 | LR: 1.00e-05
# [Adam] Epoch  7950 | Loss: 1.1019e-02 | LR: 1.00e-05
# [Adam] Epoch  7960 | Loss: 1.1019e-02 | LR: 1.00e-05
# [Adam] Epoch  7970 | Loss: 1.1019e-02 | LR: 1.00e-05
# [Adam] Epoch  7980 | Loss: 1.1018e-02 | LR: 1.00e-05
# [Adam] Epoch  7990 | Loss: 1.1018e-02 | LR: 1.00e-05
# [Adam] Epoch  8000 | Loss: 1.1018e-02 | LR: 1.00e-05
# [Adam] Epoch  8010 | Loss: 1.1018e-02 | LR: 1.00e-05
# [Adam] Epoch  8020 | Loss: 1.1018e-02 | LR: 1.00e-05
# [Adam] Epoch  8030 | Loss: 1.1018e-02 | LR: 1.00e-05
# [Adam] Epoch  8040 | Loss: 1.1018e-02 | LR: 1.00e-05
# [Adam] Epoch  8050 | Loss: 1.1017e-02 | LR: 1.00e-05
# [Adam] Epoch  8060 | Loss: 1.1017e-02 | LR: 1.00e-05
# [Adam] Epoch  8070 | Loss: 1.1017e-02 | LR: 1.00e-05
# [Adam] Epoch  8080 | Loss: 1.1017e-02 | LR: 1.00e-05
# [Adam] Epoch  8090 | Loss: 1.1017e-02 | LR: 1.00e-05
# [Adam] Epoch  8100 | Loss: 1.1017e-02 | LR: 1.00e-05
# [Adam] Epoch  8110 | Loss: 1.1017e-02 | LR: 1.00e-05
# [Adam] Epoch  8120 | Loss: 1.1016e-02 | LR: 1.00e-05
# [Adam] Epoch  8130 | Loss: 1.1016e-02 | LR: 1.00e-05
# [Adam] Epoch  8140 | Loss: 1.1016e-02 | LR: 1.00e-05
# [Adam] Epoch  8150 | Loss: 1.1016e-02 | LR: 1.00e-05
# [Adam] Epoch  8160 | Loss: 1.1016e-02 | LR: 1.00e-05
# [Adam] Epoch  8170 | Loss: 1.1016e-02 | LR: 1.00e-05
# [Adam] Epoch  8180 | Loss: 1.1016e-02 | LR: 1.00e-05
# [Adam] Epoch  8190 | Loss: 1.1015e-02 | LR: 1.00e-05
# [Adam] Epoch  8200 | Loss: 1.1015e-02 | LR: 1.00e-05
# [Adam] Epoch  8210 | Loss: 1.1015e-02 | LR: 1.00e-05
# [Adam] Epoch  8220 | Loss: 1.1015e-02 | LR: 1.00e-05
# [Adam] Epoch  8230 | Loss: 1.1015e-02 | LR: 1.00e-05
# [Adam] Epoch  8240 | Loss: 1.1015e-02 | LR: 1.00e-05
# [Adam] Epoch  8250 | Loss: 1.1015e-02 | LR: 1.00e-05
# [Adam] Epoch  8260 | Loss: 1.1014e-02 | LR: 1.00e-05
# [Adam] Epoch  8270 | Loss: 1.1014e-02 | LR: 1.00e-05
# [Adam] Epoch  8280 | Loss: 1.1014e-02 | LR: 1.00e-05
# [Adam] Epoch  8290 | Loss: 1.1014e-02 | LR: 1.00e-05
# [Adam] Epoch  8300 | Loss: 1.1014e-02 | LR: 1.00e-05
# [Adam] Epoch  8310 | Loss: 1.1014e-02 | LR: 1.00e-05
# [Adam] Epoch  8320 | Loss: 1.1013e-02 | LR: 1.00e-05
# [Adam] Epoch  8330 | Loss: 1.1013e-02 | LR: 1.00e-05
# [Adam] Epoch  8340 | Loss: 1.1013e-02 | LR: 1.00e-05
# [Adam] Epoch  8350 | Loss: 1.1013e-02 | LR: 1.00e-05
# [Adam] Epoch  8360 | Loss: 1.1013e-02 | LR: 1.00e-05
# [Adam] Epoch  8370 | Loss: 1.1013e-02 | LR: 1.00e-05
# [Adam] Epoch  8380 | Loss: 1.1013e-02 | LR: 1.00e-05
# [Adam] Epoch  8390 | Loss: 1.1013e-02 | LR: 1.00e-05
# [Adam] Epoch  8400 | Loss: 1.1012e-02 | LR: 1.00e-05
# [Adam] Epoch  8410 | Loss: 1.1012e-02 | LR: 1.00e-05
# [Adam] Epoch  8420 | Loss: 1.1012e-02 | LR: 1.00e-05
# [Adam] Epoch  8430 | Loss: 1.1012e-02 | LR: 1.00e-05
# [Adam] Epoch  8440 | Loss: 1.1012e-02 | LR: 1.00e-05
# [Adam] Epoch  8450 | Loss: 1.1012e-02 | LR: 1.00e-05
# [Adam] Epoch  8460 | Loss: 1.1012e-02 | LR: 1.00e-05
# [Adam] Epoch  8470 | Loss: 1.1011e-02 | LR: 1.00e-05
# [Adam] Epoch  8480 | Loss: 1.1011e-02 | LR: 1.00e-05
# [Adam] Epoch  8490 | Loss: 1.1011e-02 | LR: 1.00e-05
# [Adam] Epoch  8500 | Loss: 1.1011e-02 | LR: 1.00e-05
# [Adam] Epoch  8510 | Loss: 1.1011e-02 | LR: 1.00e-05
# [Adam] Epoch  8520 | Loss: 1.1011e-02 | LR: 1.00e-05
# [Adam] Epoch  8530 | Loss: 1.1011e-02 | LR: 1.00e-05
# [Adam] Epoch  8540 | Loss: 1.1010e-02 | LR: 1.00e-05
# [Adam] Epoch  8550 | Loss: 1.1010e-02 | LR: 1.00e-05
# [Adam] Epoch  8560 | Loss: 1.1010e-02 | LR: 1.00e-05
# [Adam] Epoch  8570 | Loss: 1.1010e-02 | LR: 1.00e-05
# [Adam] Epoch  8580 | Loss: 1.1010e-02 | LR: 1.00e-05
# [Adam] Epoch  8590 | Loss: 1.1010e-02 | LR: 1.00e-05
# [Adam] Epoch  8600 | Loss: 1.1010e-02 | LR: 1.00e-05
# [Adam] Epoch  8610 | Loss: 1.1010e-02 | LR: 1.00e-05
# [Adam] Epoch  8620 | Loss: 1.1009e-02 | LR: 1.00e-05
# [Adam] Epoch  8630 | Loss: 1.1009e-02 | LR: 1.00e-05
# [Adam] Epoch  8640 | Loss: 1.1009e-02 | LR: 1.00e-05
# [Adam] Epoch  8650 | Loss: 1.1009e-02 | LR: 1.00e-05
# [Adam] Epoch  8660 | Loss: 1.1009e-02 | LR: 1.00e-05
# [Adam] Epoch  8670 | Loss: 1.1009e-02 | LR: 1.00e-05
# [Adam] Epoch  8680 | Loss: 1.1009e-02 | LR: 1.00e-05
# [Adam] Epoch  8690 | Loss: 1.1009e-02 | LR: 1.00e-05
# [Adam] Epoch  8700 | Loss: 1.1008e-02 | LR: 1.00e-05
# [Adam] Epoch  8710 | Loss: 1.1008e-02 | LR: 1.00e-05
# [Adam] Epoch  8720 | Loss: 1.1008e-02 | LR: 1.00e-05
# [Adam] Epoch  8730 | Loss: 1.1008e-02 | LR: 1.00e-05
# [Adam] Epoch  8740 | Loss: 1.1008e-02 | LR: 1.00e-05
# [Adam] Epoch  8750 | Loss: 1.1008e-02 | LR: 1.00e-05
# [Adam] Epoch  8760 | Loss: 1.1008e-02 | LR: 1.00e-05
# [Adam] Epoch  8770 | Loss: 1.1007e-02 | LR: 1.00e-05
# [Adam] Epoch  8780 | Loss: 1.1007e-02 | LR: 1.00e-05
# [Adam] Epoch  8790 | Loss: 1.1007e-02 | LR: 1.00e-05
# [Adam] Epoch  8800 | Loss: 1.1007e-02 | LR: 1.00e-05
# [Adam] Epoch  8810 | Loss: 1.1007e-02 | LR: 1.00e-05
# [Adam] Epoch  8820 | Loss: 1.1007e-02 | LR: 1.00e-05
# [Adam] Epoch  8830 | Loss: 1.1007e-02 | LR: 1.00e-05
# [Adam] Epoch  8840 | Loss: 1.1006e-02 | LR: 1.00e-05
# [Adam] Epoch  8850 | Loss: 1.1006e-02 | LR: 1.00e-05
# [Adam] Epoch  8860 | Loss: 1.1006e-02 | LR: 1.00e-05
# [Adam] Epoch  8870 | Loss: 1.1006e-02 | LR: 1.00e-05
# [Adam] Epoch  8880 | Loss: 1.1006e-02 | LR: 1.00e-05
# [Adam] Epoch  8890 | Loss: 1.1006e-02 | LR: 1.00e-05
# [Adam] Epoch  8900 | Loss: 1.1006e-02 | LR: 1.00e-05
# [Adam] Epoch  8910 | Loss: 1.1006e-02 | LR: 1.00e-05
# [Adam] Epoch  8920 | Loss: 1.1005e-02 | LR: 1.00e-05
# [Adam] Epoch  8930 | Loss: 1.1005e-02 | LR: 1.00e-05
# [Adam] Epoch  8940 | Loss: 1.1005e-02 | LR: 1.00e-05
# [Adam] Epoch  8950 | Loss: 1.1005e-02 | LR: 1.00e-05
# [Adam] Epoch  8960 | Loss: 1.1005e-02 | LR: 1.00e-05
# [Adam] Epoch  8970 | Loss: 1.1005e-02 | LR: 1.00e-05
# [Adam] Epoch  8980 | Loss: 1.1005e-02 | LR: 1.00e-05
# [Adam] Epoch  8990 | Loss: 1.1004e-02 | LR: 1.00e-05
# [Adam] Epoch  9000 | Loss: 1.1004e-02 | LR: 1.00e-05
# [Adam] Epoch  9010 | Loss: 1.1004e-02 | LR: 1.00e-05
# [Adam] Epoch  9020 | Loss: 1.1004e-02 | LR: 1.00e-05
# [Adam] Epoch  9030 | Loss: 1.1004e-02 | LR: 1.00e-05
# ...
# [Adam] Epoch 11920 | Loss: 1.0901e-02 | LR: 5.00e-06
# [Adam] Epoch 11930 | Loss: 1.0901e-02 | LR: 5.00e-06
# [Adam] Epoch 11940 | Loss: 1.0901e-02 | LR: 5.00e-06
# [Adam] Epoch 11950 | Loss: 1.0901e-02 | LR: 5.00e-06
# [Adam] Epoch 11960 | Loss: 1.0901e-02 | LR: 5.00e-06
# [Adam] Epoch 11970 | Loss: 1.0901e-02 | LR: 5.00e-06
# [Adam] Epoch 11980 | Loss: 1.0900e-02 | LR: 5.00e-06
# [Adam] Epoch 11990 | Loss: 1.0900e-02 | LR: 5.00e-06
# [Adam] Epoch 12000 | Loss: 1.0900e-02 | LR: 5.00e-06
# [Adam] Epoch 12010 | Loss: 1.0900e-02 | LR: 5.00e-06
# [Adam] Epoch 12020 | Loss: 1.0900e-02 | LR: 5.00e-06
# [Adam] Epoch 12030 | Loss: 1.0900e-02 | LR: 5.00e-06
# [Adam] Epoch 12040 | Loss: 1.0899e-02 | LR: 5.00e-06
# [Adam] Epoch 12050 | Loss: 1.0899e-02 | LR: 5.00e-06
# [Adam] Epoch 12060 | Loss: 1.0899e-02 | LR: 5.00e-06
# [Adam] Epoch 12070 | Loss: 1.0899e-02 | LR: 5.00e-06
# [Adam] Epoch 12080 | Loss: 1.0899e-02 | LR: 5.00e-06
# [Adam] Epoch 12090 | Loss: 1.0899e-02 | LR: 5.00e-06
# [Adam] Epoch 12100 | Loss: 1.0898e-02 | LR: 5.00e-06
# [Adam] Epoch 12110 | Loss: 1.0898e-02 | LR: 5.00e-06
# [Adam] Epoch 12120 | Loss: 1.0898e-02 | LR: 5.00e-06
# [Adam] Epoch 12130 | Loss: 1.0898e-02 | LR: 5.00e-06
# [Adam] Epoch 12140 | Loss: 1.0898e-02 | LR: 5.00e-06
# [Adam] Epoch 12150 | Loss: 1.0898e-02 | LR: 5.00e-06
# [Adam] Epoch 12160 | Loss: 1.0898e-02 | LR: 5.00e-06
# [Adam] Epoch 12170 | Loss: 1.0897e-02 | LR: 5.00e-06
# [Adam] Epoch 12180 | Loss: 1.0897e-02 | LR: 5.00e-06
# [Adam] Epoch 12190 | Loss: 1.0897e-02 | LR: 5.00e-06
# [Adam] Epoch 12200 | Loss: 1.0897e-02 | LR: 5.00e-06
# [Adam] Epoch 12210 | Loss: 1.0897e-02 | LR: 5.00e-06
# [Adam] Epoch 12220 | Loss: 1.0897e-02 | LR: 5.00e-06
# [Adam] Epoch 12230 | Loss: 1.0897e-02 | LR: 5.00e-06
# [Adam] Epoch 12240 | Loss: 1.0896e-02 | LR: 5.00e-06
# [Adam] Epoch 12250 | Loss: 1.0896e-02 | LR: 5.00e-06
# [Adam] Epoch 12260 | Loss: 1.0896e-02 | LR: 5.00e-06
# [Adam] Epoch 12270 | Loss: 1.0896e-02 | LR: 5.00e-06
# [Adam] Epoch 12280 | Loss: 1.0896e-02 | LR: 5.00e-06
# [Adam] Epoch 12290 | Loss: 1.0896e-02 | LR: 5.00e-06
# [Adam] Epoch 12300 | Loss: 1.0895e-02 | LR: 5.00e-06
# [Adam] Epoch 12310 | Loss: 1.0895e-02 | LR: 5.00e-06
# [Adam] Epoch 12320 | Loss: 1.0895e-02 | LR: 5.00e-06
# [Adam] Epoch 12330 | Loss: 1.0895e-02 | LR: 5.00e-06
# [Adam] Epoch 12340 | Loss: 1.0895e-02 | LR: 5.00e-06
# [Adam] Epoch 12350 | Loss: 1.0895e-02 | LR: 5.00e-06
# [Adam] Epoch 12360 | Loss: 1.0895e-02 | LR: 5.00e-06
# [Adam] Epoch 12370 | Loss: 1.0895e-02 | LR: 5.00e-06
# [Adam] Epoch 12380 | Loss: 1.0894e-02 | LR: 5.00e-06
# [Adam] Epoch 12390 | Loss: 1.0894e-02 | LR: 5.00e-06
# [Adam] Epoch 12400 | Loss: 1.0894e-02 | LR: 5.00e-06
# [Adam] Epoch 12410 | Loss: 1.0894e-02 | LR: 5.00e-06
# [Adam] Epoch 12420 | Loss: 1.0894e-02 | LR: 5.00e-06
# [Adam] Epoch 12430 | Loss: 1.0894e-02 | LR: 5.00e-06
# [Adam] Epoch 12440 | Loss: 1.0894e-02 | LR: 5.00e-06
# [Adam] Epoch 12450 | Loss: 1.0894e-02 | LR: 5.00e-06
# [Adam] Epoch 12460 | Loss: 1.0893e-02 | LR: 5.00e-06
# [Adam] Epoch 12470 | Loss: 1.0893e-02 | LR: 5.00e-06
# [Adam] Epoch 12480 | Loss: 1.0893e-02 | LR: 5.00e-06
# [Adam] Epoch 12490 | Loss: 1.0893e-02 | LR: 5.00e-06
# [Adam] Epoch 12500 | Loss: 1.0893e-02 | LR: 5.00e-06
# [Adam] Epoch 12510 | Loss: 1.0893e-02 | LR: 5.00e-06
# [Adam] Epoch 12520 | Loss: 1.0893e-02 | LR: 5.00e-06
# [Adam] Epoch 12530 | Loss: 1.0893e-02 | LR: 5.00e-06
# [Adam] Epoch 12540 | Loss: 1.0892e-02 | LR: 5.00e-06
# [Adam] Epoch 12550 | Loss: 1.0892e-02 | LR: 5.00e-06
# [Adam] Epoch 12560 | Loss: 1.0892e-02 | LR: 5.00e-06
# [Adam] Epoch 12570 | Loss: 1.0892e-02 | LR: 5.00e-06
# [Adam] Epoch 12580 | Loss: 1.0892e-02 | LR: 5.00e-06
# [Adam] Epoch 12590 | Loss: 1.0892e-02 | LR: 5.00e-06
# [Adam] Epoch 12600 | Loss: 1.0892e-02 | LR: 5.00e-06
# [Adam] Epoch 12610 | Loss: 1.0892e-02 | LR: 5.00e-06
# [Adam] Epoch 12620 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12630 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12640 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12650 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12660 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12670 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12680 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12690 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12700 | Loss: 1.0891e-02 | LR: 5.00e-06
# [Adam] Epoch 12710 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12720 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12730 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12740 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12750 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12760 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12770 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12780 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12790 | Loss: 1.0890e-02 | LR: 5.00e-06
# [Adam] Epoch 12800 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12810 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12820 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12830 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12840 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12850 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12860 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12870 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12880 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12890 | Loss: 1.0889e-02 | LR: 5.00e-06
# [Adam] Epoch 12900 | Loss: 1.0888e-02 | LR: 5.00e-06
# [Adam] Epoch 12910 | Loss: 1.0888e-02 | LR: 5.00e-06
# [Adam] Epoch 12920 | Loss: 1.0888e-02 | LR: 5.00e-06
# [Adam] Epoch 12930 | Loss: 1.0888e-02 | LR: 5.00e-06
# [Adam] Epoch 12940 | Loss: 1.0888e-02 | LR: 5.00e-06
# [Adam] Epoch 12950 | Loss: 1.0888e-02 | LR: 5.00e-06
# [Adam] Epoch 12960 | Loss: 1.0888e-02 | LR: 5.00e-06
# [Adam] Epoch 12970 | Loss: 1.0888e-02 | LR: 5.00e-06
# [Adam] Epoch 12980 | Loss: 1.0860e-02 | LR: 2.50e-06
# [Adam] Epoch 12990 | Loss: 1.0859e-02 | LR: 2.50e-06
# [Adam] Epoch 13000 | Loss: 1.0859e-02 | LR: 2.50e-06
# [Adam] Epoch 13010 | Loss: 1.0858e-02 | LR: 2.50e-06
# [Adam] Epoch 13020 | Loss: 1.0858e-02 | LR: 2.50e-06
# [Adam] Epoch 13030 | Loss: 1.0857e-02 | LR: 2.50e-06
# [Adam] Epoch 13040 | Loss: 1.0857e-02 | LR: 2.50e-06
# [Adam] Epoch 13050 | Loss: 1.0857e-02 | LR: 2.50e-06
# [Adam] Epoch 13060 | Loss: 1.0857e-02 | LR: 2.50e-06
# [Adam] Epoch 13070 | Loss: 1.0856e-02 | LR: 2.50e-06
# [Adam] Epoch 13080 | Loss: 1.0856e-02 | LR: 2.50e-06
# [Adam] Epoch 13090 | Loss: 1.0856e-02 | LR: 2.50e-06
# [Adam] Epoch 13100 | Loss: 1.0856e-02 | LR: 2.50e-06
# [Adam] Epoch 13110 | Loss: 1.0855e-02 | LR: 2.50e-06
# [Adam] Epoch 13120 | Loss: 1.0855e-02 | LR: 2.50e-06
# [Adam] Epoch 13130 | Loss: 1.0855e-02 | LR: 2.50e-06
# [Adam] Epoch 13140 | Loss: 1.0855e-02 | LR: 2.50e-06
# [Adam] Epoch 13150 | Loss: 1.0855e-02 | LR: 2.50e-06
# [Adam] Epoch 13160 | Loss: 1.0854e-02 | LR: 2.50e-06
# [Adam] Epoch 13170 | Loss: 1.0854e-02 | LR: 2.50e-06
# [Adam] Epoch 13180 | Loss: 1.0854e-02 | LR: 2.50e-06
# [Adam] Epoch 13190 | Loss: 1.0854e-02 | LR: 2.50e-06
# [Adam] Epoch 13200 | Loss: 1.0854e-02 | LR: 2.50e-06
# [Adam] Epoch 13210 | Loss: 1.0854e-02 | LR: 2.50e-06
# [Adam] Epoch 13220 | Loss: 1.0853e-02 | LR: 2.50e-06
# [Adam] Epoch 13230 | Loss: 1.0853e-02 | LR: 2.50e-06
# [Adam] Epoch 13240 | Loss: 1.0853e-02 | LR: 2.50e-06
# [Adam] Epoch 13250 | Loss: 1.0853e-02 | LR: 2.50e-06
# [Adam] Epoch 13260 | Loss: 1.0853e-02 | LR: 2.50e-06
# [Adam] Epoch 13270 | Loss: 1.0853e-02 | LR: 2.50e-06
# [Adam] Epoch 13280 | Loss: 1.0853e-02 | LR: 2.50e-06
# [Adam] Epoch 13290 | Loss: 1.0852e-02 | LR: 2.50e-06
# [Adam] Epoch 13300 | Loss: 1.0852e-02 | LR: 2.50e-06
# [Adam] Epoch 13310 | Loss: 1.0852e-02 | LR: 2.50e-06
# [Adam] Epoch 13320 | Loss: 1.0852e-02 | LR: 2.50e-06
# [Adam] Epoch 13330 | Loss: 1.0852e-02 | LR: 2.50e-06
# [Adam] Epoch 13340 | Loss: 1.0852e-02 | LR: 2.50e-06
# [Adam] Epoch 13350 | Loss: 1.0852e-02 | LR: 2.50e-06
# [Adam] Epoch 13360 | Loss: 1.0852e-02 | LR: 2.50e-06
# [Adam] Epoch 13370 | Loss: 1.0851e-02 | LR: 2.50e-06
# [Adam] Epoch 13380 | Loss: 1.0851e-02 | LR: 2.50e-06
# [Adam] Epoch 13390 | Loss: 1.0851e-02 | LR: 2.50e-06
# [Adam] Epoch 13400 | Loss: 1.0851e-02 | LR: 2.50e-06
# [Adam] Epoch 13410 | Loss: 1.0851e-02 | LR: 2.50e-06
# [Adam] Epoch 13420 | Loss: 1.0851e-02 | LR: 2.50e-06
# [Adam] Epoch 13430 | Loss: 1.0851e-02 | LR: 2.50e-06
# [Adam] Epoch 13440 | Loss: 1.0851e-02 | LR: 2.50e-06
# [Adam] Epoch 13450 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13460 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13470 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13480 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13490 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13500 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13510 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13520 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13530 | Loss: 1.0850e-02 | LR: 2.50e-06
# [Adam] Epoch 13540 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13550 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13560 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13570 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13580 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13590 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13600 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13610 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13620 | Loss: 1.0849e-02 | LR: 2.50e-06
# [Adam] Epoch 13630 | Loss: 1.0848e-02 | LR: 2.50e-06
# [Adam] Epoch 13640 | Loss: 1.0848e-02 | LR: 2.50e-06
# [Adam] Epoch 13650 | Loss: 1.0833e-02 | LR: 1.25e-06
# [Adam] Epoch 13660 | Loss: 1.0833e-02 | LR: 1.25e-06
# [Adam] Epoch 13670 | Loss: 1.0833e-02 | LR: 1.25e-06
# [Adam] Epoch 13680 | Loss: 1.0833e-02 | LR: 1.25e-06
# [Adam] Epoch 13690 | Loss: 1.0833e-02 | LR: 1.25e-06
# [Adam] Epoch 13700 | Loss: 1.0833e-02 | LR: 1.25e-06
# [Adam] Epoch 13710 | Loss: 1.0832e-02 | LR: 1.25e-06
# [Adam] Epoch 13720 | Loss: 1.0832e-02 | LR: 1.25e-06
# [Adam] Epoch 13730 | Loss: 1.0832e-02 | LR: 1.25e-06
# [Adam] Epoch 13740 | Loss: 1.0832e-02 | LR: 1.25e-06
# [Adam] Epoch 13750 | Loss: 1.0832e-02 | LR: 1.25e-06
# [Adam] Epoch 13760 | Loss: 1.0832e-02 | LR: 1.25e-06
# [Adam] Epoch 13770 | Loss: 1.0832e-02 | LR: 1.25e-06
# [Adam] Epoch 13780 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13790 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13800 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13810 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13820 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13830 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13840 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13850 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13860 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13870 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13880 | Loss: 1.0831e-02 | LR: 1.25e-06
# [Adam] Epoch 13890 | Loss: 1.0830e-02 | LR: 1.25e-06
# [Adam] Epoch 13900 | Loss: 1.0830e-02 | LR: 1.25e-06
# [Adam] Epoch 13910 | Loss: 1.0830e-02 | LR: 1.25e-06
# [Adam] Epoch 13920 | Loss: 1.0830e-02 | LR: 1.25e-06
# [Adam] Epoch 13930 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 13940 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 13950 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 13960 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 13970 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 13980 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 13990 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 14000 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 14010 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 14020 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 14030 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 14040 | Loss: 1.0822e-02 | LR: 6.25e-07
# [Adam] Epoch 14050 | Loss: 1.0821e-02 | LR: 6.25e-07
# [Adam] Epoch 14060 | Loss: 1.0821e-02 | LR: 6.25e-07
# [Adam] Epoch 14070 | Loss: 1.0821e-02 | LR: 6.25e-07
# [Adam] Epoch 14080 | Loss: 1.0821e-02 | LR: 6.25e-07
# [Adam] Epoch 14090 | Loss: 1.0821e-02 | LR: 6.25e-07
# [Adam] Epoch 14100 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14110 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14120 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14130 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14140 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14150 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14160 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14170 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14180 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14190 | Loss: 1.0817e-02 | LR: 3.13e-07
# [Adam] Epoch 14200 | Loss: 1.0817e-02 | LR: 1.56e-07
# [Adam] Epoch 14210 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14220 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14230 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14240 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14250 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14260 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14270 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14280 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14290 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14300 | Loss: 1.0814e-02 | LR: 1.56e-07
# [Adam] Epoch 14310 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14320 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14330 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14340 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14350 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14360 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14370 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14380 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14390 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14400 | Loss: 1.0813e-02 | LR: 7.81e-08
# [Adam] Epoch 14410 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14420 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14430 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14440 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14450 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14460 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14470 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14480 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14490 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14500 | Loss: 1.0812e-02 | LR: 3.91e-08
# [Adam] Epoch 14510 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14520 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14530 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14540 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14550 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14560 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14570 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14580 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14590 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14600 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14610 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14620 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14630 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14640 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14650 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14660 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14670 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14680 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14690 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14700 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14710 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14720 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14730 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14740 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14750 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14760 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14770 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14780 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14790 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14800 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14810 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14820 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14830 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14840 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14850 | Loss: 1.0812e-02 | LR: 1.95e-08
# [Adam] Epoch 14860 | Loss: 1.0812e-02 | LR: 1.95e-08
# Early stopping triggered at epoch 14864
# Best model saved with loss 1.0812e-02 at epoch 14764
# [Test Evaluation] k=10, hd=1000, Adam LR=1e-05, BS=1024 → h=25: 0.061667 ± 0.000123, h=50: 0.100889 ± 0.000494, h=75: 0.156199 ± 0.001140, h=100: 0.229122 ± 0.001844
#
# === Final Results Summary ===
# Optimal config used: k=10, m=10000, hd=1000, lr=1e-05, bs=1024

# %%
# ============================================================
# Reload Fixed Best Model (Manual Parameters)
# ============================================================
model_path = model_path = f"model_k{k}_m{m}_hd{hidden_dim}_adam{lr_adam}_bs{batch_size}.pth"
best_model = AdaptiveNVARModel(dk=dk, m=m, d=d, hidden_dim=hidden_dim).to(device)
best_model.load_state_dict(torch.load(model_path, map_location=device))
best_model.eval()

all_preds, all_true, all_noisy = [], [], []

# ------------------------------------------------------------
# Rollout predictions across windows
# ------------------------------------------------------------
for w in range(num_windows):
    start, end = w * window_size, (w + 1) * window_size
    X_test_true_window = X_test_true[start:end]
    X_test_noisy_window = X_test[start:end]

    # Initialization with last k noisy points
    init_start = warmup_len + train_len + val_len + start - k
    init_end   = warmup_len + train_len + val_len + start
    X_init = X[init_start:init_end].to(device)

    x_t = [x.clone() for x in X_init.unbind(0)]
    H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

    predictions = []
    for _ in range(window_size):
        with torch.no_grad():
            delta_x = best_model(H_lin)
        x_next = x_t[-1] + delta_x.squeeze(0)
        predictions.append(x_next)

        # Update autoregressive state
        x_t = x_t[1:] + [x_next]
        H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

    all_preds.append(torch.stack(predictions).cpu().numpy())
    all_true.append(X_test_true_window.cpu().numpy())
    all_noisy.append(X_test_noisy_window.cpu().numpy())

# ------------------------------------------------------------
# Concatenate results
# ------------------------------------------------------------
y_pred = np.concatenate(all_preds)
y_true = np.concatenate(all_true)
y_noisy = np.concatenate(all_noisy)

# %%
# ============================================================
# Visualization (per variable) - First 10 windows, subset of variables
# ============================================================

max_windows_to_plot = min(10, num_windows)  # plot at most 10 windows
end_idx = max_windows_to_plot * window_size

# Slice arrays to avoid oversized figure rendering
y_true_plot = y_true[:end_idx]
y_noisy_plot = y_noisy[:end_idx]
y_pred_plot = y_pred[:end_idx]

# Limit to first 5 variables for readability
max_vars_to_plot = min(5, y_true.shape[1])
variables = [f"x_{i+1}" for i in range(max_vars_to_plot)]

fig, axes = plt.subplots(max_vars_to_plot, 1, figsize=(16, 3 * max_vars_to_plot), sharex=True)

if max_vars_to_plot == 1:
    axes = [axes]  # make iterable

for i, ax in enumerate(axes):
    # Ground truth
    ax.plot(y_true_plot[:, i], label="Ground Truth (Clean)", color="red", linestyle=":", linewidth=0.9)

    # Noisy observations
    ax.plot(y_noisy_plot[:, i], label=f"Noisy Validation Data ({dataset_noise_scale*100:.0f}%)",
            color="black", linewidth=1.0, alpha=1.0)

    # Predictions
    ax.plot(y_pred_plot[:, i], label="Adaptive NVAR Prediction", color="green", linewidth=1.2)

    # Mark window boundaries
    for w in range(1, max_windows_to_plot):
        ax.axvline(w * window_size, color="gray", linestyle="dotted", linewidth=0.8)

    # Label windows at the center
    ylim = ax.get_ylim()
    for w in range(max_windows_to_plot):
        center = w * window_size + window_size // 2
        ax.text(center, ylim[1] * 1.02, f"Window {w+1}",
                ha="center", va="bottom", fontsize=9, color="blue")

    ax.set_ylabel(f"$x_{{{i+1}}}$", fontsize=12)
    ax.grid(alpha=0.3)
    ax.legend(loc="upper right")

axes[-1].set_xlabel("Time", fontsize=12)
fig.suptitle("Test Predictions vs Ground Truth vs Noisy Data (First 10 Windows, First 5 Variables)", fontsize=14, y=0.95)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.xlim(0, end_idx)

# Save and show
filename = f"Test_pred_vs_truth_k{k}_hd{hidden_dim_grid}_noise{dataset_noise_scale:.2f}_first10_vars5.png"
plt.savefig(filename, dpi=300, bbox_inches="tight")
plt.show()
print(f"Saved plot as: {filename}")
# Out:
# Saved plot as: Test_pred_vs_truth_k10_hd[1000]_noise0.10_first10_vars5.png
