# %% [markdown]
# # Adaptive Nonlinear Vector Autoregression: Robust Forecasting for Noisy Chaotic Time Series
# ## Author
# - **Name**: Azimov Sherkhon Azizkhon Ugli
# - **Email**: sherxonazimov94@pusan.ac.kr
# - **GitHub**: @AzimovSherkhon
#
# Method: **Adaptive Nonlinear Vector Autoregression**
#
# Code: Prediction on unseen test data
#
# Best Config Found: \
# k=10, hidden_dim=1000, Adam LR=1e-05

# %%
# ============================================================
# Imports & Setup
# ============================================================
import torch
import warnings
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset

# Torch defaults
torch.set_default_dtype(torch.float32)

# ----------------------------
# Device setup (choose GPU 0)
# ----------------------------
if torch.cuda.is_available():
    torch.cuda.set_device(0)   # pick GPU 0
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")

print(f"Device in use: {device}")
if device.type == "cuda":
    print(f"CUDA device: {torch.cuda.current_device()} - {torch.cuda.get_device_name(device)}")

# Suppress unnecessary warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Device in use: cuda:0
# CUDA device: 0 - A100-PCIE-40GB

# %%
# ============================================================
# Load Lorenz 96 Clean Data
# ============================================================
data = np.load("lorenz96_100_noise_0.npy", allow_pickle=True).item()
l96_data = data["data"]   # (100, 1000001)
meta = data["meta"]   # dict with warmup/train/val/test/mean/std
l96 = l96_data.T
print(l96.shape)

# ============================================================
# Visualization: First 10 Variables of Lorenz '96
# ============================================================
plt.figure(figsize=(16, 12))
num_vars_to_plot = 10
time = np.arange(l96.shape[0])

for i in range(num_vars_to_plot):
    plt.subplot(num_vars_to_plot, 1, i + 1)
    plt.plot(time, l96[:, i], label=f'Variable {i+1}', color=f'C{i % 10}')
    plt.ylabel(f'x{i+1}')
    plt.grid(True)
    if i == 0:
        plt.title("Lorenz '96: First 10 variables (Clean data)")
    if i == num_vars_to_plot - 1:
        plt.xlabel('Time')
    plt.legend()
    plt.xlim(0, 2000)  

plt.tight_layout()
plt.show()
# Out:
# (500000, 100)

# %%
# ============================================================
# Reproducibility
# ============================================================
seed = 2025
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


# ============================================================
# # Load Lorenz 63 Noisy Data
# ============================================================
# Measurement noise (applied globally to dataset)
dataset_noise_scale = 0.0
data_noisy = np.load("lorenz96_100_noise_0.npy", allow_pickle=True).item()
X_noisy_dataset = data_noisy["data"]   # (3, 5001)
meta_noise = data_noisy["meta"]   # dict with warmup/train/val/test/mean/std
X_noisy_dataset = X_noisy_dataset.T

# ============================================================
# Visualization: First 10 Variables of Lorenz '96
# ============================================================
plt.figure(figsize=(16, 12))
num_vars_to_plot = 10
time = np.arange(l96.shape[0])

for i in range(num_vars_to_plot):
    plt.subplot(num_vars_to_plot, 1, i + 1)
    plt.plot(time, X_noisy_dataset[:, i], label=f'Variable {i+1}', color=f'C{i % 10}')
    plt.ylabel(f'x{i+1}')
    plt.grid(True)
    if i == 0:
        plt.title("Lorenz '96: First 10 variables (Noisy data)")
    if i == num_vars_to_plot - 1:
        plt.xlabel('Time')
    plt.legend()
    plt.xlim(0, 2000)  

plt.tight_layout()
plt.show()

X = torch.tensor(X_noisy_dataset, dtype=torch.float32)  # noisy input
X_true = torch.tensor(l96, dtype=torch.float32)          # clean reference

# Dataset splits
warmup_len, train_len, val_len, test_len = 1000, 399000, 50000, 50000

X_warmup = X[:warmup_len].to(device)
X_train_clean = X[warmup_len:warmup_len + train_len]
X_val  = X[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test = X[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)

# Ground truth references
X_val_true  = X_true[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test_true = X_true[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)

# Training-time noise (works as a regularization only during training)
train_noise_scale = 0.05  # We only add it for noise free-case
signal_std = X_train_clean.std(dim=0, keepdim=True).cpu().numpy()
train_noise = np.random.normal(0.0, train_noise_scale * signal_std, X_train_clean.shape)
X_train = torch.tensor((X_train_clean.cpu().numpy() + train_noise).astype(np.float32), device=device)

# %%
# ============================================================
# Adaptive NVAR Model
# ============================================================
class FeatureMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)


class AdaptiveNVARModel(nn.Module):
    def __init__(self, dk, m, d, hidden_dim):
        super().__init__()
        self.mlp = FeatureMLP(dk, hidden_dim, m)
        self.readout = nn.Linear(dk + m, d, bias=False)

    def forward(self, H_lin):
        H_nn = self.mlp(H_lin)
        H_total = torch.cat([H_lin, H_nn], dim=1)
        return self.readout(H_total)


# ============================================================
# Helper Functions
# ============================================================
def construct_H_lin(X, k):
    """Constructs delay-embedded features from time series."""
    T = X.shape[0]
    return torch.cat([X[i:T - k + i] for i in range(k)], dim=1)


def init_weights_stable(m):
    """Stable Xavier initialization for linear layers."""
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)
        with torch.no_grad():
            m.weight.mul_(1.0)


# ============================================================
# Training Function (Adam only)
# ============================================================
def train_model_adam_only(
    X, k, m, hidden_dim=200, num_epochs_adam=1000, batch_size=1024,
    save_path="best_joint_model_0percent_noise.pth",
    patience=100, tolerance=1e-8, lr=1e-5, use_amp=False
):
    X = X.to(device)
    H_lin = construct_H_lin(X, k)                 # [n, dk]
    Y = X[k:] - X[k - 1:-1]                       # [n, d]
    n, dk = H_lin.shape
    d = Y.shape[1]

    # Dataset + Dataloader
    dataset = TensorDataset(H_lin, Y)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    # Model: pass hidden_dim
    model = AdaptiveNVARModel(dk=dk, m=m, d=d, hidden_dim=hidden_dim).to(device)
#    # Freeze MLP parameters if needed
#    for param in model.mlp.parameters():
#        param.requires_grad = False

    # Optimizer
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        betas=(0.9, 0.999),
        eps=1e-8,
        weight_decay=0
    )

    # Scheduler (reduces lr when loss plateaus)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, factor=0.5, patience=100
    )

    # AMP scaler
    scaler = torch.cuda.amp.GradScaler(enabled=use_amp)

    adam_losses = []
    best_loss = float('inf')
    epochs_no_improve = 0
    best_model_state = None

    for epoch in range(num_epochs_adam):
        model.train()
        epoch_loss = 0.0

        for H_batch, Y_batch in dataloader:
            H_batch = H_batch.to(device)
            Y_batch = Y_batch.to(device)

            optimizer.zero_grad()

            # Mixed precision forward & backward
            with torch.cuda.amp.autocast(enabled=use_amp):
                Y_hat = model(H_batch)
                loss = F.mse_loss(Y_hat, Y_batch)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            epoch_loss += loss.item() * H_batch.size(0)

        current_loss = epoch_loss / n
        adam_losses.append(current_loss)

        # Step scheduler
        scheduler.step(current_loss)

        if epoch % 10 == 0 or epoch == num_epochs_adam - 1:
            current_lr = optimizer.param_groups[0]['lr']
            print(f"[Adam] Epoch {epoch:5d} | Loss: {current_loss:.4e} | LR: {current_lr:.2e}")

        # Early stopping
        if best_loss - current_loss > tolerance:
            best_loss = current_loss
            best_model_state = model.state_dict()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f"Early stopping triggered at epoch {epoch}")
            break

    # Save best model
    if best_model_state is not None:
        torch.save(best_model_state, save_path)
        print(f"Best model saved with loss {best_loss:.4e} at epoch {epoch - epochs_no_improve}")
    else:
        torch.save(model.state_dict(), save_path)
        print("Model saved (no improvement detected).")

    return model

# %%
# ============================================================ 
# Prediction on Test Data (Adam only)
# ============================================================
k_grid = [10]
hidden_dim_grid = [1000]
adam_lr_grid = [1e-5]
batch_size_grid = [1024]

horizons = [25, 50, 75, 100]

base_seed, num_runs, num_windows = 2025, 5, int(test_len / 100)
d = 100
best_config, best_rmse, all_results = None, float("inf"), []

print("Starting Test Evaluation (Adam only)...\n")

for k in k_grid:
    dk = d * k
    m = int(10 * dk)

    for hidden_dim in hidden_dim_grid:
        for lr_adam in adam_lr_grid:
            for batch_size in batch_size_grid:

                all_run_rmses = {h: [] for h in horizons}

                for run in range(num_runs):
                    seed = base_seed + run
                    torch.manual_seed(seed)
                    torch.cuda.manual_seed_all(seed)
                    torch.backends.cudnn.deterministic = True
                    torch.backends.cudnn.benchmark = False

                    model_path = f"model_k{k}_m{m}_hd{hidden_dim}_adam{lr_adam}_bs{batch_size}.pth"

                    # Load or train model
                    model = train_model_adam_only(
                        X_train, k=k, m=m, hidden_dim=hidden_dim,
                        num_epochs_adam=20000,
                        batch_size=batch_size,
                        lr=lr_adam,
                        save_path=model_path
                    )
                    model.eval()

                    window_size = len(X_test_true) // num_windows
                    horizon_rmses = {h: [] for h in horizons}

                    for w in range(num_windows):
                        start, end = w * window_size, (w + 1) * window_size
                        X_test_true_window = X_test_true[start:end]

                        # Initialization: last k points before this test window
                        init_start = warmup_len + train_len + val_len + start - k
                        init_end   = warmup_len + train_len + val_len + start
                        X_init = X[init_start:init_end].to(device)

                        x_t = [x.clone() for x in X_init.unbind(0)]
                        H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

                        predictions = []
                        for _ in range(window_size):
                            with torch.no_grad():
                                delta_x = model(H_lin)
                            x_next = x_t[-1] + delta_x.squeeze(0)
                            predictions.append(x_next)
                            x_t = x_t[1:] + [x_next]
                            H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

                        predictions_np = torch.stack(predictions).cpu().numpy()
                        y_true_np = X_test_true_window.cpu().numpy()

                        for h in horizons:
                            if h <= window_size:
                                rmse = np.sqrt(np.mean((y_true_np[:h] - predictions_np[:h]) ** 2))
                                horizon_rmses[h].append(rmse)

                    # Average RMSEs for this run
                    for h in horizons:
                        avg_rmse = np.mean(horizon_rmses[h])
                        all_run_rmses[h].append(avg_rmse)

                # Average over runs
                avg_rmse_horizons = {h: np.mean(all_run_rmses[h]) for h in horizons}
                std_rmse_horizons = {h: np.std(all_run_rmses[h]) for h in horizons}

                print(f"[Test Evaluation] k={k}, hd={hidden_dim}, Adam LR={lr_adam}, BS={batch_size} → " +
                      ", ".join([f"h={h}: {avg_rmse_horizons[h]:.6f} ± {std_rmse_horizons[h]:.6f}"
                                 for h in horizons]))

                all_results.append((k, m, hidden_dim, lr_adam, batch_size, avg_rmse_horizons))

                # Track best result (e.g., horizon=100)
                if avg_rmse_horizons[100] < best_rmse:
                    best_rmse = avg_rmse_horizons[100]
                    best_config = (k, m, hidden_dim, lr_adam, batch_size)

# ============================================================
# Final Best Results
# ============================================================
print("\n=== Final Results Summary ===")
print(f"Optimal config used: k={best_config[0]}, m={best_config[1]}, hd={best_config[2]}, "
      f"lr={best_config[3]}, bs={best_config[4]}")
# Out:
# Starting Test Evaluation (Adam only)...
#
# [Adam] Epoch     0 | Loss: 1.2034e-02 | LR: 1.00e-05
# [Adam] Epoch    10 | Loss: 5.6332e-03 | LR: 1.00e-05
# [Adam] Epoch    20 | Loss: 5.2750e-03 | LR: 1.00e-05
# [Adam] Epoch    30 | Loss: 5.0088e-03 | LR: 1.00e-05
# [Adam] Epoch    40 | Loss: 4.8297e-03 | LR: 1.00e-05
# [Adam] Epoch    50 | Loss: 4.7210e-03 | LR: 1.00e-05
# [Adam] Epoch    60 | Loss: 4.6559e-03 | LR: 1.00e-05
# [Adam] Epoch    70 | Loss: 4.6159e-03 | LR: 1.00e-05
# [Adam] Epoch    80 | Loss: 4.5903e-03 | LR: 1.00e-05
# [Adam] Epoch    90 | Loss: 4.5734e-03 | LR: 1.00e-05
# [Adam] Epoch   100 | Loss: 4.5618e-03 | LR: 1.00e-05
# [Adam] Epoch   110 | Loss: 4.5536e-03 | LR: 1.00e-05
# [Adam] Epoch   120 | Loss: 4.5476e-03 | LR: 1.00e-05
# [Adam] Epoch   130 | Loss: 4.5431e-03 | LR: 1.00e-05
# [Adam] Epoch   140 | Loss: 4.5396e-03 | LR: 1.00e-05
# [Adam] Epoch   150 | Loss: 4.5367e-03 | LR: 1.00e-05
# [Adam] Epoch   160 | Loss: 4.5344e-03 | LR: 1.00e-05
# [Adam] Epoch   170 | Loss: 4.5323e-03 | LR: 1.00e-05
# [Adam] Epoch   180 | Loss: 4.5305e-03 | LR: 1.00e-05
# [Adam] Epoch   190 | Loss: 4.5285e-03 | LR: 1.00e-05
# [Adam] Epoch   200 | Loss: 4.5265e-03 | LR: 1.00e-05
# [Adam] Epoch   210 | Loss: 4.5248e-03 | LR: 1.00e-05
# [Adam] Epoch   220 | Loss: 4.5234e-03 | LR: 1.00e-05
# [Adam] Epoch   230 | Loss: 4.5220e-03 | LR: 1.00e-05
# [Adam] Epoch   240 | Loss: 4.5204e-03 | LR: 1.00e-05
# [Adam] Epoch   250 | Loss: 4.5187e-03 | LR: 1.00e-05
# [Adam] Epoch   260 | Loss: 4.5167e-03 | LR: 1.00e-05
# [Adam] Epoch   270 | Loss: 4.5147e-03 | LR: 1.00e-05
# [Adam] Epoch   280 | Loss: 4.5129e-03 | LR: 1.00e-05
# [Adam] Epoch   290 | Loss: 4.5108e-03 | LR: 1.00e-05
# [Adam] Epoch   300 | Loss: 4.5084e-03 | LR: 1.00e-05
# [Adam] Epoch   310 | Loss: 4.5053e-03 | LR: 1.00e-05
# [Adam] Epoch   320 | Loss: 4.5017e-03 | LR: 1.00e-05
# [Adam] Epoch   330 | Loss: 4.4976e-03 | LR: 1.00e-05
# [Adam] Epoch   340 | Loss: 4.4923e-03 | LR: 1.00e-05
# [Adam] Epoch   350 | Loss: 4.4858e-03 | LR: 1.00e-05
# [Adam] Epoch   360 | Loss: 4.4784e-03 | LR: 1.00e-05
# [Adam] Epoch   370 | Loss: 4.4706e-03 | LR: 1.00e-05
# [Adam] Epoch   380 | Loss: 4.4632e-03 | LR: 1.00e-05
# [Adam] Epoch   390 | Loss: 4.4564e-03 | LR: 1.00e-05
# [Adam] Epoch   400 | Loss: 4.4496e-03 | LR: 1.00e-05
# [Adam] Epoch   410 | Loss: 4.4427e-03 | LR: 1.00e-05
# [Adam] Epoch   420 | Loss: 4.4358e-03 | LR: 1.00e-05
# [Adam] Epoch   430 | Loss: 4.4286e-03 | LR: 1.00e-05
# [Adam] Epoch   440 | Loss: 4.4206e-03 | LR: 1.00e-05
# [Adam] Epoch   450 | Loss: 4.4113e-03 | LR: 1.00e-05
# [Adam] Epoch   460 | Loss: 4.4004e-03 | LR: 1.00e-05
# [Adam] Epoch   470 | Loss: 4.3889e-03 | LR: 1.00e-05
# [Adam] Epoch   480 | Loss: 4.3770e-03 | LR: 1.00e-05
# [Adam] Epoch   490 | Loss: 4.3654e-03 | LR: 1.00e-05
# [Adam] Epoch   500 | Loss: 4.3542e-03 | LR: 1.00e-05
# [Adam] Epoch   510 | Loss: 4.3429e-03 | LR: 1.00e-05
# [Adam] Epoch   520 | Loss: 4.3312e-03 | LR: 1.00e-05
# [Adam] Epoch   530 | Loss: 4.3189e-03 | LR: 1.00e-05
# [Adam] Epoch   540 | Loss: 4.3059e-03 | LR: 1.00e-05
# [Adam] Epoch   550 | Loss: 4.2922e-03 | LR: 1.00e-05
# [Adam] Epoch   560 | Loss: 4.2777e-03 | LR: 1.00e-05
# [Adam] Epoch   570 | Loss: 4.2628e-03 | LR: 1.00e-05
# [Adam] Epoch   580 | Loss: 4.2478e-03 | LR: 1.00e-05
# [Adam] Epoch   590 | Loss: 4.2325e-03 | LR: 1.00e-05
# [Adam] Epoch   600 | Loss: 4.2170e-03 | LR: 1.00e-05
# [Adam] Epoch   610 | Loss: 4.2017e-03 | LR: 1.00e-05
# [Adam] Epoch   620 | Loss: 4.1864e-03 | LR: 1.00e-05
# [Adam] Epoch   630 | Loss: 4.1710e-03 | LR: 1.00e-05
# [Adam] Epoch   640 | Loss: 4.1556e-03 | LR: 1.00e-05
# [Adam] Epoch   650 | Loss: 4.1404e-03 | LR: 1.00e-05
# [Adam] Epoch   660 | Loss: 4.1256e-03 | LR: 1.00e-05
# [Adam] Epoch   670 | Loss: 4.1117e-03 | LR: 1.00e-05
# [Adam] Epoch   680 | Loss: 4.0988e-03 | LR: 1.00e-05
# [Adam] Epoch   690 | Loss: 4.0865e-03 | LR: 1.00e-05
# [Adam] Epoch   700 | Loss: 4.0746e-03 | LR: 1.00e-05
# [Adam] Epoch   710 | Loss: 4.0630e-03 | LR: 1.00e-05
# [Adam] Epoch   720 | Loss: 4.0516e-03 | LR: 1.00e-05
# [Adam] Epoch   730 | Loss: 4.0404e-03 | LR: 1.00e-05
# [Adam] Epoch   740 | Loss: 4.0293e-03 | LR: 1.00e-05
# [Adam] Epoch   750 | Loss: 4.0185e-03 | LR: 1.00e-05
# [Adam] Epoch   760 | Loss: 4.0081e-03 | LR: 1.00e-05
# [Adam] Epoch   770 | Loss: 3.9980e-03 | LR: 1.00e-05
# [Adam] Epoch   780 | Loss: 3.9883e-03 | LR: 1.00e-05
# [Adam] Epoch   790 | Loss: 3.9789e-03 | LR: 1.00e-05
# [Adam] Epoch   800 | Loss: 3.9696e-03 | LR: 1.00e-05
# [Adam] Epoch   810 | Loss: 3.9602e-03 | LR: 1.00e-05
# [Adam] Epoch   820 | Loss: 3.9511e-03 | LR: 1.00e-05
# [Adam] Epoch   830 | Loss: 3.9425e-03 | LR: 1.00e-05
# [Adam] Epoch   840 | Loss: 3.9341e-03 | LR: 1.00e-05
# [Adam] Epoch   850 | Loss: 3.9259e-03 | LR: 1.00e-05
# [Adam] Epoch   860 | Loss: 3.9177e-03 | LR: 1.00e-05
# [Adam] Epoch   870 | Loss: 3.9094e-03 | LR: 1.00e-05
# [Adam] Epoch   880 | Loss: 3.9009e-03 | LR: 1.00e-05
# [Adam] Epoch   890 | Loss: 3.8925e-03 | LR: 1.00e-05
# [Adam] Epoch   900 | Loss: 3.8844e-03 | LR: 1.00e-05
# [Adam] Epoch   910 | Loss: 3.8768e-03 | LR: 1.00e-05
# [Adam] Epoch   920 | Loss: 3.8696e-03 | LR: 1.00e-05
# [Adam] Epoch   930 | Loss: 3.8627e-03 | LR: 1.00e-05
# [Adam] Epoch   940 | Loss: 3.8559e-03 | LR: 1.00e-05
# [Adam] Epoch   950 | Loss: 3.8492e-03 | LR: 1.00e-05
# [Adam] Epoch   960 | Loss: 3.8429e-03 | LR: 1.00e-05
# [Adam] Epoch   970 | Loss: 3.8369e-03 | LR: 1.00e-05
# [Adam] Epoch   980 | Loss: 3.8312e-03 | LR: 1.00e-05
# [Adam] Epoch   990 | Loss: 3.8258e-03 | LR: 1.00e-05
# [Adam] Epoch  1000 | Loss: 3.8207e-03 | LR: 1.00e-05
# [Adam] Epoch  1010 | Loss: 3.8157e-03 | LR: 1.00e-05
# [Adam] Epoch  1020 | Loss: 3.8108e-03 | LR: 1.00e-05
# [Adam] Epoch  1030 | Loss: 3.8060e-03 | LR: 1.00e-05
# [Adam] Epoch  1040 | Loss: 3.8014e-03 | LR: 1.00e-05
# [Adam] Epoch  1050 | Loss: 3.7968e-03 | LR: 1.00e-05
# [Adam] Epoch  1060 | Loss: 3.7923e-03 | LR: 1.00e-05
# [Adam] Epoch  1070 | Loss: 3.7879e-03 | LR: 1.00e-05
# [Adam] Epoch  1080 | Loss: 3.7837e-03 | LR: 1.00e-05
# [Adam] Epoch  1090 | Loss: 3.7796e-03 | LR: 1.00e-05
# [Adam] Epoch  1100 | Loss: 3.7756e-03 | LR: 1.00e-05
# [Adam] Epoch  1110 | Loss: 3.7717e-03 | LR: 1.00e-05
# [Adam] Epoch  1120 | Loss: 3.7678e-03 | LR: 1.00e-05
# [Adam] Epoch  1130 | Loss: 3.7639e-03 | LR: 1.00e-05
# [Adam] Epoch  1140 | Loss: 3.7599e-03 | LR: 1.00e-05
# [Adam] Epoch  1150 | Loss: 3.7558e-03 | LR: 1.00e-05
# [Adam] Epoch  1160 | Loss: 3.7517e-03 | LR: 1.00e-05
# [Adam] Epoch  1170 | Loss: 3.7477e-03 | LR: 1.00e-05
# [Adam] Epoch  1180 | Loss: 3.7438e-03 | LR: 1.00e-05
# [Adam] Epoch  1190 | Loss: 3.7400e-03 | LR: 1.00e-05
# [Adam] Epoch  1200 | Loss: 3.7364e-03 | LR: 1.00e-05
# [Adam] Epoch  1210 | Loss: 3.7330e-03 | LR: 1.00e-05
# [Adam] Epoch  1220 | Loss: 3.7296e-03 | LR: 1.00e-05
# [Adam] Epoch  1230 | Loss: 3.7262e-03 | LR: 1.00e-05
# [Adam] Epoch  1240 | Loss: 3.7230e-03 | LR: 1.00e-05
# [Adam] Epoch  1250 | Loss: 3.7197e-03 | LR: 1.00e-05
# [Adam] Epoch  1260 | Loss: 3.7165e-03 | LR: 1.00e-05
# [Adam] Epoch  1270 | Loss: 3.7133e-03 | LR: 1.00e-05
# [Adam] Epoch  1280 | Loss: 3.7102e-03 | LR: 1.00e-05
# [Adam] Epoch  1290 | Loss: 3.7070e-03 | LR: 1.00e-05
# [Adam] Epoch  1300 | Loss: 3.7039e-03 | LR: 1.00e-05
# [Adam] Epoch  1310 | Loss: 3.7009e-03 | LR: 1.00e-05
# [Adam] Epoch  1320 | Loss: 3.6979e-03 | LR: 1.00e-05
# [Adam] Epoch  1330 | Loss: 3.6948e-03 | LR: 1.00e-05
# [Adam] Epoch  1340 | Loss: 3.6918e-03 | LR: 1.00e-05
# [Adam] Epoch  1350 | Loss: 3.6889e-03 | LR: 1.00e-05
# [Adam] Epoch  1360 | Loss: 3.6859e-03 | LR: 1.00e-05
# [Adam] Epoch  1370 | Loss: 3.6829e-03 | LR: 1.00e-05
# [Adam] Epoch  1380 | Loss: 3.6800e-03 | LR: 1.00e-05
# [Adam] Epoch  1390 | Loss: 3.6770e-03 | LR: 1.00e-05
# [Adam] Epoch  1400 | Loss: 3.6740e-03 | LR: 1.00e-05
# [Adam] Epoch  1410 | Loss: 3.6711e-03 | LR: 1.00e-05
# [Adam] Epoch  1420 | Loss: 3.6680e-03 | LR: 1.00e-05
# [Adam] Epoch  1430 | Loss: 3.6650e-03 | LR: 1.00e-05
# [Adam] Epoch  1440 | Loss: 3.6619e-03 | LR: 1.00e-05
# [Adam] Epoch  1450 | Loss: 3.6588e-03 | LR: 1.00e-05
# [Adam] Epoch  1460 | Loss: 3.6556e-03 | LR: 1.00e-05
# [Adam] Epoch  1470 | Loss: 3.6524e-03 | LR: 1.00e-05
# [Adam] Epoch  1480 | Loss: 3.6491e-03 | LR: 1.00e-05
# [Adam] Epoch  1490 | Loss: 3.6458e-03 | LR: 1.00e-05
# [Adam] Epoch  1500 | Loss: 3.6424e-03 | LR: 1.00e-05
# [Adam] Epoch  1510 | Loss: 3.6390e-03 | LR: 1.00e-05
# [Adam] Epoch  1520 | Loss: 3.6355e-03 | LR: 1.00e-05
# [Adam] Epoch  1530 | Loss: 3.6321e-03 | LR: 1.00e-05
# [Adam] Epoch  1540 | Loss: 3.6286e-03 | LR: 1.00e-05
# [Adam] Epoch  1550 | Loss: 3.6251e-03 | LR: 1.00e-05
# [Adam] Epoch  1560 | Loss: 3.6216e-03 | LR: 1.00e-05
# [Adam] Epoch  1570 | Loss: 3.6180e-03 | LR: 1.00e-05
# [Adam] Epoch  1580 | Loss: 3.6144e-03 | LR: 1.00e-05
# [Adam] Epoch  1590 | Loss: 3.6106e-03 | LR: 1.00e-05
# [Adam] Epoch  1600 | Loss: 3.6070e-03 | LR: 1.00e-05
# [Adam] Epoch  1610 | Loss: 3.6032e-03 | LR: 1.00e-05
# [Adam] Epoch  1620 | Loss: 3.5994e-03 | LR: 1.00e-05
# [Adam] Epoch  1630 | Loss: 3.5955e-03 | LR: 1.00e-05
# [Adam] Epoch  1640 | Loss: 3.5916e-03 | LR: 1.00e-05
# [Adam] Epoch  1650 | Loss: 3.5877e-03 | LR: 1.00e-05
# [Adam] Epoch  1660 | Loss: 3.5837e-03 | LR: 1.00e-05
# [Adam] Epoch  1670 | Loss: 3.5797e-03 | LR: 1.00e-05
# [Adam] Epoch  1680 | Loss: 3.5757e-03 | LR: 1.00e-05
# [Adam] Epoch  1690 | Loss: 3.5716e-03 | LR: 1.00e-05
# [Adam] Epoch  1700 | Loss: 3.5675e-03 | LR: 1.00e-05
# [Adam] Epoch  1710 | Loss: 3.5634e-03 | LR: 1.00e-05
# [Adam] Epoch  1720 | Loss: 3.5592e-03 | LR: 1.00e-05
# [Adam] Epoch  1730 | Loss: 3.5550e-03 | LR: 1.00e-05
# [Adam] Epoch  1740 | Loss: 3.5508e-03 | LR: 1.00e-05
# [Adam] Epoch  1750 | Loss: 3.5465e-03 | LR: 1.00e-05
# [Adam] Epoch  1760 | Loss: 3.5422e-03 | LR: 1.00e-05
# [Adam] Epoch  1770 | Loss: 3.5380e-03 | LR: 1.00e-05
# [Adam] Epoch  1780 | Loss: 3.5337e-03 | LR: 1.00e-05
# [Adam] Epoch  1790 | Loss: 3.5294e-03 | LR: 1.00e-05
# [Adam] Epoch  1800 | Loss: 3.5251e-03 | LR: 1.00e-05
# [Adam] Epoch  1810 | Loss: 3.5207e-03 | LR: 1.00e-05
# [Adam] Epoch  1820 | Loss: 3.5163e-03 | LR: 1.00e-05
# [Adam] Epoch  1830 | Loss: 3.5120e-03 | LR: 1.00e-05
# [Adam] Epoch  1840 | Loss: 3.5076e-03 | LR: 1.00e-05
# [Adam] Epoch  1850 | Loss: 3.5032e-03 | LR: 1.00e-05
# [Adam] Epoch  1860 | Loss: 3.4988e-03 | LR: 1.00e-05
# [Adam] Epoch  1870 | Loss: 3.4943e-03 | LR: 1.00e-05
# [Adam] Epoch  1880 | Loss: 3.4898e-03 | LR: 1.00e-05
# [Adam] Epoch  1890 | Loss: 3.4854e-03 | LR: 1.00e-05
# [Adam] Epoch  1900 | Loss: 3.4809e-03 | LR: 1.00e-05
# [Adam] Epoch  1910 | Loss: 3.4764e-03 | LR: 1.00e-05
# [Adam] Epoch  1920 | Loss: 3.4719e-03 | LR: 1.00e-05
# [Adam] Epoch  1930 | Loss: 3.4674e-03 | LR: 1.00e-05
# [Adam] Epoch  1940 | Loss: 3.4630e-03 | LR: 1.00e-05
# [Adam] Epoch  1950 | Loss: 3.4586e-03 | LR: 1.00e-05
# [Adam] Epoch  1960 | Loss: 3.4542e-03 | LR: 1.00e-05
# [Adam] Epoch  1970 | Loss: 3.4498e-03 | LR: 1.00e-05
# [Adam] Epoch  1980 | Loss: 3.4456e-03 | LR: 1.00e-05
# [Adam] Epoch  1990 | Loss: 3.4413e-03 | LR: 1.00e-05
# [Adam] Epoch  2000 | Loss: 3.4371e-03 | LR: 1.00e-05
# [Adam] Epoch  2010 | Loss: 3.4329e-03 | LR: 1.00e-05
# [Adam] Epoch  2020 | Loss: 3.4287e-03 | LR: 1.00e-05
# [Adam] Epoch  2030 | Loss: 3.4246e-03 | LR: 1.00e-05
# [Adam] Epoch  2040 | Loss: 3.4205e-03 | LR: 1.00e-05
# [Adam] Epoch  2050 | Loss: 3.4164e-03 | LR: 1.00e-05
# [Adam] Epoch  2060 | Loss: 3.4123e-03 | LR: 1.00e-05
# [Adam] Epoch  2070 | Loss: 3.4083e-03 | LR: 1.00e-05
# [Adam] Epoch  2080 | Loss: 3.4043e-03 | LR: 1.00e-05
# [Adam] Epoch  2090 | Loss: 3.4002e-03 | LR: 1.00e-05
# [Adam] Epoch  2100 | Loss: 3.3962e-03 | LR: 1.00e-05
# [Adam] Epoch  2110 | Loss: 3.3921e-03 | LR: 1.00e-05
# [Adam] Epoch  2120 | Loss: 3.3882e-03 | LR: 1.00e-05
# [Adam] Epoch  2130 | Loss: 3.3841e-03 | LR: 1.00e-05
# [Adam] Epoch  2140 | Loss: 3.3802e-03 | LR: 1.00e-05
# [Adam] Epoch  2150 | Loss: 3.3761e-03 | LR: 1.00e-05
# [Adam] Epoch  2160 | Loss: 3.3721e-03 | LR: 1.00e-05
# [Adam] Epoch  2170 | Loss: 3.3681e-03 | LR: 1.00e-05
# [Adam] Epoch  2180 | Loss: 3.3639e-03 | LR: 1.00e-05
# [Adam] Epoch  2190 | Loss: 3.3598e-03 | LR: 1.00e-05
# [Adam] Epoch  2200 | Loss: 3.3556e-03 | LR: 1.00e-05
# [Adam] Epoch  2210 | Loss: 3.3513e-03 | LR: 1.00e-05
# [Adam] Epoch  2220 | Loss: 3.3470e-03 | LR: 1.00e-05
# [Adam] Epoch  2230 | Loss: 3.3427e-03 | LR: 1.00e-05
# [Adam] Epoch  2240 | Loss: 3.3384e-03 | LR: 1.00e-05
# [Adam] Epoch  2250 | Loss: 3.3340e-03 | LR: 1.00e-05
# [Adam] Epoch  2260 | Loss: 3.3298e-03 | LR: 1.00e-05
# [Adam] Epoch  2270 | Loss: 3.3256e-03 | LR: 1.00e-05
# [Adam] Epoch  2280 | Loss: 3.3215e-03 | LR: 1.00e-05
# [Adam] Epoch  2290 | Loss: 3.3174e-03 | LR: 1.00e-05
# [Adam] Epoch  2300 | Loss: 3.3133e-03 | LR: 1.00e-05
# [Adam] Epoch  2310 | Loss: 3.3095e-03 | LR: 1.00e-05
# [Adam] Epoch  2320 | Loss: 3.3056e-03 | LR: 1.00e-05
# [Adam] Epoch  2330 | Loss: 3.3018e-03 | LR: 1.00e-05
# [Adam] Epoch  2340 | Loss: 3.2981e-03 | LR: 1.00e-05
# [Adam] Epoch  2350 | Loss: 3.2945e-03 | LR: 1.00e-05
# [Adam] Epoch  2360 | Loss: 3.2909e-03 | LR: 1.00e-05
# [Adam] Epoch  2370 | Loss: 3.2873e-03 | LR: 1.00e-05
# [Adam] Epoch  2380 | Loss: 3.2838e-03 | LR: 1.00e-05
# [Adam] Epoch  2390 | Loss: 3.2804e-03 | LR: 1.00e-05
# [Adam] Epoch  2400 | Loss: 3.2770e-03 | LR: 1.00e-05
# [Adam] Epoch  2410 | Loss: 3.2736e-03 | LR: 1.00e-05
# [Adam] Epoch  2420 | Loss: 3.2703e-03 | LR: 1.00e-05
# [Adam] Epoch  2430 | Loss: 3.2670e-03 | LR: 1.00e-05
# [Adam] Epoch  2440 | Loss: 3.2637e-03 | LR: 1.00e-05
# [Adam] Epoch  2450 | Loss: 3.2605e-03 | LR: 1.00e-05
# [Adam] Epoch  2460 | Loss: 3.2572e-03 | LR: 1.00e-05
# [Adam] Epoch  2470 | Loss: 3.2541e-03 | LR: 1.00e-05
# [Adam] Epoch  2480 | Loss: 3.2509e-03 | LR: 1.00e-05
# [Adam] Epoch  2490 | Loss: 3.2478e-03 | LR: 1.00e-05
# [Adam] Epoch  2500 | Loss: 3.2448e-03 | LR: 1.00e-05
# [Adam] Epoch  2510 | Loss: 3.2418e-03 | LR: 1.00e-05
# [Adam] Epoch  2520 | Loss: 3.2389e-03 | LR: 1.00e-05
# [Adam] Epoch  2530 | Loss: 3.2360e-03 | LR: 1.00e-05
# [Adam] Epoch  2540 | Loss: 3.2331e-03 | LR: 1.00e-05
# [Adam] Epoch  2550 | Loss: 3.2303e-03 | LR: 1.00e-05
# [Adam] Epoch  2560 | Loss: 3.2275e-03 | LR: 1.00e-05
# [Adam] Epoch  2570 | Loss: 3.2248e-03 | LR: 1.00e-05
# [Adam] Epoch  2580 | Loss: 3.2220e-03 | LR: 1.00e-05
# [Adam] Epoch  2590 | Loss: 3.2194e-03 | LR: 1.00e-05
# [Adam] Epoch  2600 | Loss: 3.2168e-03 | LR: 1.00e-05
# [Adam] Epoch  2610 | Loss: 3.2142e-03 | LR: 1.00e-05
# [Adam] Epoch  2620 | Loss: 3.2118e-03 | LR: 1.00e-05
# [Adam] Epoch  2630 | Loss: 3.2092e-03 | LR: 1.00e-05
# [Adam] Epoch  2640 | Loss: 3.2068e-03 | LR: 1.00e-05
# [Adam] Epoch  2650 | Loss: 3.2044e-03 | LR: 1.00e-05
# [Adam] Epoch  2660 | Loss: 3.2019e-03 | LR: 1.00e-05
# [Adam] Epoch  2670 | Loss: 3.1996e-03 | LR: 1.00e-05
# [Adam] Epoch  2680 | Loss: 3.1972e-03 | LR: 1.00e-05
# [Adam] Epoch  2690 | Loss: 3.1949e-03 | LR: 1.00e-05
# [Adam] Epoch  2700 | Loss: 3.1927e-03 | LR: 1.00e-05
# [Adam] Epoch  2710 | Loss: 3.1903e-03 | LR: 1.00e-05
# [Adam] Epoch  2720 | Loss: 3.1881e-03 | LR: 1.00e-05
# [Adam] Epoch  2730 | Loss: 3.1857e-03 | LR: 1.00e-05
# [Adam] Epoch  2740 | Loss: 3.1835e-03 | LR: 1.00e-05
# [Adam] Epoch  2750 | Loss: 3.1812e-03 | LR: 1.00e-05
# [Adam] Epoch  2760 | Loss: 3.1789e-03 | LR: 1.00e-05
# [Adam] Epoch  2770 | Loss: 3.1766e-03 | LR: 1.00e-05
# [Adam] Epoch  2780 | Loss: 3.1743e-03 | LR: 1.00e-05
# [Adam] Epoch  2790 | Loss: 3.1721e-03 | LR: 1.00e-05
# [Adam] Epoch  2800 | Loss: 3.1698e-03 | LR: 1.00e-05
# [Adam] Epoch  2810 | Loss: 3.1677e-03 | LR: 1.00e-05
# [Adam] Epoch  2820 | Loss: 3.1655e-03 | LR: 1.00e-05
# [Adam] Epoch  2830 | Loss: 3.1634e-03 | LR: 1.00e-05
# [Adam] Epoch  2840 | Loss: 3.1612e-03 | LR: 1.00e-05
# [Adam] Epoch  2850 | Loss: 3.1590e-03 | LR: 1.00e-05
# [Adam] Epoch  2860 | Loss: 3.1568e-03 | LR: 1.00e-05
# [Adam] Epoch  2870 | Loss: 3.1546e-03 | LR: 1.00e-05
# [Adam] Epoch  2880 | Loss: 3.1525e-03 | LR: 1.00e-05
# [Adam] Epoch  2890 | Loss: 3.1503e-03 | LR: 1.00e-05
# [Adam] Epoch  2900 | Loss: 3.1483e-03 | LR: 1.00e-05
# [Adam] Epoch  2910 | Loss: 3.1462e-03 | LR: 1.00e-05
# [Adam] Epoch  2920 | Loss: 3.1443e-03 | LR: 1.00e-05
# [Adam] Epoch  2930 | Loss: 3.1423e-03 | LR: 1.00e-05
# [Adam] Epoch  2940 | Loss: 3.1403e-03 | LR: 1.00e-05
# [Adam] Epoch  2950 | Loss: 3.1384e-03 | LR: 1.00e-05
# [Adam] Epoch  2960 | Loss: 3.1366e-03 | LR: 1.00e-05
# [Adam] Epoch  2970 | Loss: 3.1346e-03 | LR: 1.00e-05
# [Adam] Epoch  2980 | Loss: 3.1327e-03 | LR: 1.00e-05
# [Adam] Epoch  2990 | Loss: 3.1308e-03 | LR: 1.00e-05
# [Adam] Epoch  3000 | Loss: 3.1290e-03 | LR: 1.00e-05
# [Adam] Epoch  3010 | Loss: 3.1270e-03 | LR: 1.00e-05
# [Adam] Epoch  3020 | Loss: 3.1252e-03 | LR: 1.00e-05
# [Adam] Epoch  3030 | Loss: 3.1233e-03 | LR: 1.00e-05
# [Adam] Epoch  3040 | Loss: 3.1214e-03 | LR: 1.00e-05
# [Adam] Epoch  3050 | Loss: 3.1196e-03 | LR: 1.00e-05
# [Adam] Epoch  3060 | Loss: 3.1178e-03 | LR: 1.00e-05
# [Adam] Epoch  3070 | Loss: 3.1160e-03 | LR: 1.00e-05
# [Adam] Epoch  3080 | Loss: 3.1142e-03 | LR: 1.00e-05
# [Adam] Epoch  3090 | Loss: 3.1125e-03 | LR: 1.00e-05
# [Adam] Epoch  3100 | Loss: 3.1108e-03 | LR: 1.00e-05
# [Adam] Epoch  3110 | Loss: 3.1091e-03 | LR: 1.00e-05
# [Adam] Epoch  3120 | Loss: 3.1074e-03 | LR: 1.00e-05
# [Adam] Epoch  3130 | Loss: 3.1056e-03 | LR: 1.00e-05
# [Adam] Epoch  3140 | Loss: 3.1038e-03 | LR: 1.00e-05
# [Adam] Epoch  3150 | Loss: 3.1022e-03 | LR: 1.00e-05
# [Adam] Epoch  3160 | Loss: 3.1005e-03 | LR: 1.00e-05
# [Adam] Epoch  3170 | Loss: 3.0987e-03 | LR: 1.00e-05
# [Adam] Epoch  3180 | Loss: 3.0971e-03 | LR: 1.00e-05
# [Adam] Epoch  3190 | Loss: 3.0952e-03 | LR: 1.00e-05
# [Adam] Epoch  3200 | Loss: 3.0936e-03 | LR: 1.00e-05
# [Adam] Epoch  3210 | Loss: 3.0919e-03 | LR: 1.00e-05
# [Adam] Epoch  3220 | Loss: 3.0901e-03 | LR: 1.00e-05
# [Adam] Epoch  3230 | Loss: 3.0884e-03 | LR: 1.00e-05
# [Adam] Epoch  3240 | Loss: 3.0866e-03 | LR: 1.00e-05
# [Adam] Epoch  3250 | Loss: 3.0847e-03 | LR: 1.00e-05
# [Adam] Epoch  3260 | Loss: 3.0829e-03 | LR: 1.00e-05
# [Adam] Epoch  3270 | Loss: 3.0810e-03 | LR: 1.00e-05
# [Adam] Epoch  3280 | Loss: 3.0792e-03 | LR: 1.00e-05
# [Adam] Epoch  3290 | Loss: 3.0773e-03 | LR: 1.00e-05
# [Adam] Epoch  3300 | Loss: 3.0755e-03 | LR: 1.00e-05
# [Adam] Epoch  3310 | Loss: 3.0738e-03 | LR: 1.00e-05
# [Adam] Epoch  3320 | Loss: 3.0720e-03 | LR: 1.00e-05
# [Adam] Epoch  3330 | Loss: 3.0703e-03 | LR: 1.00e-05
# [Adam] Epoch  3340 | Loss: 3.0686e-03 | LR: 1.00e-05
# [Adam] Epoch  3350 | Loss: 3.0669e-03 | LR: 1.00e-05
# [Adam] Epoch  3360 | Loss: 3.0654e-03 | LR: 1.00e-05
# [Adam] Epoch  3370 | Loss: 3.0637e-03 | LR: 1.00e-05
# [Adam] Epoch  3380 | Loss: 3.0621e-03 | LR: 1.00e-05
# [Adam] Epoch  3390 | Loss: 3.0606e-03 | LR: 1.00e-05
# [Adam] Epoch  3400 | Loss: 3.0589e-03 | LR: 1.00e-05
# [Adam] Epoch  3410 | Loss: 3.0574e-03 | LR: 1.00e-05
# [Adam] Epoch  3420 | Loss: 3.0558e-03 | LR: 1.00e-05
# [Adam] Epoch  3430 | Loss: 3.0543e-03 | LR: 1.00e-05
# [Adam] Epoch  3440 | Loss: 3.0528e-03 | LR: 1.00e-05
# [Adam] Epoch  3450 | Loss: 3.0513e-03 | LR: 1.00e-05
# [Adam] Epoch  3460 | Loss: 3.0498e-03 | LR: 1.00e-05
# [Adam] Epoch  3470 | Loss: 3.0483e-03 | LR: 1.00e-05
# [Adam] Epoch  3480 | Loss: 3.0469e-03 | LR: 1.00e-05
# [Adam] Epoch  3490 | Loss: 3.0453e-03 | LR: 1.00e-05
# [Adam] Epoch  3500 | Loss: 3.0440e-03 | LR: 1.00e-05
# [Adam] Epoch  3510 | Loss: 3.0425e-03 | LR: 1.00e-05
# [Adam] Epoch  3520 | Loss: 3.0410e-03 | LR: 1.00e-05
# [Adam] Epoch  3530 | Loss: 3.0396e-03 | LR: 1.00e-05
# [Adam] Epoch  3540 | Loss: 3.0382e-03 | LR: 1.00e-05
# [Adam] Epoch  3550 | Loss: 3.0368e-03 | LR: 1.00e-05
# [Adam] Epoch  3560 | Loss: 3.0354e-03 | LR: 1.00e-05
# [Adam] Epoch  3570 | Loss: 3.0340e-03 | LR: 1.00e-05
# [Adam] Epoch  3580 | Loss: 3.0327e-03 | LR: 1.00e-05
# [Adam] Epoch  3590 | Loss: 3.0313e-03 | LR: 1.00e-05
# [Adam] Epoch  3600 | Loss: 3.0300e-03 | LR: 1.00e-05
# [Adam] Epoch  3610 | Loss: 3.0287e-03 | LR: 1.00e-05
# [Adam] Epoch  3620 | Loss: 3.0273e-03 | LR: 1.00e-05
# [Adam] Epoch  3630 | Loss: 3.0260e-03 | LR: 1.00e-05
# [Adam] Epoch  3640 | Loss: 3.0247e-03 | LR: 1.00e-05
# [Adam] Epoch  3650 | Loss: 3.0234e-03 | LR: 1.00e-05
# [Adam] Epoch  3660 | Loss: 3.0222e-03 | LR: 1.00e-05
# [Adam] Epoch  3670 | Loss: 3.0210e-03 | LR: 1.00e-05
# [Adam] Epoch  3680 | Loss: 3.0198e-03 | LR: 1.00e-05
# [Adam] Epoch  3690 | Loss: 3.0185e-03 | LR: 1.00e-05
# [Adam] Epoch  3700 | Loss: 3.0174e-03 | LR: 1.00e-05
# [Adam] Epoch  3710 | Loss: 3.0161e-03 | LR: 1.00e-05
# [Adam] Epoch  3720 | Loss: 3.0150e-03 | LR: 1.00e-05
# [Adam] Epoch  3730 | Loss: 3.0138e-03 | LR: 1.00e-05
# [Adam] Epoch  3740 | Loss: 3.0127e-03 | LR: 1.00e-05
# [Adam] Epoch  3750 | Loss: 3.0115e-03 | LR: 1.00e-05
# [Adam] Epoch  3760 | Loss: 3.0104e-03 | LR: 1.00e-05
# [Adam] Epoch  3770 | Loss: 3.0092e-03 | LR: 1.00e-05
# [Adam] Epoch  3780 | Loss: 3.0082e-03 | LR: 1.00e-05
# [Adam] Epoch  3790 | Loss: 3.0071e-03 | LR: 1.00e-05
# [Adam] Epoch  3800 | Loss: 3.0059e-03 | LR: 1.00e-05
# [Adam] Epoch  3810 | Loss: 3.0048e-03 | LR: 1.00e-05
# [Adam] Epoch  3820 | Loss: 3.0039e-03 | LR: 1.00e-05
# [Adam] Epoch  3830 | Loss: 3.0028e-03 | LR: 1.00e-05
# [Adam] Epoch  3840 | Loss: 3.0017e-03 | LR: 1.00e-05
# [Adam] Epoch  3850 | Loss: 3.0007e-03 | LR: 1.00e-05
# [Adam] Epoch  3860 | Loss: 2.9996e-03 | LR: 1.00e-05
# [Adam] Epoch  3870 | Loss: 2.9986e-03 | LR: 1.00e-05
# [Adam] Epoch  3880 | Loss: 2.9976e-03 | LR: 1.00e-05
# [Adam] Epoch  3890 | Loss: 2.9966e-03 | LR: 1.00e-05
# [Adam] Epoch  3900 | Loss: 2.9955e-03 | LR: 1.00e-05
# [Adam] Epoch  3910 | Loss: 2.9947e-03 | LR: 1.00e-05
# [Adam] Epoch  3920 | Loss: 2.9936e-03 | LR: 1.00e-05
# [Adam] Epoch  3930 | Loss: 2.9927e-03 | LR: 1.00e-05
# [Adam] Epoch  3940 | Loss: 2.9917e-03 | LR: 1.00e-05
# [Adam] Epoch  3950 | Loss: 2.9907e-03 | LR: 1.00e-05
# [Adam] Epoch  3960 | Loss: 2.9898e-03 | LR: 1.00e-05
# [Adam] Epoch  3970 | Loss: 2.9889e-03 | LR: 1.00e-05
# [Adam] Epoch  3980 | Loss: 2.9880e-03 | LR: 1.00e-05
# [Adam] Epoch  3990 | Loss: 2.9871e-03 | LR: 1.00e-05
# [Adam] Epoch  4000 | Loss: 2.9861e-03 | LR: 1.00e-05
# [Adam] Epoch  4010 | Loss: 2.9853e-03 | LR: 1.00e-05
# [Adam] Epoch  4020 | Loss: 2.9843e-03 | LR: 1.00e-05
# [Adam] Epoch  4030 | Loss: 2.9834e-03 | LR: 1.00e-05
# [Adam] Epoch  4040 | Loss: 2.9826e-03 | LR: 1.00e-05
# [Adam] Epoch  4050 | Loss: 2.9817e-03 | LR: 1.00e-05
# [Adam] Epoch  4060 | Loss: 2.9808e-03 | LR: 1.00e-05
# [Adam] Epoch  4070 | Loss: 2.9799e-03 | LR: 1.00e-05
# [Adam] Epoch  4080 | Loss: 2.9790e-03 | LR: 1.00e-05
# [Adam] Epoch  4090 | Loss: 2.9782e-03 | LR: 1.00e-05
# [Adam] Epoch  4100 | Loss: 2.9773e-03 | LR: 1.00e-05
# [Adam] Epoch  4110 | Loss: 2.9764e-03 | LR: 1.00e-05
# [Adam] Epoch  4120 | Loss: 2.9756e-03 | LR: 1.00e-05
# [Adam] Epoch  4130 | Loss: 2.9748e-03 | LR: 1.00e-05
# [Adam] Epoch  4140 | Loss: 2.9739e-03 | LR: 1.00e-05
# [Adam] Epoch  4150 | Loss: 2.9731e-03 | LR: 1.00e-05
# [Adam] Epoch  4160 | Loss: 2.9723e-03 | LR: 1.00e-05
# [Adam] Epoch  4170 | Loss: 2.9715e-03 | LR: 1.00e-05
# [Adam] Epoch  4180 | Loss: 2.9707e-03 | LR: 1.00e-05
# [Adam] Epoch  4190 | Loss: 2.9698e-03 | LR: 1.00e-05
# [Adam] Epoch  4200 | Loss: 2.9692e-03 | LR: 1.00e-05
# [Adam] Epoch  4210 | Loss: 2.9684e-03 | LR: 1.00e-05
# [Adam] Epoch  4220 | Loss: 2.9676e-03 | LR: 1.00e-05
# [Adam] Epoch  4230 | Loss: 2.9668e-03 | LR: 1.00e-05
# [Adam] Epoch  4240 | Loss: 2.9661e-03 | LR: 1.00e-05
# [Adam] Epoch  4250 | Loss: 2.9653e-03 | LR: 1.00e-05
# [Adam] Epoch  4260 | Loss: 2.9646e-03 | LR: 1.00e-05
# [Adam] Epoch  4270 | Loss: 2.9638e-03 | LR: 1.00e-05
# [Adam] Epoch  4280 | Loss: 2.9630e-03 | LR: 1.00e-05
# [Adam] Epoch  4290 | Loss: 2.9622e-03 | LR: 1.00e-05
# [Adam] Epoch  4300 | Loss: 2.9614e-03 | LR: 1.00e-05
# [Adam] Epoch  4310 | Loss: 2.9606e-03 | LR: 1.00e-05
# [Adam] Epoch  4320 | Loss: 2.9597e-03 | LR: 1.00e-05
# [Adam] Epoch  4330 | Loss: 2.9590e-03 | LR: 1.00e-05
# [Adam] Epoch  4340 | Loss: 2.9582e-03 | LR: 1.00e-05
# [Adam] Epoch  4350 | Loss: 2.9575e-03 | LR: 1.00e-05
# [Adam] Epoch  4360 | Loss: 2.9568e-03 | LR: 1.00e-05
# [Adam] Epoch  4370 | Loss: 2.9561e-03 | LR: 1.00e-05
# [Adam] Epoch  4380 | Loss: 2.9555e-03 | LR: 1.00e-05
# [Adam] Epoch  4390 | Loss: 2.9547e-03 | LR: 1.00e-05
# [Adam] Epoch  4400 | Loss: 2.9541e-03 | LR: 1.00e-05
# [Adam] Epoch  4410 | Loss: 2.9535e-03 | LR: 1.00e-05
# [Adam] Epoch  4420 | Loss: 2.9528e-03 | LR: 1.00e-05
# [Adam] Epoch  4430 | Loss: 2.9521e-03 | LR: 1.00e-05
# [Adam] Epoch  4440 | Loss: 2.9515e-03 | LR: 1.00e-05
# [Adam] Epoch  4450 | Loss: 2.9509e-03 | LR: 1.00e-05
# [Adam] Epoch  4460 | Loss: 2.9503e-03 | LR: 1.00e-05
# [Adam] Epoch  4470 | Loss: 2.9496e-03 | LR: 1.00e-05
# [Adam] Epoch  4480 | Loss: 2.9491e-03 | LR: 1.00e-05
# [Adam] Epoch  4490 | Loss: 2.9484e-03 | LR: 1.00e-05
# [Adam] Epoch  4500 | Loss: 2.9478e-03 | LR: 1.00e-05
# [Adam] Epoch  4510 | Loss: 2.9473e-03 | LR: 1.00e-05
# [Adam] Epoch  4520 | Loss: 2.9467e-03 | LR: 1.00e-05
# [Adam] Epoch  4530 | Loss: 2.9461e-03 | LR: 1.00e-05
# [Adam] Epoch  4540 | Loss: 2.9455e-03 | LR: 1.00e-05
# [Adam] Epoch  4550 | Loss: 2.9450e-03 | LR: 1.00e-05
# [Adam] Epoch  4560 | Loss: 2.9444e-03 | LR: 1.00e-05
# [Adam] Epoch  4570 | Loss: 2.9439e-03 | LR: 1.00e-05
# [Adam] Epoch  4580 | Loss: 2.9434e-03 | LR: 1.00e-05
# [Adam] Epoch  4590 | Loss: 2.9428e-03 | LR: 1.00e-05
# [Adam] Epoch  4600 | Loss: 2.9423e-03 | LR: 1.00e-05
# [Adam] Epoch  4610 | Loss: 2.9417e-03 | LR: 1.00e-05
# [Adam] Epoch  4620 | Loss: 2.9413e-03 | LR: 1.00e-05
# [Adam] Epoch  4630 | Loss: 2.9407e-03 | LR: 1.00e-05
# [Adam] Epoch  4640 | Loss: 2.9402e-03 | LR: 1.00e-05
# [Adam] Epoch  4650 | Loss: 2.9397e-03 | LR: 1.00e-05
# [Adam] Epoch  4660 | Loss: 2.9392e-03 | LR: 1.00e-05
# [Adam] Epoch  4670 | Loss: 2.9387e-03 | LR: 1.00e-05
# [Adam] Epoch  4680 | Loss: 2.9382e-03 | LR: 1.00e-05
# [Adam] Epoch  4690 | Loss: 2.9377e-03 | LR: 1.00e-05
# [Adam] Epoch  4700 | Loss: 2.9373e-03 | LR: 1.00e-05
# [Adam] Epoch  4710 | Loss: 2.9368e-03 | LR: 1.00e-05
# [Adam] Epoch  4720 | Loss: 2.9363e-03 | LR: 1.00e-05
# [Adam] Epoch  4730 | Loss: 2.9358e-03 | LR: 1.00e-05
# [Adam] Epoch  4740 | Loss: 2.9353e-03 | LR: 1.00e-05
# [Adam] Epoch  4750 | Loss: 2.9349e-03 | LR: 1.00e-05
# [Adam] Epoch  4760 | Loss: 2.9345e-03 | LR: 1.00e-05
# [Adam] Epoch  4770 | Loss: 2.9340e-03 | LR: 1.00e-05
# [Adam] Epoch  4780 | Loss: 2.9335e-03 | LR: 1.00e-05
# [Adam] Epoch  4790 | Loss: 2.9331e-03 | LR: 1.00e-05
# [Adam] Epoch  4800 | Loss: 2.9327e-03 | LR: 1.00e-05
# [Adam] Epoch  4810 | Loss: 2.9323e-03 | LR: 1.00e-05
# [Adam] Epoch  4820 | Loss: 2.9318e-03 | LR: 1.00e-05
# [Adam] Epoch  4830 | Loss: 2.9314e-03 | LR: 1.00e-05
# [Adam] Epoch  4840 | Loss: 2.9309e-03 | LR: 1.00e-05
# [Adam] Epoch  4850 | Loss: 2.9305e-03 | LR: 1.00e-05
# [Adam] Epoch  4860 | Loss: 2.9301e-03 | LR: 1.00e-05
# [Adam] Epoch  4870 | Loss: 2.9297e-03 | LR: 1.00e-05
# [Adam] Epoch  4880 | Loss: 2.9293e-03 | LR: 1.00e-05
# [Adam] Epoch  4890 | Loss: 2.9289e-03 | LR: 1.00e-05
# [Adam] Epoch  4900 | Loss: 2.9285e-03 | LR: 1.00e-05
# [Adam] Epoch  4910 | Loss: 2.9281e-03 | LR: 1.00e-05
# [Adam] Epoch  4920 | Loss: 2.9277e-03 | LR: 1.00e-05
# [Adam] Epoch  4930 | Loss: 2.9273e-03 | LR: 1.00e-05
# [Adam] Epoch  4940 | Loss: 2.9269e-03 | LR: 1.00e-05
# [Adam] Epoch  4950 | Loss: 2.9265e-03 | LR: 1.00e-05
# [Adam] Epoch  4960 | Loss: 2.9262e-03 | LR: 1.00e-05
# [Adam] Epoch  4970 | Loss: 2.9258e-03 | LR: 1.00e-05
# [Adam] Epoch  4980 | Loss: 2.9254e-03 | LR: 1.00e-05
# [Adam] Epoch  4990 | Loss: 2.9250e-03 | LR: 1.00e-05
# [Adam] Epoch  5000 | Loss: 2.9246e-03 | LR: 1.00e-05
# [Adam] Epoch  5010 | Loss: 2.9243e-03 | LR: 1.00e-05
# [Adam] Epoch  5020 | Loss: 2.9239e-03 | LR: 1.00e-05
# [Adam] Epoch  5030 | Loss: 2.9235e-03 | LR: 1.00e-05
# [Adam] Epoch  5040 | Loss: 2.9233e-03 | LR: 1.00e-05
# [Adam] Epoch  5050 | Loss: 2.9229e-03 | LR: 1.00e-05
# [Adam] Epoch  5060 | Loss: 2.9225e-03 | LR: 1.00e-05
# [Adam] Epoch  5070 | Loss: 2.9222e-03 | LR: 1.00e-05
# [Adam] Epoch  5080 | Loss: 2.9218e-03 | LR: 1.00e-05
# [Adam] Epoch  5090 | Loss: 2.9215e-03 | LR: 1.00e-05
# [Adam] Epoch  5100 | Loss: 2.9211e-03 | LR: 1.00e-05
# [Adam] Epoch  5110 | Loss: 2.9208e-03 | LR: 1.00e-05
# [Adam] Epoch  5120 | Loss: 2.9204e-03 | LR: 1.00e-05
# [Adam] Epoch  5130 | Loss: 2.9201e-03 | LR: 1.00e-05
# [Adam] Epoch  5140 | Loss: 2.9198e-03 | LR: 1.00e-05
# [Adam] Epoch  5150 | Loss: 2.9195e-03 | LR: 1.00e-05
# [Adam] Epoch  5160 | Loss: 2.9191e-03 | LR: 1.00e-05
# [Adam] Epoch  5170 | Loss: 2.9188e-03 | LR: 1.00e-05
# [Adam] Epoch  5180 | Loss: 2.9185e-03 | LR: 1.00e-05
# [Adam] Epoch  5190 | Loss: 2.9182e-03 | LR: 1.00e-05
# [Adam] Epoch  5200 | Loss: 2.9179e-03 | LR: 1.00e-05
# [Adam] Epoch  5210 | Loss: 2.9175e-03 | LR: 1.00e-05
# [Adam] Epoch  5220 | Loss: 2.9172e-03 | LR: 1.00e-05
# [Adam] Epoch  5230 | Loss: 2.9169e-03 | LR: 1.00e-05
# [Adam] Epoch  5240 | Loss: 2.9166e-03 | LR: 1.00e-05
# [Adam] Epoch  5250 | Loss: 2.9163e-03 | LR: 1.00e-05
# [Adam] Epoch  5260 | Loss: 2.9160e-03 | LR: 1.00e-05
# [Adam] Epoch  5270 | Loss: 2.9158e-03 | LR: 1.00e-05
# [Adam] Epoch  5280 | Loss: 2.9155e-03 | LR: 1.00e-05
# [Adam] Epoch  5290 | Loss: 2.9152e-03 | LR: 1.00e-05
# [Adam] Epoch  5300 | Loss: 2.9149e-03 | LR: 1.00e-05
# [Adam] Epoch  5310 | Loss: 2.9146e-03 | LR: 1.00e-05
# [Adam] Epoch  5320 | Loss: 2.9143e-03 | LR: 1.00e-05
# [Adam] Epoch  5330 | Loss: 2.9139e-03 | LR: 1.00e-05
# [Adam] Epoch  5340 | Loss: 2.9137e-03 | LR: 1.00e-05
# [Adam] Epoch  5350 | Loss: 2.9134e-03 | LR: 1.00e-05
# [Adam] Epoch  5360 | Loss: 2.9131e-03 | LR: 1.00e-05
# [Adam] Epoch  5370 | Loss: 2.9128e-03 | LR: 1.00e-05
# [Adam] Epoch  5380 | Loss: 2.9126e-03 | LR: 1.00e-05
# [Adam] Epoch  5390 | Loss: 2.9123e-03 | LR: 1.00e-05
# [Adam] Epoch  5400 | Loss: 2.9120e-03 | LR: 1.00e-05
# [Adam] Epoch  5410 | Loss: 2.9118e-03 | LR: 1.00e-05
# [Adam] Epoch  5420 | Loss: 2.9115e-03 | LR: 1.00e-05
# [Adam] Epoch  5430 | Loss: 2.9112e-03 | LR: 1.00e-05
# [Adam] Epoch  5440 | Loss: 2.9110e-03 | LR: 1.00e-05
# [Adam] Epoch  5450 | Loss: 2.9107e-03 | LR: 1.00e-05
# [Adam] Epoch  5460 | Loss: 2.9104e-03 | LR: 1.00e-05
# [Adam] Epoch  5470 | Loss: 2.9102e-03 | LR: 1.00e-05
# [Adam] Epoch  5480 | Loss: 2.9099e-03 | LR: 1.00e-05
# [Adam] Epoch  5490 | Loss: 2.9096e-03 | LR: 1.00e-05
# [Adam] Epoch  5500 | Loss: 2.9094e-03 | LR: 1.00e-05
# [Adam] Epoch  5510 | Loss: 2.9091e-03 | LR: 1.00e-05
# [Adam] Epoch  5520 | Loss: 2.9089e-03 | LR: 1.00e-05
# [Adam] Epoch  5530 | Loss: 2.9087e-03 | LR: 1.00e-05
# [Adam] Epoch  5540 | Loss: 2.9084e-03 | LR: 1.00e-05
# [Adam] Epoch  5550 | Loss: 2.9082e-03 | LR: 1.00e-05
# [Adam] Epoch  5560 | Loss: 2.9079e-03 | LR: 1.00e-05
# [Adam] Epoch  5570 | Loss: 2.9077e-03 | LR: 1.00e-05
# [Adam] Epoch  5580 | Loss: 2.9075e-03 | LR: 1.00e-05
# [Adam] Epoch  5590 | Loss: 2.9073e-03 | LR: 1.00e-05
# [Adam] Epoch  5600 | Loss: 2.9070e-03 | LR: 1.00e-05
# [Adam] Epoch  5610 | Loss: 2.9068e-03 | LR: 1.00e-05
# [Adam] Epoch  5620 | Loss: 2.9065e-03 | LR: 1.00e-05
# [Adam] Epoch  5630 | Loss: 2.9064e-03 | LR: 1.00e-05
# [Adam] Epoch  5640 | Loss: 2.9061e-03 | LR: 1.00e-05
# [Adam] Epoch  5650 | Loss: 2.9059e-03 | LR: 1.00e-05
# [Adam] Epoch  5660 | Loss: 2.9057e-03 | LR: 1.00e-05
# [Adam] Epoch  5670 | Loss: 2.9054e-03 | LR: 1.00e-05
# [Adam] Epoch  5680 | Loss: 2.9053e-03 | LR: 1.00e-05
# [Adam] Epoch  5690 | Loss: 2.9050e-03 | LR: 1.00e-05
# [Adam] Epoch  5700 | Loss: 2.9047e-03 | LR: 1.00e-05
# [Adam] Epoch  5710 | Loss: 2.9045e-03 | LR: 1.00e-05
# [Adam] Epoch  5720 | Loss: 2.9043e-03 | LR: 1.00e-05
# [Adam] Epoch  5730 | Loss: 2.9042e-03 | LR: 1.00e-05
# [Adam] Epoch  5740 | Loss: 2.9040e-03 | LR: 1.00e-05
# [Adam] Epoch  5750 | Loss: 2.9038e-03 | LR: 1.00e-05
# [Adam] Epoch  5760 | Loss: 2.9035e-03 | LR: 1.00e-05
# [Adam] Epoch  5770 | Loss: 2.9033e-03 | LR: 1.00e-05
# [Adam] Epoch  5780 | Loss: 2.9031e-03 | LR: 1.00e-05
# [Adam] Epoch  5790 | Loss: 2.9029e-03 | LR: 1.00e-05
# [Adam] Epoch  5800 | Loss: 2.9028e-03 | LR: 1.00e-05
# [Adam] Epoch  5810 | Loss: 2.9026e-03 | LR: 1.00e-05
# [Adam] Epoch  5820 | Loss: 2.9024e-03 | LR: 1.00e-05
# [Adam] Epoch  5830 | Loss: 2.9022e-03 | LR: 1.00e-05
# [Adam] Epoch  5840 | Loss: 2.9020e-03 | LR: 1.00e-05
# [Adam] Epoch  5850 | Loss: 2.9017e-03 | LR: 1.00e-05
# [Adam] Epoch  5860 | Loss: 2.9016e-03 | LR: 1.00e-05
# [Adam] Epoch  5870 | Loss: 2.9013e-03 | LR: 1.00e-05
# [Adam] Epoch  5880 | Loss: 2.9012e-03 | LR: 1.00e-05
# [Adam] Epoch  5890 | Loss: 2.9010e-03 | LR: 1.00e-05
# [Adam] Epoch  5900 | Loss: 2.9008e-03 | LR: 1.00e-05
# [Adam] Epoch  5910 | Loss: 2.9006e-03 | LR: 1.00e-05
# [Adam] Epoch  5920 | Loss: 2.9005e-03 | LR: 1.00e-05
# [Adam] Epoch  5930 | Loss: 2.9002e-03 | LR: 1.00e-05
# [Adam] Epoch  5940 | Loss: 2.9000e-03 | LR: 1.00e-05
# [Adam] Epoch  5950 | Loss: 2.8999e-03 | LR: 1.00e-05
# [Adam] Epoch  5960 | Loss: 2.8997e-03 | LR: 1.00e-05
# [Adam] Epoch  5970 | Loss: 2.8996e-03 | LR: 1.00e-05
# [Adam] Epoch  5980 | Loss: 2.8993e-03 | LR: 1.00e-05
# [Adam] Epoch  5990 | Loss: 2.8992e-03 | LR: 1.00e-05
# [Adam] Epoch  6000 | Loss: 2.8991e-03 | LR: 1.00e-05
# [Adam] Epoch  6010 | Loss: 2.8988e-03 | LR: 1.00e-05
# [Adam] Epoch  6020 | Loss: 2.8987e-03 | LR: 1.00e-05
# [Adam] Epoch  6030 | Loss: 2.8985e-03 | LR: 1.00e-05
# [Adam] Epoch  6040 | Loss: 2.8984e-03 | LR: 1.00e-05
# [Adam] Epoch  6050 | Loss: 2.8982e-03 | LR: 1.00e-05
# [Adam] Epoch  6060 | Loss: 2.8980e-03 | LR: 1.00e-05
# [Adam] Epoch  6070 | Loss: 2.8978e-03 | LR: 1.00e-05
# [Adam] Epoch  6080 | Loss: 2.8977e-03 | LR: 1.00e-05
# [Adam] Epoch  6090 | Loss: 2.8975e-03 | LR: 1.00e-05
# [Adam] Epoch  6100 | Loss: 2.8973e-03 | LR: 1.00e-05
# [Adam] Epoch  6110 | Loss: 2.8972e-03 | LR: 1.00e-05
# [Adam] Epoch  6120 | Loss: 2.8971e-03 | LR: 1.00e-05
# [Adam] Epoch  6130 | Loss: 2.8968e-03 | LR: 1.00e-05
# [Adam] Epoch  6140 | Loss: 2.8968e-03 | LR: 1.00e-05
# [Adam] Epoch  6150 | Loss: 2.8965e-03 | LR: 1.00e-05
# [Adam] Epoch  6160 | Loss: 2.8964e-03 | LR: 1.00e-05
# [Adam] Epoch  6170 | Loss: 2.8962e-03 | LR: 1.00e-05
# [Adam] Epoch  6180 | Loss: 2.8961e-03 | LR: 1.00e-05
# [Adam] Epoch  6190 | Loss: 2.8960e-03 | LR: 1.00e-05
# [Adam] Epoch  6200 | Loss: 2.8957e-03 | LR: 1.00e-05
# [Adam] Epoch  6210 | Loss: 2.8957e-03 | LR: 1.00e-05
# [Adam] Epoch  6220 | Loss: 2.8955e-03 | LR: 1.00e-05
# [Adam] Epoch  6230 | Loss: 2.8953e-03 | LR: 1.00e-05
# [Adam] Epoch  6240 | Loss: 2.8952e-03 | LR: 1.00e-05
# [Adam] Epoch  6250 | Loss: 2.8950e-03 | LR: 1.00e-05
# [Adam] Epoch  6260 | Loss: 2.8948e-03 | LR: 1.00e-05
# [Adam] Epoch  6270 | Loss: 2.8948e-03 | LR: 1.00e-05
# [Adam] Epoch  6280 | Loss: 2.8946e-03 | LR: 1.00e-05
# [Adam] Epoch  6290 | Loss: 2.8944e-03 | LR: 1.00e-05
# [Adam] Epoch  6300 | Loss: 2.8943e-03 | LR: 1.00e-05
# [Adam] Epoch  6310 | Loss: 2.8942e-03 | LR: 1.00e-05
# [Adam] Epoch  6320 | Loss: 2.8941e-03 | LR: 1.00e-05
# [Adam] Epoch  6330 | Loss: 2.8939e-03 | LR: 1.00e-05
# [Adam] Epoch  6340 | Loss: 2.8937e-03 | LR: 1.00e-05
# [Adam] Epoch  6350 | Loss: 2.8936e-03 | LR: 1.00e-05
# [Adam] Epoch  6360 | Loss: 2.8935e-03 | LR: 1.00e-05
# [Adam] Epoch  6370 | Loss: 2.8933e-03 | LR: 1.00e-05
# [Adam] Epoch  6380 | Loss: 2.8932e-03 | LR: 1.00e-05
# [Adam] Epoch  6390 | Loss: 2.8930e-03 | LR: 1.00e-05
# [Adam] Epoch  6400 | Loss: 2.8930e-03 | LR: 1.00e-05
# [Adam] Epoch  6410 | Loss: 2.8928e-03 | LR: 1.00e-05
# [Adam] Epoch  6420 | Loss: 2.8927e-03 | LR: 1.00e-05
# [Adam] Epoch  6430 | Loss: 2.8926e-03 | LR: 1.00e-05
# [Adam] Epoch  6440 | Loss: 2.8924e-03 | LR: 1.00e-05
# [Adam] Epoch  6450 | Loss: 2.8923e-03 | LR: 1.00e-05
# [Adam] Epoch  6460 | Loss: 2.8922e-03 | LR: 1.00e-05
# [Adam] Epoch  6470 | Loss: 2.8920e-03 | LR: 1.00e-05
# [Adam] Epoch  6480 | Loss: 2.8919e-03 | LR: 1.00e-05
# [Adam] Epoch  6490 | Loss: 2.8918e-03 | LR: 1.00e-05
# [Adam] Epoch  6500 | Loss: 2.8916e-03 | LR: 1.00e-05
# [Adam] Epoch  6510 | Loss: 2.8915e-03 | LR: 1.00e-05
# [Adam] Epoch  6520 | Loss: 2.8914e-03 | LR: 1.00e-05
# [Adam] Epoch  6530 | Loss: 2.8913e-03 | LR: 1.00e-05
# [Adam] Epoch  6540 | Loss: 2.8911e-03 | LR: 1.00e-05
# [Adam] Epoch  6550 | Loss: 2.8910e-03 | LR: 1.00e-05
# [Adam] Epoch  6560 | Loss: 2.8909e-03 | LR: 1.00e-05
# [Adam] Epoch  6570 | Loss: 2.8908e-03 | LR: 1.00e-05
# [Adam] Epoch  6580 | Loss: 2.8906e-03 | LR: 1.00e-05
# [Adam] Epoch  6590 | Loss: 2.8906e-03 | LR: 1.00e-05
# [Adam] Epoch  6600 | Loss: 2.8904e-03 | LR: 1.00e-05
# [Adam] Epoch  6610 | Loss: 2.8903e-03 | LR: 1.00e-05
# [Adam] Epoch  6620 | Loss: 2.8902e-03 | LR: 1.00e-05
# [Adam] Epoch  6630 | Loss: 2.8900e-03 | LR: 1.00e-05
# [Adam] Epoch  6640 | Loss: 2.8899e-03 | LR: 1.00e-05
# [Adam] Epoch  6650 | Loss: 2.8898e-03 | LR: 1.00e-05
# [Adam] Epoch  6660 | Loss: 2.8897e-03 | LR: 1.00e-05
# [Adam] Epoch  6670 | Loss: 2.8896e-03 | LR: 1.00e-05
# [Adam] Epoch  6680 | Loss: 2.8894e-03 | LR: 1.00e-05
# [Adam] Epoch  6690 | Loss: 2.8893e-03 | LR: 1.00e-05
# [Adam] Epoch  6700 | Loss: 2.8892e-03 | LR: 1.00e-05
# [Adam] Epoch  6710 | Loss: 2.8891e-03 | LR: 1.00e-05
# [Adam] Epoch  6720 | Loss: 2.8890e-03 | LR: 1.00e-05
# [Adam] Epoch  6730 | Loss: 2.8889e-03 | LR: 1.00e-05
# [Adam] Epoch  6740 | Loss: 2.8888e-03 | LR: 1.00e-05
# [Adam] Epoch  6750 | Loss: 2.8886e-03 | LR: 1.00e-05
# [Adam] Epoch  6760 | Loss: 2.8886e-03 | LR: 1.00e-05
# [Adam] Epoch  6770 | Loss: 2.8885e-03 | LR: 1.00e-05
# [Adam] Epoch  6780 | Loss: 2.8884e-03 | LR: 1.00e-05
# [Adam] Epoch  6790 | Loss: 2.8882e-03 | LR: 1.00e-05
# [Adam] Epoch  6800 | Loss: 2.8881e-03 | LR: 1.00e-05
# [Adam] Epoch  6810 | Loss: 2.8880e-03 | LR: 1.00e-05
# [Adam] Epoch  6820 | Loss: 2.8879e-03 | LR: 1.00e-05
# [Adam] Epoch  6830 | Loss: 2.8878e-03 | LR: 1.00e-05
# [Adam] Epoch  6840 | Loss: 2.8876e-03 | LR: 1.00e-05
# [Adam] Epoch  6850 | Loss: 2.8876e-03 | LR: 1.00e-05
# [Adam] Epoch  6860 | Loss: 2.8875e-03 | LR: 1.00e-05
# [Adam] Epoch  6870 | Loss: 2.8874e-03 | LR: 1.00e-05
# [Adam] Epoch  6880 | Loss: 2.8872e-03 | LR: 1.00e-05
# [Adam] Epoch  6890 | Loss: 2.8872e-03 | LR: 1.00e-05
# [Adam] Epoch  6900 | Loss: 2.8871e-03 | LR: 1.00e-05
# [Adam] Epoch  6910 | Loss: 2.8869e-03 | LR: 1.00e-05
# [Adam] Epoch  6920 | Loss: 2.8868e-03 | LR: 1.00e-05
# [Adam] Epoch  6930 | Loss: 2.8868e-03 | LR: 1.00e-05
# [Adam] Epoch  6940 | Loss: 2.8866e-03 | LR: 1.00e-05
# [Adam] Epoch  6950 | Loss: 2.8866e-03 | LR: 1.00e-05
# [Adam] Epoch  6960 | Loss: 2.8864e-03 | LR: 1.00e-05
# [Adam] Epoch  6970 | Loss: 2.8864e-03 | LR: 1.00e-05
# [Adam] Epoch  6980 | Loss: 2.8862e-03 | LR: 1.00e-05
# [Adam] Epoch  6990 | Loss: 2.8861e-03 | LR: 1.00e-05
# [Adam] Epoch  7000 | Loss: 2.8860e-03 | LR: 1.00e-05
# [Adam] Epoch  7010 | Loss: 2.8859e-03 | LR: 1.00e-05
# [Adam] Epoch  7020 | Loss: 2.8858e-03 | LR: 1.00e-05
# [Adam] Epoch  7030 | Loss: 2.8857e-03 | LR: 1.00e-05
# [Adam] Epoch  7040 | Loss: 2.8857e-03 | LR: 1.00e-05
# [Adam] Epoch  7050 | Loss: 2.8855e-03 | LR: 1.00e-05
# [Adam] Epoch  7060 | Loss: 2.8854e-03 | LR: 1.00e-05
# [Adam] Epoch  7070 | Loss: 2.8853e-03 | LR: 1.00e-05
# [Adam] Epoch  7080 | Loss: 2.8853e-03 | LR: 1.00e-05
# [Adam] Epoch  7090 | Loss: 2.8852e-03 | LR: 1.00e-05
# [Adam] Epoch  7100 | Loss: 2.8851e-03 | LR: 1.00e-05
# [Adam] Epoch  7110 | Loss: 2.8849e-03 | LR: 1.00e-05
# [Adam] Epoch  7120 | Loss: 2.8849e-03 | LR: 1.00e-05
# [Adam] Epoch  7130 | Loss: 2.8848e-03 | LR: 1.00e-05
# [Adam] Epoch  7140 | Loss: 2.8847e-03 | LR: 1.00e-05
# [Adam] Epoch  7150 | Loss: 2.8846e-03 | LR: 1.00e-05
# [Adam] Epoch  7160 | Loss: 2.8845e-03 | LR: 1.00e-05
# [Adam] Epoch  7170 | Loss: 2.8844e-03 | LR: 1.00e-05
# [Adam] Epoch  7180 | Loss: 2.8843e-03 | LR: 1.00e-05
# [Adam] Epoch  7190 | Loss: 2.8842e-03 | LR: 1.00e-05
# [Adam] Epoch  7200 | Loss: 2.8842e-03 | LR: 1.00e-05
# [Adam] Epoch  7210 | Loss: 2.8840e-03 | LR: 1.00e-05
# [Adam] Epoch  7220 | Loss: 2.8840e-03 | LR: 1.00e-05
# [Adam] Epoch  7230 | Loss: 2.8839e-03 | LR: 1.00e-05
# [Adam] Epoch  7240 | Loss: 2.8838e-03 | LR: 1.00e-05
# [Adam] Epoch  7250 | Loss: 2.8837e-03 | LR: 1.00e-05
# [Adam] Epoch  7260 | Loss: 2.8836e-03 | LR: 1.00e-05
# [Adam] Epoch  7270 | Loss: 2.8836e-03 | LR: 1.00e-05
# [Adam] Epoch  7280 | Loss: 2.8834e-03 | LR: 1.00e-05
# [Adam] Epoch  7290 | Loss: 2.8834e-03 | LR: 1.00e-05
# [Adam] Epoch  7300 | Loss: 2.8833e-03 | LR: 1.00e-05
# [Adam] Epoch  7310 | Loss: 2.8832e-03 | LR: 1.00e-05
# [Adam] Epoch  7320 | Loss: 2.8831e-03 | LR: 1.00e-05
# [Adam] Epoch  7330 | Loss: 2.8830e-03 | LR: 1.00e-05
# [Adam] Epoch  7340 | Loss: 2.8828e-03 | LR: 1.00e-05
# [Adam] Epoch  7350 | Loss: 2.8828e-03 | LR: 1.00e-05
# [Adam] Epoch  7360 | Loss: 2.8828e-03 | LR: 1.00e-05
# [Adam] Epoch  7370 | Loss: 2.8827e-03 | LR: 1.00e-05
# [Adam] Epoch  7380 | Loss: 2.8826e-03 | LR: 1.00e-05
# [Adam] Epoch  7390 | Loss: 2.8825e-03 | LR: 1.00e-05
# [Adam] Epoch  7400 | Loss: 2.8824e-03 | LR: 1.00e-05
# [Adam] Epoch  7410 | Loss: 2.8823e-03 | LR: 1.00e-05
# [Adam] Epoch  7420 | Loss: 2.8823e-03 | LR: 1.00e-05
# [Adam] Epoch  7430 | Loss: 2.8822e-03 | LR: 1.00e-05
# [Adam] Epoch  7440 | Loss: 2.8821e-03 | LR: 1.00e-05
# [Adam] Epoch  7450 | Loss: 2.8820e-03 | LR: 1.00e-05
# [Adam] Epoch  7460 | Loss: 2.8820e-03 | LR: 1.00e-05
# [Adam] Epoch  7470 | Loss: 2.8818e-03 | LR: 1.00e-05
# [Adam] Epoch  7480 | Loss: 2.8818e-03 | LR: 1.00e-05
# [Adam] Epoch  7490 | Loss: 2.8817e-03 | LR: 1.00e-05
# [Adam] Epoch  7500 | Loss: 2.8816e-03 | LR: 1.00e-05
# [Adam] Epoch  7510 | Loss: 2.8815e-03 | LR: 1.00e-05
# [Adam] Epoch  7520 | Loss: 2.8814e-03 | LR: 1.00e-05
# [Adam] Epoch  7530 | Loss: 2.8814e-03 | LR: 1.00e-05
# [Adam] Epoch  7540 | Loss: 2.8812e-03 | LR: 1.00e-05
# [Adam] Epoch  7550 | Loss: 2.8812e-03 | LR: 1.00e-05
# [Adam] Epoch  7560 | Loss: 2.8811e-03 | LR: 1.00e-05
# [Adam] Epoch  7570 | Loss: 2.8810e-03 | LR: 1.00e-05
# [Adam] Epoch  7580 | Loss: 2.8810e-03 | LR: 1.00e-05
# [Adam] Epoch  7590 | Loss: 2.8809e-03 | LR: 1.00e-05
# [Adam] Epoch  7600 | Loss: 2.8808e-03 | LR: 1.00e-05
# [Adam] Epoch  7610 | Loss: 2.8807e-03 | LR: 1.00e-05
# [Adam] Epoch  7620 | Loss: 2.8806e-03 | LR: 1.00e-05
# [Adam] Epoch  7630 | Loss: 2.8806e-03 | LR: 1.00e-05
# [Adam] Epoch  7640 | Loss: 2.8804e-03 | LR: 1.00e-05
# [Adam] Epoch  7650 | Loss: 2.8804e-03 | LR: 1.00e-05
# [Adam] Epoch  7660 | Loss: 2.8803e-03 | LR: 1.00e-05
# [Adam] Epoch  7670 | Loss: 2.8802e-03 | LR: 1.00e-05
# [Adam] Epoch  7680 | Loss: 2.8802e-03 | LR: 1.00e-05
# [Adam] Epoch  7690 | Loss: 2.8800e-03 | LR: 1.00e-05
# [Adam] Epoch  7700 | Loss: 2.8800e-03 | LR: 1.00e-05
# [Adam] Epoch  7710 | Loss: 2.8799e-03 | LR: 1.00e-05
# [Adam] Epoch  7720 | Loss: 2.8798e-03 | LR: 1.00e-05
# [Adam] Epoch  7730 | Loss: 2.8798e-03 | LR: 1.00e-05
# [Adam] Epoch  7740 | Loss: 2.8797e-03 | LR: 1.00e-05
# [Adam] Epoch  7750 | Loss: 2.8796e-03 | LR: 1.00e-05
# [Adam] Epoch  7760 | Loss: 2.8796e-03 | LR: 1.00e-05
# [Adam] Epoch  7770 | Loss: 2.8795e-03 | LR: 1.00e-05
# [Adam] Epoch  7780 | Loss: 2.8794e-03 | LR: 1.00e-05
# [Adam] Epoch  7790 | Loss: 2.8793e-03 | LR: 1.00e-05
# [Adam] Epoch  7800 | Loss: 2.8793e-03 | LR: 1.00e-05
# [Adam] Epoch  7810 | Loss: 2.8792e-03 | LR: 1.00e-05
# [Adam] Epoch  7820 | Loss: 2.8791e-03 | LR: 1.00e-05
# [Adam] Epoch  7830 | Loss: 2.8790e-03 | LR: 1.00e-05
# [Adam] Epoch  7840 | Loss: 2.8789e-03 | LR: 1.00e-05
# [Adam] Epoch  7850 | Loss: 2.8789e-03 | LR: 1.00e-05
# [Adam] Epoch  7860 | Loss: 2.8788e-03 | LR: 1.00e-05
# [Adam] Epoch  7870 | Loss: 2.8788e-03 | LR: 1.00e-05
# [Adam] Epoch  7880 | Loss: 2.8787e-03 | LR: 1.00e-05
# [Adam] Epoch  7890 | Loss: 2.8786e-03 | LR: 1.00e-05
# [Adam] Epoch  7900 | Loss: 2.8785e-03 | LR: 1.00e-05
# [Adam] Epoch  7910 | Loss: 2.8785e-03 | LR: 1.00e-05
# [Adam] Epoch  7920 | Loss: 2.8784e-03 | LR: 1.00e-05
# [Adam] Epoch  7930 | Loss: 2.8783e-03 | LR: 1.00e-05
# [Adam] Epoch  7940 | Loss: 2.8783e-03 | LR: 1.00e-05
# [Adam] Epoch  7950 | Loss: 2.8782e-03 | LR: 1.00e-05
# [Adam] Epoch  7960 | Loss: 2.8781e-03 | LR: 1.00e-05
# [Adam] Epoch  7970 | Loss: 2.8780e-03 | LR: 1.00e-05
# [Adam] Epoch  7980 | Loss: 2.8779e-03 | LR: 1.00e-05
# [Adam] Epoch  7990 | Loss: 2.8779e-03 | LR: 1.00e-05
# [Adam] Epoch  8000 | Loss: 2.8778e-03 | LR: 1.00e-05
# [Adam] Epoch  8010 | Loss: 2.8777e-03 | LR: 1.00e-05
# [Adam] Epoch  8020 | Loss: 2.8776e-03 | LR: 1.00e-05
# [Adam] Epoch  8030 | Loss: 2.8775e-03 | LR: 1.00e-05
# [Adam] Epoch  8040 | Loss: 2.8775e-03 | LR: 1.00e-05
# [Adam] Epoch  8050 | Loss: 2.8774e-03 | LR: 1.00e-05
# [Adam] Epoch  8060 | Loss: 2.8774e-03 | LR: 1.00e-05
# [Adam] Epoch  8070 | Loss: 2.8773e-03 | LR: 1.00e-05
# [Adam] Epoch  8080 | Loss: 2.8772e-03 | LR: 1.00e-05
# [Adam] Epoch  8090 | Loss: 2.8771e-03 | LR: 1.00e-05
# [Adam] Epoch  8100 | Loss: 2.8771e-03 | LR: 1.00e-05
# [Adam] Epoch  8110 | Loss: 2.8770e-03 | LR: 1.00e-05
# [Adam] Epoch  8120 | Loss: 2.8770e-03 | LR: 1.00e-05
# [Adam] Epoch  8130 | Loss: 2.8768e-03 | LR: 1.00e-05
# [Adam] Epoch  8140 | Loss: 2.8768e-03 | LR: 1.00e-05
# [Adam] Epoch  8150 | Loss: 2.8767e-03 | LR: 1.00e-05
# [Adam] Epoch  8160 | Loss: 2.8766e-03 | LR: 1.00e-05
# [Adam] Epoch  8170 | Loss: 2.8765e-03 | LR: 1.00e-05
# [Adam] Epoch  8180 | Loss: 2.8765e-03 | LR: 1.00e-05
# [Adam] Epoch  8190 | Loss: 2.8764e-03 | LR: 1.00e-05
# [Adam] Epoch  8200 | Loss: 2.8764e-03 | LR: 1.00e-05
# [Adam] Epoch  8210 | Loss: 2.8764e-03 | LR: 1.00e-05
# [Adam] Epoch  8220 | Loss: 2.8762e-03 | LR: 1.00e-05
# [Adam] Epoch  8230 | Loss: 2.8762e-03 | LR: 1.00e-05
# [Adam] Epoch  8240 | Loss: 2.8761e-03 | LR: 1.00e-05
# [Adam] Epoch  8250 | Loss: 2.8761e-03 | LR: 1.00e-05
# [Adam] Epoch  8260 | Loss: 2.8761e-03 | LR: 1.00e-05
# [Adam] Epoch  8270 | Loss: 2.8759e-03 | LR: 1.00e-05
# [Adam] Epoch  8280 | Loss: 2.8758e-03 | LR: 1.00e-05
# [Adam] Epoch  8290 | Loss: 2.8758e-03 | LR: 1.00e-05
# [Adam] Epoch  8300 | Loss: 2.8757e-03 | LR: 1.00e-05
# [Adam] Epoch  8310 | Loss: 2.8756e-03 | LR: 1.00e-05
# [Adam] Epoch  8320 | Loss: 2.8756e-03 | LR: 1.00e-05
# [Adam] Epoch  8330 | Loss: 2.8755e-03 | LR: 1.00e-05
# [Adam] Epoch  8340 | Loss: 2.8755e-03 | LR: 1.00e-05
# [Adam] Epoch  8350 | Loss: 2.8753e-03 | LR: 1.00e-05
# [Adam] Epoch  8360 | Loss: 2.8753e-03 | LR: 1.00e-05
# [Adam] Epoch  8370 | Loss: 2.8753e-03 | LR: 1.00e-05
# [Adam] Epoch  8380 | Loss: 2.8752e-03 | LR: 1.00e-05
# [Adam] Epoch  8390 | Loss: 2.8751e-03 | LR: 1.00e-05
# [Adam] Epoch  8400 | Loss: 2.8751e-03 | LR: 1.00e-05
# [Adam] Epoch  8410 | Loss: 2.8750e-03 | LR: 1.00e-05
# [Adam] Epoch  8420 | Loss: 2.8749e-03 | LR: 1.00e-05
# [Adam] Epoch  8430 | Loss: 2.8749e-03 | LR: 1.00e-05
# [Adam] Epoch  8440 | Loss: 2.8748e-03 | LR: 1.00e-05
# [Adam] Epoch  8450 | Loss: 2.8748e-03 | LR: 1.00e-05
# [Adam] Epoch  8460 | Loss: 2.8747e-03 | LR: 1.00e-05
# [Adam] Epoch  8470 | Loss: 2.8746e-03 | LR: 1.00e-05
# [Adam] Epoch  8480 | Loss: 2.8745e-03 | LR: 1.00e-05
# [Adam] Epoch  8490 | Loss: 2.8746e-03 | LR: 1.00e-05
# [Adam] Epoch  8500 | Loss: 2.8744e-03 | LR: 1.00e-05
# [Adam] Epoch  8510 | Loss: 2.8744e-03 | LR: 1.00e-05
# [Adam] Epoch  8520 | Loss: 2.8743e-03 | LR: 1.00e-05
# [Adam] Epoch  8530 | Loss: 2.8742e-03 | LR: 1.00e-05
# [Adam] Epoch  8540 | Loss: 2.8742e-03 | LR: 1.00e-05
# [Adam] Epoch  8550 | Loss: 2.8741e-03 | LR: 1.00e-05
# [Adam] Epoch  8560 | Loss: 2.8741e-03 | LR: 1.00e-05
# [Adam] Epoch  8570 | Loss: 2.8740e-03 | LR: 1.00e-05
# [Adam] Epoch  8580 | Loss: 2.8740e-03 | LR: 1.00e-05
# [Adam] Epoch  8590 | Loss: 2.8739e-03 | LR: 1.00e-05
# [Adam] Epoch  8600 | Loss: 2.8738e-03 | LR: 1.00e-05
# [Adam] Epoch  8610 | Loss: 2.8738e-03 | LR: 1.00e-05
# [Adam] Epoch  8620 | Loss: 2.8737e-03 | LR: 1.00e-05
# [Adam] Epoch  8630 | Loss: 2.8737e-03 | LR: 1.00e-05
# [Adam] Epoch  8640 | Loss: 2.8736e-03 | LR: 1.00e-05
# [Adam] Epoch  8650 | Loss: 2.8735e-03 | LR: 1.00e-05
# [Adam] Epoch  8660 | Loss: 2.8735e-03 | LR: 1.00e-05
# [Adam] Epoch  8670 | Loss: 2.8734e-03 | LR: 1.00e-05
# [Adam] Epoch  8680 | Loss: 2.8734e-03 | LR: 1.00e-05
# [Adam] Epoch  8690 | Loss: 2.8733e-03 | LR: 1.00e-05
# [Adam] Epoch  8700 | Loss: 2.8732e-03 | LR: 1.00e-05
# [Adam] Epoch  8710 | Loss: 2.8732e-03 | LR: 1.00e-05
# [Adam] Epoch  8720 | Loss: 2.8731e-03 | LR: 1.00e-05
# [Adam] Epoch  8730 | Loss: 2.8731e-03 | LR: 1.00e-05
# [Adam] Epoch  8740 | Loss: 2.8730e-03 | LR: 1.00e-05
# [Adam] Epoch  8750 | Loss: 2.8730e-03 | LR: 1.00e-05
# [Adam] Epoch  8760 | Loss: 2.8728e-03 | LR: 1.00e-05
# [Adam] Epoch  8770 | Loss: 2.8728e-03 | LR: 1.00e-05
# [Adam] Epoch  8780 | Loss: 2.8728e-03 | LR: 1.00e-05
# [Adam] Epoch  8790 | Loss: 2.8728e-03 | LR: 1.00e-05
# [Adam] Epoch  8800 | Loss: 2.8727e-03 | LR: 1.00e-05
# [Adam] Epoch  8810 | Loss: 2.8726e-03 | LR: 1.00e-05
# [Adam] Epoch  8820 | Loss: 2.8726e-03 | LR: 1.00e-05
# [Adam] Epoch  8830 | Loss: 2.8725e-03 | LR: 1.00e-05
# [Adam] Epoch  8840 | Loss: 2.8724e-03 | LR: 1.00e-05
# [Adam] Epoch  8850 | Loss: 2.8724e-03 | LR: 1.00e-05
# [Adam] Epoch  8860 | Loss: 2.8724e-03 | LR: 1.00e-05
# [Adam] Epoch  8870 | Loss: 2.8722e-03 | LR: 1.00e-05
# [Adam] Epoch  8880 | Loss: 2.8722e-03 | LR: 1.00e-05
# [Adam] Epoch  8890 | Loss: 2.8722e-03 | LR: 1.00e-05
# [Adam] Epoch  8900 | Loss: 2.8721e-03 | LR: 1.00e-05
# [Adam] Epoch  8910 | Loss: 2.8720e-03 | LR: 1.00e-05
# [Adam] Epoch  8920 | Loss: 2.8720e-03 | LR: 1.00e-05
# [Adam] Epoch  8930 | Loss: 2.8720e-03 | LR: 1.00e-05
# [Adam] Epoch  8940 | Loss: 2.8719e-03 | LR: 1.00e-05
# [Adam] Epoch  8950 | Loss: 2.8718e-03 | LR: 1.00e-05
# [Adam] Epoch  8960 | Loss: 2.8718e-03 | LR: 1.00e-05
# [Adam] Epoch  8970 | Loss: 2.8717e-03 | LR: 1.00e-05
# [Adam] Epoch  8980 | Loss: 2.8716e-03 | LR: 1.00e-05
# [Adam] Epoch  8990 | Loss: 2.8716e-03 | LR: 1.00e-05
# [Adam] Epoch  9000 | Loss: 2.8716e-03 | LR: 1.00e-05
# [Adam] Epoch  9010 | Loss: 2.8714e-03 | LR: 1.00e-05
# [Adam] Epoch  9020 | Loss: 2.8715e-03 | LR: 1.00e-05
# [Adam] Epoch  9030 | Loss: 2.8714e-03 | LR: 1.00e-05
# ...
# [Adam] Epoch 16380 | Loss: 2.8091e-03 | LR: 5.00e-06
# [Adam] Epoch 16390 | Loss: 2.8091e-03 | LR: 5.00e-06
# [Adam] Epoch 16400 | Loss: 2.8091e-03 | LR: 5.00e-06
# [Adam] Epoch 16410 | Loss: 2.8091e-03 | LR: 5.00e-06
# [Adam] Epoch 16420 | Loss: 2.8090e-03 | LR: 5.00e-06
# [Adam] Epoch 16430 | Loss: 2.8090e-03 | LR: 5.00e-06
# [Adam] Epoch 16440 | Loss: 2.8089e-03 | LR: 5.00e-06
# [Adam] Epoch 16450 | Loss: 2.8089e-03 | LR: 5.00e-06
# [Adam] Epoch 16460 | Loss: 2.8089e-03 | LR: 5.00e-06
# [Adam] Epoch 16470 | Loss: 2.8088e-03 | LR: 5.00e-06
# [Adam] Epoch 16480 | Loss: 2.8088e-03 | LR: 5.00e-06
# [Adam] Epoch 16490 | Loss: 2.8088e-03 | LR: 5.00e-06
# [Adam] Epoch 16500 | Loss: 2.8087e-03 | LR: 5.00e-06
# [Adam] Epoch 16510 | Loss: 2.8087e-03 | LR: 5.00e-06
# [Adam] Epoch 16520 | Loss: 2.8087e-03 | LR: 5.00e-06
# [Adam] Epoch 16530 | Loss: 2.8086e-03 | LR: 5.00e-06
# [Adam] Epoch 16540 | Loss: 2.8086e-03 | LR: 5.00e-06
# [Adam] Epoch 16550 | Loss: 2.8086e-03 | LR: 5.00e-06
# [Adam] Epoch 16560 | Loss: 2.8086e-03 | LR: 5.00e-06
# [Adam] Epoch 16570 | Loss: 2.8085e-03 | LR: 5.00e-06
# [Adam] Epoch 16580 | Loss: 2.8085e-03 | LR: 5.00e-06
# [Adam] Epoch 16590 | Loss: 2.8085e-03 | LR: 5.00e-06
# [Adam] Epoch 16600 | Loss: 2.8085e-03 | LR: 5.00e-06
# [Adam] Epoch 16610 | Loss: 2.8084e-03 | LR: 5.00e-06
# [Adam] Epoch 16620 | Loss: 2.8084e-03 | LR: 5.00e-06
# [Adam] Epoch 16630 | Loss: 2.8084e-03 | LR: 5.00e-06
# [Adam] Epoch 16640 | Loss: 2.8083e-03 | LR: 5.00e-06
# [Adam] Epoch 16650 | Loss: 2.8083e-03 | LR: 5.00e-06
# [Adam] Epoch 16660 | Loss: 2.8083e-03 | LR: 5.00e-06
# [Adam] Epoch 16670 | Loss: 2.8082e-03 | LR: 5.00e-06
# [Adam] Epoch 16680 | Loss: 2.8082e-03 | LR: 5.00e-06
# [Adam] Epoch 16690 | Loss: 2.8082e-03 | LR: 5.00e-06
# [Adam] Epoch 16700 | Loss: 2.8082e-03 | LR: 5.00e-06
# [Adam] Epoch 16710 | Loss: 2.8081e-03 | LR: 5.00e-06
# [Adam] Epoch 16720 | Loss: 2.8081e-03 | LR: 5.00e-06
# [Adam] Epoch 16730 | Loss: 2.7961e-03 | LR: 2.50e-06
# [Adam] Epoch 16740 | Loss: 2.7956e-03 | LR: 2.50e-06
# [Adam] Epoch 16750 | Loss: 2.7952e-03 | LR: 2.50e-06
# [Adam] Epoch 16760 | Loss: 2.7948e-03 | LR: 2.50e-06
# [Adam] Epoch 16770 | Loss: 2.7946e-03 | LR: 2.50e-06
# [Adam] Epoch 16780 | Loss: 2.7943e-03 | LR: 2.50e-06
# [Adam] Epoch 16790 | Loss: 2.7941e-03 | LR: 2.50e-06
# [Adam] Epoch 16800 | Loss: 2.7940e-03 | LR: 2.50e-06
# [Adam] Epoch 16810 | Loss: 2.7938e-03 | LR: 2.50e-06
# [Adam] Epoch 16820 | Loss: 2.7937e-03 | LR: 2.50e-06
# [Adam] Epoch 16830 | Loss: 2.7936e-03 | LR: 2.50e-06
# [Adam] Epoch 16840 | Loss: 2.7934e-03 | LR: 2.50e-06
# [Adam] Epoch 16850 | Loss: 2.7933e-03 | LR: 2.50e-06
# [Adam] Epoch 16860 | Loss: 2.7932e-03 | LR: 2.50e-06
# [Adam] Epoch 16870 | Loss: 2.7931e-03 | LR: 2.50e-06
# [Adam] Epoch 16880 | Loss: 2.7930e-03 | LR: 2.50e-06
# [Adam] Epoch 16890 | Loss: 2.7930e-03 | LR: 2.50e-06
# [Adam] Epoch 16900 | Loss: 2.7929e-03 | LR: 2.50e-06
# [Adam] Epoch 16910 | Loss: 2.7928e-03 | LR: 2.50e-06
# [Adam] Epoch 16920 | Loss: 2.7927e-03 | LR: 2.50e-06
# [Adam] Epoch 16930 | Loss: 2.7926e-03 | LR: 2.50e-06
# [Adam] Epoch 16940 | Loss: 2.7926e-03 | LR: 2.50e-06
# [Adam] Epoch 16950 | Loss: 2.7925e-03 | LR: 2.50e-06
# [Adam] Epoch 16960 | Loss: 2.7924e-03 | LR: 2.50e-06
# [Adam] Epoch 16970 | Loss: 2.7924e-03 | LR: 2.50e-06
# [Adam] Epoch 16980 | Loss: 2.7923e-03 | LR: 2.50e-06
# [Adam] Epoch 16990 | Loss: 2.7922e-03 | LR: 2.50e-06
# [Adam] Epoch 17000 | Loss: 2.7922e-03 | LR: 2.50e-06
# [Adam] Epoch 17010 | Loss: 2.7921e-03 | LR: 2.50e-06
# [Adam] Epoch 17020 | Loss: 2.7920e-03 | LR: 2.50e-06
# [Adam] Epoch 17030 | Loss: 2.7920e-03 | LR: 2.50e-06
# [Adam] Epoch 17040 | Loss: 2.7919e-03 | LR: 2.50e-06
# [Adam] Epoch 17050 | Loss: 2.7919e-03 | LR: 2.50e-06
# [Adam] Epoch 17060 | Loss: 2.7918e-03 | LR: 2.50e-06
# [Adam] Epoch 17070 | Loss: 2.7918e-03 | LR: 2.50e-06
# [Adam] Epoch 17080 | Loss: 2.7917e-03 | LR: 2.50e-06
# [Adam] Epoch 17090 | Loss: 2.7917e-03 | LR: 2.50e-06
# [Adam] Epoch 17100 | Loss: 2.7916e-03 | LR: 2.50e-06
# [Adam] Epoch 17110 | Loss: 2.7916e-03 | LR: 2.50e-06
# [Adam] Epoch 17120 | Loss: 2.7915e-03 | LR: 2.50e-06
# [Adam] Epoch 17130 | Loss: 2.7914e-03 | LR: 2.50e-06
# [Adam] Epoch 17140 | Loss: 2.7914e-03 | LR: 2.50e-06
# [Adam] Epoch 17150 | Loss: 2.7914e-03 | LR: 2.50e-06
# [Adam] Epoch 17160 | Loss: 2.7913e-03 | LR: 2.50e-06
# [Adam] Epoch 17170 | Loss: 2.7913e-03 | LR: 2.50e-06
# [Adam] Epoch 17180 | Loss: 2.7912e-03 | LR: 2.50e-06
# [Adam] Epoch 17190 | Loss: 2.7912e-03 | LR: 2.50e-06
# [Adam] Epoch 17200 | Loss: 2.7911e-03 | LR: 2.50e-06
# [Adam] Epoch 17210 | Loss: 2.7910e-03 | LR: 2.50e-06
# [Adam] Epoch 17220 | Loss: 2.7910e-03 | LR: 2.50e-06
# [Adam] Epoch 17230 | Loss: 2.7910e-03 | LR: 2.50e-06
# [Adam] Epoch 17240 | Loss: 2.7909e-03 | LR: 2.50e-06
# [Adam] Epoch 17250 | Loss: 2.7909e-03 | LR: 2.50e-06
# [Adam] Epoch 17260 | Loss: 2.7908e-03 | LR: 2.50e-06
# [Adam] Epoch 17270 | Loss: 2.7908e-03 | LR: 2.50e-06
# [Adam] Epoch 17280 | Loss: 2.7908e-03 | LR: 2.50e-06
# [Adam] Epoch 17290 | Loss: 2.7907e-03 | LR: 2.50e-06
# [Adam] Epoch 17300 | Loss: 2.7907e-03 | LR: 2.50e-06
# [Adam] Epoch 17310 | Loss: 2.7906e-03 | LR: 2.50e-06
# [Adam] Epoch 17320 | Loss: 2.7906e-03 | LR: 2.50e-06
# [Adam] Epoch 17330 | Loss: 2.7905e-03 | LR: 2.50e-06
# [Adam] Epoch 17340 | Loss: 2.7905e-03 | LR: 2.50e-06
# [Adam] Epoch 17350 | Loss: 2.7905e-03 | LR: 2.50e-06
# [Adam] Epoch 17360 | Loss: 2.7904e-03 | LR: 2.50e-06
# [Adam] Epoch 17370 | Loss: 2.7904e-03 | LR: 2.50e-06
# [Adam] Epoch 17380 | Loss: 2.7904e-03 | LR: 2.50e-06
# [Adam] Epoch 17390 | Loss: 2.7903e-03 | LR: 2.50e-06
# [Adam] Epoch 17400 | Loss: 2.7903e-03 | LR: 2.50e-06
# [Adam] Epoch 17410 | Loss: 2.7903e-03 | LR: 2.50e-06
# [Adam] Epoch 17420 | Loss: 2.7902e-03 | LR: 2.50e-06
# [Adam] Epoch 17430 | Loss: 2.7902e-03 | LR: 2.50e-06
# [Adam] Epoch 17440 | Loss: 2.7901e-03 | LR: 2.50e-06
# [Adam] Epoch 17450 | Loss: 2.7901e-03 | LR: 2.50e-06
# [Adam] Epoch 17460 | Loss: 2.7901e-03 | LR: 2.50e-06
# [Adam] Epoch 17470 | Loss: 2.7900e-03 | LR: 2.50e-06
# [Adam] Epoch 17480 | Loss: 2.7900e-03 | LR: 2.50e-06
# [Adam] Epoch 17490 | Loss: 2.7899e-03 | LR: 2.50e-06
# [Adam] Epoch 17500 | Loss: 2.7899e-03 | LR: 2.50e-06
# [Adam] Epoch 17510 | Loss: 2.7899e-03 | LR: 2.50e-06
# [Adam] Epoch 17520 | Loss: 2.7898e-03 | LR: 2.50e-06
# [Adam] Epoch 17530 | Loss: 2.7898e-03 | LR: 2.50e-06
# [Adam] Epoch 17540 | Loss: 2.7898e-03 | LR: 2.50e-06
# [Adam] Epoch 17550 | Loss: 2.7897e-03 | LR: 2.50e-06
# [Adam] Epoch 17560 | Loss: 2.7897e-03 | LR: 2.50e-06
# [Adam] Epoch 17570 | Loss: 2.7896e-03 | LR: 2.50e-06
# [Adam] Epoch 17580 | Loss: 2.7896e-03 | LR: 2.50e-06
# [Adam] Epoch 17590 | Loss: 2.7896e-03 | LR: 2.50e-06
# [Adam] Epoch 17600 | Loss: 2.7896e-03 | LR: 2.50e-06
# [Adam] Epoch 17610 | Loss: 2.7895e-03 | LR: 2.50e-06
# [Adam] Epoch 17620 | Loss: 2.7895e-03 | LR: 2.50e-06
# [Adam] Epoch 17630 | Loss: 2.7895e-03 | LR: 2.50e-06
# [Adam] Epoch 17640 | Loss: 2.7894e-03 | LR: 2.50e-06
# [Adam] Epoch 17650 | Loss: 2.7894e-03 | LR: 2.50e-06
# [Adam] Epoch 17660 | Loss: 2.7894e-03 | LR: 2.50e-06
# [Adam] Epoch 17670 | Loss: 2.7893e-03 | LR: 2.50e-06
# [Adam] Epoch 17680 | Loss: 2.7893e-03 | LR: 2.50e-06
# [Adam] Epoch 17690 | Loss: 2.7893e-03 | LR: 2.50e-06
# [Adam] Epoch 17700 | Loss: 2.7892e-03 | LR: 2.50e-06
# [Adam] Epoch 17710 | Loss: 2.7892e-03 | LR: 2.50e-06
# [Adam] Epoch 17720 | Loss: 2.7892e-03 | LR: 2.50e-06
# [Adam] Epoch 17730 | Loss: 2.7891e-03 | LR: 2.50e-06
# [Adam] Epoch 17740 | Loss: 2.7891e-03 | LR: 2.50e-06
# [Adam] Epoch 17750 | Loss: 2.7891e-03 | LR: 2.50e-06
# [Adam] Epoch 17760 | Loss: 2.7890e-03 | LR: 2.50e-06
# [Adam] Epoch 17770 | Loss: 2.7890e-03 | LR: 2.50e-06
# [Adam] Epoch 17780 | Loss: 2.7890e-03 | LR: 2.50e-06
# [Adam] Epoch 17790 | Loss: 2.7889e-03 | LR: 2.50e-06
# [Adam] Epoch 17800 | Loss: 2.7889e-03 | LR: 2.50e-06
# [Adam] Epoch 17810 | Loss: 2.7889e-03 | LR: 2.50e-06
# [Adam] Epoch 17820 | Loss: 2.7889e-03 | LR: 2.50e-06
# [Adam] Epoch 17830 | Loss: 2.7888e-03 | LR: 2.50e-06
# [Adam] Epoch 17840 | Loss: 2.7888e-03 | LR: 2.50e-06
# [Adam] Epoch 17850 | Loss: 2.7888e-03 | LR: 2.50e-06
# [Adam] Epoch 17860 | Loss: 2.7887e-03 | LR: 2.50e-06
# [Adam] Epoch 17870 | Loss: 2.7887e-03 | LR: 2.50e-06
# [Adam] Epoch 17880 | Loss: 2.7887e-03 | LR: 2.50e-06
# [Adam] Epoch 17890 | Loss: 2.7886e-03 | LR: 2.50e-06
# [Adam] Epoch 17900 | Loss: 2.7886e-03 | LR: 2.50e-06
# [Adam] Epoch 17910 | Loss: 2.7886e-03 | LR: 2.50e-06
# [Adam] Epoch 17920 | Loss: 2.7886e-03 | LR: 2.50e-06
# [Adam] Epoch 17930 | Loss: 2.7885e-03 | LR: 2.50e-06
# [Adam] Epoch 17940 | Loss: 2.7885e-03 | LR: 2.50e-06
# [Adam] Epoch 17950 | Loss: 2.7885e-03 | LR: 2.50e-06
# [Adam] Epoch 17960 | Loss: 2.7885e-03 | LR: 2.50e-06
# [Adam] Epoch 17970 | Loss: 2.7884e-03 | LR: 2.50e-06
# [Adam] Epoch 17980 | Loss: 2.7884e-03 | LR: 2.50e-06
# [Adam] Epoch 17990 | Loss: 2.7884e-03 | LR: 2.50e-06
# [Adam] Epoch 18000 | Loss: 2.7883e-03 | LR: 2.50e-06
# [Adam] Epoch 18010 | Loss: 2.7883e-03 | LR: 2.50e-06
# [Adam] Epoch 18020 | Loss: 2.7883e-03 | LR: 2.50e-06
# [Adam] Epoch 18030 | Loss: 2.7821e-03 | LR: 1.25e-06
# [Adam] Epoch 18040 | Loss: 2.7820e-03 | LR: 1.25e-06
# [Adam] Epoch 18050 | Loss: 2.7819e-03 | LR: 1.25e-06
# [Adam] Epoch 18060 | Loss: 2.7818e-03 | LR: 1.25e-06
# [Adam] Epoch 18070 | Loss: 2.7817e-03 | LR: 1.25e-06
# [Adam] Epoch 18080 | Loss: 2.7816e-03 | LR: 1.25e-06
# [Adam] Epoch 18090 | Loss: 2.7815e-03 | LR: 1.25e-06
# [Adam] Epoch 18100 | Loss: 2.7815e-03 | LR: 1.25e-06
# [Adam] Epoch 18110 | Loss: 2.7814e-03 | LR: 1.25e-06
# [Adam] Epoch 18120 | Loss: 2.7814e-03 | LR: 1.25e-06
# [Adam] Epoch 18130 | Loss: 2.7813e-03 | LR: 1.25e-06
# [Adam] Epoch 18140 | Loss: 2.7813e-03 | LR: 1.25e-06
# [Adam] Epoch 18150 | Loss: 2.7812e-03 | LR: 1.25e-06
# [Adam] Epoch 18160 | Loss: 2.7812e-03 | LR: 1.25e-06
# [Adam] Epoch 18170 | Loss: 2.7811e-03 | LR: 1.25e-06
# [Adam] Epoch 18180 | Loss: 2.7811e-03 | LR: 1.25e-06
# [Adam] Epoch 18190 | Loss: 2.7810e-03 | LR: 1.25e-06
# [Adam] Epoch 18200 | Loss: 2.7810e-03 | LR: 1.25e-06
# [Adam] Epoch 18210 | Loss: 2.7810e-03 | LR: 1.25e-06
# [Adam] Epoch 18220 | Loss: 2.7809e-03 | LR: 1.25e-06
# [Adam] Epoch 18230 | Loss: 2.7809e-03 | LR: 1.25e-06
# [Adam] Epoch 18240 | Loss: 2.7809e-03 | LR: 1.25e-06
# [Adam] Epoch 18250 | Loss: 2.7808e-03 | LR: 1.25e-06
# [Adam] Epoch 18260 | Loss: 2.7808e-03 | LR: 1.25e-06
# [Adam] Epoch 18270 | Loss: 2.7808e-03 | LR: 1.25e-06
# [Adam] Epoch 18280 | Loss: 2.7807e-03 | LR: 1.25e-06
# [Adam] Epoch 18290 | Loss: 2.7807e-03 | LR: 1.25e-06
# [Adam] Epoch 18300 | Loss: 2.7807e-03 | LR: 1.25e-06
# [Adam] Epoch 18310 | Loss: 2.7806e-03 | LR: 1.25e-06
# [Adam] Epoch 18320 | Loss: 2.7806e-03 | LR: 1.25e-06
# [Adam] Epoch 18330 | Loss: 2.7806e-03 | LR: 1.25e-06
# [Adam] Epoch 18340 | Loss: 2.7806e-03 | LR: 1.25e-06
# [Adam] Epoch 18350 | Loss: 2.7805e-03 | LR: 1.25e-06
# [Adam] Epoch 18360 | Loss: 2.7805e-03 | LR: 1.25e-06
# [Adam] Epoch 18370 | Loss: 2.7805e-03 | LR: 1.25e-06
# [Adam] Epoch 18380 | Loss: 2.7804e-03 | LR: 1.25e-06
# [Adam] Epoch 18390 | Loss: 2.7804e-03 | LR: 1.25e-06
# [Adam] Epoch 18400 | Loss: 2.7804e-03 | LR: 1.25e-06
# [Adam] Epoch 18410 | Loss: 2.7804e-03 | LR: 1.25e-06
# [Adam] Epoch 18420 | Loss: 2.7803e-03 | LR: 1.25e-06
# [Adam] Epoch 18430 | Loss: 2.7803e-03 | LR: 1.25e-06
# [Adam] Epoch 18440 | Loss: 2.7803e-03 | LR: 1.25e-06
# [Adam] Epoch 18450 | Loss: 2.7802e-03 | LR: 1.25e-06
# [Adam] Epoch 18460 | Loss: 2.7802e-03 | LR: 1.25e-06
# [Adam] Epoch 18470 | Loss: 2.7802e-03 | LR: 1.25e-06
# [Adam] Epoch 18480 | Loss: 2.7802e-03 | LR: 1.25e-06
# [Adam] Epoch 18490 | Loss: 2.7801e-03 | LR: 1.25e-06
# [Adam] Epoch 18500 | Loss: 2.7801e-03 | LR: 1.25e-06
# [Adam] Epoch 18510 | Loss: 2.7769e-03 | LR: 6.25e-07
# [Adam] Epoch 18520 | Loss: 2.7769e-03 | LR: 6.25e-07
# [Adam] Epoch 18530 | Loss: 2.7768e-03 | LR: 6.25e-07
# [Adam] Epoch 18540 | Loss: 2.7768e-03 | LR: 6.25e-07
# [Adam] Epoch 18550 | Loss: 2.7768e-03 | LR: 6.25e-07
# [Adam] Epoch 18560 | Loss: 2.7767e-03 | LR: 6.25e-07
# [Adam] Epoch 18570 | Loss: 2.7767e-03 | LR: 6.25e-07
# [Adam] Epoch 18580 | Loss: 2.7767e-03 | LR: 6.25e-07
# [Adam] Epoch 18590 | Loss: 2.7767e-03 | LR: 6.25e-07
# [Adam] Epoch 18600 | Loss: 2.7766e-03 | LR: 6.25e-07
# [Adam] Epoch 18610 | Loss: 2.7766e-03 | LR: 6.25e-07
# [Adam] Epoch 18620 | Loss: 2.7766e-03 | LR: 6.25e-07
# [Adam] Epoch 18630 | Loss: 2.7766e-03 | LR: 6.25e-07
# [Adam] Epoch 18640 | Loss: 2.7749e-03 | LR: 3.13e-07
# [Adam] Epoch 18650 | Loss: 2.7749e-03 | LR: 3.13e-07
# [Adam] Epoch 18660 | Loss: 2.7749e-03 | LR: 3.13e-07
# [Adam] Epoch 18670 | Loss: 2.7748e-03 | LR: 3.13e-07
# [Adam] Epoch 18680 | Loss: 2.7748e-03 | LR: 3.13e-07
# [Adam] Epoch 18690 | Loss: 2.7748e-03 | LR: 3.13e-07
# [Adam] Epoch 18700 | Loss: 2.7748e-03 | LR: 3.13e-07
# [Adam] Epoch 18710 | Loss: 2.7748e-03 | LR: 3.13e-07
# [Adam] Epoch 18720 | Loss: 2.7748e-03 | LR: 3.13e-07
# [Adam] Epoch 18730 | Loss: 2.7747e-03 | LR: 3.13e-07
# [Adam] Epoch 18740 | Loss: 2.7747e-03 | LR: 3.13e-07
# [Adam] Epoch 18750 | Loss: 2.7747e-03 | LR: 3.13e-07
# [Adam] Epoch 18760 | Loss: 2.7747e-03 | LR: 3.13e-07
# [Adam] Epoch 18770 | Loss: 2.7747e-03 | LR: 3.13e-07
# [Adam] Epoch 18780 | Loss: 2.7747e-03 | LR: 3.13e-07
# [Adam] Epoch 18790 | Loss: 2.7747e-03 | LR: 3.13e-07
# [Adam] Epoch 18800 | Loss: 2.7747e-03 | LR: 3.13e-07
# [Adam] Epoch 18810 | Loss: 2.7746e-03 | LR: 3.13e-07
# [Adam] Epoch 18820 | Loss: 2.7746e-03 | LR: 1.56e-07
# [Adam] Epoch 18830 | Loss: 2.7738e-03 | LR: 1.56e-07
# [Adam] Epoch 18840 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18850 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18860 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18870 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18880 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18890 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18900 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18910 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18920 | Loss: 2.7737e-03 | LR: 1.56e-07
# [Adam] Epoch 18930 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 18940 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 18950 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 18960 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 18970 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 18980 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 18990 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 19000 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 19010 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 19020 | Loss: 2.7732e-03 | LR: 7.81e-08
# [Adam] Epoch 19030 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19040 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19050 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19060 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19070 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19080 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19090 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19100 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19110 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19120 | Loss: 2.7729e-03 | LR: 3.91e-08
# [Adam] Epoch 19130 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19140 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19150 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19160 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19170 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19180 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19190 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19200 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19210 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19220 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19230 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19240 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19250 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19260 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19270 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19280 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19290 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19300 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19310 | Loss: 2.7727e-03 | LR: 1.95e-08
# [Adam] Epoch 19320 | Loss: 2.7727e-03 | LR: 1.95e-08
# Early stopping triggered at epoch 19327
# Best model saved with loss 2.7727e-03 at epoch 19227
# [Test Evaluation] k=10, hd=1000, Adam LR=1e-05, BS=1024 → h=25: 0.021469 ± 0.000057, h=50: 0.039723 ± 0.000135, h=75: 0.065598 ± 0.000567, h=100: 0.103087 ± 0.001190
#
# === Final Results Summary ===
# Optimal config used: k=10, m=10000, hd=1000, lr=1e-05, bs=1024

# %%
# ============================================================
# Reload Fixed Best Model (Manual Parameters)
# ============================================================
model_path = model_path = f"model_k{k}_m{m}_hd{hidden_dim}_adam{lr_adam}_bs{batch_size}.pth"
best_model = AdaptiveNVARModel(dk=dk, m=m, d=d, hidden_dim=hidden_dim).to(device)
best_model.load_state_dict(torch.load(model_path, map_location=device))
best_model.eval()

all_preds, all_true, all_noisy = [], [], []

# ------------------------------------------------------------
# Rollout predictions across windows
# ------------------------------------------------------------
for w in range(num_windows):
    start, end = w * window_size, (w + 1) * window_size
    X_test_true_window = X_test_true[start:end]
    X_test_noisy_window = X_test[start:end]

    # Initialization with last k noisy points
    init_start = warmup_len + train_len + val_len + start - k
    init_end   = warmup_len + train_len + val_len + start
    X_init = X[init_start:init_end].to(device)

    x_t = [x.clone() for x in X_init.unbind(0)]
    H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

    predictions = []
    for _ in range(window_size):
        with torch.no_grad():
            delta_x = best_model(H_lin)
        x_next = x_t[-1] + delta_x.squeeze(0)
        predictions.append(x_next)

        # Update autoregressive state
        x_t = x_t[1:] + [x_next]
        H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

    all_preds.append(torch.stack(predictions).cpu().numpy())
    all_true.append(X_test_true_window.cpu().numpy())
    all_noisy.append(X_test_noisy_window.cpu().numpy())

# ------------------------------------------------------------
# Concatenate results
# ------------------------------------------------------------
y_pred = np.concatenate(all_preds)
y_true = np.concatenate(all_true)
y_noisy = np.concatenate(all_noisy)

# %%
# ============================================================
# Visualization (per variable) - First 10 windows, subset of variables
# ============================================================

max_windows_to_plot = min(10, num_windows)  # plot at most 10 windows
end_idx = max_windows_to_plot * window_size

# Slice arrays to avoid oversized figure rendering
y_true_plot = y_true[:end_idx]
y_noisy_plot = y_noisy[:end_idx]
y_pred_plot = y_pred[:end_idx]

# Limit to first 5 variables for readability
max_vars_to_plot = min(5, y_true.shape[1])
variables = [f"x_{i+1}" for i in range(max_vars_to_plot)]

fig, axes = plt.subplots(max_vars_to_plot, 1, figsize=(16, 3 * max_vars_to_plot), sharex=True)

if max_vars_to_plot == 1:
    axes = [axes]  # make iterable

for i, ax in enumerate(axes):
    # Ground truth
    ax.plot(y_true_plot[:, i], label="Ground Truth (Clean)", color="red", linestyle=":", linewidth=0.9)

    # Noisy observations
    ax.plot(y_noisy_plot[:, i], label=f"Noisy Validation Data ({dataset_noise_scale*100:.0f}%)",
            color="black", linewidth=1.0, alpha=1.0)

    # Predictions
    ax.plot(y_pred_plot[:, i], label="Adaptive NVAR Prediction", color="green", linewidth=1.2)

    # Mark window boundaries
    for w in range(1, max_windows_to_plot):
        ax.axvline(w * window_size, color="gray", linestyle="dotted", linewidth=0.8)

    # Label windows at the center
    ylim = ax.get_ylim()
    for w in range(max_windows_to_plot):
        center = w * window_size + window_size // 2
        ax.text(center, ylim[1] * 1.02, f"Window {w+1}",
                ha="center", va="bottom", fontsize=9, color="blue")

    ax.set_ylabel(f"$x_{{{i+1}}}$", fontsize=12)
    ax.grid(alpha=0.3)
    ax.legend(loc="upper right")

axes[-1].set_xlabel("Time", fontsize=12)
fig.suptitle("Test Predictions vs Ground Truth vs Noisy Data (First 10 Windows, First 5 Variables)", fontsize=14, y=0.95)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.xlim(0, end_idx)

# Save and show
filename = f"Test_pred_vs_truth_k{k}_hd{hidden_dim_grid}_noise{dataset_noise_scale:.2f}_first10_vars5.png"
plt.savefig(filename, dpi=300, bbox_inches="tight")
plt.show()
print(f"Saved plot as: {filename}")
# Out:
# Saved plot as: Test_pred_vs_truth_k10_hd[1000]_noise0.00_first10_vars5.png
