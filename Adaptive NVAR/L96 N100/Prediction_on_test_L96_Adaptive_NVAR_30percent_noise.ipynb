# %% [markdown]
# # Adaptive Nonlinear Vector Autoregression: Robust Forecasting for Noisy Chaotic Time Series
# ## Author
# - **Name**: Azimov Sherkhon Azizkhon Ugli
# - **Email**: sherxonazimov94@pusan.ac.kr
# - **GitHub**: @AzimovSherkhon
#
# Method: **Adaptive Nonlinear Vector Autoregression**
#
# Code: Prediction on unseen test data
#
# Best Config Found: \
# k=10, hidden_dim=1000, Adam LR=1e-05

# %%
# ============================================================
# Imports & Setup
# ============================================================
import torch
import warnings
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset

# Torch defaults
torch.set_default_dtype(torch.float32)

# ----------------------------
# Device setup (choose GPU 0)
# ----------------------------
if torch.cuda.is_available():
    torch.cuda.set_device(0)   # pick GPU 0
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")

print(f"Device in use: {device}")
if device.type == "cuda":
    print(f"CUDA device: {torch.cuda.current_device()} - {torch.cuda.get_device_name(device)}")

# Suppress unnecessary warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Device in use: cuda:0
# CUDA device: 0 - A100-PCIE-40GB

# %%
# ============================================================
# Load Lorenz 96 Clean Data
# ============================================================
data = np.load("lorenz96_100_noise_0.npy", allow_pickle=True).item()
l96_data = data["data"]   # (100, 1000001)
meta = data["meta"]   # dict with warmup/train/val/test/mean/std
l96 = l96_data.T
print(l96.shape)

# ============================================================
# Visualization: First 10 Variables of Lorenz '96
# ============================================================
plt.figure(figsize=(16, 12))
num_vars_to_plot = 10
time = np.arange(l96.shape[0])

for i in range(num_vars_to_plot):
    plt.subplot(num_vars_to_plot, 1, i + 1)
    plt.plot(time, l96[:, i], label=f'Variable {i+1}', color=f'C{i % 10}')
    plt.ylabel(f'x{i+1}')
    plt.grid(True)
    if i == 0:
        plt.title("Lorenz '96: First 10 variables (Clean data)")
    if i == num_vars_to_plot - 1:
        plt.xlabel('Time')
    plt.legend()
    plt.xlim(0, 2000)  

plt.tight_layout()
plt.show()
# Out:
# (500000, 100)

# %%
# ============================================================
# Reproducibility
# ============================================================
seed = 2025
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


# ============================================================
# # Load Lorenz 63 Noisy Data
# ============================================================
# Measurement noise (applied globally to dataset)
dataset_noise_scale = 0.30
data_noisy = np.load("lorenz96_100_noise_30.npy", allow_pickle=True).item()
X_noisy_dataset = data_noisy["data"]   # (3, 5001)
meta_noise = data_noisy["meta"]   # dict with warmup/train/val/test/mean/std
X_noisy_dataset = X_noisy_dataset.T

# ============================================================
# Visualization: First 10 Variables of Lorenz '96
# ============================================================
plt.figure(figsize=(16, 12))
num_vars_to_plot = 10
time = np.arange(l96.shape[0])

for i in range(num_vars_to_plot):
    plt.subplot(num_vars_to_plot, 1, i + 1)
    plt.plot(time, X_noisy_dataset[:, i], label=f'Variable {i+1}', color=f'C{i % 10}')
    plt.ylabel(f'x{i+1}')
    plt.grid(True)
    if i == 0:
        plt.title("Lorenz '96: First 10 variables (Noisy data)")
    if i == num_vars_to_plot - 1:
        plt.xlabel('Time')
    plt.legend()
    plt.xlim(0, 2000)  

plt.tight_layout()
plt.show()

X = torch.tensor(X_noisy_dataset, dtype=torch.float32)  # noisy input
X_true = torch.tensor(l96, dtype=torch.float32)          # clean reference

# Dataset splits
warmup_len, train_len, val_len, test_len = 1000, 399000, 50000, 50000

X_warmup = X[:warmup_len].to(device)
X_train_clean = X[warmup_len:warmup_len + train_len]
X_val  = X[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test = X[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)

# Ground truth references
X_val_true  = X_true[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test_true = X_true[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)

# Training-time noise (works as a regularization only during training)
train_noise_scale = 0.0  # We only add it for noise free-case
signal_std = X_train_clean.std(dim=0, keepdim=True).cpu().numpy()
train_noise = np.random.normal(0.0, train_noise_scale * signal_std, X_train_clean.shape)
X_train = torch.tensor((X_train_clean.cpu().numpy() + train_noise).astype(np.float32), device=device)

# %%
# ============================================================
# Adaptive NVAR Model
# ============================================================
class FeatureMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)


class AdaptiveNVARModel(nn.Module):
    def __init__(self, dk, m, d, hidden_dim):
        super().__init__()
        self.mlp = FeatureMLP(dk, hidden_dim, m)
        self.readout = nn.Linear(dk + m, d, bias=False)

    def forward(self, H_lin):
        H_nn = self.mlp(H_lin)
        H_total = torch.cat([H_lin, H_nn], dim=1)
        return self.readout(H_total)


# ============================================================
# Helper Functions
# ============================================================
def construct_H_lin(X, k):
    """Constructs delay-embedded features from time series."""
    T = X.shape[0]
    return torch.cat([X[i:T - k + i] for i in range(k)], dim=1)


def init_weights_stable(m):
    """Stable Xavier initialization for linear layers."""
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)
        with torch.no_grad():
            m.weight.mul_(1.0)


# ============================================================
# Training Function (Adam only)
# ============================================================
def train_model_adam_only(
    X, k, m, hidden_dim=200, num_epochs_adam=1000, batch_size=1024,
    save_path="best_joint_model_0percent_noise.pth",
    patience=100, tolerance=1e-8, lr=1e-5, use_amp=False
):
    X = X.to(device)
    H_lin = construct_H_lin(X, k)                 # [n, dk]
    Y = X[k:] - X[k - 1:-1]                       # [n, d]
    n, dk = H_lin.shape
    d = Y.shape[1]

    # Dataset + Dataloader
    dataset = TensorDataset(H_lin, Y)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    # Model: pass hidden_dim
    model = AdaptiveNVARModel(dk=dk, m=m, d=d, hidden_dim=hidden_dim).to(device)
#    # Freeze MLP parameters if needed
#    for param in model.mlp.parameters():
#        param.requires_grad = False

    # Optimizer
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        betas=(0.9, 0.999),
        eps=1e-8,
        weight_decay=0
    )

    # Scheduler (reduces lr when loss plateaus)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, factor=0.5, patience=100
    )

    # AMP scaler
    scaler = torch.cuda.amp.GradScaler(enabled=use_amp)

    adam_losses = []
    best_loss = float('inf')
    epochs_no_improve = 0
    best_model_state = None

    for epoch in range(num_epochs_adam):
        model.train()
        epoch_loss = 0.0

        for H_batch, Y_batch in dataloader:
            H_batch = H_batch.to(device)
            Y_batch = Y_batch.to(device)

            optimizer.zero_grad()

            # Mixed precision forward & backward
            with torch.cuda.amp.autocast(enabled=use_amp):
                Y_hat = model(H_batch)
                loss = F.mse_loss(Y_hat, Y_batch)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            epoch_loss += loss.item() * H_batch.size(0)

        current_loss = epoch_loss / n
        adam_losses.append(current_loss)

        # Step scheduler
        scheduler.step(current_loss)

        if epoch % 10 == 0 or epoch == num_epochs_adam - 1:
            current_lr = optimizer.param_groups[0]['lr']
            print(f"[Adam] Epoch {epoch:5d} | Loss: {current_loss:.4e} | LR: {current_lr:.2e}")

        # Early stopping
        if best_loss - current_loss > tolerance:
            best_loss = current_loss
            best_model_state = model.state_dict()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f"Early stopping triggered at epoch {epoch}")
            break

    # Save best model
    if best_model_state is not None:
        torch.save(best_model_state, save_path)
        print(f"Best model saved with loss {best_loss:.4e} at epoch {epoch - epochs_no_improve}")
    else:
        torch.save(model.state_dict(), save_path)
        print("Model saved (no improvement detected).")

    return model

# %%
# ============================================================ 
# Prediction on Test Data (Adam only)
# ============================================================
k_grid = [10]
hidden_dim_grid = [1000]
adam_lr_grid = [1e-5]
batch_size_grid = [1024]

horizons = [25, 50, 75, 100]

base_seed, num_runs, num_windows = 2025, 5, int(test_len / 100)
d = 100
best_config, best_rmse, all_results = None, float("inf"), []

print("Starting Test Evaluation (Adam only)...\n")

for k in k_grid:
    dk = d * k
    m = int(10 * dk)

    for hidden_dim in hidden_dim_grid:
        for lr_adam in adam_lr_grid:
            for batch_size in batch_size_grid:

                all_run_rmses = {h: [] for h in horizons}

                for run in range(num_runs):
                    seed = base_seed + run
                    torch.manual_seed(seed)
                    torch.cuda.manual_seed_all(seed)
                    torch.backends.cudnn.deterministic = True
                    torch.backends.cudnn.benchmark = False

                    model_path = f"model_k{k}_m{m}_hd{hidden_dim}_adam{lr_adam}_bs{batch_size}.pth"

                    # Load or train model
                    model = train_model_adam_only(
                        X_train, k=k, m=m, hidden_dim=hidden_dim,
                        num_epochs_adam=20000,
                        batch_size=batch_size,
                        lr=lr_adam,
                        save_path=model_path
                    )
                    model.eval()

                    window_size = len(X_test_true) // num_windows
                    horizon_rmses = {h: [] for h in horizons}

                    for w in range(num_windows):
                        start, end = w * window_size, (w + 1) * window_size
                        X_test_true_window = X_test_true[start:end]

                        # Initialization: last k points before this test window
                        init_start = warmup_len + train_len + val_len + start - k
                        init_end   = warmup_len + train_len + val_len + start
                        X_init = X[init_start:init_end].to(device)

                        x_t = [x.clone() for x in X_init.unbind(0)]
                        H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

                        predictions = []
                        for _ in range(window_size):
                            with torch.no_grad():
                                delta_x = model(H_lin)
                            x_next = x_t[-1] + delta_x.squeeze(0)
                            predictions.append(x_next)
                            x_t = x_t[1:] + [x_next]
                            H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

                        predictions_np = torch.stack(predictions).cpu().numpy()
                        y_true_np = X_test_true_window.cpu().numpy()

                        for h in horizons:
                            if h <= window_size:
                                rmse = np.sqrt(np.mean((y_true_np[:h] - predictions_np[:h]) ** 2))
                                horizon_rmses[h].append(rmse)

                    # Average RMSEs for this run
                    for h in horizons:
                        avg_rmse = np.mean(horizon_rmses[h])
                        all_run_rmses[h].append(avg_rmse)

                # Average over runs
                avg_rmse_horizons = {h: np.mean(all_run_rmses[h]) for h in horizons}
                std_rmse_horizons = {h: np.std(all_run_rmses[h]) for h in horizons}

                print(f"[Test Evaluation] k={k}, hd={hidden_dim}, Adam LR={lr_adam}, BS={batch_size} → " +
                      ", ".join([f"h={h}: {avg_rmse_horizons[h]:.6f} ± {std_rmse_horizons[h]:.6f}"
                                 for h in horizons]))

                all_results.append((k, m, hidden_dim, lr_adam, batch_size, avg_rmse_horizons))

                # Track best result (e.g., horizon=100)
                if avg_rmse_horizons[100] < best_rmse:
                    best_rmse = avg_rmse_horizons[100]
                    best_config = (k, m, hidden_dim, lr_adam, batch_size)

# ============================================================
# Final Best Results
# ============================================================
print("\n=== Final Results Summary ===")
print(f"Optimal config used: k={best_config[0]}, m={best_config[1]}, hd={best_config[2]}, "
      f"lr={best_config[3]}, bs={best_config[4]}")
# Out:
# Starting Test Evaluation (Adam only)...
#
# [Adam] Epoch     0 | Loss: 1.7029e-01 | LR: 1.00e-05
# [Adam] Epoch    10 | Loss: 1.1223e-01 | LR: 1.00e-05
# [Adam] Epoch    20 | Loss: 1.1013e-01 | LR: 1.00e-05
# [Adam] Epoch    30 | Loss: 1.0976e-01 | LR: 1.00e-05
# [Adam] Epoch    40 | Loss: 1.0960e-01 | LR: 1.00e-05
# [Adam] Epoch    50 | Loss: 1.0950e-01 | LR: 1.00e-05
# [Adam] Epoch    60 | Loss: 1.0943e-01 | LR: 1.00e-05
# [Adam] Epoch    70 | Loss: 1.0937e-01 | LR: 1.00e-05
# [Adam] Epoch    80 | Loss: 1.0933e-01 | LR: 1.00e-05
# [Adam] Epoch    90 | Loss: 1.0929e-01 | LR: 1.00e-05
# [Adam] Epoch   100 | Loss: 1.0925e-01 | LR: 1.00e-05
# [Adam] Epoch   110 | Loss: 1.0922e-01 | LR: 1.00e-05
# [Adam] Epoch   120 | Loss: 1.0919e-01 | LR: 1.00e-05
# [Adam] Epoch   130 | Loss: 1.0916e-01 | LR: 1.00e-05
# [Adam] Epoch   140 | Loss: 1.0913e-01 | LR: 1.00e-05
# [Adam] Epoch   150 | Loss: 1.0910e-01 | LR: 1.00e-05
# [Adam] Epoch   160 | Loss: 1.0906e-01 | LR: 1.00e-05
# [Adam] Epoch   170 | Loss: 1.0903e-01 | LR: 1.00e-05
# [Adam] Epoch   180 | Loss: 1.0899e-01 | LR: 1.00e-05
# [Adam] Epoch   190 | Loss: 1.0895e-01 | LR: 1.00e-05
# [Adam] Epoch   200 | Loss: 1.0891e-01 | LR: 1.00e-05
# [Adam] Epoch   210 | Loss: 1.0887e-01 | LR: 1.00e-05
# [Adam] Epoch   220 | Loss: 1.0882e-01 | LR: 1.00e-05
# [Adam] Epoch   230 | Loss: 1.0877e-01 | LR: 1.00e-05
# [Adam] Epoch   240 | Loss: 1.0870e-01 | LR: 1.00e-05
# [Adam] Epoch   250 | Loss: 1.0863e-01 | LR: 1.00e-05
# [Adam] Epoch   260 | Loss: 1.0854e-01 | LR: 1.00e-05
# [Adam] Epoch   270 | Loss: 1.0843e-01 | LR: 1.00e-05
# [Adam] Epoch   280 | Loss: 1.0829e-01 | LR: 1.00e-05
# [Adam] Epoch   290 | Loss: 1.0813e-01 | LR: 1.00e-05
# [Adam] Epoch   300 | Loss: 1.0796e-01 | LR: 1.00e-05
# [Adam] Epoch   310 | Loss: 1.0777e-01 | LR: 1.00e-05
# [Adam] Epoch   320 | Loss: 1.0757e-01 | LR: 1.00e-05
# [Adam] Epoch   330 | Loss: 1.0735e-01 | LR: 1.00e-05
# [Adam] Epoch   340 | Loss: 1.0712e-01 | LR: 1.00e-05
# [Adam] Epoch   350 | Loss: 1.0688e-01 | LR: 1.00e-05
# [Adam] Epoch   360 | Loss: 1.0662e-01 | LR: 1.00e-05
# [Adam] Epoch   370 | Loss: 1.0635e-01 | LR: 1.00e-05
# [Adam] Epoch   380 | Loss: 1.0606e-01 | LR: 1.00e-05
# [Adam] Epoch   390 | Loss: 1.0575e-01 | LR: 1.00e-05
# [Adam] Epoch   400 | Loss: 1.0544e-01 | LR: 1.00e-05
# [Adam] Epoch   410 | Loss: 1.0511e-01 | LR: 1.00e-05
# [Adam] Epoch   420 | Loss: 1.0479e-01 | LR: 1.00e-05
# [Adam] Epoch   430 | Loss: 1.0446e-01 | LR: 1.00e-05
# [Adam] Epoch   440 | Loss: 1.0413e-01 | LR: 1.00e-05
# [Adam] Epoch   450 | Loss: 1.0378e-01 | LR: 1.00e-05
# [Adam] Epoch   460 | Loss: 1.0342e-01 | LR: 1.00e-05
# [Adam] Epoch   470 | Loss: 1.0306e-01 | LR: 1.00e-05
# [Adam] Epoch   480 | Loss: 1.0270e-01 | LR: 1.00e-05
# [Adam] Epoch   490 | Loss: 1.0234e-01 | LR: 1.00e-05
# [Adam] Epoch   500 | Loss: 1.0198e-01 | LR: 1.00e-05
# [Adam] Epoch   510 | Loss: 1.0162e-01 | LR: 1.00e-05
# [Adam] Epoch   520 | Loss: 1.0127e-01 | LR: 1.00e-05
# [Adam] Epoch   530 | Loss: 1.0093e-01 | LR: 1.00e-05
# [Adam] Epoch   540 | Loss: 1.0060e-01 | LR: 1.00e-05
# [Adam] Epoch   550 | Loss: 1.0028e-01 | LR: 1.00e-05
# [Adam] Epoch   560 | Loss: 9.9967e-02 | LR: 1.00e-05
# [Adam] Epoch   570 | Loss: 9.9664e-02 | LR: 1.00e-05
# [Adam] Epoch   580 | Loss: 9.9372e-02 | LR: 1.00e-05
# [Adam] Epoch   590 | Loss: 9.9088e-02 | LR: 1.00e-05
# [Adam] Epoch   600 | Loss: 9.8813e-02 | LR: 1.00e-05
# [Adam] Epoch   610 | Loss: 9.8546e-02 | LR: 1.00e-05
# [Adam] Epoch   620 | Loss: 9.8288e-02 | LR: 1.00e-05
# [Adam] Epoch   630 | Loss: 9.8038e-02 | LR: 1.00e-05
# [Adam] Epoch   640 | Loss: 9.7795e-02 | LR: 1.00e-05
# [Adam] Epoch   650 | Loss: 9.7559e-02 | LR: 1.00e-05
# [Adam] Epoch   660 | Loss: 9.7330e-02 | LR: 1.00e-05
# [Adam] Epoch   670 | Loss: 9.7108e-02 | LR: 1.00e-05
# [Adam] Epoch   680 | Loss: 9.6894e-02 | LR: 1.00e-05
# [Adam] Epoch   690 | Loss: 9.6686e-02 | LR: 1.00e-05
# [Adam] Epoch   700 | Loss: 9.6484e-02 | LR: 1.00e-05
# [Adam] Epoch   710 | Loss: 9.6289e-02 | LR: 1.00e-05
# [Adam] Epoch   720 | Loss: 9.6099e-02 | LR: 1.00e-05
# [Adam] Epoch   730 | Loss: 9.5914e-02 | LR: 1.00e-05
# [Adam] Epoch   740 | Loss: 9.5733e-02 | LR: 1.00e-05
# [Adam] Epoch   750 | Loss: 9.5556e-02 | LR: 1.00e-05
# [Adam] Epoch   760 | Loss: 9.5386e-02 | LR: 1.00e-05
# [Adam] Epoch   770 | Loss: 9.5220e-02 | LR: 1.00e-05
# [Adam] Epoch   780 | Loss: 9.5060e-02 | LR: 1.00e-05
# [Adam] Epoch   790 | Loss: 9.4905e-02 | LR: 1.00e-05
# [Adam] Epoch   800 | Loss: 9.4754e-02 | LR: 1.00e-05
# [Adam] Epoch   810 | Loss: 9.4606e-02 | LR: 1.00e-05
# [Adam] Epoch   820 | Loss: 9.4462e-02 | LR: 1.00e-05
# [Adam] Epoch   830 | Loss: 9.4320e-02 | LR: 1.00e-05
# [Adam] Epoch   840 | Loss: 9.4180e-02 | LR: 1.00e-05
# [Adam] Epoch   850 | Loss: 9.4044e-02 | LR: 1.00e-05
# [Adam] Epoch   860 | Loss: 9.3912e-02 | LR: 1.00e-05
# [Adam] Epoch   870 | Loss: 9.3785e-02 | LR: 1.00e-05
# [Adam] Epoch   880 | Loss: 9.3663e-02 | LR: 1.00e-05
# [Adam] Epoch   890 | Loss: 9.3544e-02 | LR: 1.00e-05
# [Adam] Epoch   900 | Loss: 9.3430e-02 | LR: 1.00e-05
# [Adam] Epoch   910 | Loss: 9.3320e-02 | LR: 1.00e-05
# [Adam] Epoch   920 | Loss: 9.3214e-02 | LR: 1.00e-05
# [Adam] Epoch   930 | Loss: 9.3111e-02 | LR: 1.00e-05
# [Adam] Epoch   940 | Loss: 9.3012e-02 | LR: 1.00e-05
# [Adam] Epoch   950 | Loss: 9.2916e-02 | LR: 1.00e-05
# [Adam] Epoch   960 | Loss: 9.2823e-02 | LR: 1.00e-05
# [Adam] Epoch   970 | Loss: 9.2733e-02 | LR: 1.00e-05
# [Adam] Epoch   980 | Loss: 9.2645e-02 | LR: 1.00e-05
# [Adam] Epoch   990 | Loss: 9.2560e-02 | LR: 1.00e-05
# [Adam] Epoch  1000 | Loss: 9.2476e-02 | LR: 1.00e-05
# [Adam] Epoch  1010 | Loss: 9.2395e-02 | LR: 1.00e-05
# [Adam] Epoch  1020 | Loss: 9.2317e-02 | LR: 1.00e-05
# [Adam] Epoch  1030 | Loss: 9.2240e-02 | LR: 1.00e-05
# [Adam] Epoch  1040 | Loss: 9.2166e-02 | LR: 1.00e-05
# [Adam] Epoch  1050 | Loss: 9.2094e-02 | LR: 1.00e-05
# [Adam] Epoch  1060 | Loss: 9.2023e-02 | LR: 1.00e-05
# [Adam] Epoch  1070 | Loss: 9.1955e-02 | LR: 1.00e-05
# [Adam] Epoch  1080 | Loss: 9.1889e-02 | LR: 1.00e-05
# [Adam] Epoch  1090 | Loss: 9.1824e-02 | LR: 1.00e-05
# [Adam] Epoch  1100 | Loss: 9.1761e-02 | LR: 1.00e-05
# [Adam] Epoch  1110 | Loss: 9.1700e-02 | LR: 1.00e-05
# [Adam] Epoch  1120 | Loss: 9.1642e-02 | LR: 1.00e-05
# [Adam] Epoch  1130 | Loss: 9.1585e-02 | LR: 1.00e-05
# [Adam] Epoch  1140 | Loss: 9.1531e-02 | LR: 1.00e-05
# [Adam] Epoch  1150 | Loss: 9.1479e-02 | LR: 1.00e-05
# [Adam] Epoch  1160 | Loss: 9.1429e-02 | LR: 1.00e-05
# [Adam] Epoch  1170 | Loss: 9.1381e-02 | LR: 1.00e-05
# [Adam] Epoch  1180 | Loss: 9.1334e-02 | LR: 1.00e-05
# [Adam] Epoch  1190 | Loss: 9.1290e-02 | LR: 1.00e-05
# [Adam] Epoch  1200 | Loss: 9.1247e-02 | LR: 1.00e-05
# [Adam] Epoch  1210 | Loss: 9.1206e-02 | LR: 1.00e-05
# [Adam] Epoch  1220 | Loss: 9.1166e-02 | LR: 1.00e-05
# [Adam] Epoch  1230 | Loss: 9.1128e-02 | LR: 1.00e-05
# [Adam] Epoch  1240 | Loss: 9.1091e-02 | LR: 1.00e-05
# [Adam] Epoch  1250 | Loss: 9.1056e-02 | LR: 1.00e-05
# [Adam] Epoch  1260 | Loss: 9.1022e-02 | LR: 1.00e-05
# [Adam] Epoch  1270 | Loss: 9.0989e-02 | LR: 1.00e-05
# [Adam] Epoch  1280 | Loss: 9.0957e-02 | LR: 1.00e-05
# [Adam] Epoch  1290 | Loss: 9.0926e-02 | LR: 1.00e-05
# [Adam] Epoch  1300 | Loss: 9.0897e-02 | LR: 1.00e-05
# [Adam] Epoch  1310 | Loss: 9.0868e-02 | LR: 1.00e-05
# [Adam] Epoch  1320 | Loss: 9.0840e-02 | LR: 1.00e-05
# [Adam] Epoch  1330 | Loss: 9.0814e-02 | LR: 1.00e-05
# [Adam] Epoch  1340 | Loss: 9.0788e-02 | LR: 1.00e-05
# [Adam] Epoch  1350 | Loss: 9.0762e-02 | LR: 1.00e-05
# [Adam] Epoch  1360 | Loss: 9.0738e-02 | LR: 1.00e-05
# [Adam] Epoch  1370 | Loss: 9.0714e-02 | LR: 1.00e-05
# [Adam] Epoch  1380 | Loss: 9.0691e-02 | LR: 1.00e-05
# [Adam] Epoch  1390 | Loss: 9.0669e-02 | LR: 1.00e-05
# [Adam] Epoch  1400 | Loss: 9.0647e-02 | LR: 1.00e-05
# [Adam] Epoch  1410 | Loss: 9.0626e-02 | LR: 1.00e-05
# [Adam] Epoch  1420 | Loss: 9.0606e-02 | LR: 1.00e-05
# [Adam] Epoch  1430 | Loss: 9.0586e-02 | LR: 1.00e-05
# [Adam] Epoch  1440 | Loss: 9.0567e-02 | LR: 1.00e-05
# [Adam] Epoch  1450 | Loss: 9.0548e-02 | LR: 1.00e-05
# [Adam] Epoch  1460 | Loss: 9.0530e-02 | LR: 1.00e-05
# [Adam] Epoch  1470 | Loss: 9.0512e-02 | LR: 1.00e-05
# [Adam] Epoch  1480 | Loss: 9.0494e-02 | LR: 1.00e-05
# [Adam] Epoch  1490 | Loss: 9.0477e-02 | LR: 1.00e-05
# [Adam] Epoch  1500 | Loss: 9.0460e-02 | LR: 1.00e-05
# [Adam] Epoch  1510 | Loss: 9.0444e-02 | LR: 1.00e-05
# [Adam] Epoch  1520 | Loss: 9.0428e-02 | LR: 1.00e-05
# [Adam] Epoch  1530 | Loss: 9.0412e-02 | LR: 1.00e-05
# [Adam] Epoch  1540 | Loss: 9.0397e-02 | LR: 1.00e-05
# [Adam] Epoch  1550 | Loss: 9.0382e-02 | LR: 1.00e-05
# [Adam] Epoch  1560 | Loss: 9.0368e-02 | LR: 1.00e-05
# [Adam] Epoch  1570 | Loss: 9.0353e-02 | LR: 1.00e-05
# [Adam] Epoch  1580 | Loss: 9.0339e-02 | LR: 1.00e-05
# [Adam] Epoch  1590 | Loss: 9.0325e-02 | LR: 1.00e-05
# [Adam] Epoch  1600 | Loss: 9.0312e-02 | LR: 1.00e-05
# [Adam] Epoch  1610 | Loss: 9.0298e-02 | LR: 1.00e-05
# [Adam] Epoch  1620 | Loss: 9.0285e-02 | LR: 1.00e-05
# [Adam] Epoch  1630 | Loss: 9.0272e-02 | LR: 1.00e-05
# [Adam] Epoch  1640 | Loss: 9.0260e-02 | LR: 1.00e-05
# [Adam] Epoch  1650 | Loss: 9.0247e-02 | LR: 1.00e-05
# [Adam] Epoch  1660 | Loss: 9.0235e-02 | LR: 1.00e-05
# [Adam] Epoch  1670 | Loss: 9.0223e-02 | LR: 1.00e-05
# [Adam] Epoch  1680 | Loss: 9.0211e-02 | LR: 1.00e-05
# [Adam] Epoch  1690 | Loss: 9.0199e-02 | LR: 1.00e-05
# [Adam] Epoch  1700 | Loss: 9.0188e-02 | LR: 1.00e-05
# [Adam] Epoch  1710 | Loss: 9.0176e-02 | LR: 1.00e-05
# [Adam] Epoch  1720 | Loss: 9.0165e-02 | LR: 1.00e-05
# [Adam] Epoch  1730 | Loss: 9.0154e-02 | LR: 1.00e-05
# [Adam] Epoch  1740 | Loss: 9.0143e-02 | LR: 1.00e-05
# [Adam] Epoch  1750 | Loss: 9.0132e-02 | LR: 1.00e-05
# [Adam] Epoch  1760 | Loss: 9.0121e-02 | LR: 1.00e-05
# [Adam] Epoch  1770 | Loss: 9.0111e-02 | LR: 1.00e-05
# [Adam] Epoch  1780 | Loss: 9.0100e-02 | LR: 1.00e-05
# [Adam] Epoch  1790 | Loss: 9.0090e-02 | LR: 1.00e-05
# [Adam] Epoch  1800 | Loss: 9.0080e-02 | LR: 1.00e-05
# [Adam] Epoch  1810 | Loss: 9.0070e-02 | LR: 1.00e-05
# [Adam] Epoch  1820 | Loss: 9.0060e-02 | LR: 1.00e-05
# [Adam] Epoch  1830 | Loss: 9.0050e-02 | LR: 1.00e-05
# [Adam] Epoch  1840 | Loss: 9.0040e-02 | LR: 1.00e-05
# [Adam] Epoch  1850 | Loss: 9.0030e-02 | LR: 1.00e-05
# [Adam] Epoch  1860 | Loss: 9.0020e-02 | LR: 1.00e-05
# [Adam] Epoch  1870 | Loss: 9.0011e-02 | LR: 1.00e-05
# [Adam] Epoch  1880 | Loss: 9.0001e-02 | LR: 1.00e-05
# [Adam] Epoch  1890 | Loss: 8.9992e-02 | LR: 1.00e-05
# [Adam] Epoch  1900 | Loss: 8.9983e-02 | LR: 1.00e-05
# [Adam] Epoch  1910 | Loss: 8.9974e-02 | LR: 1.00e-05
# [Adam] Epoch  1920 | Loss: 8.9965e-02 | LR: 1.00e-05
# [Adam] Epoch  1930 | Loss: 8.9955e-02 | LR: 1.00e-05
# [Adam] Epoch  1940 | Loss: 8.9946e-02 | LR: 1.00e-05
# [Adam] Epoch  1950 | Loss: 8.9937e-02 | LR: 1.00e-05
# [Adam] Epoch  1960 | Loss: 8.9929e-02 | LR: 1.00e-05
# [Adam] Epoch  1970 | Loss: 8.9920e-02 | LR: 1.00e-05
# [Adam] Epoch  1980 | Loss: 8.9911e-02 | LR: 1.00e-05
# [Adam] Epoch  1990 | Loss: 8.9902e-02 | LR: 1.00e-05
# [Adam] Epoch  2000 | Loss: 8.9894e-02 | LR: 1.00e-05
# [Adam] Epoch  2010 | Loss: 8.9885e-02 | LR: 1.00e-05
# [Adam] Epoch  2020 | Loss: 8.9877e-02 | LR: 1.00e-05
# [Adam] Epoch  2030 | Loss: 8.9868e-02 | LR: 1.00e-05
# [Adam] Epoch  2040 | Loss: 8.9860e-02 | LR: 1.00e-05
# [Adam] Epoch  2050 | Loss: 8.9852e-02 | LR: 1.00e-05
# [Adam] Epoch  2060 | Loss: 8.9844e-02 | LR: 1.00e-05
# [Adam] Epoch  2070 | Loss: 8.9835e-02 | LR: 1.00e-05
# [Adam] Epoch  2080 | Loss: 8.9827e-02 | LR: 1.00e-05
# [Adam] Epoch  2090 | Loss: 8.9819e-02 | LR: 1.00e-05
# [Adam] Epoch  2100 | Loss: 8.9811e-02 | LR: 1.00e-05
# [Adam] Epoch  2110 | Loss: 8.9803e-02 | LR: 1.00e-05
# [Adam] Epoch  2120 | Loss: 8.9795e-02 | LR: 1.00e-05
# [Adam] Epoch  2130 | Loss: 8.9787e-02 | LR: 1.00e-05
# [Adam] Epoch  2140 | Loss: 8.9780e-02 | LR: 1.00e-05
# [Adam] Epoch  2150 | Loss: 8.9772e-02 | LR: 1.00e-05
# [Adam] Epoch  2160 | Loss: 8.9764e-02 | LR: 1.00e-05
# [Adam] Epoch  2170 | Loss: 8.9756e-02 | LR: 1.00e-05
# [Adam] Epoch  2180 | Loss: 8.9749e-02 | LR: 1.00e-05
# [Adam] Epoch  2190 | Loss: 8.9741e-02 | LR: 1.00e-05
# [Adam] Epoch  2200 | Loss: 8.9733e-02 | LR: 1.00e-05
# [Adam] Epoch  2210 | Loss: 8.9726e-02 | LR: 1.00e-05
# [Adam] Epoch  2220 | Loss: 8.9719e-02 | LR: 1.00e-05
# [Adam] Epoch  2230 | Loss: 8.9711e-02 | LR: 1.00e-05
# [Adam] Epoch  2240 | Loss: 8.9704e-02 | LR: 1.00e-05
# [Adam] Epoch  2250 | Loss: 8.9696e-02 | LR: 1.00e-05
# [Adam] Epoch  2260 | Loss: 8.9689e-02 | LR: 1.00e-05
# [Adam] Epoch  2270 | Loss: 8.9682e-02 | LR: 1.00e-05
# [Adam] Epoch  2280 | Loss: 8.9675e-02 | LR: 1.00e-05
# [Adam] Epoch  2290 | Loss: 8.9668e-02 | LR: 1.00e-05
# [Adam] Epoch  2300 | Loss: 8.9660e-02 | LR: 1.00e-05
# [Adam] Epoch  2310 | Loss: 8.9653e-02 | LR: 1.00e-05
# [Adam] Epoch  2320 | Loss: 8.9646e-02 | LR: 1.00e-05
# [Adam] Epoch  2330 | Loss: 8.9639e-02 | LR: 1.00e-05
# [Adam] Epoch  2340 | Loss: 8.9632e-02 | LR: 1.00e-05
# [Adam] Epoch  2350 | Loss: 8.9625e-02 | LR: 1.00e-05
# [Adam] Epoch  2360 | Loss: 8.9618e-02 | LR: 1.00e-05
# [Adam] Epoch  2370 | Loss: 8.9611e-02 | LR: 1.00e-05
# [Adam] Epoch  2380 | Loss: 8.9605e-02 | LR: 1.00e-05
# [Adam] Epoch  2390 | Loss: 8.9598e-02 | LR: 1.00e-05
# [Adam] Epoch  2400 | Loss: 8.9591e-02 | LR: 1.00e-05
# [Adam] Epoch  2410 | Loss: 8.9584e-02 | LR: 1.00e-05
# [Adam] Epoch  2420 | Loss: 8.9578e-02 | LR: 1.00e-05
# [Adam] Epoch  2430 | Loss: 8.9571e-02 | LR: 1.00e-05
# [Adam] Epoch  2440 | Loss: 8.9564e-02 | LR: 1.00e-05
# [Adam] Epoch  2450 | Loss: 8.9558e-02 | LR: 1.00e-05
# [Adam] Epoch  2460 | Loss: 8.9551e-02 | LR: 1.00e-05
# [Adam] Epoch  2470 | Loss: 8.9545e-02 | LR: 1.00e-05
# [Adam] Epoch  2480 | Loss: 8.9538e-02 | LR: 1.00e-05
# [Adam] Epoch  2490 | Loss: 8.9532e-02 | LR: 1.00e-05
# [Adam] Epoch  2500 | Loss: 8.9525e-02 | LR: 1.00e-05
# [Adam] Epoch  2510 | Loss: 8.9519e-02 | LR: 1.00e-05
# [Adam] Epoch  2520 | Loss: 8.9512e-02 | LR: 1.00e-05
# [Adam] Epoch  2530 | Loss: 8.9506e-02 | LR: 1.00e-05
# [Adam] Epoch  2540 | Loss: 8.9500e-02 | LR: 1.00e-05
# [Adam] Epoch  2550 | Loss: 8.9493e-02 | LR: 1.00e-05
# [Adam] Epoch  2560 | Loss: 8.9487e-02 | LR: 1.00e-05
# [Adam] Epoch  2570 | Loss: 8.9481e-02 | LR: 1.00e-05
# [Adam] Epoch  2580 | Loss: 8.9475e-02 | LR: 1.00e-05
# [Adam] Epoch  2590 | Loss: 8.9469e-02 | LR: 1.00e-05
# [Adam] Epoch  2600 | Loss: 8.9462e-02 | LR: 1.00e-05
# [Adam] Epoch  2610 | Loss: 8.9456e-02 | LR: 1.00e-05
# [Adam] Epoch  2620 | Loss: 8.9450e-02 | LR: 1.00e-05
# [Adam] Epoch  2630 | Loss: 8.9444e-02 | LR: 1.00e-05
# [Adam] Epoch  2640 | Loss: 8.9438e-02 | LR: 1.00e-05
# [Adam] Epoch  2650 | Loss: 8.9432e-02 | LR: 1.00e-05
# [Adam] Epoch  2660 | Loss: 8.9426e-02 | LR: 1.00e-05
# [Adam] Epoch  2670 | Loss: 8.9420e-02 | LR: 1.00e-05
# [Adam] Epoch  2680 | Loss: 8.9414e-02 | LR: 1.00e-05
# [Adam] Epoch  2690 | Loss: 8.9409e-02 | LR: 1.00e-05
# [Adam] Epoch  2700 | Loss: 8.9403e-02 | LR: 1.00e-05
# [Adam] Epoch  2710 | Loss: 8.9397e-02 | LR: 1.00e-05
# [Adam] Epoch  2720 | Loss: 8.9391e-02 | LR: 1.00e-05
# [Adam] Epoch  2730 | Loss: 8.9385e-02 | LR: 1.00e-05
# [Adam] Epoch  2740 | Loss: 8.9380e-02 | LR: 1.00e-05
# [Adam] Epoch  2750 | Loss: 8.9374e-02 | LR: 1.00e-05
# [Adam] Epoch  2760 | Loss: 8.9368e-02 | LR: 1.00e-05
# [Adam] Epoch  2770 | Loss: 8.9362e-02 | LR: 1.00e-05
# [Adam] Epoch  2780 | Loss: 8.9357e-02 | LR: 1.00e-05
# [Adam] Epoch  2790 | Loss: 8.9351e-02 | LR: 1.00e-05
# [Adam] Epoch  2800 | Loss: 8.9346e-02 | LR: 1.00e-05
# [Adam] Epoch  2810 | Loss: 8.9340e-02 | LR: 1.00e-05
# [Adam] Epoch  2820 | Loss: 8.9334e-02 | LR: 1.00e-05
# [Adam] Epoch  2830 | Loss: 8.9329e-02 | LR: 1.00e-05
# [Adam] Epoch  2840 | Loss: 8.9323e-02 | LR: 1.00e-05
# [Adam] Epoch  2850 | Loss: 8.9318e-02 | LR: 1.00e-05
# [Adam] Epoch  2860 | Loss: 8.9313e-02 | LR: 1.00e-05
# [Adam] Epoch  2870 | Loss: 8.9307e-02 | LR: 1.00e-05
# [Adam] Epoch  2880 | Loss: 8.9302e-02 | LR: 1.00e-05
# [Adam] Epoch  2890 | Loss: 8.9296e-02 | LR: 1.00e-05
# [Adam] Epoch  2900 | Loss: 8.9291e-02 | LR: 1.00e-05
# [Adam] Epoch  2910 | Loss: 8.9286e-02 | LR: 1.00e-05
# [Adam] Epoch  2920 | Loss: 8.9280e-02 | LR: 1.00e-05
# [Adam] Epoch  2930 | Loss: 8.9275e-02 | LR: 1.00e-05
# [Adam] Epoch  2940 | Loss: 8.9270e-02 | LR: 1.00e-05
# [Adam] Epoch  2950 | Loss: 8.9265e-02 | LR: 1.00e-05
# [Adam] Epoch  2960 | Loss: 8.9259e-02 | LR: 1.00e-05
# [Adam] Epoch  2970 | Loss: 8.9254e-02 | LR: 1.00e-05
# [Adam] Epoch  2980 | Loss: 8.9249e-02 | LR: 1.00e-05
# [Adam] Epoch  2990 | Loss: 8.9244e-02 | LR: 1.00e-05
# [Adam] Epoch  3000 | Loss: 8.9239e-02 | LR: 1.00e-05
# [Adam] Epoch  3010 | Loss: 8.9234e-02 | LR: 1.00e-05
# [Adam] Epoch  3020 | Loss: 8.9229e-02 | LR: 1.00e-05
# [Adam] Epoch  3030 | Loss: 8.9223e-02 | LR: 1.00e-05
# [Adam] Epoch  3040 | Loss: 8.9218e-02 | LR: 1.00e-05
# [Adam] Epoch  3050 | Loss: 8.9213e-02 | LR: 1.00e-05
# [Adam] Epoch  3060 | Loss: 8.9208e-02 | LR: 1.00e-05
# [Adam] Epoch  3070 | Loss: 8.9203e-02 | LR: 1.00e-05
# [Adam] Epoch  3080 | Loss: 8.9199e-02 | LR: 1.00e-05
# [Adam] Epoch  3090 | Loss: 8.9194e-02 | LR: 1.00e-05
# [Adam] Epoch  3100 | Loss: 8.9189e-02 | LR: 1.00e-05
# [Adam] Epoch  3110 | Loss: 8.9184e-02 | LR: 1.00e-05
# [Adam] Epoch  3120 | Loss: 8.9179e-02 | LR: 1.00e-05
# [Adam] Epoch  3130 | Loss: 8.9174e-02 | LR: 1.00e-05
# [Adam] Epoch  3140 | Loss: 8.9169e-02 | LR: 1.00e-05
# [Adam] Epoch  3150 | Loss: 8.9164e-02 | LR: 1.00e-05
# [Adam] Epoch  3160 | Loss: 8.9160e-02 | LR: 1.00e-05
# [Adam] Epoch  3170 | Loss: 8.9155e-02 | LR: 1.00e-05
# [Adam] Epoch  3180 | Loss: 8.9150e-02 | LR: 1.00e-05
# [Adam] Epoch  3190 | Loss: 8.9145e-02 | LR: 1.00e-05
# [Adam] Epoch  3200 | Loss: 8.9141e-02 | LR: 1.00e-05
# [Adam] Epoch  3210 | Loss: 8.9136e-02 | LR: 1.00e-05
# [Adam] Epoch  3220 | Loss: 8.9131e-02 | LR: 1.00e-05
# [Adam] Epoch  3230 | Loss: 8.9126e-02 | LR: 1.00e-05
# [Adam] Epoch  3240 | Loss: 8.9122e-02 | LR: 1.00e-05
# [Adam] Epoch  3250 | Loss: 8.9117e-02 | LR: 1.00e-05
# [Adam] Epoch  3260 | Loss: 8.9113e-02 | LR: 1.00e-05
# [Adam] Epoch  3270 | Loss: 8.9108e-02 | LR: 1.00e-05
# [Adam] Epoch  3280 | Loss: 8.9103e-02 | LR: 1.00e-05
# [Adam] Epoch  3290 | Loss: 8.9099e-02 | LR: 1.00e-05
# [Adam] Epoch  3300 | Loss: 8.9094e-02 | LR: 1.00e-05
# [Adam] Epoch  3310 | Loss: 8.9090e-02 | LR: 1.00e-05
# [Adam] Epoch  3320 | Loss: 8.9085e-02 | LR: 1.00e-05
# [Adam] Epoch  3330 | Loss: 8.9081e-02 | LR: 1.00e-05
# [Adam] Epoch  3340 | Loss: 8.9076e-02 | LR: 1.00e-05
# [Adam] Epoch  3350 | Loss: 8.9072e-02 | LR: 1.00e-05
# [Adam] Epoch  3360 | Loss: 8.9068e-02 | LR: 1.00e-05
# [Adam] Epoch  3370 | Loss: 8.9063e-02 | LR: 1.00e-05
# [Adam] Epoch  3380 | Loss: 8.9059e-02 | LR: 1.00e-05
# [Adam] Epoch  3390 | Loss: 8.9054e-02 | LR: 1.00e-05
# [Adam] Epoch  3400 | Loss: 8.9050e-02 | LR: 1.00e-05
# [Adam] Epoch  3410 | Loss: 8.9046e-02 | LR: 1.00e-05
# [Adam] Epoch  3420 | Loss: 8.9041e-02 | LR: 1.00e-05
# [Adam] Epoch  3430 | Loss: 8.9037e-02 | LR: 1.00e-05
# [Adam] Epoch  3440 | Loss: 8.9033e-02 | LR: 1.00e-05
# [Adam] Epoch  3450 | Loss: 8.9028e-02 | LR: 1.00e-05
# [Adam] Epoch  3460 | Loss: 8.9024e-02 | LR: 1.00e-05
# [Adam] Epoch  3470 | Loss: 8.9020e-02 | LR: 1.00e-05
# [Adam] Epoch  3480 | Loss: 8.9016e-02 | LR: 1.00e-05
# [Adam] Epoch  3490 | Loss: 8.9011e-02 | LR: 1.00e-05
# [Adam] Epoch  3500 | Loss: 8.9007e-02 | LR: 1.00e-05
# [Adam] Epoch  3510 | Loss: 8.9003e-02 | LR: 1.00e-05
# [Adam] Epoch  3520 | Loss: 8.8999e-02 | LR: 1.00e-05
# [Adam] Epoch  3530 | Loss: 8.8995e-02 | LR: 1.00e-05
# [Adam] Epoch  3540 | Loss: 8.8990e-02 | LR: 1.00e-05
# [Adam] Epoch  3550 | Loss: 8.8986e-02 | LR: 1.00e-05
# [Adam] Epoch  3560 | Loss: 8.8982e-02 | LR: 1.00e-05
# [Adam] Epoch  3570 | Loss: 8.8978e-02 | LR: 1.00e-05
# [Adam] Epoch  3580 | Loss: 8.8974e-02 | LR: 1.00e-05
# [Adam] Epoch  3590 | Loss: 8.8970e-02 | LR: 1.00e-05
# [Adam] Epoch  3600 | Loss: 8.8966e-02 | LR: 1.00e-05
# [Adam] Epoch  3610 | Loss: 8.8962e-02 | LR: 1.00e-05
# [Adam] Epoch  3620 | Loss: 8.8958e-02 | LR: 1.00e-05
# [Adam] Epoch  3630 | Loss: 8.8954e-02 | LR: 1.00e-05
# [Adam] Epoch  3640 | Loss: 8.8950e-02 | LR: 1.00e-05
# [Adam] Epoch  3650 | Loss: 8.8946e-02 | LR: 1.00e-05
# [Adam] Epoch  3660 | Loss: 8.8942e-02 | LR: 1.00e-05
# [Adam] Epoch  3670 | Loss: 8.8938e-02 | LR: 1.00e-05
# [Adam] Epoch  3680 | Loss: 8.8934e-02 | LR: 1.00e-05
# [Adam] Epoch  3690 | Loss: 8.8930e-02 | LR: 1.00e-05
# [Adam] Epoch  3700 | Loss: 8.8926e-02 | LR: 1.00e-05
# [Adam] Epoch  3710 | Loss: 8.8922e-02 | LR: 1.00e-05
# [Adam] Epoch  3720 | Loss: 8.8918e-02 | LR: 1.00e-05
# [Adam] Epoch  3730 | Loss: 8.8914e-02 | LR: 1.00e-05
# [Adam] Epoch  3740 | Loss: 8.8910e-02 | LR: 1.00e-05
# [Adam] Epoch  3750 | Loss: 8.8907e-02 | LR: 1.00e-05
# [Adam] Epoch  3760 | Loss: 8.8903e-02 | LR: 1.00e-05
# [Adam] Epoch  3770 | Loss: 8.8899e-02 | LR: 1.00e-05
# [Adam] Epoch  3780 | Loss: 8.8895e-02 | LR: 1.00e-05
# [Adam] Epoch  3790 | Loss: 8.8891e-02 | LR: 1.00e-05
# [Adam] Epoch  3800 | Loss: 8.8887e-02 | LR: 1.00e-05
# [Adam] Epoch  3810 | Loss: 8.8884e-02 | LR: 1.00e-05
# [Adam] Epoch  3820 | Loss: 8.8880e-02 | LR: 1.00e-05
# [Adam] Epoch  3830 | Loss: 8.8876e-02 | LR: 1.00e-05
# [Adam] Epoch  3840 | Loss: 8.8872e-02 | LR: 1.00e-05
# [Adam] Epoch  3850 | Loss: 8.8869e-02 | LR: 1.00e-05
# [Adam] Epoch  3860 | Loss: 8.8865e-02 | LR: 1.00e-05
# [Adam] Epoch  3870 | Loss: 8.8861e-02 | LR: 1.00e-05
# [Adam] Epoch  3880 | Loss: 8.8857e-02 | LR: 1.00e-05
# [Adam] Epoch  3890 | Loss: 8.8854e-02 | LR: 1.00e-05
# [Adam] Epoch  3900 | Loss: 8.8850e-02 | LR: 1.00e-05
# [Adam] Epoch  3910 | Loss: 8.8847e-02 | LR: 1.00e-05
# [Adam] Epoch  3920 | Loss: 8.8843e-02 | LR: 1.00e-05
# [Adam] Epoch  3930 | Loss: 8.8839e-02 | LR: 1.00e-05
# [Adam] Epoch  3940 | Loss: 8.8836e-02 | LR: 1.00e-05
# [Adam] Epoch  3950 | Loss: 8.8832e-02 | LR: 1.00e-05
# [Adam] Epoch  3960 | Loss: 8.8828e-02 | LR: 1.00e-05
# [Adam] Epoch  3970 | Loss: 8.8825e-02 | LR: 1.00e-05
# [Adam] Epoch  3980 | Loss: 8.8821e-02 | LR: 1.00e-05
# [Adam] Epoch  3990 | Loss: 8.8818e-02 | LR: 1.00e-05
# [Adam] Epoch  4000 | Loss: 8.8814e-02 | LR: 1.00e-05
# [Adam] Epoch  4010 | Loss: 8.8810e-02 | LR: 1.00e-05
# [Adam] Epoch  4020 | Loss: 8.8807e-02 | LR: 1.00e-05
# [Adam] Epoch  4030 | Loss: 8.8803e-02 | LR: 1.00e-05
# [Adam] Epoch  4040 | Loss: 8.8800e-02 | LR: 1.00e-05
# [Adam] Epoch  4050 | Loss: 8.8796e-02 | LR: 1.00e-05
# [Adam] Epoch  4060 | Loss: 8.8793e-02 | LR: 1.00e-05
# [Adam] Epoch  4070 | Loss: 8.8789e-02 | LR: 1.00e-05
# [Adam] Epoch  4080 | Loss: 8.8786e-02 | LR: 1.00e-05
# [Adam] Epoch  4090 | Loss: 8.8783e-02 | LR: 1.00e-05
# [Adam] Epoch  4100 | Loss: 8.8779e-02 | LR: 1.00e-05
# [Adam] Epoch  4110 | Loss: 8.8776e-02 | LR: 1.00e-05
# [Adam] Epoch  4120 | Loss: 8.8772e-02 | LR: 1.00e-05
# [Adam] Epoch  4130 | Loss: 8.8769e-02 | LR: 1.00e-05
# [Adam] Epoch  4140 | Loss: 8.8765e-02 | LR: 1.00e-05
# [Adam] Epoch  4150 | Loss: 8.8762e-02 | LR: 1.00e-05
# [Adam] Epoch  4160 | Loss: 8.8759e-02 | LR: 1.00e-05
# [Adam] Epoch  4170 | Loss: 8.8755e-02 | LR: 1.00e-05
# [Adam] Epoch  4180 | Loss: 8.8752e-02 | LR: 1.00e-05
# [Adam] Epoch  4190 | Loss: 8.8749e-02 | LR: 1.00e-05
# [Adam] Epoch  4200 | Loss: 8.8745e-02 | LR: 1.00e-05
# [Adam] Epoch  4210 | Loss: 8.8742e-02 | LR: 1.00e-05
# [Adam] Epoch  4220 | Loss: 8.8739e-02 | LR: 1.00e-05
# [Adam] Epoch  4230 | Loss: 8.8735e-02 | LR: 1.00e-05
# [Adam] Epoch  4240 | Loss: 8.8732e-02 | LR: 1.00e-05
# [Adam] Epoch  4250 | Loss: 8.8729e-02 | LR: 1.00e-05
# [Adam] Epoch  4260 | Loss: 8.8725e-02 | LR: 1.00e-05
# [Adam] Epoch  4270 | Loss: 8.8722e-02 | LR: 1.00e-05
# [Adam] Epoch  4280 | Loss: 8.8719e-02 | LR: 1.00e-05
# [Adam] Epoch  4290 | Loss: 8.8716e-02 | LR: 1.00e-05
# [Adam] Epoch  4300 | Loss: 8.8712e-02 | LR: 1.00e-05
# [Adam] Epoch  4310 | Loss: 8.8709e-02 | LR: 1.00e-05
# [Adam] Epoch  4320 | Loss: 8.8706e-02 | LR: 1.00e-05
# [Adam] Epoch  4330 | Loss: 8.8703e-02 | LR: 1.00e-05
# [Adam] Epoch  4340 | Loss: 8.8699e-02 | LR: 1.00e-05
# [Adam] Epoch  4350 | Loss: 8.8696e-02 | LR: 1.00e-05
# [Adam] Epoch  4360 | Loss: 8.8693e-02 | LR: 1.00e-05
# [Adam] Epoch  4370 | Loss: 8.8690e-02 | LR: 1.00e-05
# [Adam] Epoch  4380 | Loss: 8.8687e-02 | LR: 1.00e-05
# [Adam] Epoch  4390 | Loss: 8.8683e-02 | LR: 1.00e-05
# [Adam] Epoch  4400 | Loss: 8.8680e-02 | LR: 1.00e-05
# [Adam] Epoch  4410 | Loss: 8.8677e-02 | LR: 1.00e-05
# [Adam] Epoch  4420 | Loss: 8.8674e-02 | LR: 1.00e-05
# [Adam] Epoch  4430 | Loss: 8.8671e-02 | LR: 1.00e-05
# [Adam] Epoch  4440 | Loss: 8.8668e-02 | LR: 1.00e-05
# [Adam] Epoch  4450 | Loss: 8.8665e-02 | LR: 1.00e-05
# [Adam] Epoch  4460 | Loss: 8.8661e-02 | LR: 1.00e-05
# [Adam] Epoch  4470 | Loss: 8.8658e-02 | LR: 1.00e-05
# [Adam] Epoch  4480 | Loss: 8.8655e-02 | LR: 1.00e-05
# [Adam] Epoch  4490 | Loss: 8.8652e-02 | LR: 1.00e-05
# [Adam] Epoch  4500 | Loss: 8.8649e-02 | LR: 1.00e-05
# [Adam] Epoch  4510 | Loss: 8.8646e-02 | LR: 1.00e-05
# [Adam] Epoch  4520 | Loss: 8.8643e-02 | LR: 1.00e-05
# [Adam] Epoch  4530 | Loss: 8.8640e-02 | LR: 1.00e-05
# [Adam] Epoch  4540 | Loss: 8.8637e-02 | LR: 1.00e-05
# [Adam] Epoch  4550 | Loss: 8.8634e-02 | LR: 1.00e-05
# [Adam] Epoch  4560 | Loss: 8.8631e-02 | LR: 1.00e-05
# [Adam] Epoch  4570 | Loss: 8.8628e-02 | LR: 1.00e-05
# [Adam] Epoch  4580 | Loss: 8.8625e-02 | LR: 1.00e-05
# [Adam] Epoch  4590 | Loss: 8.8622e-02 | LR: 1.00e-05
# [Adam] Epoch  4600 | Loss: 8.8619e-02 | LR: 1.00e-05
# [Adam] Epoch  4610 | Loss: 8.8616e-02 | LR: 1.00e-05
# [Adam] Epoch  4620 | Loss: 8.8613e-02 | LR: 1.00e-05
# [Adam] Epoch  4630 | Loss: 8.8610e-02 | LR: 1.00e-05
# [Adam] Epoch  4640 | Loss: 8.8607e-02 | LR: 1.00e-05
# [Adam] Epoch  4650 | Loss: 8.8604e-02 | LR: 1.00e-05
# [Adam] Epoch  4660 | Loss: 8.8601e-02 | LR: 1.00e-05
# [Adam] Epoch  4670 | Loss: 8.8598e-02 | LR: 1.00e-05
# [Adam] Epoch  4680 | Loss: 8.8595e-02 | LR: 1.00e-05
# [Adam] Epoch  4690 | Loss: 8.8592e-02 | LR: 1.00e-05
# [Adam] Epoch  4700 | Loss: 8.8589e-02 | LR: 1.00e-05
# [Adam] Epoch  4710 | Loss: 8.8586e-02 | LR: 1.00e-05
# [Adam] Epoch  4720 | Loss: 8.8584e-02 | LR: 1.00e-05
# [Adam] Epoch  4730 | Loss: 8.8581e-02 | LR: 1.00e-05
# [Adam] Epoch  4740 | Loss: 8.8578e-02 | LR: 1.00e-05
# [Adam] Epoch  4750 | Loss: 8.8575e-02 | LR: 1.00e-05
# [Adam] Epoch  4760 | Loss: 8.8572e-02 | LR: 1.00e-05
# [Adam] Epoch  4770 | Loss: 8.8569e-02 | LR: 1.00e-05
# [Adam] Epoch  4780 | Loss: 8.8566e-02 | LR: 1.00e-05
# [Adam] Epoch  4790 | Loss: 8.8563e-02 | LR: 1.00e-05
# [Adam] Epoch  4800 | Loss: 8.8561e-02 | LR: 1.00e-05
# [Adam] Epoch  4810 | Loss: 8.8558e-02 | LR: 1.00e-05
# [Adam] Epoch  4820 | Loss: 8.8555e-02 | LR: 1.00e-05
# [Adam] Epoch  4830 | Loss: 8.8552e-02 | LR: 1.00e-05
# [Adam] Epoch  4840 | Loss: 8.8549e-02 | LR: 1.00e-05
# [Adam] Epoch  4850 | Loss: 8.8546e-02 | LR: 1.00e-05
# [Adam] Epoch  4860 | Loss: 8.8544e-02 | LR: 1.00e-05
# [Adam] Epoch  4870 | Loss: 8.8541e-02 | LR: 1.00e-05
# [Adam] Epoch  4880 | Loss: 8.8538e-02 | LR: 1.00e-05
# [Adam] Epoch  4890 | Loss: 8.8536e-02 | LR: 1.00e-05
# [Adam] Epoch  4900 | Loss: 8.8533e-02 | LR: 1.00e-05
# [Adam] Epoch  4910 | Loss: 8.8530e-02 | LR: 1.00e-05
# [Adam] Epoch  4920 | Loss: 8.8527e-02 | LR: 1.00e-05
# [Adam] Epoch  4930 | Loss: 8.8524e-02 | LR: 1.00e-05
# [Adam] Epoch  4940 | Loss: 8.8522e-02 | LR: 1.00e-05
# [Adam] Epoch  4950 | Loss: 8.8519e-02 | LR: 1.00e-05
# [Adam] Epoch  4960 | Loss: 8.8516e-02 | LR: 1.00e-05
# [Adam] Epoch  4970 | Loss: 8.8513e-02 | LR: 1.00e-05
# [Adam] Epoch  4980 | Loss: 8.8511e-02 | LR: 1.00e-05
# [Adam] Epoch  4990 | Loss: 8.8508e-02 | LR: 1.00e-05
# [Adam] Epoch  5000 | Loss: 8.8505e-02 | LR: 1.00e-05
# [Adam] Epoch  5010 | Loss: 8.8503e-02 | LR: 1.00e-05
# [Adam] Epoch  5020 | Loss: 8.8500e-02 | LR: 1.00e-05
# [Adam] Epoch  5030 | Loss: 8.8497e-02 | LR: 1.00e-05
# [Adam] Epoch  5040 | Loss: 8.8495e-02 | LR: 1.00e-05
# [Adam] Epoch  5050 | Loss: 8.8492e-02 | LR: 1.00e-05
# [Adam] Epoch  5060 | Loss: 8.8489e-02 | LR: 1.00e-05
# [Adam] Epoch  5070 | Loss: 8.8487e-02 | LR: 1.00e-05
# [Adam] Epoch  5080 | Loss: 8.8484e-02 | LR: 1.00e-05
# [Adam] Epoch  5090 | Loss: 8.8481e-02 | LR: 1.00e-05
# [Adam] Epoch  5100 | Loss: 8.8479e-02 | LR: 1.00e-05
# [Adam] Epoch  5110 | Loss: 8.8476e-02 | LR: 1.00e-05
# [Adam] Epoch  5120 | Loss: 8.8473e-02 | LR: 1.00e-05
# [Adam] Epoch  5130 | Loss: 8.8471e-02 | LR: 1.00e-05
# [Adam] Epoch  5140 | Loss: 8.8468e-02 | LR: 1.00e-05
# [Adam] Epoch  5150 | Loss: 8.8465e-02 | LR: 1.00e-05
# [Adam] Epoch  5160 | Loss: 8.8463e-02 | LR: 1.00e-05
# [Adam] Epoch  5170 | Loss: 8.8460e-02 | LR: 1.00e-05
# [Adam] Epoch  5180 | Loss: 8.8458e-02 | LR: 1.00e-05
# [Adam] Epoch  5190 | Loss: 8.8455e-02 | LR: 1.00e-05
# [Adam] Epoch  5200 | Loss: 8.8452e-02 | LR: 1.00e-05
# [Adam] Epoch  5210 | Loss: 8.8450e-02 | LR: 1.00e-05
# [Adam] Epoch  5220 | Loss: 8.8447e-02 | LR: 1.00e-05
# [Adam] Epoch  5230 | Loss: 8.8445e-02 | LR: 1.00e-05
# [Adam] Epoch  5240 | Loss: 8.8442e-02 | LR: 1.00e-05
# [Adam] Epoch  5250 | Loss: 8.8440e-02 | LR: 1.00e-05
# [Adam] Epoch  5260 | Loss: 8.8437e-02 | LR: 1.00e-05
# [Adam] Epoch  5270 | Loss: 8.8435e-02 | LR: 1.00e-05
# [Adam] Epoch  5280 | Loss: 8.8432e-02 | LR: 1.00e-05
# [Adam] Epoch  5290 | Loss: 8.8430e-02 | LR: 1.00e-05
# [Adam] Epoch  5300 | Loss: 8.8427e-02 | LR: 1.00e-05
# [Adam] Epoch  5310 | Loss: 8.8425e-02 | LR: 1.00e-05
# [Adam] Epoch  5320 | Loss: 8.8422e-02 | LR: 1.00e-05
# [Adam] Epoch  5330 | Loss: 8.8420e-02 | LR: 1.00e-05
# [Adam] Epoch  5340 | Loss: 8.8417e-02 | LR: 1.00e-05
# [Adam] Epoch  5350 | Loss: 8.8415e-02 | LR: 1.00e-05
# [Adam] Epoch  5360 | Loss: 8.8412e-02 | LR: 1.00e-05
# [Adam] Epoch  5370 | Loss: 8.8410e-02 | LR: 1.00e-05
# [Adam] Epoch  5380 | Loss: 8.8407e-02 | LR: 1.00e-05
# [Adam] Epoch  5390 | Loss: 8.8405e-02 | LR: 1.00e-05
# [Adam] Epoch  5400 | Loss: 8.8402e-02 | LR: 1.00e-05
# [Adam] Epoch  5410 | Loss: 8.8400e-02 | LR: 1.00e-05
# [Adam] Epoch  5420 | Loss: 8.8397e-02 | LR: 1.00e-05
# [Adam] Epoch  5430 | Loss: 8.8395e-02 | LR: 1.00e-05
# [Adam] Epoch  5440 | Loss: 8.8392e-02 | LR: 1.00e-05
# [Adam] Epoch  5450 | Loss: 8.8390e-02 | LR: 1.00e-05
# [Adam] Epoch  5460 | Loss: 8.8388e-02 | LR: 1.00e-05
# [Adam] Epoch  5470 | Loss: 8.8385e-02 | LR: 1.00e-05
# [Adam] Epoch  5480 | Loss: 8.8383e-02 | LR: 1.00e-05
# [Adam] Epoch  5490 | Loss: 8.8380e-02 | LR: 1.00e-05
# [Adam] Epoch  5500 | Loss: 8.8378e-02 | LR: 1.00e-05
# [Adam] Epoch  5510 | Loss: 8.8376e-02 | LR: 1.00e-05
# [Adam] Epoch  5520 | Loss: 8.8373e-02 | LR: 1.00e-05
# [Adam] Epoch  5530 | Loss: 8.8371e-02 | LR: 1.00e-05
# [Adam] Epoch  5540 | Loss: 8.8368e-02 | LR: 1.00e-05
# [Adam] Epoch  5550 | Loss: 8.8366e-02 | LR: 1.00e-05
# [Adam] Epoch  5560 | Loss: 8.8364e-02 | LR: 1.00e-05
# [Adam] Epoch  5570 | Loss: 8.8361e-02 | LR: 1.00e-05
# [Adam] Epoch  5580 | Loss: 8.8359e-02 | LR: 1.00e-05
# [Adam] Epoch  5590 | Loss: 8.8356e-02 | LR: 1.00e-05
# [Adam] Epoch  5600 | Loss: 8.8354e-02 | LR: 1.00e-05
# [Adam] Epoch  5610 | Loss: 8.8352e-02 | LR: 1.00e-05
# [Adam] Epoch  5620 | Loss: 8.8349e-02 | LR: 1.00e-05
# [Adam] Epoch  5630 | Loss: 8.8347e-02 | LR: 1.00e-05
# [Adam] Epoch  5640 | Loss: 8.8345e-02 | LR: 1.00e-05
# [Adam] Epoch  5650 | Loss: 8.8342e-02 | LR: 1.00e-05
# [Adam] Epoch  5660 | Loss: 8.8340e-02 | LR: 1.00e-05
# [Adam] Epoch  5670 | Loss: 8.8338e-02 | LR: 1.00e-05
# [Adam] Epoch  5680 | Loss: 8.8336e-02 | LR: 1.00e-05
# [Adam] Epoch  5690 | Loss: 8.8333e-02 | LR: 1.00e-05
# [Adam] Epoch  5700 | Loss: 8.8331e-02 | LR: 1.00e-05
# [Adam] Epoch  5710 | Loss: 8.8329e-02 | LR: 1.00e-05
# [Adam] Epoch  5720 | Loss: 8.8326e-02 | LR: 1.00e-05
# [Adam] Epoch  5730 | Loss: 8.8324e-02 | LR: 1.00e-05
# [Adam] Epoch  5740 | Loss: 8.8322e-02 | LR: 1.00e-05
# [Adam] Epoch  5750 | Loss: 8.8319e-02 | LR: 1.00e-05
# [Adam] Epoch  5760 | Loss: 8.8317e-02 | LR: 1.00e-05
# [Adam] Epoch  5770 | Loss: 8.8315e-02 | LR: 1.00e-05
# [Adam] Epoch  5780 | Loss: 8.8313e-02 | LR: 1.00e-05
# [Adam] Epoch  5790 | Loss: 8.8310e-02 | LR: 1.00e-05
# [Adam] Epoch  5800 | Loss: 8.8308e-02 | LR: 1.00e-05
# [Adam] Epoch  5810 | Loss: 8.8306e-02 | LR: 1.00e-05
# [Adam] Epoch  5820 | Loss: 8.8304e-02 | LR: 1.00e-05
# [Adam] Epoch  5830 | Loss: 8.8301e-02 | LR: 1.00e-05
# [Adam] Epoch  5840 | Loss: 8.8299e-02 | LR: 1.00e-05
# [Adam] Epoch  5850 | Loss: 8.8297e-02 | LR: 1.00e-05
# [Adam] Epoch  5860 | Loss: 8.8295e-02 | LR: 1.00e-05
# [Adam] Epoch  5870 | Loss: 8.8292e-02 | LR: 1.00e-05
# [Adam] Epoch  5880 | Loss: 8.8290e-02 | LR: 1.00e-05
# [Adam] Epoch  5890 | Loss: 8.8288e-02 | LR: 1.00e-05
# [Adam] Epoch  5900 | Loss: 8.8286e-02 | LR: 1.00e-05
# [Adam] Epoch  5910 | Loss: 8.8283e-02 | LR: 1.00e-05
# [Adam] Epoch  5920 | Loss: 8.8281e-02 | LR: 1.00e-05
# [Adam] Epoch  5930 | Loss: 8.8279e-02 | LR: 1.00e-05
# [Adam] Epoch  5940 | Loss: 8.8277e-02 | LR: 1.00e-05
# [Adam] Epoch  5950 | Loss: 8.8275e-02 | LR: 1.00e-05
# [Adam] Epoch  5960 | Loss: 8.8273e-02 | LR: 1.00e-05
# [Adam] Epoch  5970 | Loss: 8.8270e-02 | LR: 1.00e-05
# [Adam] Epoch  5980 | Loss: 8.8268e-02 | LR: 1.00e-05
# [Adam] Epoch  5990 | Loss: 8.8266e-02 | LR: 1.00e-05
# [Adam] Epoch  6000 | Loss: 8.8264e-02 | LR: 1.00e-05
# [Adam] Epoch  6010 | Loss: 8.8262e-02 | LR: 1.00e-05
# [Adam] Epoch  6020 | Loss: 8.8259e-02 | LR: 1.00e-05
# [Adam] Epoch  6030 | Loss: 8.8257e-02 | LR: 1.00e-05
# [Adam] Epoch  6040 | Loss: 8.8255e-02 | LR: 1.00e-05
# [Adam] Epoch  6050 | Loss: 8.8253e-02 | LR: 1.00e-05
# [Adam] Epoch  6060 | Loss: 8.8251e-02 | LR: 1.00e-05
# [Adam] Epoch  6070 | Loss: 8.8249e-02 | LR: 1.00e-05
# [Adam] Epoch  6080 | Loss: 8.8247e-02 | LR: 1.00e-05
# [Adam] Epoch  6090 | Loss: 8.8245e-02 | LR: 1.00e-05
# [Adam] Epoch  6100 | Loss: 8.8242e-02 | LR: 1.00e-05
# [Adam] Epoch  6110 | Loss: 8.8240e-02 | LR: 1.00e-05
# [Adam] Epoch  6120 | Loss: 8.8238e-02 | LR: 1.00e-05
# [Adam] Epoch  6130 | Loss: 8.8236e-02 | LR: 1.00e-05
# [Adam] Epoch  6140 | Loss: 8.8234e-02 | LR: 1.00e-05
# [Adam] Epoch  6150 | Loss: 8.8232e-02 | LR: 1.00e-05
# [Adam] Epoch  6160 | Loss: 8.8230e-02 | LR: 1.00e-05
# [Adam] Epoch  6170 | Loss: 8.8228e-02 | LR: 1.00e-05
# [Adam] Epoch  6180 | Loss: 8.8226e-02 | LR: 1.00e-05
# [Adam] Epoch  6190 | Loss: 8.8223e-02 | LR: 1.00e-05
# [Adam] Epoch  6200 | Loss: 8.8221e-02 | LR: 1.00e-05
# [Adam] Epoch  6210 | Loss: 8.8219e-02 | LR: 1.00e-05
# [Adam] Epoch  6220 | Loss: 8.8217e-02 | LR: 1.00e-05
# [Adam] Epoch  6230 | Loss: 8.8215e-02 | LR: 1.00e-05
# [Adam] Epoch  6240 | Loss: 8.8213e-02 | LR: 1.00e-05
# [Adam] Epoch  6250 | Loss: 8.8211e-02 | LR: 1.00e-05
# [Adam] Epoch  6260 | Loss: 8.8209e-02 | LR: 1.00e-05
# [Adam] Epoch  6270 | Loss: 8.8207e-02 | LR: 1.00e-05
# [Adam] Epoch  6280 | Loss: 8.8205e-02 | LR: 1.00e-05
# [Adam] Epoch  6290 | Loss: 8.8203e-02 | LR: 1.00e-05
# [Adam] Epoch  6300 | Loss: 8.8201e-02 | LR: 1.00e-05
# [Adam] Epoch  6310 | Loss: 8.8199e-02 | LR: 1.00e-05
# [Adam] Epoch  6320 | Loss: 8.8197e-02 | LR: 1.00e-05
# [Adam] Epoch  6330 | Loss: 8.8195e-02 | LR: 1.00e-05
# [Adam] Epoch  6340 | Loss: 8.8193e-02 | LR: 1.00e-05
# [Adam] Epoch  6350 | Loss: 8.8191e-02 | LR: 1.00e-05
# [Adam] Epoch  6360 | Loss: 8.8188e-02 | LR: 1.00e-05
# [Adam] Epoch  6370 | Loss: 8.8186e-02 | LR: 1.00e-05
# [Adam] Epoch  6380 | Loss: 8.8184e-02 | LR: 1.00e-05
# [Adam] Epoch  6390 | Loss: 8.8183e-02 | LR: 1.00e-05
# [Adam] Epoch  6400 | Loss: 8.8180e-02 | LR: 1.00e-05
# [Adam] Epoch  6410 | Loss: 8.8178e-02 | LR: 1.00e-05
# [Adam] Epoch  6420 | Loss: 8.8177e-02 | LR: 1.00e-05
# [Adam] Epoch  6430 | Loss: 8.8174e-02 | LR: 1.00e-05
# [Adam] Epoch  6440 | Loss: 8.8172e-02 | LR: 1.00e-05
# [Adam] Epoch  6450 | Loss: 8.8170e-02 | LR: 1.00e-05
# [Adam] Epoch  6460 | Loss: 8.8168e-02 | LR: 1.00e-05
# [Adam] Epoch  6470 | Loss: 8.8166e-02 | LR: 1.00e-05
# [Adam] Epoch  6480 | Loss: 8.8164e-02 | LR: 1.00e-05
# [Adam] Epoch  6490 | Loss: 8.8163e-02 | LR: 1.00e-05
# [Adam] Epoch  6500 | Loss: 8.8161e-02 | LR: 1.00e-05
# [Adam] Epoch  6510 | Loss: 8.8159e-02 | LR: 1.00e-05
# [Adam] Epoch  6520 | Loss: 8.8157e-02 | LR: 1.00e-05
# [Adam] Epoch  6530 | Loss: 8.8155e-02 | LR: 1.00e-05
# [Adam] Epoch  6540 | Loss: 8.8153e-02 | LR: 1.00e-05
# [Adam] Epoch  6550 | Loss: 8.8151e-02 | LR: 1.00e-05
# [Adam] Epoch  6560 | Loss: 8.8149e-02 | LR: 1.00e-05
# [Adam] Epoch  6570 | Loss: 8.8147e-02 | LR: 1.00e-05
# [Adam] Epoch  6580 | Loss: 8.8145e-02 | LR: 1.00e-05
# [Adam] Epoch  6590 | Loss: 8.8143e-02 | LR: 1.00e-05
# [Adam] Epoch  6600 | Loss: 8.8141e-02 | LR: 1.00e-05
# [Adam] Epoch  6610 | Loss: 8.8139e-02 | LR: 1.00e-05
# [Adam] Epoch  6620 | Loss: 8.8137e-02 | LR: 1.00e-05
# [Adam] Epoch  6630 | Loss: 8.8135e-02 | LR: 1.00e-05
# [Adam] Epoch  6640 | Loss: 8.8133e-02 | LR: 1.00e-05
# [Adam] Epoch  6650 | Loss: 8.8131e-02 | LR: 1.00e-05
# [Adam] Epoch  6660 | Loss: 8.8129e-02 | LR: 1.00e-05
# [Adam] Epoch  6670 | Loss: 8.8128e-02 | LR: 1.00e-05
# [Adam] Epoch  6680 | Loss: 8.8126e-02 | LR: 1.00e-05
# [Adam] Epoch  6690 | Loss: 8.8124e-02 | LR: 1.00e-05
# [Adam] Epoch  6700 | Loss: 8.8122e-02 | LR: 1.00e-05
# [Adam] Epoch  6710 | Loss: 8.8120e-02 | LR: 1.00e-05
# [Adam] Epoch  6720 | Loss: 8.8118e-02 | LR: 1.00e-05
# [Adam] Epoch  6730 | Loss: 8.8116e-02 | LR: 1.00e-05
# [Adam] Epoch  6740 | Loss: 8.8114e-02 | LR: 1.00e-05
# [Adam] Epoch  6750 | Loss: 8.8112e-02 | LR: 1.00e-05
# [Adam] Epoch  6760 | Loss: 8.8110e-02 | LR: 1.00e-05
# [Adam] Epoch  6770 | Loss: 8.8109e-02 | LR: 1.00e-05
# [Adam] Epoch  6780 | Loss: 8.8107e-02 | LR: 1.00e-05
# [Adam] Epoch  6790 | Loss: 8.8105e-02 | LR: 1.00e-05
# [Adam] Epoch  6800 | Loss: 8.8103e-02 | LR: 1.00e-05
# [Adam] Epoch  6810 | Loss: 8.8101e-02 | LR: 1.00e-05
# [Adam] Epoch  6820 | Loss: 8.8099e-02 | LR: 1.00e-05
# [Adam] Epoch  6830 | Loss: 8.8097e-02 | LR: 1.00e-05
# [Adam] Epoch  6840 | Loss: 8.8096e-02 | LR: 1.00e-05
# [Adam] Epoch  6850 | Loss: 8.8094e-02 | LR: 1.00e-05
# [Adam] Epoch  6860 | Loss: 8.8092e-02 | LR: 1.00e-05
# [Adam] Epoch  6870 | Loss: 8.8090e-02 | LR: 1.00e-05
# [Adam] Epoch  6880 | Loss: 8.8088e-02 | LR: 1.00e-05
# [Adam] Epoch  6890 | Loss: 8.8086e-02 | LR: 1.00e-05
# [Adam] Epoch  6900 | Loss: 8.8084e-02 | LR: 1.00e-05
# [Adam] Epoch  6910 | Loss: 8.8082e-02 | LR: 1.00e-05
# [Adam] Epoch  6920 | Loss: 8.8081e-02 | LR: 1.00e-05
# [Adam] Epoch  6930 | Loss: 8.8079e-02 | LR: 1.00e-05
# [Adam] Epoch  6940 | Loss: 8.8077e-02 | LR: 1.00e-05
# [Adam] Epoch  6950 | Loss: 8.8075e-02 | LR: 1.00e-05
# [Adam] Epoch  6960 | Loss: 8.8073e-02 | LR: 1.00e-05
# [Adam] Epoch  6970 | Loss: 8.8072e-02 | LR: 1.00e-05
# [Adam] Epoch  6980 | Loss: 8.8070e-02 | LR: 1.00e-05
# [Adam] Epoch  6990 | Loss: 8.8068e-02 | LR: 1.00e-05
# [Adam] Epoch  7000 | Loss: 8.8066e-02 | LR: 1.00e-05
# [Adam] Epoch  7010 | Loss: 8.8064e-02 | LR: 1.00e-05
# [Adam] Epoch  7020 | Loss: 8.8063e-02 | LR: 1.00e-05
# [Adam] Epoch  7030 | Loss: 8.8061e-02 | LR: 1.00e-05
# [Adam] Epoch  7040 | Loss: 8.8059e-02 | LR: 1.00e-05
# [Adam] Epoch  7050 | Loss: 8.8057e-02 | LR: 1.00e-05
# [Adam] Epoch  7060 | Loss: 8.8055e-02 | LR: 1.00e-05
# [Adam] Epoch  7070 | Loss: 8.8054e-02 | LR: 1.00e-05
# [Adam] Epoch  7080 | Loss: 8.8052e-02 | LR: 1.00e-05
# [Adam] Epoch  7090 | Loss: 8.8050e-02 | LR: 1.00e-05
# [Adam] Epoch  7100 | Loss: 8.8048e-02 | LR: 1.00e-05
# [Adam] Epoch  7110 | Loss: 8.8046e-02 | LR: 1.00e-05
# [Adam] Epoch  7120 | Loss: 8.8045e-02 | LR: 1.00e-05
# [Adam] Epoch  7130 | Loss: 8.8043e-02 | LR: 1.00e-05
# [Adam] Epoch  7140 | Loss: 8.8041e-02 | LR: 1.00e-05
# [Adam] Epoch  7150 | Loss: 8.8039e-02 | LR: 1.00e-05
# [Adam] Epoch  7160 | Loss: 8.8038e-02 | LR: 1.00e-05
# [Adam] Epoch  7170 | Loss: 8.8036e-02 | LR: 1.00e-05
# [Adam] Epoch  7180 | Loss: 8.8034e-02 | LR: 1.00e-05
# [Adam] Epoch  7190 | Loss: 8.8032e-02 | LR: 1.00e-05
# [Adam] Epoch  7200 | Loss: 8.8031e-02 | LR: 1.00e-05
# [Adam] Epoch  7210 | Loss: 8.8029e-02 | LR: 1.00e-05
# [Adam] Epoch  7220 | Loss: 8.8027e-02 | LR: 1.00e-05
# [Adam] Epoch  7230 | Loss: 8.8025e-02 | LR: 1.00e-05
# [Adam] Epoch  7240 | Loss: 8.8024e-02 | LR: 1.00e-05
# [Adam] Epoch  7250 | Loss: 8.8022e-02 | LR: 1.00e-05
# [Adam] Epoch  7260 | Loss: 8.8020e-02 | LR: 1.00e-05
# [Adam] Epoch  7270 | Loss: 8.8018e-02 | LR: 1.00e-05
# [Adam] Epoch  7280 | Loss: 8.8017e-02 | LR: 1.00e-05
# [Adam] Epoch  7290 | Loss: 8.8015e-02 | LR: 1.00e-05
# [Adam] Epoch  7300 | Loss: 8.8013e-02 | LR: 1.00e-05
# [Adam] Epoch  7310 | Loss: 8.8012e-02 | LR: 1.00e-05
# [Adam] Epoch  7320 | Loss: 8.8010e-02 | LR: 1.00e-05
# [Adam] Epoch  7330 | Loss: 8.8008e-02 | LR: 1.00e-05
# [Adam] Epoch  7340 | Loss: 8.8006e-02 | LR: 1.00e-05
# [Adam] Epoch  7350 | Loss: 8.8005e-02 | LR: 1.00e-05
# [Adam] Epoch  7360 | Loss: 8.8003e-02 | LR: 1.00e-05
# [Adam] Epoch  7370 | Loss: 8.8001e-02 | LR: 1.00e-05
# [Adam] Epoch  7380 | Loss: 8.8000e-02 | LR: 1.00e-05
# [Adam] Epoch  7390 | Loss: 8.7998e-02 | LR: 1.00e-05
# [Adam] Epoch  7400 | Loss: 8.7996e-02 | LR: 1.00e-05
# [Adam] Epoch  7410 | Loss: 8.7994e-02 | LR: 1.00e-05
# [Adam] Epoch  7420 | Loss: 8.7993e-02 | LR: 1.00e-05
# [Adam] Epoch  7430 | Loss: 8.7991e-02 | LR: 1.00e-05
# [Adam] Epoch  7440 | Loss: 8.7990e-02 | LR: 1.00e-05
# [Adam] Epoch  7450 | Loss: 8.7988e-02 | LR: 1.00e-05
# [Adam] Epoch  7460 | Loss: 8.7986e-02 | LR: 1.00e-05
# [Adam] Epoch  7470 | Loss: 8.7984e-02 | LR: 1.00e-05
# [Adam] Epoch  7480 | Loss: 8.7983e-02 | LR: 1.00e-05
# [Adam] Epoch  7490 | Loss: 8.7981e-02 | LR: 1.00e-05
# [Adam] Epoch  7500 | Loss: 8.7979e-02 | LR: 1.00e-05
# [Adam] Epoch  7510 | Loss: 8.7978e-02 | LR: 1.00e-05
# [Adam] Epoch  7520 | Loss: 8.7976e-02 | LR: 1.00e-05
# [Adam] Epoch  7530 | Loss: 8.7974e-02 | LR: 1.00e-05
# [Adam] Epoch  7540 | Loss: 8.7973e-02 | LR: 1.00e-05
# [Adam] Epoch  7550 | Loss: 8.7971e-02 | LR: 1.00e-05
# [Adam] Epoch  7560 | Loss: 8.7969e-02 | LR: 1.00e-05
# [Adam] Epoch  7570 | Loss: 8.7968e-02 | LR: 1.00e-05
# [Adam] Epoch  7580 | Loss: 8.7966e-02 | LR: 1.00e-05
# [Adam] Epoch  7590 | Loss: 8.7964e-02 | LR: 1.00e-05
# [Adam] Epoch  7600 | Loss: 8.7963e-02 | LR: 1.00e-05
# [Adam] Epoch  7610 | Loss: 8.7961e-02 | LR: 1.00e-05
# [Adam] Epoch  7620 | Loss: 8.7960e-02 | LR: 1.00e-05
# [Adam] Epoch  7630 | Loss: 8.7958e-02 | LR: 1.00e-05
# [Adam] Epoch  7640 | Loss: 8.7956e-02 | LR: 1.00e-05
# [Adam] Epoch  7650 | Loss: 8.7955e-02 | LR: 1.00e-05
# [Adam] Epoch  7660 | Loss: 8.7953e-02 | LR: 1.00e-05
# [Adam] Epoch  7670 | Loss: 8.7951e-02 | LR: 1.00e-05
# [Adam] Epoch  7680 | Loss: 8.7950e-02 | LR: 1.00e-05
# [Adam] Epoch  7690 | Loss: 8.7948e-02 | LR: 1.00e-05
# [Adam] Epoch  7700 | Loss: 8.7947e-02 | LR: 1.00e-05
# [Adam] Epoch  7710 | Loss: 8.7945e-02 | LR: 1.00e-05
# [Adam] Epoch  7720 | Loss: 8.7943e-02 | LR: 1.00e-05
# [Adam] Epoch  7730 | Loss: 8.7942e-02 | LR: 1.00e-05
# [Adam] Epoch  7740 | Loss: 8.7940e-02 | LR: 1.00e-05
# [Adam] Epoch  7750 | Loss: 8.7938e-02 | LR: 1.00e-05
# [Adam] Epoch  7760 | Loss: 8.7937e-02 | LR: 1.00e-05
# [Adam] Epoch  7770 | Loss: 8.7935e-02 | LR: 1.00e-05
# [Adam] Epoch  7780 | Loss: 8.7934e-02 | LR: 1.00e-05
# [Adam] Epoch  7790 | Loss: 8.7932e-02 | LR: 1.00e-05
# [Adam] Epoch  7800 | Loss: 8.7931e-02 | LR: 1.00e-05
# [Adam] Epoch  7810 | Loss: 8.7929e-02 | LR: 1.00e-05
# [Adam] Epoch  7820 | Loss: 8.7927e-02 | LR: 1.00e-05
# [Adam] Epoch  7830 | Loss: 8.7926e-02 | LR: 1.00e-05
# [Adam] Epoch  7840 | Loss: 8.7924e-02 | LR: 1.00e-05
# [Adam] Epoch  7850 | Loss: 8.7923e-02 | LR: 1.00e-05
# [Adam] Epoch  7860 | Loss: 8.7921e-02 | LR: 1.00e-05
# [Adam] Epoch  7870 | Loss: 8.7919e-02 | LR: 1.00e-05
# [Adam] Epoch  7880 | Loss: 8.7918e-02 | LR: 1.00e-05
# [Adam] Epoch  7890 | Loss: 8.7916e-02 | LR: 1.00e-05
# [Adam] Epoch  7900 | Loss: 8.7915e-02 | LR: 1.00e-05
# [Adam] Epoch  7910 | Loss: 8.7913e-02 | LR: 1.00e-05
# [Adam] Epoch  7920 | Loss: 8.7912e-02 | LR: 1.00e-05
# [Adam] Epoch  7930 | Loss: 8.7910e-02 | LR: 1.00e-05
# [Adam] Epoch  7940 | Loss: 8.7908e-02 | LR: 1.00e-05
# [Adam] Epoch  7950 | Loss: 8.7907e-02 | LR: 1.00e-05
# [Adam] Epoch  7960 | Loss: 8.7905e-02 | LR: 1.00e-05
# [Adam] Epoch  7970 | Loss: 8.7904e-02 | LR: 1.00e-05
# [Adam] Epoch  7980 | Loss: 8.7902e-02 | LR: 1.00e-05
# [Adam] Epoch  7990 | Loss: 8.7900e-02 | LR: 1.00e-05
# [Adam] Epoch  8000 | Loss: 8.7899e-02 | LR: 1.00e-05
# [Adam] Epoch  8010 | Loss: 8.7897e-02 | LR: 1.00e-05
# [Adam] Epoch  8020 | Loss: 8.7896e-02 | LR: 1.00e-05
# [Adam] Epoch  8030 | Loss: 8.7894e-02 | LR: 1.00e-05
# [Adam] Epoch  8040 | Loss: 8.7893e-02 | LR: 1.00e-05
# [Adam] Epoch  8050 | Loss: 8.7891e-02 | LR: 1.00e-05
# [Adam] Epoch  8060 | Loss: 8.7890e-02 | LR: 1.00e-05
# [Adam] Epoch  8070 | Loss: 8.7888e-02 | LR: 1.00e-05
# [Adam] Epoch  8080 | Loss: 8.7887e-02 | LR: 1.00e-05
# [Adam] Epoch  8090 | Loss: 8.7885e-02 | LR: 1.00e-05
# [Adam] Epoch  8100 | Loss: 8.7884e-02 | LR: 1.00e-05
# [Adam] Epoch  8110 | Loss: 8.7882e-02 | LR: 1.00e-05
# [Adam] Epoch  8120 | Loss: 8.7881e-02 | LR: 1.00e-05
# [Adam] Epoch  8130 | Loss: 8.7879e-02 | LR: 1.00e-05
# [Adam] Epoch  8140 | Loss: 8.7878e-02 | LR: 1.00e-05
# [Adam] Epoch  8150 | Loss: 8.7876e-02 | LR: 1.00e-05
# [Adam] Epoch  8160 | Loss: 8.7874e-02 | LR: 1.00e-05
# [Adam] Epoch  8170 | Loss: 8.7873e-02 | LR: 1.00e-05
# [Adam] Epoch  8180 | Loss: 8.7871e-02 | LR: 1.00e-05
# [Adam] Epoch  8190 | Loss: 8.7870e-02 | LR: 1.00e-05
# [Adam] Epoch  8200 | Loss: 8.7868e-02 | LR: 1.00e-05
# [Adam] Epoch  8210 | Loss: 8.7867e-02 | LR: 1.00e-05
# [Adam] Epoch  8220 | Loss: 8.7866e-02 | LR: 1.00e-05
# [Adam] Epoch  8230 | Loss: 8.7864e-02 | LR: 1.00e-05
# [Adam] Epoch  8240 | Loss: 8.7862e-02 | LR: 1.00e-05
# [Adam] Epoch  8250 | Loss: 8.7861e-02 | LR: 1.00e-05
# [Adam] Epoch  8260 | Loss: 8.7859e-02 | LR: 1.00e-05
# [Adam] Epoch  8270 | Loss: 8.7858e-02 | LR: 1.00e-05
# [Adam] Epoch  8280 | Loss: 8.7857e-02 | LR: 1.00e-05
# [Adam] Epoch  8290 | Loss: 8.7855e-02 | LR: 1.00e-05
# [Adam] Epoch  8300 | Loss: 8.7854e-02 | LR: 1.00e-05
# [Adam] Epoch  8310 | Loss: 8.7852e-02 | LR: 1.00e-05
# [Adam] Epoch  8320 | Loss: 8.7851e-02 | LR: 1.00e-05
# [Adam] Epoch  8330 | Loss: 8.7849e-02 | LR: 1.00e-05
# [Adam] Epoch  8340 | Loss: 8.7848e-02 | LR: 1.00e-05
# [Adam] Epoch  8350 | Loss: 8.7846e-02 | LR: 1.00e-05
# [Adam] Epoch  8360 | Loss: 8.7845e-02 | LR: 1.00e-05
# [Adam] Epoch  8370 | Loss: 8.7843e-02 | LR: 1.00e-05
# [Adam] Epoch  8380 | Loss: 8.7842e-02 | LR: 1.00e-05
# [Adam] Epoch  8390 | Loss: 8.7840e-02 | LR: 1.00e-05
# [Adam] Epoch  8400 | Loss: 8.7839e-02 | LR: 1.00e-05
# [Adam] Epoch  8410 | Loss: 8.7837e-02 | LR: 1.00e-05
# [Adam] Epoch  8420 | Loss: 8.7836e-02 | LR: 1.00e-05
# [Adam] Epoch  8430 | Loss: 8.7834e-02 | LR: 1.00e-05
# [Adam] Epoch  8440 | Loss: 8.7833e-02 | LR: 1.00e-05
# [Adam] Epoch  8450 | Loss: 8.7831e-02 | LR: 1.00e-05
# [Adam] Epoch  8460 | Loss: 8.7830e-02 | LR: 1.00e-05
# [Adam] Epoch  8470 | Loss: 8.7829e-02 | LR: 1.00e-05
# [Adam] Epoch  8480 | Loss: 8.7827e-02 | LR: 1.00e-05
# [Adam] Epoch  8490 | Loss: 8.7826e-02 | LR: 1.00e-05
# [Adam] Epoch  8500 | Loss: 8.7824e-02 | LR: 1.00e-05
# [Adam] Epoch  8510 | Loss: 8.7823e-02 | LR: 1.00e-05
# [Adam] Epoch  8520 | Loss: 8.7821e-02 | LR: 1.00e-05
# [Adam] Epoch  8530 | Loss: 8.7820e-02 | LR: 1.00e-05
# [Adam] Epoch  8540 | Loss: 8.7818e-02 | LR: 1.00e-05
# [Adam] Epoch  8550 | Loss: 8.7817e-02 | LR: 1.00e-05
# [Adam] Epoch  8560 | Loss: 8.7815e-02 | LR: 1.00e-05
# [Adam] Epoch  8570 | Loss: 8.7814e-02 | LR: 1.00e-05
# [Adam] Epoch  8580 | Loss: 8.7813e-02 | LR: 1.00e-05
# [Adam] Epoch  8590 | Loss: 8.7811e-02 | LR: 1.00e-05
# [Adam] Epoch  8600 | Loss: 8.7810e-02 | LR: 1.00e-05
# [Adam] Epoch  8610 | Loss: 8.7808e-02 | LR: 1.00e-05
# [Adam] Epoch  8620 | Loss: 8.7807e-02 | LR: 1.00e-05
# [Adam] Epoch  8630 | Loss: 8.7806e-02 | LR: 1.00e-05
# [Adam] Epoch  8640 | Loss: 8.7804e-02 | LR: 1.00e-05
# [Adam] Epoch  8650 | Loss: 8.7803e-02 | LR: 1.00e-05
# [Adam] Epoch  8660 | Loss: 8.7801e-02 | LR: 1.00e-05
# [Adam] Epoch  8670 | Loss: 8.7800e-02 | LR: 1.00e-05
# [Adam] Epoch  8680 | Loss: 8.7798e-02 | LR: 1.00e-05
# [Adam] Epoch  8690 | Loss: 8.7797e-02 | LR: 1.00e-05
# [Adam] Epoch  8700 | Loss: 8.7796e-02 | LR: 1.00e-05
# [Adam] Epoch  8710 | Loss: 8.7794e-02 | LR: 1.00e-05
# [Adam] Epoch  8720 | Loss: 8.7793e-02 | LR: 1.00e-05
# [Adam] Epoch  8730 | Loss: 8.7791e-02 | LR: 1.00e-05
# [Adam] Epoch  8740 | Loss: 8.7790e-02 | LR: 1.00e-05
# [Adam] Epoch  8750 | Loss: 8.7789e-02 | LR: 1.00e-05
# [Adam] Epoch  8760 | Loss: 8.7787e-02 | LR: 1.00e-05
# [Adam] Epoch  8770 | Loss: 8.7786e-02 | LR: 1.00e-05
# [Adam] Epoch  8780 | Loss: 8.7784e-02 | LR: 1.00e-05
# [Adam] Epoch  8790 | Loss: 8.7783e-02 | LR: 1.00e-05
# [Adam] Epoch  8800 | Loss: 8.7782e-02 | LR: 1.00e-05
# [Adam] Epoch  8810 | Loss: 8.7780e-02 | LR: 1.00e-05
# [Adam] Epoch  8820 | Loss: 8.7779e-02 | LR: 1.00e-05
# [Adam] Epoch  8830 | Loss: 8.7777e-02 | LR: 1.00e-05
# [Adam] Epoch  8840 | Loss: 8.7776e-02 | LR: 1.00e-05
# [Adam] Epoch  8850 | Loss: 8.7775e-02 | LR: 1.00e-05
# [Adam] Epoch  8860 | Loss: 8.7773e-02 | LR: 1.00e-05
# [Adam] Epoch  8870 | Loss: 8.7772e-02 | LR: 1.00e-05
# [Adam] Epoch  8880 | Loss: 8.7771e-02 | LR: 1.00e-05
# [Adam] Epoch  8890 | Loss: 8.7769e-02 | LR: 1.00e-05
# [Adam] Epoch  8900 | Loss: 8.7768e-02 | LR: 1.00e-05
# [Adam] Epoch  8910 | Loss: 8.7767e-02 | LR: 1.00e-05
# [Adam] Epoch  8920 | Loss: 8.7765e-02 | LR: 1.00e-05
# [Adam] Epoch  8930 | Loss: 8.7764e-02 | LR: 1.00e-05
# [Adam] Epoch  8940 | Loss: 8.7762e-02 | LR: 1.00e-05
# [Adam] Epoch  8950 | Loss: 8.7761e-02 | LR: 1.00e-05
# [Adam] Epoch  8960 | Loss: 8.7760e-02 | LR: 1.00e-05
# [Adam] Epoch  8970 | Loss: 8.7758e-02 | LR: 1.00e-05
# [Adam] Epoch  8980 | Loss: 8.7757e-02 | LR: 1.00e-05
# [Adam] Epoch  8990 | Loss: 8.7756e-02 | LR: 1.00e-05
# [Adam] Epoch  9000 | Loss: 8.7754e-02 | LR: 1.00e-05
# [Adam] Epoch  9010 | Loss: 8.7753e-02 | LR: 1.00e-05
# [Adam] Epoch  9020 | Loss: 8.7752e-02 | LR: 1.00e-05
# [Adam] Epoch  9030 | Loss: 8.7750e-02 | LR: 1.00e-05
# ...
# [Adam] Epoch 13860 | Loss: 8.6839e-02 | LR: 1.25e-06
# [Adam] Epoch 13870 | Loss: 8.6839e-02 | LR: 1.25e-06
# [Adam] Epoch 13880 | Loss: 8.6838e-02 | LR: 1.25e-06
# [Adam] Epoch 13890 | Loss: 8.6807e-02 | LR: 6.25e-07
# [Adam] Epoch 13900 | Loss: 8.6804e-02 | LR: 6.25e-07
# [Adam] Epoch 13910 | Loss: 8.6804e-02 | LR: 6.25e-07
# [Adam] Epoch 13920 | Loss: 8.6803e-02 | LR: 6.25e-07
# [Adam] Epoch 13930 | Loss: 8.6803e-02 | LR: 6.25e-07
# [Adam] Epoch 13940 | Loss: 8.6803e-02 | LR: 6.25e-07
# [Adam] Epoch 13950 | Loss: 8.6803e-02 | LR: 6.25e-07
# [Adam] Epoch 13960 | Loss: 8.6803e-02 | LR: 6.25e-07
# [Adam] Epoch 13970 | Loss: 8.6802e-02 | LR: 6.25e-07
# [Adam] Epoch 13980 | Loss: 8.6802e-02 | LR: 6.25e-07
# [Adam] Epoch 13990 | Loss: 8.6802e-02 | LR: 6.25e-07
# [Adam] Epoch 14000 | Loss: 8.6783e-02 | LR: 3.13e-07
# [Adam] Epoch 14010 | Loss: 8.6783e-02 | LR: 3.13e-07
# [Adam] Epoch 14020 | Loss: 8.6783e-02 | LR: 3.13e-07
# [Adam] Epoch 14030 | Loss: 8.6783e-02 | LR: 3.13e-07
# [Adam] Epoch 14040 | Loss: 8.6783e-02 | LR: 3.13e-07
# [Adam] Epoch 14050 | Loss: 8.6783e-02 | LR: 3.13e-07
# [Adam] Epoch 14060 | Loss: 8.6783e-02 | LR: 3.13e-07
# [Adam] Epoch 14070 | Loss: 8.6782e-02 | LR: 3.13e-07
# [Adam] Epoch 14080 | Loss: 8.6782e-02 | LR: 3.13e-07
# [Adam] Epoch 14090 | Loss: 8.6782e-02 | LR: 3.13e-07
# [Adam] Epoch 14100 | Loss: 8.6772e-02 | LR: 1.56e-07
# [Adam] Epoch 14110 | Loss: 8.6772e-02 | LR: 1.56e-07
# [Adam] Epoch 14120 | Loss: 8.6772e-02 | LR: 1.56e-07
# [Adam] Epoch 14130 | Loss: 8.6772e-02 | LR: 1.56e-07
# [Adam] Epoch 14140 | Loss: 8.6772e-02 | LR: 1.56e-07
# [Adam] Epoch 14150 | Loss: 8.6771e-02 | LR: 1.56e-07
# [Adam] Epoch 14160 | Loss: 8.6771e-02 | LR: 1.56e-07
# [Adam] Epoch 14170 | Loss: 8.6771e-02 | LR: 1.56e-07
# [Adam] Epoch 14180 | Loss: 8.6771e-02 | LR: 1.56e-07
# [Adam] Epoch 14190 | Loss: 8.6771e-02 | LR: 1.56e-07
# [Adam] Epoch 14200 | Loss: 8.6766e-02 | LR: 7.81e-08
# [Adam] Epoch 14210 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14220 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14230 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14240 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14250 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14260 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14270 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14280 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14290 | Loss: 8.6765e-02 | LR: 7.81e-08
# [Adam] Epoch 14300 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14310 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14320 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14330 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14340 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14350 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14360 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14370 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14380 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14390 | Loss: 8.6762e-02 | LR: 3.91e-08
# [Adam] Epoch 14400 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14410 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14420 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14430 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14440 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14450 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14460 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14470 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14480 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14490 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14500 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14510 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14520 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14530 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14540 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14550 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14560 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14570 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14580 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14590 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14600 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14610 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14620 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14630 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14640 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14650 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14660 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14670 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14680 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14690 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14700 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14710 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14720 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14730 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14740 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14750 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14760 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14770 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14780 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14790 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14800 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14810 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14820 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14830 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14840 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14850 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14860 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14870 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14880 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14890 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14900 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14910 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14920 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14930 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14940 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14950 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14960 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14970 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14980 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 14990 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15000 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15010 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15020 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15030 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15040 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15050 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15060 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15070 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15080 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15090 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15100 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15110 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15120 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15130 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15140 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15150 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15160 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15170 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15180 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15190 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15200 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15210 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15220 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15230 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15240 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15250 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15260 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15270 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15280 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15290 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15300 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15310 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15320 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15330 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15340 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15350 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15360 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15370 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15380 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15390 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15400 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15410 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15420 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15430 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15440 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15450 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15460 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15470 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15480 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15490 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15500 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15510 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15520 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15530 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15540 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15550 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15560 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15570 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15580 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15590 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15600 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15610 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15620 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15630 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15640 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15650 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15660 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15670 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15680 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15690 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15700 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15710 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15720 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15730 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15740 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15750 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15760 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15770 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15780 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15790 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15800 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15810 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15820 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15830 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15840 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15850 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15860 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15870 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15880 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15890 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15900 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15910 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15920 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15930 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15940 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15950 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15960 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 15970 | Loss: 8.6760e-02 | LR: 1.95e-08
# [Adam] Epoch 15980 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 15990 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16000 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16010 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16020 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16030 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16040 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16050 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16060 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16070 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16080 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16090 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16100 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16110 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16120 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16130 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16140 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16150 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16160 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16170 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16180 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16190 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16200 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16210 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16220 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16230 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16240 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16250 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16260 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16270 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16280 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16290 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16300 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16310 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16320 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16330 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16340 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16350 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16360 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16370 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16380 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16390 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16400 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16410 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16420 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16430 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16440 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16450 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16460 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16470 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16480 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16490 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16500 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16510 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16520 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16530 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16540 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16550 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16560 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16570 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16580 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16590 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16600 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16610 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16620 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16630 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16640 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16650 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16660 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16670 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16680 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16690 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16700 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16710 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16720 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16730 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16740 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16750 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16760 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16770 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16780 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16790 | Loss: 8.6759e-02 | LR: 1.95e-08
# [Adam] Epoch 16800 | Loss: 8.6759e-02 | LR: 1.95e-08
# Early stopping triggered at epoch 16802
# Best model saved with loss 8.6759e-02 at epoch 16702
# [Test Evaluation] k=10, hd=1000, Adam LR=1e-05, BS=1024 → h=25: 0.187157 ± 0.000630, h=50: 0.297696 ± 0.001652, h=75: 0.420975 ± 0.002360, h=100: 0.536157 ± 0.002534
#
# === Final Results Summary ===
# Optimal config used: k=10, m=10000, hd=1000, lr=1e-05, bs=1024

# %%
# ============================================================
# Reload Fixed Best Model (Manual Parameters)
# ============================================================
model_path = model_path = f"model_k{k}_m{m}_hd{hidden_dim}_adam{lr_adam}_bs{batch_size}.pth"
best_model = AdaptiveNVARModel(dk=dk, m=m, d=d, hidden_dim=hidden_dim).to(device)
best_model.load_state_dict(torch.load(model_path, map_location=device))
best_model.eval()

all_preds, all_true, all_noisy = [], [], []

# ------------------------------------------------------------
# Rollout predictions across windows
# ------------------------------------------------------------
for w in range(num_windows):
    start, end = w * window_size, (w + 1) * window_size
    X_test_true_window = X_test_true[start:end]
    X_test_noisy_window = X_test[start:end]

    # Initialization with last k noisy points
    init_start = warmup_len + train_len + val_len + start - k
    init_end   = warmup_len + train_len + val_len + start
    X_init = X[init_start:init_end].to(device)

    x_t = [x.clone() for x in X_init.unbind(0)]
    H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

    predictions = []
    for _ in range(window_size):
        with torch.no_grad():
            delta_x = best_model(H_lin)
        x_next = x_t[-1] + delta_x.squeeze(0)
        predictions.append(x_next)

        # Update autoregressive state
        x_t = x_t[1:] + [x_next]
        H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

    all_preds.append(torch.stack(predictions).cpu().numpy())
    all_true.append(X_test_true_window.cpu().numpy())
    all_noisy.append(X_test_noisy_window.cpu().numpy())

# ------------------------------------------------------------
# Concatenate results
# ------------------------------------------------------------
y_pred = np.concatenate(all_preds)
y_true = np.concatenate(all_true)
y_noisy = np.concatenate(all_noisy)

# %%
# ============================================================
# Visualization (per variable) - First 10 windows, subset of variables
# ============================================================

max_windows_to_plot = min(10, num_windows)  # plot at most 10 windows
end_idx = max_windows_to_plot * window_size

# Slice arrays to avoid oversized figure rendering
y_true_plot = y_true[:end_idx]
y_noisy_plot = y_noisy[:end_idx]
y_pred_plot = y_pred[:end_idx]

# Limit to first 5 variables for readability
max_vars_to_plot = min(5, y_true.shape[1])
variables = [f"x_{i+1}" for i in range(max_vars_to_plot)]

fig, axes = plt.subplots(max_vars_to_plot, 1, figsize=(16, 3 * max_vars_to_plot), sharex=True)

if max_vars_to_plot == 1:
    axes = [axes]  # make iterable

for i, ax in enumerate(axes):
    # Ground truth
    ax.plot(y_true_plot[:, i], label="Ground Truth (Clean)", color="red", linestyle=":", linewidth=0.9)

    # Noisy observations
    ax.plot(y_noisy_plot[:, i], label=f"Noisy Validation Data ({dataset_noise_scale*100:.0f}%)",
            color="black", linewidth=1.0, alpha=1.0)

    # Predictions
    ax.plot(y_pred_plot[:, i], label="Adaptive NVAR Prediction", color="green", linewidth=1.2)

    # Mark window boundaries
    for w in range(1, max_windows_to_plot):
        ax.axvline(w * window_size, color="gray", linestyle="dotted", linewidth=0.8)

    # Label windows at the center
    ylim = ax.get_ylim()
    for w in range(max_windows_to_plot):
        center = w * window_size + window_size // 2
        ax.text(center, ylim[1] * 1.02, f"Window {w+1}",
                ha="center", va="bottom", fontsize=9, color="blue")

    ax.set_ylabel(f"$x_{{{i+1}}}$", fontsize=12)
    ax.grid(alpha=0.3)
    ax.legend(loc="upper right")

axes[-1].set_xlabel("Time", fontsize=12)
fig.suptitle("Test Predictions vs Ground Truth vs Noisy Data (First 10 Windows, First 5 Variables)", fontsize=14, y=0.95)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.xlim(0, end_idx)

# Save and show
filename = f"Test_pred_vs_truth_k{k}_hd{hidden_dim_grid}_noise{dataset_noise_scale:.2f}_first10_vars5.png"
plt.savefig(filename, dpi=300, bbox_inches="tight")
plt.show()
print(f"Saved plot as: {filename}")
# Out:
# Saved plot as: Test_pred_vs_truth_k10_hd[1000]_noise0.30_first10_vars5.png
