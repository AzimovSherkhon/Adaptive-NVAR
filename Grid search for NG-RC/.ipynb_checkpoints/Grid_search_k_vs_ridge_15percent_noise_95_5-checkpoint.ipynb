# %% [markdown]
# # Grid search for Delay Embedding & Ridge Regression for NVAR
#
# It performs a grid search over delay taps k and ridge regularization values $\alpha$, then visualizes prediction accuracy via RMSE heatmaps.
#
# Azimov Sherkhon \\
# Pusan National University \\
# sherxonazimov94@pusan.ac.kr \\
# May 2025

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import os

# %%
# Time settings
dt = 0.025
warmup = 5.0
traintime = 38.0
testtime = 2.0
maxtime = warmup + traintime + testtime
plottime = 2.0

# Convert to discrete steps
warmup_pts = round(warmup / dt)
traintime_pts = round(traintime / dt)
warmtrain_pts = warmup_pts + traintime_pts
testtime_pts = round(testtime / dt)
maxtime_pts = round(maxtime / dt)
plottime_pts = round(plottime / dt)

# %%
# ---------------------- Load Data ----------------------
t_eval = np.linspace(0, maxtime, maxtime_pts + 1)

data_file = "15percent0025.npy"
lorenz_soln = (np.load(data_file)).T

# Plot Lorenz variables
variables = ['x', 'y', 'z']
plt.figure(figsize=(12, 8))
for i in range(3):
    plt.subplot(3, 1, i + 1)
    plt.plot(t_eval, lorenz_soln[i], label=variables[i], color=f'C{i}')
    plt.ylabel(variables[i])
    plt.grid(True)
    if i == 0:
        plt.title("Lorenz '63 variables vs time")
plt.xlabel('Time')
plt.tight_layout()
plt.show()

# %%
# ---------------------- Grid Search Parameters Phase 1 ----------------------
d = 3  # Dimension of the system
k_values = range(1, 26)  # Delay taps
ridge_values = np.linspace(1, 1000, 101)  # Ridge parameters
results = []

# ---------------------- Grid Search ----------------------
for k, ridge_param in itertools.product(k_values, ridge_values):
    dlin = k * d
    dnonlin = int(dlin * (dlin + 1) / 2)
    dtot = 1 + dlin + dnonlin

    x = np.zeros((dlin, maxtime_pts))
    for delay in range(k):
        for j in range(delay, maxtime_pts):
            x[d * delay:d * (delay + 1), j] = lorenz_soln[:, j - delay]

    # Training features
    out_train = np.ones((dtot, traintime_pts))
    out_train[1:dlin + 1, :] = x[:, warmup_pts - 1:warmtrain_pts - 1]

    cnt = 0
    for row in range(dlin):
        for col in range(row, dlin):
            out_train[dlin + 1 + cnt] = (
                x[row, warmup_pts - 1:warmtrain_pts - 1] *
                x[col, warmup_pts - 1:warmtrain_pts - 1]
            )
            cnt += 1

    # Ridge regression
    delta_x = x[0:d, warmup_pts:warmtrain_pts] - x[0:d, warmup_pts - 1:warmtrain_pts - 1]
    W_out = delta_x @ out_train.T @ np.linalg.pinv(out_train @ out_train.T + ridge_param * np.identity(dtot))

    # Prediction
    out_test = np.zeros(dtot)
    x_test = np.zeros((dlin, testtime_pts))
    x_test[:, 0] = x[:, warmtrain_pts - 1]

    for j in range(testtime_pts - 1):
        out_test[1:dlin + 1] = x_test[:, j]
        cnt = 0
        for row in range(dlin):
            for col in range(row, dlin):
                out_test[dlin + 1 + cnt] = x_test[row, j] * x_test[col, j]
                cnt += 1
        x_test[d:dlin, j + 1] = x_test[0:(dlin - d), j]
        x_test[0:d, j + 1] = x_test[0:d, j] + W_out @ out_test

    # RMSE evaluation
    X_true = x[0:3, warmtrain_pts - 1:warmtrain_pts + plottime_pts - 1]
    X_pred = x_test[0:3, 0:plottime_pts]
    rmse = np.sqrt(np.mean((X_true - X_pred) ** 2))

    results.append((k, ridge_param, rmse))
    print(f"k = {k:2d} | ridge = {ridge_param:.3f} | Test RMSE = {rmse:.6f}")

# ---------------------- Best Result ----------------------
best_k, best_ridge, best_rmse = min(results, key=lambda x: x[2])
print(f"Best k = {best_k}, ridge = {best_ridge:.3f} → Validation RMSE = {best_rmse:.6f}")
# Out:
# k =  1 | ridge = 1.000 | Test RMSE = 11.344608
# k =  1 | ridge = 10.990 | Test RMSE = 11.072856
# k =  1 | ridge = 20.980 | Test RMSE = 11.029129
# k =  1 | ridge = 30.970 | Test RMSE = 11.035011
# k =  1 | ridge = 40.960 | Test RMSE = 11.051680
# k =  1 | ridge = 50.950 | Test RMSE = 11.069137
# k =  1 | ridge = 60.940 | Test RMSE = 11.084724
# k =  1 | ridge = 70.930 | Test RMSE = 11.097910
# k =  1 | ridge = 80.920 | Test RMSE = 11.108800
# k =  1 | ridge = 90.910 | Test RMSE = 11.117671
# k =  1 | ridge = 100.900 | Test RMSE = 11.124820
# k =  1 | ridge = 110.890 | Test RMSE = 11.130514
# k =  1 | ridge = 120.880 | Test RMSE = 11.134981
# k =  1 | ridge = 130.870 | Test RMSE = 11.138411
# k =  1 | ridge = 140.860 | Test RMSE = 11.140962
# k =  1 | ridge = 150.850 | Test RMSE = 11.142763
# k =  1 | ridge = 160.840 | Test RMSE = 11.143922
# k =  1 | ridge = 170.830 | Test RMSE = 11.144529
# k =  1 | ridge = 180.820 | Test RMSE = 11.144658
# k =  1 | ridge = 190.810 | Test RMSE = 11.144372
# k =  1 | ridge = 200.800 | Test RMSE = 11.143724
# k =  1 | ridge = 210.790 | Test RMSE = 11.142760
# k =  1 | ridge = 220.780 | Test RMSE = 11.141518
# k =  1 | ridge = 230.770 | Test RMSE = 11.140031
# k =  1 | ridge = 240.760 | Test RMSE = 11.138328
# k =  1 | ridge = 250.750 | Test RMSE = 11.136434
# k =  1 | ridge = 260.740 | Test RMSE = 11.134370
# k =  1 | ridge = 270.730 | Test RMSE = 11.132156
# k =  1 | ridge = 280.720 | Test RMSE = 11.129808
# k =  1 | ridge = 290.710 | Test RMSE = 11.127342
# k =  1 | ridge = 300.700 | Test RMSE = 11.124769
# k =  1 | ridge = 310.690 | Test RMSE = 11.122101
# k =  1 | ridge = 320.680 | Test RMSE = 11.119350
# k =  1 | ridge = 330.670 | Test RMSE = 11.116524
# k =  1 | ridge = 340.660 | Test RMSE = 11.113631
# k =  1 | ridge = 350.650 | Test RMSE = 11.110680
# k =  1 | ridge = 360.640 | Test RMSE = 11.107676
# k =  1 | ridge = 370.630 | Test RMSE = 11.104626
# k =  1 | ridge = 380.620 | Test RMSE = 11.101536
# k =  1 | ridge = 390.610 | Test RMSE = 11.098410
# k =  1 | ridge = 400.600 | Test RMSE = 11.095253
# k =  1 | ridge = 410.590 | Test RMSE = 11.092070
# k =  1 | ridge = 420.580 | Test RMSE = 11.088864
# k =  1 | ridge = 430.570 | Test RMSE = 11.085638
# k =  1 | ridge = 440.560 | Test RMSE = 11.082396
# k =  1 | ridge = 450.550 | Test RMSE = 11.079141
# k =  1 | ridge = 460.540 | Test RMSE = 11.075876
# k =  1 | ridge = 470.530 | Test RMSE = 11.072603
# k =  1 | ridge = 480.520 | Test RMSE = 11.069324
# k =  1 | ridge = 490.510 | Test RMSE = 11.066043
# k =  1 | ridge = 500.500 | Test RMSE = 11.062759
# k =  1 | ridge = 510.490 | Test RMSE = 11.059477
# k =  1 | ridge = 520.480 | Test RMSE = 11.056196
# k =  1 | ridge = 530.470 | Test RMSE = 11.052920
# k =  1 | ridge = 540.460 | Test RMSE = 11.049649
# k =  1 | ridge = 550.450 | Test RMSE = 11.046384
# k =  1 | ridge = 560.440 | Test RMSE = 11.043128
# k =  1 | ridge = 570.430 | Test RMSE = 11.039881
# k =  1 | ridge = 580.420 | Test RMSE = 11.036645
# k =  1 | ridge = 590.410 | Test RMSE = 11.033420
# k =  1 | ridge = 600.400 | Test RMSE = 11.030208
# k =  1 | ridge = 610.390 | Test RMSE = 11.027009
# k =  1 | ridge = 620.380 | Test RMSE = 11.023824
# k =  1 | ridge = 630.370 | Test RMSE = 11.020655
# k =  1 | ridge = 640.360 | Test RMSE = 11.017501
# k =  1 | ridge = 650.350 | Test RMSE = 11.014365
# k =  1 | ridge = 660.340 | Test RMSE = 11.011245
# k =  1 | ridge = 670.330 | Test RMSE = 11.008144
# k =  1 | ridge = 680.320 | Test RMSE = 11.005061
# k =  1 | ridge = 690.310 | Test RMSE = 11.001997
# k =  1 | ridge = 700.300 | Test RMSE = 10.998953
# k =  1 | ridge = 710.290 | Test RMSE = 10.995929
# k =  1 | ridge = 720.280 | Test RMSE = 10.992926
# k =  1 | ridge = 730.270 | Test RMSE = 10.989944
# k =  1 | ridge = 740.260 | Test RMSE = 10.986983
# k =  1 | ridge = 750.250 | Test RMSE = 10.984044
# k =  1 | ridge = 760.240 | Test RMSE = 10.981128
# k =  1 | ridge = 770.230 | Test RMSE = 10.978234
# k =  1 | ridge = 780.220 | Test RMSE = 10.975362
# k =  1 | ridge = 790.210 | Test RMSE = 10.972514
# k =  1 | ridge = 800.200 | Test RMSE = 10.969690
# k =  1 | ridge = 810.190 | Test RMSE = 10.966889
# k =  1 | ridge = 820.180 | Test RMSE = 10.964112
# k =  1 | ridge = 830.170 | Test RMSE = 10.961360
# k =  1 | ridge = 840.160 | Test RMSE = 10.958631
# k =  1 | ridge = 850.150 | Test RMSE = 10.955928
# k =  1 | ridge = 860.140 | Test RMSE = 10.953249
# k =  1 | ridge = 870.130 | Test RMSE = 10.950595
# k =  1 | ridge = 880.120 | Test RMSE = 10.947966
# k =  1 | ridge = 890.110 | Test RMSE = 10.945363
# k =  1 | ridge = 900.100 | Test RMSE = 10.942785
# k =  1 | ridge = 910.090 | Test RMSE = 10.940232
# k =  1 | ridge = 920.080 | Test RMSE = 10.937705
# k =  1 | ridge = 930.070 | Test RMSE = 10.935204
# k =  1 | ridge = 940.060 | Test RMSE = 10.932729
# k =  1 | ridge = 950.050 | Test RMSE = 10.930280
# k =  1 | ridge = 960.040 | Test RMSE = 10.927856
# k =  4 | ridge = 10.990 | Test RMSE = 4.506119
# k =  4 | ridge = 20.980 | Test RMSE = 3.936481
# k =  4 | ridge = 30.970 | Test RMSE = 3.679335
# k =  4 | ridge = 40.960 | Test RMSE = 3.541426
# k =  4 | ridge = 50.950 | Test RMSE = 3.459226
# k =  4 | ridge = 60.940 | Test RMSE = 3.406702
# k =  4 | ridge = 70.930 | Test RMSE = 3.371549
# k =  4 | ridge = 80.920 | Test RMSE = 3.347314
# k =  4 | ridge = 90.910 | Test RMSE = 3.330336
# k =  4 | ridge = 100.900 | Test RMSE = 3.318398
# k =  4 | ridge = 110.890 | Test RMSE = 3.310091
# k =  4 | ridge = 120.880 | Test RMSE = 3.304476
# k =  4 | ridge = 130.870 | Test RMSE = 3.300908
# k =  4 | ridge = 140.860 | Test RMSE = 3.298928
# k =  4 | ridge = 150.850 | Test RMSE = 3.298201
# k =  4 | ridge = 160.840 | Test RMSE = 3.298476
# k =  4 | ridge = 170.830 | Test RMSE = 3.299564
# k =  4 | ridge = 180.820 | Test RMSE = 3.301316
# k =  4 | ridge = 190.810 | Test RMSE = 3.303616
# k =  4 | ridge = 200.800 | Test RMSE = 3.306371
# k =  4 | ridge = 210.790 | Test RMSE = 3.309507
# k =  4 | ridge = 220.780 | Test RMSE = 3.312961
# k =  4 | ridge = 230.770 | Test RMSE = 3.316683
# k =  4 | ridge = 240.760 | Test RMSE = 3.320631
# k =  4 | ridge = 250.750 | Test RMSE = 3.324770
# k =  4 | ridge = 260.740 | Test RMSE = 3.329070
# k =  4 | ridge = 270.730 | Test RMSE = 3.333507
# k =  4 | ridge = 280.720 | Test RMSE = 3.338057
# k =  4 | ridge = 290.710 | Test RMSE = 3.342704
# k =  4 | ridge = 300.700 | Test RMSE = 3.347431
# k =  4 | ridge = 310.690 | Test RMSE = 3.352224
# k =  4 | ridge = 320.680 | Test RMSE = 3.357071
# k =  4 | ridge = 330.670 | Test RMSE = 3.361963
# k =  4 | ridge = 340.660 | Test RMSE = 3.366890
# k =  4 | ridge = 350.650 | Test RMSE = 3.371844
# k =  4 | ridge = 360.640 | Test RMSE = 3.376819
# k =  4 | ridge = 370.630 | Test RMSE = 3.381808
# k =  4 | ridge = 380.620 | Test RMSE = 3.386806
# k =  4 | ridge = 390.610 | Test RMSE = 3.391809
# k =  4 | ridge = 400.600 | Test RMSE = 3.396812
# k =  4 | ridge = 410.590 | Test RMSE = 3.401812
# k =  4 | ridge = 420.580 | Test RMSE = 3.406805
# k =  4 | ridge = 430.570 | Test RMSE = 3.411790
# k =  4 | ridge = 440.560 | Test RMSE = 3.416764
# k =  4 | ridge = 450.550 | Test RMSE = 3.421723
# k =  4 | ridge = 460.540 | Test RMSE = 3.426668
# k =  4 | ridge = 470.530 | Test RMSE = 3.431595
# k =  4 | ridge = 480.520 | Test RMSE = 3.436504
# k =  4 | ridge = 490.510 | Test RMSE = 3.441393
# k =  4 | ridge = 500.500 | Test RMSE = 3.446262
# k =  4 | ridge = 510.490 | Test RMSE = 3.451109
# k =  4 | ridge = 520.480 | Test RMSE = 3.455934
# k =  4 | ridge = 530.470 | Test RMSE = 3.460736
# k =  4 | ridge = 540.460 | Test RMSE = 3.465514
# k =  4 | ridge = 550.450 | Test RMSE = 3.470269
# k =  4 | ridge = 560.440 | Test RMSE = 3.474999
# k =  4 | ridge = 570.430 | Test RMSE = 3.479705
# k =  4 | ridge = 580.420 | Test RMSE = 3.484386
# k =  4 | ridge = 590.410 | Test RMSE = 3.489042
# k =  4 | ridge = 600.400 | Test RMSE = 3.493673
# k =  4 | ridge = 610.390 | Test RMSE = 3.498279
# k =  4 | ridge = 620.380 | Test RMSE = 3.502859
# k =  4 | ridge = 630.370 | Test RMSE = 3.507415
# k =  4 | ridge = 640.360 | Test RMSE = 3.511946
# k =  4 | ridge = 650.350 | Test RMSE = 3.516452
# k =  4 | ridge = 660.340 | Test RMSE = 3.520934
# k =  4 | ridge = 670.330 | Test RMSE = 3.525390
# k =  4 | ridge = 680.320 | Test RMSE = 3.529823
# k =  4 | ridge = 690.310 | Test RMSE = 3.534231
# k =  4 | ridge = 700.300 | Test RMSE = 3.538616
# k =  4 | ridge = 710.290 | Test RMSE = 3.542977
# k =  4 | ridge = 720.280 | Test RMSE = 3.547314
# k =  4 | ridge = 730.270 | Test RMSE = 3.551628
# k =  4 | ridge = 740.260 | Test RMSE = 3.555919
# k =  4 | ridge = 750.250 | Test RMSE = 3.560188
# k =  4 | ridge = 760.240 | Test RMSE = 3.564434
# k =  4 | ridge = 770.230 | Test RMSE = 3.568659
# k =  4 | ridge = 780.220 | Test RMSE = 3.572861
# k =  4 | ridge = 790.210 | Test RMSE = 3.577042
# k =  4 | ridge = 800.200 | Test RMSE = 3.581202
# k =  4 | ridge = 810.190 | Test RMSE = 3.585341
# k =  4 | ridge = 820.180 | Test RMSE = 3.589460
# k =  4 | ridge = 830.170 | Test RMSE = 3.593559
# k =  4 | ridge = 840.160 | Test RMSE = 3.597637
# k =  4 | ridge = 850.150 | Test RMSE = 3.601697
# k =  4 | ridge = 860.140 | Test RMSE = 3.605737
# k =  4 | ridge = 870.130 | Test RMSE = 3.609758
# k =  4 | ridge = 880.120 | Test RMSE = 3.613760
# k =  4 | ridge = 890.110 | Test RMSE = 3.617744
# k =  4 | ridge = 900.100 | Test RMSE = 3.621711
# k =  4 | ridge = 910.090 | Test RMSE = 3.625659
# k =  4 | ridge = 920.080 | Test RMSE = 3.629591
# k =  4 | ridge = 930.070 | Test RMSE = 3.633505
# k =  4 | ridge = 940.060 | Test RMSE = 3.637403
# k =  4 | ridge = 950.050 | Test RMSE = 3.641284
# k =  4 | ridge = 960.040 | Test RMSE = 3.645149
# k =  4 | ridge = 970.030 | Test RMSE = 3.648999
# k =  4 | ridge = 980.020 | Test RMSE = 3.652833
# k =  4 | ridge = 990.010 | Test RMSE = 3.656652
# k =  4 | ridge = 1000.000 | Test RMSE = 3.660455
# k =  5 | ridge = 1.000 | Test RMSE = 5.026630
# k =  5 | ridge = 10.990 | Test RMSE = 3.221901
# k =  5 | ridge = 20.980 | Test RMSE = 2.653515
# k =  5 | ridge = 30.970 | Test RMSE = 2.400576
# k =  5 | ridge = 40.960 | Test RMSE = 2.265380
# k =  5 | ridge = 50.950 | Test RMSE = 2.184308
# k =  5 | ridge = 60.940 | Test RMSE = 2.131707
# k =  5 | ridge = 70.930 | Test RMSE = 2.095562
# k =  5 | ridge = 80.920 | Test RMSE = 2.069612
# k =  5 | ridge = 90.910 | Test RMSE = 2.050319
# k =  5 | ridge = 100.900 | Test RMSE = 2.035557
# k =  5 | ridge = 110.890 | Test RMSE = 2.023985
# k =  5 | ridge = 120.880 | Test RMSE = 2.014720
# k =  5 | ridge = 130.870 | Test RMSE = 2.007165
# k =  5 | ridge = 140.860 | Test RMSE = 2.000903
# k =  5 | ridge = 150.850 | Test RMSE = 1.995639
# k =  5 | ridge = 160.840 | Test RMSE = 1.991157
# k =  5 | ridge = 170.830 | Test RMSE = 1.987298
# k =  5 | ridge = 180.820 | Test RMSE = 1.983945
# k =  5 | ridge = 190.810 | Test RMSE = 1.981009
# k =  5 | ridge = 200.800 | Test RMSE = 1.978422
# k =  5 | ridge = 210.790 | Test RMSE = 1.976131
# k =  5 | ridge = 220.780 | Test RMSE = 1.974098
# k =  5 | ridge = 230.770 | Test RMSE = 1.972289
# k =  5 | ridge = 240.760 | Test RMSE = 1.970682
# k =  5 | ridge = 250.750 | Test RMSE = 1.969257
# k =  5 | ridge = 260.740 | Test RMSE = 1.967998
# k =  5 | ridge = 270.730 | Test RMSE = 1.966895
# k =  5 | ridge = 280.720 | Test RMSE = 1.965937
# k =  5 | ridge = 290.710 | Test RMSE = 1.965116
# k =  5 | ridge = 300.700 | Test RMSE = 1.964428
# k =  5 | ridge = 310.690 | Test RMSE = 1.963866
# k =  5 | ridge = 320.680 | Test RMSE = 1.963426
# k =  5 | ridge = 330.670 | Test RMSE = 1.963106
# k =  5 | ridge = 340.660 | Test RMSE = 1.962903
# k =  5 | ridge = 350.650 | Test RMSE = 1.962813
# k =  5 | ridge = 360.640 | Test RMSE = 1.962836
# k =  5 | ridge = 370.630 | Test RMSE = 1.962968
# k =  5 | ridge = 380.620 | Test RMSE = 1.963209
# k =  5 | ridge = 390.610 | Test RMSE = 1.963557
# k =  5 | ridge = 400.600 | Test RMSE = 1.964010
# k =  5 | ridge = 410.590 | Test RMSE = 1.964567
# k =  5 | ridge = 420.580 | Test RMSE = 1.965227
# k =  5 | ridge = 430.570 | Test RMSE = 1.965988
# k =  5 | ridge = 440.560 | Test RMSE = 1.966849
# k =  5 | ridge = 450.550 | Test RMSE = 1.967808
# k =  5 | ridge = 460.540 | Test RMSE = 1.968865
# k =  5 | ridge = 470.530 | Test RMSE = 1.970018
# k =  5 | ridge = 480.520 | Test RMSE = 1.971265
# k =  5 | ridge = 490.510 | Test RMSE = 1.972606
# k =  5 | ridge = 500.500 | Test RMSE = 1.974038
# k =  5 | ridge = 510.490 | Test RMSE = 1.975561
# k =  5 | ridge = 520.480 | Test RMSE = 1.977173
# k =  5 | ridge = 530.470 | Test RMSE = 1.978872
# k =  5 | ridge = 540.460 | Test RMSE = 1.980656
# k =  5 | ridge = 550.450 | Test RMSE = 1.982526
# k =  7 | ridge = 100.900 | Test RMSE = 1.554527
# k =  7 | ridge = 110.890 | Test RMSE = 1.552779
# k =  7 | ridge = 120.880 | Test RMSE = 1.552449
# k =  7 | ridge = 130.870 | Test RMSE = 1.553094
# k =  7 | ridge = 140.860 | Test RMSE = 1.554435
# k =  7 | ridge = 150.850 | Test RMSE = 1.556288
# k =  7 | ridge = 160.840 | Test RMSE = 1.558530
# k =  7 | ridge = 170.830 | Test RMSE = 1.561074
# k =  7 | ridge = 180.820 | Test RMSE = 1.563858
# k =  7 | ridge = 190.810 | Test RMSE = 1.566837
# k =  7 | ridge = 200.800 | Test RMSE = 1.569977
# k =  7 | ridge = 210.790 | Test RMSE = 1.573251
# k =  7 | ridge = 220.780 | Test RMSE = 1.576640
# k =  7 | ridge = 230.770 | Test RMSE = 1.580126
# k =  7 | ridge = 240.760 | Test RMSE = 1.583699
# k =  7 | ridge = 250.750 | Test RMSE = 1.587346
# k =  7 | ridge = 260.740 | Test RMSE = 1.591061
# k =  7 | ridge = 270.730 | Test RMSE = 1.594835
# k =  7 | ridge = 280.720 | Test RMSE = 1.598663
# k =  7 | ridge = 290.710 | Test RMSE = 1.602540
# k =  7 | ridge = 300.700 | Test RMSE = 1.606463
# k =  7 | ridge = 310.690 | Test RMSE = 1.610428
# k =  7 | ridge = 320.680 | Test RMSE = 1.614432
# k =  7 | ridge = 330.670 | Test RMSE = 1.618473
# k =  7 | ridge = 340.660 | Test RMSE = 1.622549
# k =  7 | ridge = 350.650 | Test RMSE = 1.626658
# k =  7 | ridge = 360.640 | Test RMSE = 1.630800
# k =  7 | ridge = 370.630 | Test RMSE = 1.634972
# k =  7 | ridge = 380.620 | Test RMSE = 1.639175
# k =  7 | ridge = 390.610 | Test RMSE = 1.643407
# k =  7 | ridge = 400.600 | Test RMSE = 1.647668
# k =  7 | ridge = 410.590 | Test RMSE = 1.651958
# k =  7 | ridge = 420.580 | Test RMSE = 1.656275
# k =  7 | ridge = 430.570 | Test RMSE = 1.660620
# k =  7 | ridge = 440.560 | Test RMSE = 1.664993
# k =  7 | ridge = 450.550 | Test RMSE = 1.669394
# k =  7 | ridge = 460.540 | Test RMSE = 1.673822
# k =  7 | ridge = 470.530 | Test RMSE = 1.678277
# k =  7 | ridge = 480.520 | Test RMSE = 1.682760
# k =  7 | ridge = 490.510 | Test RMSE = 1.687270
# k =  7 | ridge = 500.500 | Test RMSE = 1.691808
# k =  7 | ridge = 510.490 | Test RMSE = 1.696374
# k =  7 | ridge = 520.480 | Test RMSE = 1.700967
# k =  7 | ridge = 530.470 | Test RMSE = 1.705589
# k =  7 | ridge = 540.460 | Test RMSE = 1.710239
# k =  7 | ridge = 550.450 | Test RMSE = 1.714917
# k =  7 | ridge = 560.440 | Test RMSE = 1.719624
# k =  7 | ridge = 570.430 | Test RMSE = 1.724360
# k =  7 | ridge = 580.420 | Test RMSE = 1.729124
# k =  7 | ridge = 590.410 | Test RMSE = 1.733917
# k =  7 | ridge = 600.400 | Test RMSE = 1.738740
# k =  7 | ridge = 610.390 | Test RMSE = 1.743593
# k =  7 | ridge = 620.380 | Test RMSE = 1.748474
# k =  7 | ridge = 630.370 | Test RMSE = 1.753386
# k =  7 | ridge = 640.360 | Test RMSE = 1.758328
# k =  7 | ridge = 650.350 | Test RMSE = 1.763300
# k =  7 | ridge = 660.340 | Test RMSE = 1.768302
# k =  7 | ridge = 670.330 | Test RMSE = 1.773334
# k =  7 | ridge = 680.320 | Test RMSE = 1.778398
# k =  7 | ridge = 690.310 | Test RMSE = 1.783492
# k =  7 | ridge = 700.300 | Test RMSE = 1.788616
# k =  7 | ridge = 710.290 | Test RMSE = 1.793772
# k =  7 | ridge = 720.280 | Test RMSE = 1.798959
# k =  7 | ridge = 730.270 | Test RMSE = 1.804178
# k =  7 | ridge = 740.260 | Test RMSE = 1.809427
# k =  7 | ridge = 750.250 | Test RMSE = 1.814709
# k =  7 | ridge = 760.240 | Test RMSE = 1.820021
# k =  7 | ridge = 770.230 | Test RMSE = 1.825366
# k =  7 | ridge = 780.220 | Test RMSE = 1.830742
# k =  7 | ridge = 790.210 | Test RMSE = 1.836150
# k =  7 | ridge = 800.200 | Test RMSE = 1.841590
# k =  7 | ridge = 810.190 | Test RMSE = 1.847062
# k =  7 | ridge = 820.180 | Test RMSE = 1.852566
# k =  7 | ridge = 830.170 | Test RMSE = 1.858102
# k =  7 | ridge = 840.160 | Test RMSE = 1.863670
# k =  7 | ridge = 850.150 | Test RMSE = 1.869271
# k =  7 | ridge = 860.140 | Test RMSE = 1.874903
# k =  7 | ridge = 870.130 | Test RMSE = 1.880568
# k =  7 | ridge = 880.120 | Test RMSE = 1.886265
# k =  7 | ridge = 890.110 | Test RMSE = 1.891994
# k =  7 | ridge = 900.100 | Test RMSE = 1.897755
# k =  7 | ridge = 910.090 | Test RMSE = 1.903549
# k =  7 | ridge = 920.080 | Test RMSE = 1.909375
# k =  7 | ridge = 930.070 | Test RMSE = 1.915233
# k =  7 | ridge = 940.060 | Test RMSE = 1.921123
# k =  7 | ridge = 950.050 | Test RMSE = 1.927046
# k =  7 | ridge = 960.040 | Test RMSE = 1.933001
# k =  7 | ridge = 970.030 | Test RMSE = 1.938988
# k =  7 | ridge = 980.020 | Test RMSE = 1.945007
# k =  7 | ridge = 990.010 | Test RMSE = 1.951058
# k =  7 | ridge = 1000.000 | Test RMSE = 1.957141
# k =  8 | ridge = 1.000 | Test RMSE = 13.756382
# k =  8 | ridge = 10.990 | Test RMSE = 14.191976
# k =  8 | ridge = 20.980 | Test RMSE = 14.420006
# k =  8 | ridge = 30.970 | Test RMSE = 14.500884
# k =  8 | ridge = 40.960 | Test RMSE = 14.543361
# k =  8 | ridge = 50.950 | Test RMSE = 14.570065
# k =  8 | ridge = 60.940 | Test RMSE = 14.588578
# k =  8 | ridge = 70.930 | Test RMSE = 14.602191
# k =  8 | ridge = 80.920 | Test RMSE = 14.612584
# k =  8 | ridge = 90.910 | Test RMSE = 14.620716
# k =  8 | ridge = 100.900 | Test RMSE = 14.627182
# k =  8 | ridge = 110.890 | Test RMSE = 14.632371
# k =  8 | ridge = 120.880 | Test RMSE = 14.636555
# k =  8 | ridge = 130.870 | Test RMSE = 14.639926
# k =  8 | ridge = 140.860 | Test RMSE = 14.642629
# k =  8 | ridge = 150.850 | Test RMSE = 14.644773
# k =  8 | ridge = 160.840 | Test RMSE = 14.646444
# k =  8 | ridge = 170.830 | Test RMSE = 14.647709
# k =  8 | ridge = 180.820 | Test RMSE = 14.648621
# k =  8 | ridge = 190.810 | Test RMSE = 14.649226
# k =  8 | ridge = 200.800 | Test RMSE = 14.649560
# k =  8 | ridge = 210.790 | Test RMSE = 14.649652
# k =  8 | ridge = 220.780 | Test RMSE = 14.649529
# k =  8 | ridge = 230.770 | Test RMSE = 14.649211
# k =  8 | ridge = 240.760 | Test RMSE = 14.648718
# k =  8 | ridge = 250.750 | Test RMSE = 14.648065
# k =  8 | ridge = 260.740 | Test RMSE = 14.647267
# k =  8 | ridge = 270.730 | Test RMSE = 14.646334
# k =  8 | ridge = 280.720 | Test RMSE = 14.645277
# k =  8 | ridge = 290.710 | Test RMSE = 14.644105
# k =  8 | ridge = 300.700 | Test RMSE = 14.642827
# k =  8 | ridge = 310.690 | Test RMSE = 14.641450
# k =  8 | ridge = 320.680 | Test RMSE = 14.639980
# k =  8 | ridge = 330.670 | Test RMSE = 14.638423
# k =  8 | ridge = 340.660 | Test RMSE = 14.636783
# k =  8 | ridge = 350.650 | Test RMSE = 14.635066
# k =  8 | ridge = 360.640 | Test RMSE = 14.633276
# k =  8 | ridge = 370.630 | Test RMSE = 14.631416
# k =  8 | ridge = 380.620 | Test RMSE = 14.629489
# k =  8 | ridge = 390.610 | Test RMSE = 14.627500
# k =  8 | ridge = 400.600 | Test RMSE = 14.625450
# k =  8 | ridge = 410.590 | Test RMSE = 14.623343
# k =  8 | ridge = 420.580 | Test RMSE = 14.621180
# k =  8 | ridge = 430.570 | Test RMSE = 14.618963
# k =  8 | ridge = 440.560 | Test RMSE = 14.616696
# k =  8 | ridge = 450.550 | Test RMSE = 14.614379
# k =  8 | ridge = 460.540 | Test RMSE = 14.612015
# k =  8 | ridge = 470.530 | Test RMSE = 14.609605
# k =  8 | ridge = 480.520 | Test RMSE = 14.607150
# k =  8 | ridge = 490.510 | Test RMSE = 14.604652
# k =  8 | ridge = 500.500 | Test RMSE = 14.602112
# k =  8 | ridge = 510.490 | Test RMSE = 14.599531
# k =  8 | ridge = 520.480 | Test RMSE = 14.596911
# k =  8 | ridge = 530.470 | Test RMSE = 14.594253
# k =  8 | ridge = 540.460 | Test RMSE = 14.591557
# k =  8 | ridge = 550.450 | Test RMSE = 14.588825
# k =  8 | ridge = 560.440 | Test RMSE = 14.586058
# k =  8 | ridge = 570.430 | Test RMSE = 14.583256
# k =  8 | ridge = 580.420 | Test RMSE = 14.580421
# k =  8 | ridge = 590.410 | Test RMSE = 14.577552
# k =  8 | ridge = 600.400 | Test RMSE = 14.574652
# k =  8 | ridge = 610.390 | Test RMSE = 14.571721
# k =  8 | ridge = 620.380 | Test RMSE = 14.568759
# k =  8 | ridge = 630.370 | Test RMSE = 14.565767
# k =  8 | ridge = 640.360 | Test RMSE = 14.562746
# k =  8 | ridge = 650.350 | Test RMSE = 14.559696
# k =  8 | ridge = 660.340 | Test RMSE = 14.556618
# k =  8 | ridge = 670.330 | Test RMSE = 14.553513
# k =  8 | ridge = 680.320 | Test RMSE = 14.550381
# k =  8 | ridge = 690.310 | Test RMSE = 14.547223
# k =  8 | ridge = 700.300 | Test RMSE = 14.544038
# k =  8 | ridge = 710.290 | Test RMSE = 14.540828
# k =  8 | ridge = 720.280 | Test RMSE = 14.537592
# k =  8 | ridge = 730.270 | Test RMSE = 14.534332
# k =  8 | ridge = 740.260 | Test RMSE = 14.531047
# k =  8 | ridge = 750.250 | Test RMSE = 14.527737
# k =  8 | ridge = 760.240 | Test RMSE = 14.524404
# k =  8 | ridge = 770.230 | Test RMSE = 14.521047
# k =  8 | ridge = 780.220 | Test RMSE = 14.517665
# k =  8 | ridge = 790.210 | Test RMSE = 14.514261
# k =  8 | ridge = 800.200 | Test RMSE = 14.510833
# k =  8 | ridge = 810.190 | Test RMSE = 14.507382
# k =  8 | ridge = 820.180 | Test RMSE = 14.503908
# k =  8 | ridge = 830.170 | Test RMSE = 14.500410
# k =  8 | ridge = 840.160 | Test RMSE = 14.496890
# k =  8 | ridge = 850.150 | Test RMSE = 14.493347
# k =  8 | ridge = 860.140 | Test RMSE = 14.489782
# k =  8 | ridge = 870.130 | Test RMSE = 14.486193
# k =  8 | ridge = 880.120 | Test RMSE = 14.482583
# k =  8 | ridge = 890.110 | Test RMSE = 14.478949
# k =  8 | ridge = 900.100 | Test RMSE = 14.475293
# k =  8 | ridge = 910.090 | Test RMSE = 14.471614
# k =  8 | ridge = 920.080 | Test RMSE = 14.467913
# k =  8 | ridge = 930.070 | Test RMSE = 14.464189
# k =  8 | ridge = 940.060 | Test RMSE = 14.460442
# k =  8 | ridge = 950.050 | Test RMSE = 14.456672
# k =  8 | ridge = 960.040 | Test RMSE = 14.452880
# k =  8 | ridge = 970.030 | Test RMSE = 14.449064
# k =  8 | ridge = 980.020 | Test RMSE = 14.445225
# k =  8 | ridge = 990.010 | Test RMSE = 14.441364
# k =  8 | ridge = 1000.000 | Test RMSE = 14.437479
# k =  9 | ridge = 1.000 | Test RMSE = 13.336861
# k =  9 | ridge = 10.990 | Test RMSE = 14.522521
# k =  9 | ridge = 20.980 | Test RMSE = 14.685398
# k =  9 | ridge = 30.970 | Test RMSE = 14.736883
# k =  9 | ridge = 40.960 | Test RMSE = 14.761862
# k =  9 | ridge = 50.950 | Test RMSE = 14.776520
# k =  9 | ridge = 60.940 | Test RMSE = 14.786044
# k =  9 | ridge = 70.930 | Test RMSE = 14.792609
# k =  9 | ridge = 80.920 | Test RMSE = 14.797289
# k =  9 | ridge = 90.910 | Test RMSE = 14.800682
# k =  9 | ridge = 100.900 | Test RMSE = 14.803144
# k =  9 | ridge = 110.890 | Test RMSE = 14.804905
# k =  9 | ridge = 120.880 | Test RMSE = 14.806119
# k =  9 | ridge = 130.870 | Test RMSE = 14.806896
# k =  9 | ridge = 140.860 | Test RMSE = 14.807311
# k =  9 | ridge = 150.850 | Test RMSE = 14.807425
# k =  9 | ridge = 160.840 | Test RMSE = 14.807280
# k =  9 | ridge = 170.830 | Test RMSE = 14.806912
# k =  9 | ridge = 180.820 | Test RMSE = 14.806346
# k =  9 | ridge = 190.810 | Test RMSE = 14.805606
# k =  9 | ridge = 200.800 | Test RMSE = 14.804709
# k =  9 | ridge = 210.790 | Test RMSE = 14.803670
# k =  9 | ridge = 220.780 | Test RMSE = 14.802501
# k =  9 | ridge = 230.770 | Test RMSE = 14.801214
# k =  9 | ridge = 240.760 | Test RMSE = 14.799816
# k =  9 | ridge = 250.750 | Test RMSE = 14.798317
# k =  9 | ridge = 260.740 | Test RMSE = 14.796723
# k =  9 | ridge = 270.730 | Test RMSE = 14.795042
# k =  9 | ridge = 280.720 | Test RMSE = 14.793279
# k =  9 | ridge = 290.710 | Test RMSE = 14.791439
# k =  9 | ridge = 300.700 | Test RMSE = 14.789527
# k =  9 | ridge = 310.690 | Test RMSE = 14.787549
# k =  9 | ridge = 320.680 | Test RMSE = 14.785507
# k =  9 | ridge = 330.670 | Test RMSE = 14.783407
# k =  9 | ridge = 340.660 | Test RMSE = 14.781251
# k =  9 | ridge = 350.650 | Test RMSE = 14.779042
# k =  9 | ridge = 360.640 | Test RMSE = 14.776783
# k =  9 | ridge = 370.630 | Test RMSE = 14.774477
# k =  9 | ridge = 380.620 | Test RMSE = 14.772126
# k =  9 | ridge = 390.610 | Test RMSE = 14.769730
# k =  9 | ridge = 400.600 | Test RMSE = 14.767291
# k =  9 | ridge = 410.590 | Test RMSE = 14.764810
# k =  9 | ridge = 420.580 | Test RMSE = 14.762288
# k =  9 | ridge = 430.570 | Test RMSE = 14.759725
# k =  9 | ridge = 440.560 | Test RMSE = 14.757121
# k =  9 | ridge = 450.550 | Test RMSE = 14.754475
# k =  9 | ridge = 460.540 | Test RMSE = 14.751789
# k =  9 | ridge = 470.530 | Test RMSE = 14.749060
# k =  9 | ridge = 480.520 | Test RMSE = 14.746290
# k =  9 | ridge = 490.510 | Test RMSE = 14.743478
# k =  9 | ridge = 500.500 | Test RMSE = 14.740624
# k =  9 | ridge = 510.490 | Test RMSE = 14.737728
# k =  9 | ridge = 520.480 | Test RMSE = 14.734790
# k =  9 | ridge = 530.470 | Test RMSE = 14.731812
# k =  9 | ridge = 540.460 | Test RMSE = 14.728792
# k =  9 | ridge = 550.450 | Test RMSE = 14.725734
# k =  9 | ridge = 560.440 | Test RMSE = 14.722638
# k =  9 | ridge = 570.430 | Test RMSE = 14.719506
# k =  9 | ridge = 580.420 | Test RMSE = 14.716339
# k =  9 | ridge = 590.410 | Test RMSE = 14.713140
# k =  9 | ridge = 600.400 | Test RMSE = 14.709911
# k =  9 | ridge = 610.390 | Test RMSE = 14.706652
# k =  9 | ridge = 620.380 | Test RMSE = 14.703368
# k =  9 | ridge = 630.370 | Test RMSE = 14.700058
# k =  9 | ridge = 640.360 | Test RMSE = 14.696726
# k =  9 | ridge = 650.350 | Test RMSE = 14.693371
# k =  9 | ridge = 660.340 | Test RMSE = 14.689996
# k =  9 | ridge = 670.330 | Test RMSE = 14.686600
# k =  9 | ridge = 680.320 | Test RMSE = 14.683183
# k =  9 | ridge = 690.310 | Test RMSE = 14.679747
# k =  9 | ridge = 700.300 | Test RMSE = 14.676289
# k =  9 | ridge = 710.290 | Test RMSE = 14.672809
# k =  9 | ridge = 720.280 | Test RMSE = 14.669306
# k =  9 | ridge = 730.270 | Test RMSE = 14.665778
# k =  9 | ridge = 740.260 | Test RMSE = 14.662223
# k =  9 | ridge = 750.250 | Test RMSE = 14.658640
# k =  9 | ridge = 760.240 | Test RMSE = 14.655026
# k =  9 | ridge = 770.230 | Test RMSE = 14.651381
# k =  9 | ridge = 780.220 | Test RMSE = 14.647702
# k =  9 | ridge = 790.210 | Test RMSE = 14.643990
# k =  9 | ridge = 800.200 | Test RMSE = 14.640243
# k =  9 | ridge = 810.190 | Test RMSE = 14.636461
# k =  9 | ridge = 820.180 | Test RMSE = 14.632645
# k =  9 | ridge = 830.170 | Test RMSE = 14.628797
# k =  9 | ridge = 840.160 | Test RMSE = 14.624917
# k =  9 | ridge = 850.150 | Test RMSE = 14.621009
# k =  9 | ridge = 860.140 | Test RMSE = 14.617074
# k =  9 | ridge = 870.130 | Test RMSE = 14.613115
# k =  9 | ridge = 880.120 | Test RMSE = 14.609135
# k =  9 | ridge = 890.110 | Test RMSE = 14.605137
# k =  9 | ridge = 900.100 | Test RMSE = 14.601123
# k =  9 | ridge = 910.090 | Test RMSE = 14.597094
# k =  9 | ridge = 920.080 | Test RMSE = 14.593052
# k =  9 | ridge = 930.070 | Test RMSE = 14.588998
# k =  9 | ridge = 940.060 | Test RMSE = 14.584929
# k =  9 | ridge = 950.050 | Test RMSE = 14.580846
# k =  9 | ridge = 960.040 | Test RMSE = 14.576746
# k =  9 | ridge = 970.030 | Test RMSE = 14.572626
# k =  9 | ridge = 980.020 | Test RMSE = 14.568481
# k =  9 | ridge = 990.010 | Test RMSE = 14.564309
# k =  9 | ridge = 1000.000 | Test RMSE = 14.560104
# k = 10 | ridge = 1.000 | Test RMSE = 14.101926
# k = 10 | ridge = 10.990 | Test RMSE = 14.599689
# <ipython-input-4-4c430987512b>:45: RuntimeWarning: overflow encountered in scalar multiply
#   out_test[dlin + 1 + cnt] = x_test[row, j] * x_test[col, j]
# <ipython-input-4-4c430987512b>:48: RuntimeWarning: invalid value encountered in matmul
#   x_test[0:d, j + 1] = x_test[0:d, j] + W_out @ out_test
# <ipython-input-4-4c430987512b>:53: RuntimeWarning: overflow encountered in square
#   rmse = np.sqrt(np.mean((X_true - X_pred) ** 2))
# k = 10 | ridge = 20.980 | Test RMSE = nan
# k = 10 | ridge = 30.970 | Test RMSE = nan
# k = 10 | ridge = 40.960 | Test RMSE = nan
# k = 10 | ridge = 50.950 | Test RMSE = nan
# k = 10 | ridge = 60.940 | Test RMSE = nan
# k = 10 | ridge = 70.930 | Test RMSE = nan
# k = 10 | ridge = 80.920 | Test RMSE = nan
# k = 10 | ridge = 90.910 | Test RMSE = nan
# k = 10 | ridge = 100.900 | Test RMSE = nan
# k = 10 | ridge = 630.370 | Test RMSE = 2.668117
# k = 10 | ridge = 640.360 | Test RMSE = 2.619699
# k = 10 | ridge = 650.350 | Test RMSE = 2.572719
# k = 10 | ridge = 660.340 | Test RMSE = 2.527148
# k = 10 | ridge = 670.330 | Test RMSE = 2.482954
# k = 10 | ridge = 680.320 | Test RMSE = 2.440108
# k = 10 | ridge = 690.310 | Test RMSE = 2.398576
# k = 10 | ridge = 700.300 | Test RMSE = 2.358327
# k = 10 | ridge = 710.290 | Test RMSE = 2.319328
# k = 10 | ridge = 720.280 | Test RMSE = 2.281547
# k = 10 | ridge = 730.270 | Test RMSE = 2.244954
# k = 10 | ridge = 740.260 | Test RMSE = 2.209518
# k = 10 | ridge = 750.250 | Test RMSE = 2.175210
# k = 10 | ridge = 760.240 | Test RMSE = 2.142003
# k = 10 | ridge = 770.230 | Test RMSE = 2.109870
# ...
# k = 22 | ridge = 530.470 | Test RMSE = nan
# k = 22 | ridge = 540.460 | Test RMSE = nan
# k = 22 | ridge = 550.450 | Test RMSE = nan
# k = 22 | ridge = 560.440 | Test RMSE = nan
# k = 22 | ridge = 570.430 | Test RMSE = nan
# k = 22 | ridge = 580.420 | Test RMSE = nan
# k = 22 | ridge = 590.410 | Test RMSE = nan
# k = 22 | ridge = 600.400 | Test RMSE = nan
# k = 22 | ridge = 610.390 | Test RMSE = nan
# k = 22 | ridge = 620.380 | Test RMSE = nan
# k = 22 | ridge = 630.370 | Test RMSE = nan
# k = 22 | ridge = 640.360 | Test RMSE = nan
# k = 22 | ridge = 650.350 | Test RMSE = nan
# k = 22 | ridge = 660.340 | Test RMSE = nan
# k = 22 | ridge = 670.330 | Test RMSE = nan
# k = 22 | ridge = 680.320 | Test RMSE = nan
# k = 22 | ridge = 690.310 | Test RMSE = nan
# k = 22 | ridge = 700.300 | Test RMSE = nan
# k = 22 | ridge = 710.290 | Test RMSE = nan
# k = 22 | ridge = 720.280 | Test RMSE = nan
# k = 22 | ridge = 730.270 | Test RMSE = nan
# k = 22 | ridge = 740.260 | Test RMSE = nan
# k = 22 | ridge = 750.250 | Test RMSE = nan
# k = 22 | ridge = 760.240 | Test RMSE = nan
# k = 22 | ridge = 770.230 | Test RMSE = nan
# k = 22 | ridge = 780.220 | Test RMSE = nan
# k = 22 | ridge = 790.210 | Test RMSE = nan
# k = 22 | ridge = 800.200 | Test RMSE = nan
# k = 22 | ridge = 810.190 | Test RMSE = nan
# k = 22 | ridge = 820.180 | Test RMSE = nan
# k = 22 | ridge = 830.170 | Test RMSE = nan
# k = 22 | ridge = 840.160 | Test RMSE = nan
# k = 22 | ridge = 850.150 | Test RMSE = nan
# k = 22 | ridge = 860.140 | Test RMSE = nan
# k = 22 | ridge = 870.130 | Test RMSE = nan
# k = 22 | ridge = 880.120 | Test RMSE = nan
# k = 22 | ridge = 890.110 | Test RMSE = nan
# k = 22 | ridge = 900.100 | Test RMSE = nan
# k = 22 | ridge = 910.090 | Test RMSE = nan
# k = 22 | ridge = 920.080 | Test RMSE = nan
# k = 22 | ridge = 930.070 | Test RMSE = nan
# k = 24 | ridge = 50.950 | Test RMSE = nan
# k = 24 | ridge = 60.940 | Test RMSE = nan
# k = 24 | ridge = 70.930 | Test RMSE = nan
# k = 24 | ridge = 80.920 | Test RMSE = nan
# k = 24 | ridge = 90.910 | Test RMSE = nan
# k = 24 | ridge = 100.900 | Test RMSE = nan
# k = 24 | ridge = 110.890 | Test RMSE = nan
# k = 24 | ridge = 120.880 | Test RMSE = nan
# k = 24 | ridge = 130.870 | Test RMSE = nan
# k = 24 | ridge = 140.860 | Test RMSE = nan
# k = 24 | ridge = 150.850 | Test RMSE = nan
# k = 24 | ridge = 160.840 | Test RMSE = nan
# k = 24 | ridge = 170.830 | Test RMSE = nan
# k = 24 | ridge = 180.820 | Test RMSE = nan
# k = 24 | ridge = 190.810 | Test RMSE = nan
# k = 24 | ridge = 200.800 | Test RMSE = nan
# k = 24 | ridge = 210.790 | Test RMSE = nan
# k = 24 | ridge = 220.780 | Test RMSE = nan
# k = 24 | ridge = 230.770 | Test RMSE = nan
# k = 24 | ridge = 240.760 | Test RMSE = nan
# k = 24 | ridge = 250.750 | Test RMSE = nan
# k = 24 | ridge = 260.740 | Test RMSE = nan
# k = 24 | ridge = 270.730 | Test RMSE = nan
# k = 24 | ridge = 280.720 | Test RMSE = nan
# k = 24 | ridge = 290.710 | Test RMSE = nan
# k = 24 | ridge = 300.700 | Test RMSE = nan
# k = 24 | ridge = 310.690 | Test RMSE = nan
# k = 24 | ridge = 320.680 | Test RMSE = nan
# k = 24 | ridge = 330.670 | Test RMSE = nan
# k = 24 | ridge = 340.660 | Test RMSE = nan
# k = 24 | ridge = 350.650 | Test RMSE = nan
# k = 24 | ridge = 360.640 | Test RMSE = nan
# k = 24 | ridge = 370.630 | Test RMSE = nan
# k = 24 | ridge = 380.620 | Test RMSE = nan
# k = 24 | ridge = 390.610 | Test RMSE = nan
# k = 24 | ridge = 400.600 | Test RMSE = nan
# k = 24 | ridge = 410.590 | Test RMSE = nan
# k = 24 | ridge = 420.580 | Test RMSE = nan
# k = 24 | ridge = 430.570 | Test RMSE = nan
# k = 24 | ridge = 440.560 | Test RMSE = nan
# k = 24 | ridge = 450.550 | Test RMSE = nan
# k = 24 | ridge = 460.540 | Test RMSE = nan
# k = 24 | ridge = 470.530 | Test RMSE = nan
# k = 24 | ridge = 480.520 | Test RMSE = nan
# k = 24 | ridge = 490.510 | Test RMSE = nan
# k = 24 | ridge = 500.500 | Test RMSE = nan
# k = 24 | ridge = 510.490 | Test RMSE = nan
# k = 24 | ridge = 520.480 | Test RMSE = nan
# k = 24 | ridge = 530.470 | Test RMSE = nan
# k = 24 | ridge = 540.460 | Test RMSE = nan
# k = 24 | ridge = 550.450 | Test RMSE = nan
# k = 24 | ridge = 560.440 | Test RMSE = nan
# k = 24 | ridge = 570.430 | Test RMSE = nan
# k = 24 | ridge = 580.420 | Test RMSE = nan
# k = 24 | ridge = 590.410 | Test RMSE = nan
# k = 24 | ridge = 600.400 | Test RMSE = nan
# k = 24 | ridge = 610.390 | Test RMSE = nan
# k = 24 | ridge = 620.380 | Test RMSE = nan
# k = 24 | ridge = 630.370 | Test RMSE = nan
# k = 24 | ridge = 640.360 | Test RMSE = nan
# k = 24 | ridge = 650.350 | Test RMSE = nan
# k = 24 | ridge = 660.340 | Test RMSE = nan
# k = 24 | ridge = 670.330 | Test RMSE = nan
# k = 24 | ridge = 680.320 | Test RMSE = nan
# k = 24 | ridge = 690.310 | Test RMSE = nan
# k = 24 | ridge = 700.300 | Test RMSE = nan
# k = 24 | ridge = 710.290 | Test RMSE = nan
# k = 24 | ridge = 720.280 | Test RMSE = nan
# k = 24 | ridge = 730.270 | Test RMSE = nan
# k = 24 | ridge = 740.260 | Test RMSE = nan
# k = 24 | ridge = 750.250 | Test RMSE = nan
# k = 24 | ridge = 760.240 | Test RMSE = 7307928304767743747605045800124747108731716632576.000000
# k = 24 | ridge = 770.230 | Test RMSE = 3046.288162
# k = 24 | ridge = 780.220 | Test RMSE = 22.948158
# k = 24 | ridge = 790.210 | Test RMSE = 13.447154
# k = 24 | ridge = 800.200 | Test RMSE = 13.184424
# k = 24 | ridge = 810.190 | Test RMSE = 13.155638
# k = 24 | ridge = 820.180 | Test RMSE = 13.121719
# k = 24 | ridge = 830.170 | Test RMSE = 13.065204
# k = 24 | ridge = 840.160 | Test RMSE = 13.004112
# k = 24 | ridge = 850.150 | Test RMSE = 12.949445
# k = 24 | ridge = 860.140 | Test RMSE = 12.903801
# k = 24 | ridge = 870.130 | Test RMSE = 12.866249
# k = 24 | ridge = 880.120 | Test RMSE = 12.835107
# k = 24 | ridge = 890.110 | Test RMSE = 12.808872
# k = 24 | ridge = 900.100 | Test RMSE = 12.786404
# k = 24 | ridge = 910.090 | Test RMSE = 12.766870
# k = 24 | ridge = 920.080 | Test RMSE = 12.749666
# k = 24 | ridge = 930.070 | Test RMSE = 12.734348
# k = 24 | ridge = 940.060 | Test RMSE = 12.720585
# k = 24 | ridge = 950.050 | Test RMSE = 12.708131
# k = 24 | ridge = 960.040 | Test RMSE = 12.696801
# k = 24 | ridge = 970.030 | Test RMSE = 12.686453
# k = 24 | ridge = 980.020 | Test RMSE = 12.676984
# k = 24 | ridge = 990.010 | Test RMSE = 12.668310
# k = 24 | ridge = 1000.000 | Test RMSE = 12.660368
# k = 25 | ridge = 1.000 | Test RMSE = nan
# k = 25 | ridge = 10.990 | Test RMSE = nan
# k = 25 | ridge = 20.980 | Test RMSE = nan
# k = 25 | ridge = 30.970 | Test RMSE = nan
# k = 25 | ridge = 40.960 | Test RMSE = nan
# k = 25 | ridge = 50.950 | Test RMSE = nan
# k = 25 | ridge = 60.940 | Test RMSE = nan
# k = 25 | ridge = 70.930 | Test RMSE = nan
# k = 25 | ridge = 80.920 | Test RMSE = nan
# k = 25 | ridge = 90.910 | Test RMSE = nan
# k = 25 | ridge = 100.900 | Test RMSE = nan
# k = 25 | ridge = 110.890 | Test RMSE = nan
# k = 25 | ridge = 120.880 | Test RMSE = nan
# k = 25 | ridge = 130.870 | Test RMSE = nan
# k = 25 | ridge = 140.860 | Test RMSE = nan
# k = 25 | ridge = 150.850 | Test RMSE = nan
# k = 25 | ridge = 160.840 | Test RMSE = nan
# k = 25 | ridge = 170.830 | Test RMSE = nan
# k = 25 | ridge = 180.820 | Test RMSE = nan
# k = 25 | ridge = 190.810 | Test RMSE = nan
# k = 25 | ridge = 200.800 | Test RMSE = nan
# k = 25 | ridge = 210.790 | Test RMSE = nan
# k = 25 | ridge = 220.780 | Test RMSE = nan
# k = 25 | ridge = 230.770 | Test RMSE = nan
# k = 25 | ridge = 240.760 | Test RMSE = nan
# k = 25 | ridge = 250.750 | Test RMSE = nan
# k = 25 | ridge = 260.740 | Test RMSE = nan
# k = 25 | ridge = 270.730 | Test RMSE = nan
# k = 25 | ridge = 280.720 | Test RMSE = nan
# k = 25 | ridge = 290.710 | Test RMSE = nan
# k = 25 | ridge = 300.700 | Test RMSE = nan
# k = 25 | ridge = 310.690 | Test RMSE = nan
# k = 25 | ridge = 320.680 | Test RMSE = nan
# k = 25 | ridge = 330.670 | Test RMSE = nan
# k = 25 | ridge = 340.660 | Test RMSE = nan
# k = 25 | ridge = 350.650 | Test RMSE = nan
# k = 25 | ridge = 360.640 | Test RMSE = nan
# k = 25 | ridge = 370.630 | Test RMSE = nan
# k = 25 | ridge = 380.620 | Test RMSE = nan
# k = 25 | ridge = 390.610 | Test RMSE = nan
# k = 25 | ridge = 400.600 | Test RMSE = nan
# k = 25 | ridge = 410.590 | Test RMSE = nan
# k = 25 | ridge = 420.580 | Test RMSE = nan
# k = 25 | ridge = 430.570 | Test RMSE = nan
# k = 25 | ridge = 440.560 | Test RMSE = 13863745637445630027865960006348142392136708728345758562562806328102535694394117681196223013322752.000000
# k = 25 | ridge = 450.550 | Test RMSE = 383179520325733152951598317568.000000
# k = 25 | ridge = 460.540 | Test RMSE = 950073953183998017536.000000
# k = 25 | ridge = 470.530 | Test RMSE = 9962881002.288588
# k = 25 | ridge = 480.520 | Test RMSE = 53.110311
# k = 25 | ridge = 490.510 | Test RMSE = 14.215360
# k = 25 | ridge = 500.500 | Test RMSE = 17.511174
# k = 25 | ridge = 510.490 | Test RMSE = 17.037017
# k = 25 | ridge = 520.480 | Test RMSE = 14.719985
# k = 25 | ridge = 530.470 | Test RMSE = 13.158182
# k = 25 | ridge = 540.460 | Test RMSE = 12.413487
# k = 25 | ridge = 550.450 | Test RMSE = 12.069678
# k = 25 | ridge = 560.440 | Test RMSE = 11.890919
# k = 25 | ridge = 570.430 | Test RMSE = 11.782900
# k = 25 | ridge = 580.420 | Test RMSE = 11.710016
# k = 25 | ridge = 590.410 | Test RMSE = 11.657765
# k = 25 | ridge = 600.400 | Test RMSE = 11.619278
# k = 25 | ridge = 610.390 | Test RMSE = 11.590696
# k = 25 | ridge = 620.380 | Test RMSE = 11.569531
# k = 25 | ridge = 630.370 | Test RMSE = 11.554033
# k = 25 | ridge = 640.360 | Test RMSE = 11.542911
# k = 25 | ridge = 650.350 | Test RMSE = 11.535189
# k = 25 | ridge = 660.340 | Test RMSE = 11.530116
# k = 25 | ridge = 670.330 | Test RMSE = 11.527115
# k = 25 | ridge = 680.320 | Test RMSE = 11.525736
# k = 25 | ridge = 690.310 | Test RMSE = 11.525632
# k = 25 | ridge = 700.300 | Test RMSE = 11.526530
# k = 25 | ridge = 710.290 | Test RMSE = 11.528220
# k = 25 | ridge = 720.280 | Test RMSE = 11.530535
# k = 25 | ridge = 730.270 | Test RMSE = 11.533347
# k = 25 | ridge = 740.260 | Test RMSE = 11.536554
# k = 25 | ridge = 750.250 | Test RMSE = 11.540075
# k = 25 | ridge = 760.240 | Test RMSE = 11.543848
# k = 25 | ridge = 770.230 | Test RMSE = 11.547823
# k = 25 | ridge = 780.220 | Test RMSE = 11.551960
# k = 25 | ridge = 790.210 | Test RMSE = 11.556227
# k = 25 | ridge = 800.200 | Test RMSE = 11.560598
# k = 25 | ridge = 810.190 | Test RMSE = 11.565053
# k = 25 | ridge = 820.180 | Test RMSE = 11.569573
# k = 25 | ridge = 830.170 | Test RMSE = 11.574146
# k = 25 | ridge = 840.160 | Test RMSE = 11.578757
# k = 25 | ridge = 850.150 | Test RMSE = 11.583398
# k = 25 | ridge = 860.140 | Test RMSE = 11.588060
# k = 25 | ridge = 870.130 | Test RMSE = 11.592734
# k = 25 | ridge = 880.120 | Test RMSE = 11.597414
# k = 25 | ridge = 890.110 | Test RMSE = 11.602094
# k = 25 | ridge = 900.100 | Test RMSE = 11.606768
# k = 25 | ridge = 910.090 | Test RMSE = 11.611432
# k = 25 | ridge = 920.080 | Test RMSE = 11.616080
# k = 25 | ridge = 930.070 | Test RMSE = 11.620709
# k = 25 | ridge = 940.060 | Test RMSE = 11.625314
# k = 25 | ridge = 950.050 | Test RMSE = 11.629893
# k = 25 | ridge = 960.040 | Test RMSE = 11.634442
# k = 25 | ridge = 970.030 | Test RMSE = 11.638958
# k = 25 | ridge = 980.020 | Test RMSE = 11.643438
# k = 25 | ridge = 990.010 | Test RMSE = 11.647879
# k = 25 | ridge = 1000.000 | Test RMSE = 11.652280
# Best k = 7, ridge = 120.880 → Validation RMSE = 1.552449

# %%
# ---------------------- Heatmap Phase 1 ----------------------
k_list = sorted(set(k for k, _, _ in results))
ridge_list = sorted(set(r for _, r, _ in results))
rmse_matrix = np.zeros((len(k_list), len(ridge_list)))

for k, ridge, rmse in results:
    i = k_list.index(k)
    j = ridge_list.index(ridge)
    rmse_matrix[i, j] = rmse

rmse_matrix[rmse_matrix > 1e2] = np.nan
log_ridge_list = ridge_list

plt.figure(figsize=(24, 8))
im = plt.imshow(rmse_matrix, aspect='auto', origin='lower',
                extent=[log_ridge_list[0], log_ridge_list[-1], k_list[0], k_list[-1]],
                cmap='viridis')
plt.colorbar(im, label='Test RMSE')
plt.xlabel('Ridge Parameter')
plt.ylabel('Delay Taps (k)')
plt.title('Grid Search RMSE Heatmap (15% noise)')
plt.xticks(log_ridge_list, [f"{v:.0e}" for v in ridge_list], rotation=45)
plt.yticks(k_list)
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.savefig("grid_search_rmse_heatmap_15percent_1(95_5_split).png", dpi=600)
plt.show()

# %%
#---------------Grid Search Parameters Phase 2 ----------------------
d = 3  # Dimension of the system
k_values2 = range(7,8)  # Delay taps
ridge_values2 = np.linspace(100, 150, 101)  # Ridge parameters
results2 = []

# ---------------------- Grid Search ----------------------
for k, ridge_param in itertools.product(k_values2, ridge_values2):
    dlin = k * d
    dnonlin = int(dlin * (dlin + 1) / 2)
    dtot = 1 + dlin + dnonlin

    x = np.zeros((dlin, maxtime_pts))
    for delay in range(k):
        for j in range(delay, maxtime_pts):
            x[d * delay:d * (delay + 1), j] = lorenz_soln[:, j - delay]

    # Training features
    out_train = np.ones((dtot, traintime_pts))
    out_train[1:dlin + 1, :] = x[:, warmup_pts - 1:warmtrain_pts - 1]

    cnt = 0
    for row in range(dlin):
        for col in range(row, dlin):
            out_train[dlin + 1 + cnt] = (
                x[row, warmup_pts - 1:warmtrain_pts - 1] *
                x[col, warmup_pts - 1:warmtrain_pts - 1]
            )
            cnt += 1

    # Ridge regression
    delta_x = x[0:d, warmup_pts:warmtrain_pts] - x[0:d, warmup_pts - 1:warmtrain_pts - 1]
    W_out = delta_x @ out_train.T @ np.linalg.pinv(out_train @ out_train.T + ridge_param * np.identity(dtot))

    # Prediction
    out_test = np.zeros(dtot)
    x_test = np.zeros((dlin, testtime_pts))
    x_test[:, 0] = x[:, warmtrain_pts - 1]

    for j in range(testtime_pts - 1):
        out_test[1:dlin + 1] = x_test[:, j]
        cnt = 0
        for row in range(dlin):
            for col in range(row, dlin):
                out_test[dlin + 1 + cnt] = x_test[row, j] * x_test[col, j]
                cnt += 1
        x_test[d:dlin, j + 1] = x_test[0:(dlin - d), j]
        x_test[0:d, j + 1] = x_test[0:d, j] + W_out @ out_test

    # RMSE evaluation
    X_true = x[0:3, warmtrain_pts - 1:warmtrain_pts + plottime_pts - 1]
    X_pred = x_test[0:3, 0:plottime_pts]
    rmse = np.sqrt(np.mean((X_true - X_pred) ** 2))

    results2.append((k, ridge_param, rmse))
    print(f"k = {k:2d} | ridge = {ridge_param:.3f} | Test RMSE = {rmse:.6f}")

# ---------------------- Best Result ----------------------
best_k, best_ridge, best_rmse = min(results2, key=lambda x: x[2])
print(f"Best k = {best_k}, ridge = {best_ridge:.3f} → Validation RMSE = {best_rmse:.6f}")
# Out:
# k =  7 | ridge = 100.000 | Test RMSE = 1.554776
# k =  7 | ridge = 100.500 | Test RMSE = 1.554636
# k =  7 | ridge = 101.000 | Test RMSE = 1.554501
# k =  7 | ridge = 101.500 | Test RMSE = 1.554371
# k =  7 | ridge = 102.000 | Test RMSE = 1.554246
# k =  7 | ridge = 102.500 | Test RMSE = 1.554127
# k =  7 | ridge = 103.000 | Test RMSE = 1.554012
# k =  7 | ridge = 103.500 | Test RMSE = 1.553902
# k =  7 | ridge = 104.000 | Test RMSE = 1.553797
# k =  7 | ridge = 104.500 | Test RMSE = 1.553696
# k =  7 | ridge = 105.000 | Test RMSE = 1.553600
# k =  7 | ridge = 105.500 | Test RMSE = 1.553509
# k =  7 | ridge = 106.000 | Test RMSE = 1.553421
# k =  7 | ridge = 106.500 | Test RMSE = 1.553338
# k =  7 | ridge = 107.000 | Test RMSE = 1.553259
# k =  7 | ridge = 107.500 | Test RMSE = 1.553185
# k =  7 | ridge = 108.000 | Test RMSE = 1.553114
# k =  7 | ridge = 108.500 | Test RMSE = 1.553047
# k =  7 | ridge = 109.000 | Test RMSE = 1.552984
# k =  7 | ridge = 109.500 | Test RMSE = 1.552925
# k =  7 | ridge = 110.000 | Test RMSE = 1.552869
# k =  7 | ridge = 110.500 | Test RMSE = 1.552817
# k =  7 | ridge = 111.000 | Test RMSE = 1.552769
# k =  7 | ridge = 111.500 | Test RMSE = 1.552724
# k =  7 | ridge = 112.000 | Test RMSE = 1.552682
# k =  7 | ridge = 112.500 | Test RMSE = 1.552644
# k =  7 | ridge = 113.000 | Test RMSE = 1.552609
# k =  7 | ridge = 113.500 | Test RMSE = 1.552578
# k =  7 | ridge = 114.000 | Test RMSE = 1.552549
# k =  7 | ridge = 114.500 | Test RMSE = 1.552524
# k =  7 | ridge = 115.000 | Test RMSE = 1.552501
# k =  7 | ridge = 115.500 | Test RMSE = 1.552482
# k =  7 | ridge = 116.000 | Test RMSE = 1.552466
# k =  7 | ridge = 116.500 | Test RMSE = 1.552452
# k =  7 | ridge = 117.000 | Test RMSE = 1.552441
# k =  7 | ridge = 117.500 | Test RMSE = 1.552433
# k =  7 | ridge = 118.000 | Test RMSE = 1.552428
# k =  7 | ridge = 118.500 | Test RMSE = 1.552426
# k =  7 | ridge = 119.000 | Test RMSE = 1.552426
# k =  7 | ridge = 119.500 | Test RMSE = 1.552428
# k =  7 | ridge = 120.000 | Test RMSE = 1.552433
# k =  7 | ridge = 120.500 | Test RMSE = 1.552441
# k =  7 | ridge = 121.000 | Test RMSE = 1.552451
# k =  7 | ridge = 121.500 | Test RMSE = 1.552464
# k =  7 | ridge = 122.000 | Test RMSE = 1.552479
# k =  7 | ridge = 122.500 | Test RMSE = 1.552496
# k =  7 | ridge = 123.000 | Test RMSE = 1.552515
# k =  7 | ridge = 123.500 | Test RMSE = 1.552537
# k =  7 | ridge = 124.000 | Test RMSE = 1.552561
# k =  7 | ridge = 124.500 | Test RMSE = 1.552587
# k =  7 | ridge = 125.000 | Test RMSE = 1.552615
# k =  7 | ridge = 125.500 | Test RMSE = 1.552646
# k =  7 | ridge = 126.000 | Test RMSE = 1.552678
# k =  7 | ridge = 126.500 | Test RMSE = 1.552712
# k =  7 | ridge = 127.000 | Test RMSE = 1.552749
# k =  7 | ridge = 127.500 | Test RMSE = 1.552787
# k =  7 | ridge = 128.000 | Test RMSE = 1.552827
# k =  7 | ridge = 128.500 | Test RMSE = 1.552869
# k =  7 | ridge = 129.000 | Test RMSE = 1.552913
# k =  7 | ridge = 129.500 | Test RMSE = 1.552959
# k =  7 | ridge = 130.000 | Test RMSE = 1.553007
# k =  7 | ridge = 130.500 | Test RMSE = 1.553056
# k =  7 | ridge = 131.000 | Test RMSE = 1.553107
# k =  7 | ridge = 131.500 | Test RMSE = 1.553160
# k =  7 | ridge = 132.000 | Test RMSE = 1.553215
# k =  7 | ridge = 132.500 | Test RMSE = 1.553271
# k =  7 | ridge = 133.000 | Test RMSE = 1.553329
# k =  7 | ridge = 133.500 | Test RMSE = 1.553388
# k =  7 | ridge = 134.000 | Test RMSE = 1.553449
# k =  7 | ridge = 134.500 | Test RMSE = 1.553512
# k =  7 | ridge = 135.000 | Test RMSE = 1.553576
# k =  7 | ridge = 135.500 | Test RMSE = 1.553642
# k =  7 | ridge = 136.000 | Test RMSE = 1.553709
# k =  7 | ridge = 136.500 | Test RMSE = 1.553777
# k =  7 | ridge = 137.000 | Test RMSE = 1.553847
# k =  7 | ridge = 137.500 | Test RMSE = 1.553919
# k =  7 | ridge = 138.000 | Test RMSE = 1.553992
# k =  7 | ridge = 138.500 | Test RMSE = 1.554066
# k =  7 | ridge = 139.000 | Test RMSE = 1.554142
# k =  7 | ridge = 139.500 | Test RMSE = 1.554219
# k =  7 | ridge = 140.000 | Test RMSE = 1.554297
# k =  7 | ridge = 140.500 | Test RMSE = 1.554377
# k =  7 | ridge = 141.000 | Test RMSE = 1.554458
# k =  7 | ridge = 141.500 | Test RMSE = 1.554540
# k =  7 | ridge = 142.000 | Test RMSE = 1.554623
# k =  7 | ridge = 142.500 | Test RMSE = 1.554708
# k =  7 | ridge = 143.000 | Test RMSE = 1.554794
# k =  7 | ridge = 143.500 | Test RMSE = 1.554881
# k =  7 | ridge = 144.000 | Test RMSE = 1.554969
# k =  7 | ridge = 144.500 | Test RMSE = 1.555058
# k =  7 | ridge = 145.000 | Test RMSE = 1.555149
# k =  7 | ridge = 145.500 | Test RMSE = 1.555240
# k =  7 | ridge = 146.000 | Test RMSE = 1.555333
# k =  7 | ridge = 146.500 | Test RMSE = 1.555427
# k =  7 | ridge = 147.000 | Test RMSE = 1.555522
# k =  7 | ridge = 147.500 | Test RMSE = 1.555618
# k =  7 | ridge = 148.000 | Test RMSE = 1.555715
# k =  7 | ridge = 148.500 | Test RMSE = 1.555813
# k =  7 | ridge = 149.000 | Test RMSE = 1.555913
# k =  7 | ridge = 149.500 | Test RMSE = 1.556013
# k =  7 | ridge = 150.000 | Test RMSE = 1.556114
# Best k = 7, ridge = 118.500 → Validation RMSE = 1.552426

# %%
# ---------------------- Heatmap Phase 2 ----------------------
k_list = sorted(set(k for k, _, _ in results2))  # Only one value
ridge_list = sorted(set(r for _, r, _ in results2))

rmse_matrix = np.zeros((1, len(ridge_list)))
for _, ridge, rmse in results2:
    j = ridge_list.index(ridge)
    rmse_matrix[0, j] = rmse

log_ridge_list = ridge_list

# --- Plot heatmap ---
plt.figure(figsize=(20, 3))
im = plt.imshow(
    rmse_matrix,
    aspect='auto',
    origin='lower',
    extent=[log_ridge_list[0], log_ridge_list[-1], 0, 1],
    cmap='viridis'
)

plt.colorbar(im, label='Test RMSE')
plt.xlabel('Ridge Parameter')
plt.yticks([])
plt.title(f'RMSE Heatmap at 15% Noise (k = {k_list[0]})')
plt.xticks(
    log_ridge_list[::2],
    [f"{v:.0e}" for v in ridge_list][::2],
    rotation=45
)
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.savefig("grid_search_rmse_heatmap_15percent_2(95_5_split).png", dpi=300)
plt.show()
